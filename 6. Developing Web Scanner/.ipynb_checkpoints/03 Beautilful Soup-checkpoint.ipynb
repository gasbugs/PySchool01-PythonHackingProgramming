# %% [markdown]
# # 02 Beautilful Soup
#
# ## 1) url 요청하기

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen("http://www.daum.net")
bsObj = BeautifulSoup(html.read(), "html.parser")
print(bsObj.h1)
# Out:
# <h1 class="tit_daum #logosearch">
# <a class="link_daum #logo" href="http://www.daum.net/" rel="home">
# <img alt="Daum" class="img_thumb" height="94" id="daum" src="https://t1.daumcdn.net/daumtop_chanel/op/20170315064553027.png" width="180">
# </img></a>
# </h1>

# %%
bsObj.html
# Out:
# <html class="" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta content="http://www.daum.net/" property="og:url">
# <meta content="website" property="og:type">
# <meta content="Daum" property="og:title">
# <meta content="http://i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" property="og:image">
# <meta content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum" property="og:description">
# <meta content="name=Daum;action-uri=http://www.daum.net/;icon-uri=/favicon.ico" name="msapplication-task">
# <meta content="name=미디어다음;action-uri=http://media.daum.net/;icon-uri=/media_favicon.ico" name="msapplication-task">
# <meta content="name=tv팟;action-uri=http://tvpot.daum.net;icon-uri=/tvpot_favicon.ico" name="msapplication-task">
# <meta content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico" name="msapplication-task">
# <link href="http://search.daum.net/OpenSearch.xml" rel="search" title="다음" type="application/opensearchdescription+xml">
# <style type="text/css">
# @charset "utf-8";
# body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,button{margin:0;padding:0}
# fieldset,img{border:0 none}
# dl,ul,ol,menu,li{list-style:none}
# blockquote, q{quotes: none}
# blockquote:before, blockquote:after,q:before, q:after{content:'';content:none}
# input,select,textarea,button{vertical-align:middle}
# input::-ms-clear{display:none}
# button{border:0 none;background-color:transparent;cursor:pointer}
# body{background:#fff;direction:ltr;-webkit-text-size-adjust:none}
# body,th,td,input,select,textarea,button{font-size:13px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,'Malgun Gothic','맑은 고딕',dotum,'돋움',sans-serif;color:#222;letter-spacing:-1px}
# .os_mac body,.os_mac th,.os_mac td,.os_mac input,.os_mac select,.os_mac textarea,.os_mac button{letter-spacing:0}
# a{color:#222;text-decoration:none}
# a:hover{color:#118eff;text-decoration:underline}
# a:active{background-color:transparent}
# address,caption,cite,code,dfn,em,var{font-style:normal;font-weight:normal}
# .ir_pm{display:block;overflow:hidden;font-size:1px;line-height:0;text-indent:-9999px}
# .ir_wa{display:block;overflow:hidden;position:relative;width:100%;height:100%;z-index:-1}
# .screen_out{overflow:hidden;position:absolute;width:0;height:0;line-height:0;text-indent:-9999px}
# .show{display:block}
# .hide{display:none}
# .d_index{position:relative;width:100%;z-index:101}
# .d_index .shortcut_g{position:absolute;top:-34px;left:0;height:33px;padding:0 20px 0 26px;border-bottom:1px solid #3f4243;font-size:11px;line-height:14px;background-color:#26292a;color:#fff;letter-spacing:-1px;text-align:center}
# .d_index .shortcut_g:active,
# .d_index .shortcut_g:focus{overflow:hidden;top:0;text-decoration:none}
# .d_index .shortcut_g:active,
# .d_index .shortcut_g:hover{color:#fff}
# .d_index .shortcut_g .inner_shortcut{display:inline-block;padding-right:10px;margin-top:11px;background-position:100% -223px;vertical-align:top}
# .ico_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_170405.png) no-repeat 0 0}
# .ico_vert{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_vert.png) no-repeat 0 0}
# .txt_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/txt_pctop_170410.png) no-repeat 0 0;letter-spacing:-1px;white-space:nowrap}
# .bg_pctop{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat 0 0}
# .num_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/num_pctop_170405.png) no-repeat 0 0}
# .img_thumb{display:block;vertical-align:top}
# .frame_g{position:absolute;top:0;left:0;border:1px solid #000;opacity:0.08;filter:alpha(opacity=8)}
# .thumb_g{display:block;position:relative}
# .thumb_g .ico_view{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-40px 0;text-indent:-9999px;cursor:pointer}
# .thumb_g .ico_video{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-70px 0;text-indent:-9999px;cursor:pointer}
# .thumb_g .ico_live{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-130px 0;text-indent:-9999px;cursor:pointer}
# .ico_label{overflow:hidden;position:absolute;top:20px;left:20px;height:26px;padding:0 8px;font-size:14px;line-height:24px;color:#fff;background-color:#1382e9}
# .ico_label2{overflow:hidden;position:absolute;top:0;left:0;height:20px;padding:0 7px;font-size:11px;line-height:17px;color:#fff;background-color:rgba(0,0,0,0.6);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#99000000',endColorstr='#99000000',GradientType=0)}
# .os_mac .ico_label{line-height:27px}
# .os_mac .ico_label2{line-height:21px}
# .color_g1{color:#e30000}
# .color_g2{color:#118eff}
# .tit_tabcont{position:absolute;font-size:16px}
# .wrap_tabcont{display:none}
# #daumWrap{position:relative;min-width:1080px}
# .head_daum{position:relative;z-index:100}
# .cont_main{position:relative;width:990px;margin:25px auto 0}
# .cont_topic{position:relative;z-index:0;width:100%;border-top:1px solid #ececec;background-color:#fbfbfc;background-position:50% 100%;background-repeat:no-repeat}
# .wrap_feature{display:inline-block;height:130px;vertical-align:top}
# .wrap_main{display:inline-block;vertical-align:top}
# .main_tmp{float:left;width:655px;margin-right:35px;padding-bottom:50px}
# .wing_tmp{float:left;width:300px}
# .os_mac .cont_main{transform:translate3d(0px, 0px, 0px)}
# .d_head{border-bottom:1px solid #ececec}
# .d_head .inner_head{position:relative;z-index:1;width:1080px;height:140px;margin:0 auto}
# .tit_daum{overflow:hidden;float:left;width:180px;height:140px;text-align:center}
# .link_daum{overflow:hidden;display:block;margin:23px auto}
# .link_launch{position:absolute;top:6px;left:45px;padding-right:8px;font-size:11px;color:#888;background-position:100% -18px}
# .os_mac .link_launch{top:9px;background-position:100% -21px}
# .wrap_search{float:left;position:relative;margin-top:45px}
# .wrap_search .d_sch{background-color:#fff}
# .head_daum .box_search{position:relative;height:44px;margin:1px 1px 0 0;border:1px solid #0089ff;border-radius:1px}
# .head_daum .box_search .inner_search{position:relative;z-index:1;height:44px;padding:0 60px 0 14px;}
# .head_daum .box_search::before, .head_daum .box_search .inner_search::before, .head_daum .box_search::after{position:absolute;left:0;right:100%;height:1px;content:'';background-color:#0089ff}
# .head_daum .box_search::before{top:-1px}
# .head_daum .box_search::after{bottom:-1px}
# .head_daum .box_search:hover::before, .head_daum .box_search:hover::after{right:0;transition-property:right;transition-duration:0.8s;background:linear-gradient(to right, #86aaff, #70bc4c, #ffbe00, #f46e85)}
# .head_daum .box_search:hover .inner_search::before{top:-1px;bottom:-1px;left:auto;right:-1px;width:1px;height:46px;background-color:#f46e85;transition-property:height;transition-delay:0.8s}
# .head_daum .tf_keyword{float:left;width:440px;margin-top:7px;border:1px solid transparent;font-size:16px;line-height:24px;background-color:transparent;outline:0;ime-mode:active;-webkit-appearance:none}
# .head_daum .btn_search{position:absolute;top:0;right:0;width:49px;height:42px;margin:1px;line-height:44px;background-position:-200px -231px;background-color:transparent}
# .slide_favorsch{overflow:hidden;width:480px;height:28px}
# .list_favorsch{overflow:hidden;padding-top:7px}
# .list_favorsch li{float:left;padding-right:10px}
# .list_favorsch .link_favorsch{display:block;font-size:12px;color:#555}
# .head_daum .page_pctop{z-index:1;right:1px;bottom:3px}
# .head_daum .page_pctop .btn_page{width:16px;height:16px;background-position:-210px 0}
# .head_daum .page_pctop .btn_next{width:15px;background-position:-226px 0}
# .head_bnr{position:absolute;top:28px;right:45px}
# .head_bnr .link_headbnr{display:block}
# .os_mac .head_daum .box_search{margin-top:0}
# .os_mac .head_daum .tf_keyword{margin-top:11px}
# .os_mac .list_favorsch{padding-top:10px}
# .os_mac .list_favorsch li{padding-right:14px}
# .daumSuggestWrap{position:relative;margin-right:90px;clear:both}
# .suggestBox{position:absolute;top:45px;left:0;z-index:9999;width:520px;padding:0;-webkit-box-shadow:0 1px 3px 0 rgba(0,0,0,0.12);box-shadow:0 1px 3px 0 rgba(0,0,0,0.12);background:none}
# .baseBox{border-top:1px solid #dcdcdc;font-size:12px;line-height:17px;font-family:'굴림',gulim,sans-serif;background-color:#fff}
# .os_mac .baseBox{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .list{padding:7px 0 13px;border-left:1px solid #dcdcdc;border-right:1px solid #dcdcdc;color:#333;background-color:#fff}
# .suggestBox.reverseType .list{padding:3px 0 7px;color:#333}
# .suggestBox .baseBox li{overflow:hidden;height:26px;padding:0 16px;line-height:26px;text-align:left;cursor:pointer}
# .suggestBox li .item{display:block;height:100%}
# .suggestBox li .item:hover{text-decoration:none}
# .suggestBox .list .on{background-color:#f6f6f6}
# .suggestBox li strong{font-weight:normal;color:#0089ff}
# .suggestBox .line{overflow:hidden;height:1px;margin:7px 0px 6px;padding:0;font-size:1px;line-height:1px;background-color:#e5e5e5}
# .suggestBox .guide{padding:15px 10px;color:#555}
# .suggestBox .footer{position:relative;height:20px;padding:8px 12px 4px 7px;border:1px solid #dcdcdc;border-top:1px solid #ececec;font-size:11px;background-color:#fbfbfb;letter-spacing:-1px;clear:both}
# .suggestBox.reverseType .footer{border-top-color:#dcdcdc;border-bottom-color:#ededed}
# .suggestBox .footer .fl{float:left}
# .suggestBox .footer .fr{float:right}
# .suggestBox .footer .btn_close{padding-left:12px;background-position:0 -939px}
# .suggestBox .footer .bar{display:none;padding:0 2px;color:#ddd}
# .suggestBox .footer .fl .bar{padding:0 2px 0 1px}
# .suggestBox .footer .offGuide{display:none;position:absolute;right:0;bottom:19px;width:211px;height:27px;background:url(http://search1.daumcdn.net/search/statics/common/pi/suggest_service.gif) no-repeat;text-indent:-999em}
# .suggestBox .footer .offSuggest{display:none}
# .os_mac .suggestBox .list{padding:9px 0 11px}
# .os_mac .suggestBox .baseBox li{padding:0 17px}
# .suggestBox a{color:#777}
# .suggestBox .answer{border-left:1px solid #dcdcdc;border-right:1px solid #dcdcdc}
# .suggestBox .answer span{cursor:pointer}
# .suggestBox .baseBox li a{font-size:14px;color:#333;font-family:'돋움',dotum,sans-serif;text-decoration:none}
# .os_mac .suggestBox .baseBox li a{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .line{display:block;overflow:hidden;clear:both}
# .suggestBox .b_line{border-bottom:1px solid #ededed}
# .suggestBox .suggest_exact{display:block;overflow:hidden;height:40px;padding:12px 0 11px 18px}
# .suggestBox .suggest_exact:hover{text-decoration:none}
# .suggestBox .e_on{background-color:#f8f8f8;text-decoration:none}
# .suggestBox .suggest_exact .txt_exact{overflow:hidden;float:left;height:44px;margin-top:0;background-position:0 0}
# .suggestBox .suggest_exact .ico_w01{padding-left:42px;background-position:0 1px}
# .suggestBox .suggest_exact .ico_w02{padding-left:47px;background-position:0 -49px}
# .suggestBox .suggest_exact .ico_w03{padding-left:47px;background-position:0 -98px}
# .suggestBox .suggest_exact .ico_w04{padding-left:41px;background-position:0 -142px}
# .suggestBox .suggest_exact .ico_w05{padding-left:50px;background-position:0 -199px}
# .suggestBox .suggest_exact .ico_w06{padding-left:53px;background-position:0 -246px}
# .suggestBox .suggest_exact .ico_w07{padding-left:41px;background-position:0 -297px}
# .suggestBox .suggest_exact .ico_w08{padding-left:47px;background-position:0 -347px}
# .suggestBox .suggest_exact .ico_w09{padding-left:39px;background-position:0 -396px}
# .suggestBox .suggest_exact .ico_w10{padding-left:39px;background-position:0 -450px}
# .suggestBox .suggest_exact .ico_w11{padding-left:48px;background-position:0 -600px}
# .suggestBox .suggest_exact .ico_w12{padding-left:41px;background-position:0 -546px}
# .suggestBox .suggest_exact .ico_w13{padding-left:48px;background-position:0 -600px}
# .suggestBox .suggest_exact .ico_w14{padding-left:45px;background-position:0 -650px}
# .suggestBox .suggest_exact .ico_w15{padding-left:41px;background-position:0 -699px}
# .suggestBox .suggest_exact .ico_w16{padding-left:46px;background-position:0 -750px}
# .suggestBox .suggest_exact .ico_w17{padding-left:41px;background-position:0 -797px}
# .suggestBox .suggest_exact .ico_w18{padding-left:44px;background-position:0 -844px}
# .suggestBox .suggest_exact .txt_unit{font-size:14px;font-family:arial,sans-serif}
# .suggestBox .suggest_exact .tit{margin-left:-1px;font-weight:normal;font-size:12px;line-height:18px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .cont{display:block}
# .suggestBox .suggest_exact .txt_cont{margin-right:4px;font-weight:bold;font-size:14px;line-height:16px;font-family:'돋움',dotum,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num1{font-size:18px;line-height:20px;font-family:tahoma,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num2{margin-left:3px;font-size:12px;line-height:14px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num3{font-size:20px;line-height:23px;font-family:arial,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num4{margin-left:-3px;font-size:12px;line-height:14px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_exact .ico_suggest2{background:url(http://search1.daumcdn.net/search/statics/common/pi/ico/ico_suggest_20110721.gif) no-repeat 0 0}
# .suggestBox .suggest_exact .txt_exact .ico_celsius{background:none}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_up{padding-left:11px;background-position:0 -58px}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_down{padding-left:11px;background-position:0 -98px}
# .suggestBox .suggest_exact .ico_arrow_equal{padding-left:14px;background-position:1px -77px}
# .suggestBox .suggest_exact .txt_blue{color:#007aff}
# .suggestBox .suggest_exact .txt_blue2{color:#007aff}
# .suggestBox .suggest_exact .txt_red{color:#e52d38}
# .suggestBox .suggest_exact .txt_red2{color:#e52d38}
# .suggestBox .suggest_exact .txt_time{float:right;margin:25px 16px 0 0;font-size:11px;font-family:'돋움',dotum,sans-serif;color:#a1a1a1}
# .suggestBox .suggest_exact .ico_celsius{width:12px;height:13px;font-family:arial,sans-serif;background-position:right 5px}
# .suggestBox .suggest_exact .bar{font-size:14px;color:#dedede}
# .suggestBox .wrap_today{overflow:hidden;height:21px;padding:4px 10px 2px 9px;line-height:21px}
# .suggestBox .wrap_today .cont{font-size:14px;color:#333;text-decoration:none}
# .suggestBox .wrap_today .cont_import{font-weight:normal;color:#ea570a}
# .os_mac .suggestBox .suggest_exact .tit{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_num2{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_num4{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_time{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .ico_lotto{float:left;width:28px;height:28px;margin:6px 5px 0 0;border-radius:20px;text-align:center}
# .suggestBox .ico_lotto .txt_num{display:inline-block;margin-top:7px;font-size:14px;line-height:1;font-family:arial,sans-serif;color:#fff;vertical-align:top}
# .suggestBox .num1{background-color:#f6a800}
# .suggestBox .num10{background-color:#4155cb}
# .suggestBox .num20{background-color:#f64d61}
# .suggestBox .num30{background-color:#585d6e}
# .suggestBox .num40{background-color:#f6a800}
# .suggestBox .plus{width:8px;height:8px;margin:16px 8px 0 4px;background:url(http://search1.daumcdn.net/search/statics/common/pi/ico/ico_suggest_20110721.gif) no-repeat 0 -40px;text-indent:-9999px;opacity:0.5}
# .suggestBox .weather_comp{font-size:12px;line-height:17px;color:#555}
# .suggestBox .weather_comp .ico_suggest{padding-left:59px;background:url(http://search1.daumcdn.net/search/statics/common/pi/ico_weather_m_160616.gif) no-repeat}
# .suggestBox .weather_comp .txt_exact{overflow:hidden;float:left;height:44px;margin-top:0}
# .suggestBox .weather_comp .ico_w00{background-position:0 -1620px}
# .suggestBox .weather_comp .ico_w01{background-position:0 0}
# .suggestBox .weather_comp .night .ico_w01{background-position:0 -60px}
# .suggestBox .weather_comp .ico_w02{background-position:0 -120px}
# .suggestBox .weather_comp .night .ico_w02{background-position:0 -180px}
# .suggestBox .weather_comp .ico_w03{background-position:0 -240px}
# .suggestBox .weather_comp .night .ico_w03{background-position:0 -300px}
# .suggestBox .weather_comp .ico_w04{background-position:0 -360px}
# .suggestBox .weather_comp .ico_w05{background-position:0 -420px}
# .suggestBox .weather_comp .night .ico_w05{background-position:0 -480px}
# .suggestBox .weather_comp .ico_w06{background-position:0 -540px}
# .suggestBox .weather_comp .night .ico_w06{background-position:0 -600px}
# .suggestBox .weather_comp .ico_w07{background-position:0 -660px}
# .suggestBox .weather_comp .ico_w08{background-position:0 -720px}
# .suggestBox .weather_comp .ico_w09{background-position:0 -780px}
# .suggestBox .weather_comp .ico_w10{background-position:0 -840px}
# .suggestBox .weather_comp .night .ico_w10{background-position:0 -900px}
# .suggestBox .weather_comp .ico_w11{background-position:0 -960px}
# .suggestBox .weather_comp .ico_w12{background-position:0 -1020px}
# .suggestBox .weather_comp .ico_w13{background-position:0 -1080px}
# .suggestBox .weather_comp .night .ico_w13{background-position:0 -1140px}
# .suggestBox .weather_comp .ico_w14{background-position:0 -1200px}
# .suggestBox .weather_comp .ico_w15{background-position:0 -1260px}
# .suggestBox .weather_comp .ico_w16{background-position:0 -1320px}
# .suggestBox .weather_comp .night .ico_w16{background-position:0 -1380px}
# .suggestBox .weather_comp .ico_w17{background-position:0 -1440px}
# .suggestBox .weather_comp .ico_w18{background-position:0 -1500px}
# .suggestBox .weather_comp .ico_w19{background-position:0 -1560px}
# .d_service{border-bottom:1px solid #888}
# .d_service .inner_service{position:relative;width:990px;height:50px;margin:0 auto}
# .menu_service{float:left;position:relative;width:570px}
# .menu_service .link_more{overflow:hidden;float:left;width:60px;height:20px;padding:15px 0;line-height:20px;background-position:-469px -350px;background-color:transparent;text-align:center}
# .menu_on .link_more{background-position:-530px -350px}
# .list_mainsvc{float:left}
# .list_mainsvc li{float:left;height:50px}
# .list_mainsvc .txt_pctop{display:block;height:20px;padding:15px 0;font-weight:bold;font-size:13px;line-height:20px;background-color:transparent;text-align:center}
# .list_mainsvc .link_cafe{width:28px;background-position:0 -350px}
# .list_mainsvc .link_mail{width:35px;background-position:-28px -350px}
# .list_mainsvc .link_news{width:35px;background-position:-63px -350px}
# .list_mainsvc .link_map{width:34px;background-position:-98px -350px}
# .list_mainsvc .link_stock{width:35px;background-position:-132px -350px}
# .list_mainsvc .link_shopping{width:34px;background-position:-167px -350px}
# .list_mainsvc .link_kakaotv{width:63px;background-position:-201px -350px}
# .list_mainsvc .link_webtoon{width:33px;background-position:-264px -350px}
# .list_mainsvc .link_brunch{width:46px;background-position:-297px -350px}
# .list_mainsvc .link_dic{width:35px;background-position:-343px -350px}
# .list_mainsvc .link_game{width:34px;background-position:-378px -350px}
# .list_mainsvc .link_together{width:57px;background-position:-412px -350px}
# .service_layer{display:none;position:absolute;top:50px;left:0;width:653px;border:1px solid #888;background-color:#fff}
# .menu_on .service_layer{display:block}
# .service_layer .layer_body{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_line.gif) repeat-y 0 0}
# .service_layer .sort_service{float:left;width:94px;padding:0 0 15px 15px}
# .service_layer .sort_service.fst{padding-left:14px}
# .service_layer .sort_service dt{margin:11px 0 4px;font-weight:bold;font-size:12px}
# .service_layer .sort_service dt.tit_split{float:left;margin-top:22px;padding-right:9px;background-position:100% 5px}
# .service_layer .sort_service dd{clear:both;font-size:12px;line-height:22px}
# .service_layer .sort_service .link_svc{color:#555}
# .service_layer .sort_service .link_svc:hover{color:#118eff}
# .service_layer .sort_service .ico_new{display:inline-block;width:11px;height:11px;margin:3px 0 0 2px;font-size:0;line-height:0;background-position:-160px -80px;vertical-align:top;text-indent:-9999px}
# .service_layer .layer_foot{overflow:hidden;height:32px;border-top:1px solid #ececec;background-color:#fbfbfb}
# .service_layer .layer_foot .link_total{float:left;padding-right:8px;margin-left:13px;font-size:11px;line-height:29px;color:#555;background-position:100% -12px}
# .service_layer .layer_foot .btn_close{float:right;padding:0 13px;margin:2px;font-size:11px;line-height:24px;color:#888}
# .os_mac .service_layer .sort_service{padding-bottom:12px}
# .os_mac .service_layer .sort_service dt{margin:14px 0 4px}
# .os_mac .service_layer .sort_service dt.tit_split{background-position:100% 3px}
# .os_mac .service_layer .layer_foot .link_total{padding-right:10px;margin-left:14px;line-height:32px;background-position:100% -12px}
# .os_mac .service_layer .layer_foot .btn_close{padding:0 12px;line-height:28px}
# .foot_daum{border-top:1px solid #888}
# .foot_daum .inner_foot{overflow:hidden;position:relative;width:990px;margin:0 auto;padding:37px 0 78px}
# .foot_daum .link_logo{float:left}
# .foot_daum .info_notice{overflow:hidden;padding:0 250px 0 30px}
# .foot_daum .tit_notice{float:left;font-size:13px}
# .foot_daum .link_notice{display:block;padding-right:9px;background-position:100% -169px}
# .foot_daum .link_notice:hover{color:#222}
# .foot_daum .list_notice{overflow:hidden;width:542px;height:19px;padding-left:9px}
# .foot_daum .list_notice .link_info{display:block;overflow:hidden;text-overflow:ellipsis;white-space:nowrap}
# .foot_daum .list_notice .link_info:hover{color:#222}
# .foot_daum .search_foot{position:absolute;top:32px;right:0}
# .foot_daum .box_search{position:relative;z-index:1;width:209px;height:28px;border:1px solid #c8c8c8}
# .foot_daum .search_on{border-color:#0089ff}
# .foot_daum .tf_keyword{float:left;width:164px;margin:5px 0 0 9px;border:1px solid transparent;line-height:19px;outline:0}
# .foot_daum .btn_search{float:right;width:32px;height:28px;line-height:28px;background-position:-160px -230px;background-color:transparent}
# .foot_daum .link_svcall{position:absolute;top:81px;right:0;padding-right:10px;font-weight:bold;color:#888;background-position:100% -194px}
# .foot_daum .info_policy{padding:23px 250px 0 0}
# .foot_daum .info_policy .link_policy{font-size:12px;color:#888}
# .foot_daum .info_policy .txt_dot{padding:0 2px;font-size:12px;color:#888}
# .foot_daum .txt_copyright{display:block;padding-top:6px;font-size:11px;color:#888}
# .foot_daum .txt_copyright .link_kakao{color:#888}
# .os_mac .foot_daum .info_notice{padding:3px 250px 0 31px}
# .os_mac .foot_daum .link_notice{padding-right:12px;background-position-y:-172px}
# .os_mac .foot_daum .tf_keyword{margin-top:4px}
# .os_mac .foot_daum .link_svcall{top:83px;background-position-y:-196px}
# .os_mac .foot_daum .info_policy{padding-top:24px}
# .os_mac .foot_daum .txt_copyright{padding-top:5px}
# .today_base{float:right;position:relative;height:50px}
# .today_base .comp_base{display:inline-block;vertical-align:top}
# .today_base .img_weather{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/img_weather.png);background-repeat:no-repeat;font-size:0;line-height:0;text-indent:-9999px}
# .info_today{float:left}
# .info_today .date_today{float:left;height:24px;padding:13px 0;font-size:12px;line-height:19px;letter-spacing:0}
# .info_today .txt_part{float:left;font-weight:bold;font-size:12px;line-height:24px}
# .info_today .link_weather{float:left;height:24px;margin-left:20px;padding:11px 0;line-height:23px;text-align:right}
# .info_today .link_weather:hover{color:#222;text-decoration:none}
# .info_today .link_weather .txt_temper{float:left;font-family:tahoma,arial,sans-serif;letter-spacing:0}
# .os_mac .info_today .date_today{line-height:25px}
# .os_mac .info_today .txt_part{line-height:29px}
# .os_mac .info_today .link_weather{height:28px;line-height:27px}
# .os_mac .info_today .link_weather .txt_temper{font-family:helvetica,arial,sans-serif}
# .info_today .img_weather{float:left;width:26px;height:26px;margin:1px 0 0 2px;vertical-align:top}
# .os_mac .info_today .img_weather{margin-left:4px}
# .info_today .ico_wm01{background-position:0 -240px}
# .info_today .night .ico_wm01{background-position:-30px -240px}
# .info_today .ico_wm02{background-position:-60px -240px}
# .info_today .night .ico_wm02{background-position:-90px -240px}
# .info_today .ico_wm03{background-position:0 -270px}
# .info_today .night .ico_wm03{background-position:-30px -270px}
# .info_today .ico_wm04{background-position:-60px -270px}
# .info_today .ico_wm07{background-position:-90px -270px}
# .info_today .ico_wm09{background-position:0 -300px}
# .info_today .ico_wm10{background-position:-30px -300px}
# .info_today .night .ico_wm10{background-position:-60px -300px}
# .info_today .ico_wm11{background-position:-90px -300px}
# .info_today .ico_wm14{background-position:0 -330px}
# .info_today .ico_wm17{background-position:-30px -330px}
# .info_today .ico_wm18{background-position:-60px -330px}
# .info_today .ico_wm19{background-position:-90px -330px}
# .info_today .ico_degree{float:left;width:17px;height:15px;margin:5px 0 0;font-size:12px;line-height:17px;background-position:-210px -270px;background-color:transparent;text-align:center;text-indent:0}
# .os_mac .info_today .ico_degree{margin:6px 0 0}
# .info_today .link_stock{float:left;height:28px;margin-left:14px;padding:11px 0;line-height:23px;text-align:right}
# .info_today .link_stock:hover{color:#222;text-decoration:none}
# .info_today .num_stock{float:left;padding:0 3px;font-weight:normal;font-family:tahoma,arial,sans-serif}
# .info_today .num_status{font-size:11px;line-height:25px;letter-spacing:0}
# .info_today .num_status .ico_arrow{display:inline-block;width:9px;height:10px;margin:8px 3px 0 0;font-size:10px;line-height:11px;background-color:transparent;vertical-align:top}
# .info_today .stock_up .num_status{color:#e30000}
# .info_today .stock_down .num_status{color:#118eff}
# .info_today .stock_up .num_status .ico_arrow{background-position:-120px -150px}
# .info_today .stock_down .num_status .ico_arrow{background-position:-130px -150px}
# .info_today .stock_stay .num_status .ico_arrow{background-position:-140px -150px}
# .os_mac .info_today .link_stock{margin-left:17px;line-height:25px}
# .os_mac .info_today .num_stock{padding-top:1px;font-family:helvetica,arial,sans-serif}
# .os_mac .info_today .num_status{line-height:27px}
# .os_mac .info_today .num_status .ico_arrow{margin:9px 4px 0 0}
# .today_layer{position:absolute;top:50px;right:0;width:298px;border:1px solid #888;background-color:#fff}
# .today_layer .layer_body{overflow:hidden}
# .today_layer .weather_part{float:left;position:relative;width:148px;height:126px;border-right:1px solid #ececec}
# .today_layer .btn_locate{position:absolute;top:12px;right:10px;width:19px;height:19px;font-size:0;line-height:0;background-position: -190px -240px;text-indent:-9999px}
# .today_layer .btn_locate.on{background-position:-190px -260px}
# .today_layer .link_weather{display:block;overflow:hidden;height:126px}
# .today_layer .link_weather:hover{color:#222;text-decoration:none}
# .today_layer .txt_place{display:block;margin:11px 0 0 14px;font-weight:bold;font-size:12px;line-height:18px}
# .today_layer .txt_place .txt_local{display:block}
# .today_layer .link_weather .img_weather{float:left;margin:7px 0 0 15px;width:56px;height:56px;vertical-align:top}
# .today_layer .ico_wm01{background-position:0 0}
# .today_layer .night .ico_wm01{background-position:-60px 0}
# .today_layer .ico_wm02{background-position:-120px 0}
# .today_layer .night .ico_wm02{background-position:-180px 0}
# .today_layer .ico_wm03{background-position:0 -60px}
# .today_layer .night .ico_wm03{background-position:-60px -60px}
# .today_layer .ico_wm04{background-position:-120px -60px}
# .today_layer .ico_wm07{background-position:-180px -60px}
# .today_layer .ico_wm09{background-position:0 -120px}
# .today_layer .ico_wm10{background-position:-60px -120px}
# .today_layer .night .ico_wm10{background-position:-120px -120px}
# .today_layer .ico_wm11{background-position:-180px -120px}
# .today_layer .ico_wm14{background-position:0 -180px}
# .today_layer .ico_wm17{background-position:-60px -180px}
# .today_layer .ico_wm18{background-position:-120px -180px}
# .today_layer .ico_wm19{background-position:-180px -180px}
# .today_layer .info_temper{float:left;margin:24px 0 0 4px;font-family:tahoma,arial,sans-serif}
# .today_layer .info_temper .img_weather{float:left;width:14px;height:20px;margin:0}
# .today_layer .info_temper .num0{background-position:-240px 0}
# .today_layer .info_temper .num1{background-position:-240px -30px}
# .today_layer .info_temper .num2{background-position:-240px -60px}
# .today_layer .info_temper .num3{background-position:-240px -90px}
# .today_layer .info_temper .num4{background-position:-240px -120px}
# .today_layer .info_temper .num5{background-position:-240px -150px}
# .today_layer .info_temper .num6{background-position:-240px -180px}
# .today_layer .info_temper .num7{background-position:-240px -210px}
# .today_layer .info_temper .num8{background-position:-240px -240px}
# .today_layer .info_temper .num9{background-position:-240px -270px}
# .today_layer .info_temper .ico_minus{width:8px;height:20px;margin-top:1px;background-position:-240px -300px}
# .today_layer .info_temper .ico_degree{width:23px;height:20px;background-position:-210px -240px}
# .os_mac .today_layer .txt_place{margin-top:14px}
# .today_layer .stock_part{float:left;width:148px;height:126px}
# .today_layer .link_stock{display:block;overflow:hidden;height:43px;padding:13px 14px 0;line-height:26px}
# .today_layer .link_stock:hover{color:#222;text-decoration:none}
# .today_layer .link_stock + .link_stock{height:57px}
# .today_layer .tit_stock{display:block;margin-bottom:1px;font-weight:bold;font-size:12px;line-height:16px}
# .today_layer .num_stock{font-weight:normal;font-size:16px;font-family:tahoma,arial,sans-serif;letter-spacing:-0.03em}
# .today_layer .num_status{padding-left:3px;font-size:12px;letter-spacing:0}
# .today_layer .num_status .ico_arrow{display:inline-block;width:9px;height:10px;margin:10px 3px 0 0;font-size:0;line-height:0;text-indent:-9999px;vertical-align:top}
# .today_layer .stock_up .num_status{color:#e30000}
# .today_layer .stock_down .num_status{color:#118eff}
# .today_layer .stock_up .num_status .ico_arrow{background-position:-120px -150px}
# .today_layer .stock_down .num_status .ico_arrow{background-position:-130px -150px}
# .today_layer .stock_stay .num_status .ico_arrow{background-position:-140px -150px}
# .today_layer .layer_foot{overflow:hidden;padding-right:14px;height:32px;border-top:1px solid #ececec;background-color:#fbfbfb;text-align:right}
# .today_layer .layer_foot .link_today{display:inline-block;height:32px;padding-right:8px;margin-left:8px;font-size:11px;line-height:29px;color:#888;background-position:100% -12px}
# .os_mac .today_layer .link_stock{padding-top:14px}
# .os_mac .today_layer .num_stock{font-family:helvetica,arial,sans-serif}
# .os_mac .today_layer .num_status .ico_arrow{margin:9px 4px 0 0}
# .os_mac .today_layer .layer_foot .link_today{padding-right:7px;margin-left:7px;line-height:31px;background-position:100% -13px}
# .advert_tmp{float:left;position:relative;width:655px;height:120px;margin-right:35px}
# .advert_tmp .bg_line{position:absolute;top:0;left:0;z-index:-1;width:653px;height:118px;border:1px solid #ececec}
# .advert_station{display:inline-block;position:relative;width:300px;height:150px;margin-top:20px;font-size:0;line-height:0;vertical-align:top}
# .advert_station .bg_line{position:absolute;top:0;left:0;z-index:-1;width:298px;height:148px;border:1px solid #ececec}
# .box_shopping{display:inline-block;position:relative;width:300px;height:1193px;margin-top:20px;vertical-align:top}
# .box_shopping .bg_line1{position:absolute;top:0;left:0;z-index:-1;width:298px;height:781px;border:1px solid #ececec}
# .box_shopping .bg_line2{position:absolute;top:802px;left:0;z-index:-1;width:298px;height:389px;border:1px solid #ececec}
# .advert_svcbnr{margin-top:20px}
# .advert_svcbnr .link_bnr{display:block;position:relative;height:60px}
# .advert_svcbnr .frame_g{width:298px;height:58px}
# .advert_bnr{margin-top:20px}
# .advert_bnr .link_bnr{display:block;position:relative;height:272px}
# .advert_bnr .frame_g{width:298px;height:270px}
# .wrap_tiercont{position:relative;z-index:99;width:990px;margin:0 auto}
# .login_tmp{position:absolute;top:0;right:0;z-index:0;width:300px;height:120px;letter-spacing:-1px}
# .login_my{z-index:10;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat 0 0}
# .login_my .wrap_my{width:285px;height:45px;padding:15px 0 17px 15px}
# .login_my .info_my{float:left;padding:1px 0 0 10px}
# .login_my .rel_my{float:right;padding-right:15px}
# .login_my .name_user{float:left;margin-right:4px;font-weight:bold}
# .login_my .link_myinfo{float:left;font-size:11px;margin:2px 2px 0 0;line-height:14px;color:#555;text-decoration:underline}
# .login_my .profile_img{float:left;position:relative;width:45px;height:45px;margin-top:1px;background-position:-310px -150px}
# .login_my .profile_img .bg_frame{position:absolute;left:0;top:0;width:45px;height:45px;background-position:-360px -150px}
# .login_my .link_privacy{float:left;width:13px;height:15px;margin-top:3px;background-position:-160px -40px;text-indent:-9999px}
# .login_my .link_empathy{float:left;margin:5px 8px 0 0;font-size:11px;line-height:14px;color:#5b6473}
# .login_my .btn_logout{float:left;width:56px;height:24px;font-size:11px;line-height:24px;background-position:-180px -30px;background-color:transparent}
# .login_my .list_basis{overflow:hidden;position:absolute;left:70px;top:42px;height:31px;letter-spacing:-0.12em}
# .login_my .list_basis li{float:left;padding-right:8px;line-height:15px}
# .login_my .list_basis .link_basis{float:left;font-size:12px;color:#555}
# .login_my .list_basis .num_basis{margin-left:3px;color:#118eff}
# .login_my .list_basis .num_msg{width:30px}
# .login_my .list_basis .link_num{font-weight:bold;color:#118eff}
# .login_my .my_mileage .link_basis{margin-right:8px}
# .login_my .wrap_mysvc{position:relative;z-index:10;width:300px}
# .mysvc_list{position:relative;width:300px;height:43px}
# .list_mysvc{display:inline-block;position:relative;width:300px;height:43px;vertical-align:top;letter-spacing:-1px}
# .list_mysvc li{position:relative;float:left;width:100px;height:43px}
# .list_mysvc .link_mysvc{display:block;overflow:hidden;height:31px;padding-top:12px;font-size:12px;line-height:18px;text-align:center;color:#555}
# .list_mysvc .link_mysvc:hover{text-decoration:none}
# .list_mysvc .cafe_g .link_mysvc{height:30px;padding-top:13px;line-height:16px}
# .list_mysvc .txt_mysvc{display:inline-block;height:26px;color:#555;vertical-align:top}
# .list_mysvc .cafe_g .txt_mysvc{padding-left:24px;background-position:0 -80px}
# .list_mysvc .stock_g .txt_mysvc{padding-left:27px;background-position:0 -109px}
# .list_mysvc .blog_g .txt_mysvc{padding-left:29px;background-position:0 -139px}
# .list_mysvc .ico_new{display:none;width:11px;height:11px;margin:5px 0 0 4px;background-position:-160px -80px;text-indent:-9999px;vertical-align:top}
# .list_mysvc .new_g .ico_new{display:inline-block}
# .list_mysvc .cafe_g .ico_new{margin-top:4px}
# .mycafe_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px 0}
# .mystock_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px -50px}
# .myblog_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px -100px}
# .layer_mycont{position:absolute;top:120px;left:0;width:300px;height:353px;background-position:0 -130px}
# .layer_mycont .btn_close{position:absolute;top:320px;right:0;width:46px;height:32px;padding:3px 0 4px;font-size:11px;line-height:18px;color:#888}
# .os_mac .login_tmp{letter-spacing:0}
# .os_mac .login_my .info_my{padding-top:4px}
# .os_mac .login_my .name_user{margin-right:6px}
# .os_mac .login_my .link_privacy{margin-top:0}
# .os_mac .login_my .list_basis{top:45px;letter-spacing:0}
# .os_mac .list_basis li{padding-right:9px}
# .os_mac .list_mysvc .link_mysvc{line-height:21px}
# .os_mac .cafe_g .link_mysvc{line-height:20px}
# .os_mac .list_mysvc .ico_new{margin-top:4px}
# .os_mac .cafe_g .ico_new{margin-top:3px}
# .os_mac .layer_mycont .btn_close{padding-top:5px}
# .tag_live{width:30px;height:15px;background-position:-120px -70px}
# .tag_new{width:31px;height:15px;background-position:-120px -90px}
# .tag_event{width:40px;height:15px;background-position:-120px -110px}
# .tag_issue{width:37px;height:15px;background-position:-120px -130px}
# .list_thumb{overflow:hidden}
# .list_thumb li{float:left;width:152px;height:160px;margin-left:16px}
# .list_thumb .fst{margin-left:0}
# .list_thumb .lst{margin-left:15px}
# .list_thumb .link_item{display:block}
# .list_thumb .thumb_g{width:152px;height:100px}
# .list_thumb .frame_g{width:150px;height:98px}
# .list_thumb .cont_item{margin:6px 2px 0}
# .list_thumb .tit_item{display:block;overflow:hidden;max-height:36px;font-weight:normal;line-height:18px;word-break:keep-all;word-wrap:break-word}
# .list_txt{float:left}
# .list_txt li{overflow:hidden;height:20px;padding-top:3px;white-space:nowrap;text-overflow:ellipsis}
# .list_txt .split_txt{padding-left:10px;margin-left:10px;color:#888;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_vert.png) 0 -50px}
# .list_txt .split_txt:hover{color:#118eff}
# .list_txt .part_mid{padding-top:13px;line-height:16px}
# .list_txt .part_mid .split_part{display:inline-block;overflow:hidden;vertical-align:top}
# .list_txt .part_mid .ico_pctop{display:inline-block;margin:3px 4px 0 0;text-indent:-9999px;vertical-align:top}
# .list_txt .part_mid .link_txt{margin-right:3px}
# .os_mac .list_thumb .cont_item{margin-top:7px}
# .os_mac .list_txt li{line-height:20px}
# .os_mac .list_txt .part_mid{line-height:22px}
# .os_mac .list_txt .part_mid .split_part{letter-spacing:-0.03em}
# .os_mac .list_txt .part_mid .link_txt{margin-right:7px}
# .news_prime .list_txt li{width:318px;padding-left:2px}
# .group_news{display:inline-block;height:320px;vertical-align:top}
# .box_issue{float:left;position:relative;width:320px;height:290px;margin-right:15px}
# .box_issue .link_issue{display:block;position:relative;height:290px}
# .box_issue .frame_g{width:318px;height:288px}
# .box_issue .cover_g{position:absolute;left:0;bottom:0;width:320px;height:128px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate1.png) 0 100%}
# .box_issue .cont_item{overflow:hidden;position:absolute;left:0;width:320px}
# .box_issue .link_issue .cont_item{bottom:20px}
# .box_issue .link_issue .tit_item{display:block;overflow:hidden;max-height:44px;padding:0 21px;font-weight:normal;font-size:16px;line-height:22px;color:#fff}
# .special_issue .tit_issue{overflow:hidden;position:absolute;top:25px;left:21px;max-height:60px;padding-right:20px;font-size:22px;color:#fff}
# .special_issue .cont_item{bottom:22px}
# .special_issue .list_item li{overflow:hidden;margin:3px 20px 0;font-size:13px}
# .special_issue .list_item li.fst{font-weight:bold;font-size:16px;line-height:26px}
# .special_issue .list_item .link_item{display:block;overflow:hidden;color:#fff;white-space:nowrap;text-overflow:ellipsis}
# .os_mac .box_issue .link_issue .cont_item{bottom:16px}
# .os_mac .special_issue .cont_item{bottom:19px}
# .box_sector{float:left;width:320px;margin-right:15px}
# .link_sector{display:block;position:relative;width:320px;height:136px;margin-bottom:24px}
# .link_sector .frame_g{width:318px;height:134px}
# .link_sector .ico_label{height:22px;font-size:11px;line-height:19px}
# .link_sector .cont_item{position:absolute;left:0;bottom:0;width:320px;height:100px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate2.png) no-repeat 0 100%}
# .link_sector .tit_item{overflow:hidden;position:absolute;left:0;bottom:18px;right:0;padding:0 21px;font-weight:normal;font-size:13px;color:#fff;white-space:nowrap;text-overflow:ellipsis}
# .os_mac .link_sector .ico_label{line-height:23px}
# .os_mac .link_sector .tit_item{bottom:16px}
# .section_media{position:relative}
# .media_bloc{position:relative;width:655px;height:522px;padding-top:58px}
# .media_bloc .wrap_tabcont{width:655px;height:522px}
# .media_bloc .news_prime{width:655px;height:480px}
# .media_bloc .tit_tabcont{top:11px;left:0}
# .media_bloc .tit_news{left:-10px}
# .media_bloc .tit_entertain{left:70px}
# .media_bloc .tit_sports{left:120px}
# .media_bloc .tit_movie{left:180px}
# .media_bloc .tit_auto{left:227px}
# .media_bloc .tit_realestate{left:287px}
# .media_bloc .tit_tabcont .link_tit{display:block;height:36px;line-height:36px;background-color:transparent;text-align:center}
# .media_bloc .tit_news .link_tit{width:43px;background-position:0 0}
# .media_bloc .tit_entertain .link_tit{width:50px;background-position:-50px 0}
# .media_bloc .tit_sports .link_tit{width:60px;background-position:-100px 0}
# .media_bloc .tit_movie .link_tit{width:47px;background-position:-160px 0}
# .media_bloc .tit_auto .link_tit{width:60px;background-position:-207px 0}
# .media_bloc .tit_realestate .link_tit{width:60px;background-position:-267px 0}
# .news_on .tit_news .link_tit{background-position:0 -40px}
# .entertain_on .tit_entertain .link_tit{background-position:-50px -40px}
# .sports_on .tit_sports .link_tit{background-position:-100px -40px}
# .movie_on .tit_movie .link_tit{background-position:-160px -40px}
# .auto_on .tit_auto .link_tit{background-position:-207px -40px}
# .realestate_on .tit_realestate .link_tit{background-position:-267px -40px}
# .news_on .wrap_news, .entertain_on .wrap_entertain, .sports_on .wrap_sports, .movie_on .wrap_movie, .auto_on .wrap_auto, .realestate_on .wrap_realestate{display:block}
# .news_flow{overflow:hidden;position:relative;width:655px;height:40px;border-top:1px solid #ececec;border-bottom:1px solid #ececec;line-height:35px}
# .unit_home{float:left}
# .unit_home .tit_home{float:left;margin-right:12px}
# .unit_home .tit_home .link_home{padding-right:7px;background-position:100% 6px}
# .unit_home .list_home{float:left}
# .unit_home .list_home li{float:left;padding:0 7px}
# .unit_home .list_home .link_home{color:#555}
# .unit_home .link_home:hover{color:#118eff}
# .unit_live{float:left;padding-left:25px}
# .unit_live .ico_pctop{float:left;margin:12px 6px 0 0;text-indent:-9999px}
# .unit_live .link_live{margin-right:5px;color:#555}
# .unit_live .link_live:hover{color:#118eff}
# .news_flow .link_hash{padding:0 7px;color:#118eff}
# .page_pctop{position:absolute;right:0;bottom:11px}
# .page_pctop .info_page{float:left;padding:1px 8px 0 0;line-height:16px;color:#888;font-family:tahoma,arial,sans-serif}
# .page_pctop .info_page .num_index{font-weight:normal;color:#555}
# .page_pctop .info_page .txt_slash{padding:0 2px}
# .page_pctop .btn_page{float:left;width:20px;height:20px;line-height:20px;background-color:transparent;background-position:-160px 0}
# .page_pctop .btn_next{width:19px;background-position:-180px 0}
# .page_tabcont{position:absolute;z-index:1;top:23px;left:34px}
# .page_tabcont .btn_page{overflow:hidden;float:left;width:10px;height:10px;margin:0 1px;font-size:10px;line-height:12px;background-position:-100px -170px;background-color:transparent}
# .page_tabcont .on{position:relative;background-position:-100px -180px}
# .os_mac .news_flow{line-height:40px}
# .os_mac .unit_home .tit_home{margin-right:16px}
# .os_mac .unit_home .tit_home .link_home{padding-right:9px;background-position:100% 3px}
# .os_mac .page_pctop .info_page{line-height:19px;font-family:helvetica,arial,sans-serif}
# .ranking_news{overflow:hidden;padding-top:23px}
# .ranking_news.fst{padding-top:35px;border-top:1px solid #ececec}
# .ranking_news .box_ranking{float:left;width:320px}
# .ranking_news .box_ranking.fst{margin-right:15px}
# .ranking_news .tit_ranking{height:21px;font-size:14px;line-height:21px;color:#118eff}
# .ranking_news .tit_ranking .ico_pctop{display:inline-block;font-size:0;line-height:0;text-indent:-9999px;vertical-align:top}
# .ranking_news .tit_ranking .ico_chat{width:15px;height:12px;margin:5px 0 0 4px;background-position:-170px -140px}
# .ranking_news .tit_ranking .ico_share{width:14px;height:12px;margin:6px 0 0 4px;background-position:-170px -160px}
# .tab_ranking{overflow:hidden;margin:10px 0 2px}
# .tab_ranking li{float:left;margin-right:6px}
# .tab_ranking .link_tit{display:block;overflow:hidden;padding-left:10px;height:26px;font-size:12px;line-height:24px;color:#888;background-position:-510px -150px;background-color:#fff;text-align:center;cursor:pointer;white-space:nowrap}
# .tab_ranking .link_tit .inner_tit{display:inline-block;height:26px;padding-right:10px;background-position:100% -150px;background-color:#fff;vertical-align:top}
# .tab_ranking .on .link_tit{font-weight:bold;color:#222;background-position:-510px -180px}
# .tab_ranking .on .link_tit .inner_tit{background-position:100% -180px}
# .tab_ranking .tab_click1 .inner_tit{width:30px}
# .tab_ranking .tab_click2 .inner_tit{width:30px}
# .tab_ranking .tab_click3 .link_tit{padding-left:4px}
# .tab_ranking .tab_click3 .inner_tit{width:43px;padding-right:3px}
# .tab_ranking .tab_click4 .inner_tit{width:30px}
# .tab_ranking .tab_age1 .link_tit{padding-left:7px}
# .tab_ranking .tab_age1 .inner_tit{width:47px;padding-right:5px}
# .tab_ranking .tab_age2 .inner_tit{width:30px}
# .tab_ranking .tab_age3 .inner_tit{width:30px}
# .tab_ranking .tab_age4 .link_tit{padding-left:7px}
# .tab_ranking .tab_age4 .inner_tit{width:48px;padding-right:4px}
# .tab_ranking .tab_age5 .inner_tit{width:30px}
# .tab_ranking .link_tit .ico_pctop{display:inline-block;width:7px;height:10px;margin-top:8px;font-size:0;line-height:0;text-indent:-9999px;vertical-align:top}
# .tab_ranking .link_tit .ico_down{background-position:-70px -150px}
# .tab_ranking .link_tit .ico_up{background-position:-60px -150px}
# .tab_ranking .on .link_tit .ico_down{background-position:-90px -150px}
# .tab_ranking .on .link_tit .ico_up{background-position:-80px -150px}
# .cont_ranking{display:none;overflow:hidden}
# .cont_ranking.on{display:block}
# .ranking_news .list_ranking{margin-top:12px}
# .ranking_news .list_ranking li{height:16px;margin-bottom:12px;line-height:16px}
# .ranking_news .link_ranking{display:block;overflow:hidden}
# .ranking_news .txt_ranking{overflow:hidden;float:left;width:290px;white-space:nowrap;text-overflow:ellipsis}
# .ranking_news .num_pctop{float:left;width:16px;height:16px;margin:2px 6px 0 0;text-indent:-9999px;vertical-align:top}
# .ranking_news .num1{background-position:0 0}
# .ranking_news .num2{background-position:0 -20px}
# .ranking_news .num3{background-position:0 -40px}
# .ranking_news .num4{background-position:0 -60px}
# .ranking_news .num5{background-position:0 -80px}
# .os_mac .ranking_news .tit_ranking{line-height:25px}
# .os_mac .tab_ranking .link_tit{line-height:29px}
# .os_mac .ranking_news .list_ranking li{line-height:22px}
# .cast_sports{position:relative;width:320px;margin-bottom:20px}
# .cast_sports .head_cast{height:44px;border:1px solid #ececec;background-color:#fbfbfb}
# .cast_sports .tit_cast{font-size:13px;margin:10px 0 0 11px}
# .cast_sports .page_pctop{top:14px;right:14px;bottom:auto}
# .cast_sports .page_pctop .btn_page{width:16px;height:16px;line-height:16px;background-position:-210px 0}
# .cast_sports .page_pctop .btn_next{width:15px;background-position:-226px 0}
# .cast_sports .link_more{position:absolute;top:14px;right:14px;padding-right:7px;font-size:11px;color:#888;background-position:100% -18px}
# .list_relay{width:318px;border:1px solid #ececec;border-top:0 none}
# .list_relay li{overflow:hidden}
# .list_relay .link_relay:hover{color:#222;text-decoration:none}
# .list_relay .txt_team{overflow:hidden;font-size:12px;line-height:26px;white-space:nowrap;text-overflow:ellipsis}
# .list_relay .txt_time{float:left;font-size:11px;font-family:tahoma,arial,sans-serif;letter-spacing:0}
# .list_relay .txt_league{float:left;padding-left:3px;font-size:11px;color:#888}
# .list_relay .txt_score .inner_score{display:inline-block;vertical-align:top}
# .list_relay .txt_score .num_pctop{float:left;width:11px;height:16px;background-color:transparent}
# .list_relay .txt_score .num0{background-position:-60px 0}
# .list_relay .txt_score .num1{background-position:-60px -20px}
# ...
# <span class="ico_pctop ico_photo">포토뷰</span>
# <h3 class="tit_gallery"></h3>
# <span class="desc_source"></span>
# </a>
# </div>
# <a class="btn_preview btn_prev #function #photoslide_top #preBtn" href="#prevPhoto">
# <span class="frame_g"></span>
# <span class="ico_pctop ico_prev">이전 포토 보기</span>
# <span class="txt_gallery">추천갤러리<br>바로가기</br></span>
# </a>
# <a class="btn_preview btn_next #function #photoslide_top #nextBtn" href="#nextPhoto">
# <span class="frame_g"></span>
# <span class="ico_pctop ico_next">다음 포토 보기</span>
# <span class="txt_gallery">추천갤러리<br>바로가기</br></span>
# </a>
# </div>
# <div class="view_slide">
# <ul class="list_thumbnail #photoslide #gallery #img">
# <li class="fst @1"> <a class="link_thumb" href="#pic0">
# <img alt="WHO 첫 아프리카 출신 사무총장, 에티오피아의 게브레예수스" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/reuters/20170524213402639kvcl.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @2"> <a class="link_thumb" href="#pic1">
# <img alt="[포토엔HD] 엘르 패닝-니콜 키드먼-콜린 파렐-커스틴 던스트 만난 '비가일드'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/newsen/20170524193235111tcup.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @3"> <a class="link_thumb" href="#pic2">
# <img alt="트럼프 대통령 부부와 개인 알현 중인 교황" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/reuters/20170524180950048mtoy.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @4"> <a class="link_thumb" href="#pic3">
# <img alt='미국, "최저 임금 인상하라!"' class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/reuters/20170524180731808bquy.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @5"> <a class="link_thumb" href="#pic4">
# <img alt="콜롬비아, 노동 조건 개선을 요구하는 교사들" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/reuters/20170524180728800mfwo.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @6"> <a class="link_thumb" href="#pic5">
# <img alt="[포토엔HD] 손예진 '청순미모 돋보이는 레드카펫'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/newsen/20170524180703054fzmz.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @7"> <a class="link_thumb" href="#pic6">
# <img alt="[서소문사진관]아버지가 목숨 바쳐 지킨 한국 찾은 유가족" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/joongang/20170524174806719flba.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @8"> <a class="link_thumb" href="#pic7">
# <img alt='"올해도 풍년"..고창 중산리 천연기념물 이팝나무 만개' class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/NEWS1/20170524172036432vsod.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @9"> <a class="link_thumb" href="#pic8">
# <img alt="[포토친구] 이야기가 있는 정원" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/kppa/20170524164320775fguh.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @10"> <a class="link_thumb" href="#pic9">
# <img alt="일자리 상황판 설명하는 문재인 대통령" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/NEWS1/20170524161837238kkxm.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @11"> <a class="link_thumb" href="#pic10">
# <img alt="[M+포토] 전력질주하는 커쇼와 류현진, '포사이드 딱 기다려'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/mbcsportsplus/20170524155015578whzl.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @12"> <a class="link_thumb" href="#pic11">
# <img alt="영국, 맨체스터 아레나 공격 희생자를 위한 꽃들" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/reuters/20170524151825570ckfs.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @13"> <a class="link_thumb" href="#pic12">
# <img alt="미국, 이민자들의 시민권 선서" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/reuters/20170524151822587sodi.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @14"> <a class="link_thumb" href="#pic13">
# <img alt="러시아, 훈련 중인 소녀 격려하는 푸틴 대통령" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/reuters/20170524151758537wpft.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @15"> <a class="link_thumb" href="#pic14">
# <img alt="[포토엔HD]박명수 '세련된 패션으로 등장'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/newsen/20170524142007402rdxh.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @16"> <a class="link_thumb" href="#pic15">
# <img alt="시청 앞 서커스 공연" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/NEWS1/20170524135005273wjfs.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @17"> <a class="link_thumb" href="#pic16">
# <img alt="[포토친구] 푸름 가득한 청도읍성" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/kppa/20170524131411419eyrs.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @18"> <a class="link_thumb" href="#pic17">
# <img alt="'그리운 가족의 얼굴'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/NEWS1/20170524130220264viib.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @19"> <a class="link_thumb" href="#pic18">
# <img alt="[사진] 두테르테, 자신의 '영웅' 푸틴과 정상회담" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/NEWS1/20170524124317210gqoy.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @20"> <a class="link_thumb" href="#pic19">
# <img alt="제주 한라산 털진달래 만개 '연분홍빛 산상화원'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/nocut/20170524114502961zwgc.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @21"> <a class="link_thumb" href="#pic20">
# <img alt="이동 시작한 새끼두꺼비" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/NEWS1/20170524111900735rbfg.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @22"> <a class="link_thumb" href="#pic21">
# <img alt="[포토]문재인 정부 첫 인사청문회, '답변하는 이낙연 국무총리 후보자'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/Edaily/20170524111034610odki.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @23"> <a class="link_thumb" href="#pic22">
# <img alt="맨체스터 희생자 추모회 참석한 노동당 코빈과 맨체스터 시장" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/reuters/20170524110356685hbtw.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @24"> <a class="link_thumb" href="#pic23">
# <img alt="업무보고로 분주한 국정기획자문위원회" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/NEWS1/20170524104248595ctkf.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @25"> <a class="link_thumb" href="#pic24">
# <img alt="[포토친구] 비 오는 수요일의 빨간 장미" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/kppa/20170524103838221fgnl.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @26"> <a class="link_thumb" href="#pic25">
# <img alt="법정 도착한 서미경" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/NEWS1/20170524103830901vjyl.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @27"> <a class="link_thumb" href="#pic26">
# <img alt="연분홍빛으로 물든 한라산" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/NEWS1/20170524102520127axsm.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @28"> <a class="link_thumb" href="#pic27">
# <img alt="[포토친구] 비지리 다랑논" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/kppa/20170524102458408sxxg.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @29"> <a class="link_thumb" href="#pic28">
# <img alt="[포토] 백스윙 탑 최나연, '연습 벌레'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/Edaily/20170524095007897cerx.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# <li class=" @30"> <a class="link_thumb" href="#pic29">
# <img alt="[M+포토] 류현진, '파이널보스는 내가 지킨다'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=http://t1.daumcdn.net/news/201705/24/mbcsportsplus/20170524094147896dacj.jpg" height="60" src="http://t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60">
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </img></a>
# </li>
# </ul>
# <a class="btn_move btn_prev #function #photoslide_bottom #preBtn" href="#prevPhotoList"><span class="ico_pctop">이전 이미지 목록 보기</span></a>
# <a class="btn_move btn_next #function #photoslide_bottom #nextBtn" href="#nextPhotoList"><span class="ico_pctop">다음 이미지 목록 보기</span></a>
# </div>
# </div>
# </div>
# </main>
# <!-- // daumContent -->
# <hr class="hide">
# <footer class="foot_daum #footer" id="daumFoot">
# <div class="inner_foot">
# <a class="link_logo #logo" href="http://www.daum.net/"><img alt="다음" class="img_thumb" height="22" src="//t1.daumcdn.net/daumtop_deco/images/top/2017/logo_foot.gif" width="52"/></a>
# <div class="info_notice">
# <h2 class="tit_notice"><a class="ico_vert link_notice #title" href="http://m.daum.net/channel/noticePC?order=recent">공지사항</a></h2>
# <ul class="list_notice">
# <li>
# <a class="link_info #notice" href="https://channel.daum.net/content/377561?dmp_channel=noticePC&amp;dmp_id=377561">카카오 위치기반서비스 변경 안내</a>
# </li>
# </ul>
# </div>
# <div class="search_foot">
# <h2 class="screen_out">검색</h2>
# <form accept-charset="utf-8" action="http://search.daum.net/search" method="get" role="search">
# <input name="w" type="hidden" value="tot"/>
# <input name="DA" type="hidden" value="YZR"/>
# <input name="t__nil_searchbox" type="hidden" value="btn"/>
# <input name="sug" type="hidden"/>
# <input name="sugo" type="hidden"/>
# <input name="sq" type="hidden"/>
# <input name="o" type="hidden"/>
# <fieldset>
# <legend class="screen_out">통합 검색</legend>
# <div class="box_search" id="searchMiniBar">
# <input autocapitalize="off" autocomplete="off" autocorrect="off" class="tf_keyword" id="qMini" name="q" spellcheck="false" title="검색어 입력" type="text">
# <button class="ico_pctop btn_search" id="qMiniBtn" type="submit">
# <span class="ir_wa">검색</span>
# </button>
# </input></div>
# </fieldset>
# </form>
# </div>
# <a class="ico_vert link_svcall #sitemap" href="sitemap/index.html">서비스 전체보기</a>
# <h2 class="screen_out">다음 소개 및 약관</h2>
# <div class="info_policy">
# <a class="link_policy #kakaocorp" href="http://www.kakaocorp.com/main">회사소개</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #biz" href="http://ad.kakaocorp.com/">광고안내</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #search" href="https://register.search.daum.net/index.daum">검색등록</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #propose" href="http://with.kakao.com/">제휴문의</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #recruit" href="http://www.kakaocorp.com/recruit/recruitprocess.html">인재채용</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #servicepolicy" href="http://policy.daum.net/info/info">서비스약관</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #youthpolicy" href="http://policy.daum.net/youthpolicy/youthpolicy">청소년보호정책</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #infopolicy" href="http://policy.daum.net/info_protection/info_protection"><strong>개인정보처리방침</strong></a>
# <span class="txt_dot">·</span>
# <a class="link_policy #top_accessibility" href="http://www.daum.net/doc/top_accessibility.html">웹접근성안내</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #cs" href="http://cs.daum.net/">고객센터</a>
# </div>
# <small class="txt_copyright">Copyright © <a class="link_kakao #copyright" href="http://www.kakaocorp.com/">Kakao Corp.</a> All rights reserved.</small>
# </div>
# </footer>
# </hr></hr></div>
# <script src="//t1.daumcdn.net/daumtop_deco/scripts/201705151400/top.js" type="text/javascript"></script>
# <script async="" src="https://m2.daumcdn.net/tiara/js/tiara-iframe.min.js?v=20151105"></script>
# </body>
# </html>

# %%
bsObj.html.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta content="http://www.daum.net/" property="og:url">
# <meta content="website" property="og:type">
# <meta content="Daum" property="og:title">
# <meta content="http://i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" property="og:image">
# <meta content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum" property="og:description">
# <meta content="name=Daum;action-uri=http://www.daum.net/;icon-uri=/favicon.ico" name="msapplication-task">
# <meta content="name=미디어다음;action-uri=http://media.daum.net/;icon-uri=/media_favicon.ico" name="msapplication-task">
# <meta content="name=tv팟;action-uri=http://tvpot.daum.net;icon-uri=/tvpot_favicon.ico" name="msapplication-task">
# <meta content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico" name="msapplication-task">
# <link href="http://search.daum.net/OpenSearch.xml" rel="search" title="다음" type="application/opensearchdescription+xml">
# <style type="text/css">
# @charset "utf-8";
# body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,button{margin:0;padding:0}
# fieldset,img{border:0 none}
# dl,ul,ol,menu,li{list-style:none}
# blockquote, q{quotes: none}
# blockquote:before, blockquote:after,q:before, q:after{content:'';content:none}
# input,select,textarea,button{vertical-align:middle}
# input::-ms-clear{display:none}
# button{border:0 none;background-color:transparent;cursor:pointer}
# body{background:#fff;direction:ltr;-webkit-text-size-adjust:none}
# body,th,td,input,select,textarea,button{font-size:13px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,'Malgun Gothic','맑은 고딕',dotum,'돋움',sans-serif;color:#222;letter-spacing:-1px}
# .os_mac body,.os_mac th,.os_mac td,.os_mac input,.os_mac select,.os_mac textarea,.os_mac button{letter-spacing:0}
# a{color:#222;text-decoration:none}
# a:hover{color:#118eff;text-decoration:underline}
# a:active{background-color:transparent}
# address,caption,cite,code,dfn,em,var{font-style:normal;font-weight:normal}
# .ir_pm{display:block;overflow:hidden;font-size:1px;line-height:0;text-indent:-9999px}
# .ir_wa{display:block;overflow:hidden;position:relative;width:100%;height:100%;z-index:-1}
# .screen_out{overflow:hidden;position:absolute;width:0;height:0;line-height:0;text-indent:-9999px}
# .show{display:block}
# .hide{display:none}
# .d_index{position:relative;width:100%;z-index:101}
# .d_index .shortcut_g{position:absolute;top:-34px;left:0;height:33px;padding:0 20px 0 26px;border-bottom:1px solid #3f4243;font-size:11px;line-height:14px;background-color:#26292a;color:#fff;letter-spacing:-1px;text-align:center}
# .d_index .shortcut_g:active,
# .d_index .shortcut_g:focus{overflow:hidden;top:0;text-decoration:none}
# .d_index .shortcut_g:active,
# .d_index .shortcut_g:hover{color:#fff}
# .d_index .shortcut_g .inner_shortcut{display:inline-block;padding-right:10px;margin-top:11px;background-position:100% -223px;vertical-align:top}
# .ico_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_170405.png) no-repeat 0 0}
# .ico_vert{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_vert.png) no-repeat 0 0}
# .txt_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/txt_pctop_170410.png) no-repeat 0 0;letter-spacing:-1px;white-space:nowrap}
# .bg_pctop{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat 0 0}
# .num_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/num_pctop_170405.png) no-repeat 0 0}
# .img_thumb{display:block;vertical-align:top}
# .frame_g{position:absolute;top:0;left:0;border:1px solid #000;opacity:0.08;filter:alpha(opacity=8)}
# .thumb_g{display:block;position:relative}
# .thumb_g .ico_view{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-40px 0;text-indent:-9999px;cursor:pointer}
# .thumb_g .ico_video{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-70px 0;text-indent:-9999px;cursor:pointer}
# .thumb_g .ico_live{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-130px 0;text-indent:-9999px;cursor:pointer}
# .ico_label{overflow:hidden;position:absolute;top:20px;left:20px;height:26px;padding:0 8px;font-size:14px;line-height:24px;color:#fff;background-color:#1382e9}
# .ico_label2{overflow:hidden;position:absolute;top:0;left:0;height:20px;padding:0 7px;font-size:11px;line-height:17px;color:#fff;background-color:rgba(0,0,0,0.6);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#99000000',endColorstr='#99000000',GradientType=0)}
# .os_mac .ico_label{line-height:27px}
# .os_mac .ico_label2{line-height:21px}
# .color_g1{color:#e30000}
# .color_g2{color:#118eff}
# .tit_tabcont{position:absolute;font-size:16px}
# .wrap_tabcont{display:none}
# #daumWrap{position:relative;min-width:1080px}
# .head_daum{position:relative;z-index:100}
# .cont_main{position:relative;width:990px;margin:25px auto 0}
# .cont_topic{position:relative;z-index:0;width:100%;border-top:1px solid #ececec;background-color:#fbfbfc;background-position:50% 100%;background-repeat:no-repeat}
# .wrap_feature{display:inline-block;height:130px;vertical-align:top}
# .wrap_main{display:inline-block;vertical-align:top}
# .main_tmp{float:left;width:655px;margin-right:35px;padding-bottom:50px}
# .wing_tmp{float:left;width:300px}
# .os_mac .cont_main{transform:translate3d(0px, 0px, 0px)}
# .d_head{border-bottom:1px solid #ececec}
# .d_head .inner_head{position:relative;z-index:1;width:1080px;height:140px;margin:0 auto}
# .tit_daum{overflow:hidden;float:left;width:180px;height:140px;text-align:center}
# .link_daum{overflow:hidden;display:block;margin:23px auto}
# .link_launch{position:absolute;top:6px;left:45px;padding-right:8px;font-size:11px;color:#888;background-position:100% -18px}
# .os_mac .link_launch{top:9px;background-position:100% -21px}
# .wrap_search{float:left;position:relative;margin-top:45px}
# .wrap_search .d_sch{background-color:#fff}
# .head_daum .box_search{position:relative;height:44px;margin:1px 1px 0 0;border:1px solid #0089ff;border-radius:1px}
# .head_daum .box_search .inner_search{position:relative;z-index:1;height:44px;padding:0 60px 0 14px;}
# .head_daum .box_search::before, .head_daum .box_search .inner_search::before, .head_daum .box_search::after{position:absolute;left:0;right:100%;height:1px;content:'';background-color:#0089ff}
# .head_daum .box_search::before{top:-1px}
# .head_daum .box_search::after{bottom:-1px}
# .head_daum .box_search:hover::before, .head_daum .box_search:hover::after{right:0;transition-property:right;transition-duration:0.8s;background:linear-gradient(to right, #86aaff, #70bc4c, #ffbe00, #f46e85)}
# .head_daum .box_search:hover .inner_search::before{top:-1px;bottom:-1px;left:auto;right:-1px;width:1px;height:46px;background-color:#f46e85;transition-property:height;transition-delay:0.8s}
# .head_daum .tf_keyword{float:left;width:440px;margin-top:7px;border:1px solid transparent;font-size:16px;line-height:24px;background-color:transparent;outline:0;ime-mode:active;-webkit-appearance:none}
# .head_daum .btn_search{position:absolute;top:0;right:0;width:49px;height:42px;margin:1px;line-height:44px;background-position:-200px -231px;background-color:transparent}
# .slide_favorsch{overflow:hidden;width:480px;height:28px}
# .list_favorsch{overflow:hidden;padding-top:7px}
# .list_favorsch li{float:left;padding-right:10px}
# .list_favorsch .link_favorsch{display:block;font-size:12px;color:#555}
# .head_daum .page_pctop{z-index:1;right:1px;bottom:3px}
# .head_daum .page_pctop .btn_page{width:16px;height:16px;background-position:-210px 0}
# .head_daum .page_pctop .btn_next{width:15px;background-position:-226px 0}
# .head_bnr{position:absolute;top:28px;right:45px}
# .head_bnr .link_headbnr{display:block}
# .os_mac .head_daum .box_search{margin-top:0}
# .os_mac .head_daum .tf_keyword{margin-top:11px}
# .os_mac .list_favorsch{padding-top:10px}
# .os_mac .list_favorsch li{padding-right:14px}
# .daumSuggestWrap{position:relative;margin-right:90px;clear:both}
# .suggestBox{position:absolute;top:45px;left:0;z-index:9999;width:520px;padding:0;-webkit-box-shadow:0 1px 3px 0 rgba(0,0,0,0.12);box-shadow:0 1px 3px 0 rgba(0,0,0,0.12);background:none}
# .baseBox{border-top:1px solid #dcdcdc;font-size:12px;line-height:17px;font-family:'굴림',gulim,sans-serif;background-color:#fff}
# .os_mac .baseBox{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .list{padding:7px 0 13px;border-left:1px solid #dcdcdc;border-right:1px solid #dcdcdc;color:#333;background-color:#fff}
# .suggestBox.reverseType .list{padding:3px 0 7px;color:#333}
# .suggestBox .baseBox li{overflow:hidden;height:26px;padding:0 16px;line-height:26px;text-align:left;cursor:pointer}
# .suggestBox li .item{display:block;height:100%}
# .suggestBox li .item:hover{text-decoration:none}
# .suggestBox .list .on{background-color:#f6f6f6}
# .suggestBox li strong{font-weight:normal;color:#0089ff}
# .suggestBox .line{overflow:hidden;height:1px;margin:7px 0px 6px;padding:0;font-size:1px;line-height:1px;background-color:#e5e5e5}
# .suggestBox .guide{padding:15px 10px;color:#555}
# .suggestBox .footer{position:relative;height:20px;padding:8px 12px 4px 7px;border:1px solid #dcdcdc;border-top:1px solid #ececec;font-size:11px;background-color:#fbfbfb;letter-spacing:-1px;clear:both}
# .suggestBox.reverseType .footer{border-top-color:#dcdcdc;border-bottom-color:#ededed}
# .suggestBox .footer .fl{float:left}
# .suggestBox .footer .fr{float:right}
# .suggestBox .footer .btn_close{padding-left:12px;background-position:0 -939px}
# .suggestBox .footer .bar{display:none;padding:0 2px;color:#ddd}
# .suggestBox .footer .fl .bar{padding:0 2px 0 1px}
# .suggestBox .footer .offGuide{display:none;position:absolute;right:0;bottom:19px;width:211px;height:27px;background:url(http://search1.daumcdn.net/search/statics/common/pi/suggest_service.gif) no-repeat;text-indent:-999em}
# .suggestBox .footer .offSuggest{display:none}
# .os_mac .suggestBox .list{padding:9px 0 11px}
# .os_mac .suggestBox .baseBox li{padding:0 17px}
# .suggestBox a{color:#777}
# .suggestBox .answer{border-left:1px solid #dcdcdc;border-right:1px solid #dcdcdc}
# .suggestBox .answer span{cursor:pointer}
# .suggestBox .baseBox li a{font-size:14px;color:#333;font-family:'돋움',dotum,sans-serif;text-decoration:none}
# .os_mac .suggestBox .baseBox li a{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .line{display:block;overflow:hidden;clear:both}
# .suggestBox .b_line{border-bottom:1px solid #ededed}
# .suggestBox .suggest_exact{display:block;overflow:hidden;height:40px;padding:12px 0 11px 18px}
# .suggestBox .suggest_exact:hover{text-decoration:none}
# .suggestBox .e_on{background-color:#f8f8f8;text-decoration:none}
# .suggestBox .suggest_exact .txt_exact{overflow:hidden;float:left;height:44px;margin-top:0;background-position:0 0}
# .suggestBox .suggest_exact .ico_w01{padding-left:42px;background-position:0 1px}
# .suggestBox .suggest_exact .ico_w02{padding-left:47px;background-position:0 -49px}
# .suggestBox .suggest_exact .ico_w03{padding-left:47px;background-position:0 -98px}
# .suggestBox .suggest_exact .ico_w04{padding-left:41px;background-position:0 -142px}
# .suggestBox .suggest_exact .ico_w05{padding-left:50px;background-position:0 -199px}
# .suggestBox .suggest_exact .ico_w06{padding-left:53px;background-position:0 -246px}
# .suggestBox .suggest_exact .ico_w07{padding-left:41px;background-position:0 -297px}
# .suggestBox .suggest_exact .ico_w08{padding-left:47px;background-position:0 -347px}
# .suggestBox .suggest_exact .ico_w09{padding-left:39px;background-position:0 -396px}
# .suggestBox .suggest_exact .ico_w10{padding-left:39px;background-position:0 -450px}
# .suggestBox .suggest_exact .ico_w11{padding-left:48px;background-position:0 -600px}
# .suggestBox .suggest_exact .ico_w12{padding-left:41px;background-position:0 -546px}
# .suggestBox .suggest_exact .ico_w13{padding-left:48px;background-position:0 -600px}
# .suggestBox .suggest_exact .ico_w14{padding-left:45px;background-position:0 -650px}
# .suggestBox .suggest_exact .ico_w15{padding-left:41px;background-position:0 -699px}
# .suggestBox .suggest_exact .ico_w16{padding-left:46px;background-position:0 -750px}
# .suggestBox .suggest_exact .ico_w17{padding-left:41px;background-position:0 -797px}
# .suggestBox .suggest_exact .ico_w18{padding-left:44px;background-position:0 -844px}
# .suggestBox .suggest_exact .txt_unit{font-size:14px;font-family:arial,sans-serif}
# .suggestBox .suggest_exact .tit{margin-left:-1px;font-weight:normal;font-size:12px;line-height:18px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .cont{display:block}
# .suggestBox .suggest_exact .txt_cont{margin-right:4px;font-weight:bold;font-size:14px;line-height:16px;font-family:'돋움',dotum,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num1{font-size:18px;line-height:20px;font-family:tahoma,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num2{margin-left:3px;font-size:12px;line-height:14px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num3{font-size:20px;line-height:23px;font-family:arial,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num4{margin-left:-3px;font-size:12px;line-height:14px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_exact .ico_suggest2{background:url(http://search1.daumcdn.net/search/statics/common/pi/ico/ico_suggest_20110721.gif) no-repeat 0 0}
# .suggestBox .suggest_exact .txt_exact .ico_celsius{background:none}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_up{padding-left:11px;background-position:0 -58px}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_down{padding-left:11px;background-position:0 -98px}
# .suggestBox .suggest_exact .ico_arrow_equal{padding-left:14px;background-position:1px -77px}
# .suggestBox .suggest_exact .txt_blue{color:#007aff}
# .suggestBox .suggest_exact .txt_blue2{color:#007aff}
# .suggestBox .suggest_exact .txt_red{color:#e52d38}
# .suggestBox .suggest_exact .txt_red2{color:#e52d38}
# .suggestBox .suggest_exact .txt_time{float:right;margin:25px 16px 0 0;font-size:11px;font-family:'돋움',dotum,sans-serif;color:#a1a1a1}
# .suggestBox .suggest_exact .ico_celsius{width:12px;height:13px;font-family:arial,sans-serif;background-position:right 5px}
# .suggestBox .suggest_exact .bar{font-size:14px;color:#dedede}
# .suggestBox .wrap_today{overflow:hidden;height:21px;padding:4px 10px 2px 9px;line-height:21px}
# .suggestBox .wrap_today .cont{font-size:14px;color:#333;text-decoration:none}
# .suggestBox .wrap_today .cont_import{font-weight:normal;color:#ea570a}
# .os_mac .suggestBox .suggest_exact .tit{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_num2{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_num4{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_time{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .ico_lotto{float:left;width:28px;height:28px;margin:6px 5px 0 0;border-radius:20px;text-align:center}
# .suggestBox .ico_lotto .txt_num{display:inline-block;margin-top:7px;font-size:14px;line-height:1;font-family:arial,sans-serif;color:#fff;vertical-align:top}
# .suggestBox .num1{background-color:#f6a800}
# .suggestBox .num10{background-color:#4155cb}
# .suggestBox .num20{background-color:#f64d61}
# .suggestBox .num30{background-color:#585d6e}
# .suggestBox .num40{background-color:#f6a800}
# .suggestBox .plus{width:8px;height:8px;margin:16px 8px 0 4px;background:url(http://search1.daumcdn.net/search/statics/common/pi/ico/ico_suggest_20110721.gif) no-repeat 0 -40px;text-indent:-9999px;opacity:0.5}
# .suggestBox .weather_comp{font-size:12px;line-height:17px;color:#555}
# .suggestBox .weather_comp .ico_suggest{padding-left:59px;background:url(http://search1.daumcdn.net/search/statics/common/pi/ico_weather_m_160616.gif) no-repeat}
# .suggestBox .weather_comp .txt_exact{overflow:hidden;float:left;height:44px;margin-top:0}
# .suggestBox .weather_comp .ico_w00{background-position:0 -1620px}
# .suggestBox .weather_comp .ico_w01{background-position:0 0}
# .suggestBox .weather_comp .night .ico_w01{background-position:0 -60px}
# .suggestBox .weather_comp .ico_w02{background-position:0 -120px}
# .suggestBox .weather_comp .night .ico_w02{background-position:0 -180px}
# .suggestBox .weather_comp .ico_w03{background-position:0 -240px}
# .suggestBox .weather_comp .night .ico_w03{background-position:0 -300px}
# .suggestBox .weather_comp .ico_w04{background-position:0 -360px}
# .suggestBox .weather_comp .ico_w05{background-position:0 -420px}
# .suggestBox .weather_comp .night .ico_w05{background-position:0 -480px}
# .suggestBox .weather_comp .ico_w06{background-position:0 -540px}
# .suggestBox .weather_comp .night .ico_w06{background-position:0 -600px}
# .suggestBox .weather_comp .ico_w07{background-position:0 -660px}
# .suggestBox .weather_comp .ico_w08{background-position:0 -720px}
# .suggestBox .weather_comp .ico_w09{background-position:0 -780px}
# .suggestBox .weather_comp .ico_w10{background-position:0 -840px}
# .suggestBox .weather_comp .night .ico_w10{background-position:0 -900px}
# .suggestBox .weather_comp .ico_w11{background-position:0 -960px}
# .suggestBox .weather_comp .ico_w12{background-position:0 -1020px}
# .suggestBox .weather_comp .ico_w13{background-position:0 -1080px}
# .suggestBox .weather_comp .night .ico_w13{background-position:0 -1140px}
# .suggestBox .weather_comp .ico_w14{background-position:0 -1200px}
# .suggestBox .weather_comp .ico_w15{background-position:0 -1260px}
# .suggestBox .weather_comp .ico_w16{background-position:0 -1320px}
# .suggestBox .weather_comp .night .ico_w16{background-position:0 -1380px}
# .suggestBox .weather_comp .ico_w17{background-position:0 -1440px}
# .suggestBox .weather_comp .ico_w18{background-position:0 -1500px}
# .suggestBox .weather_comp .ico_w19{background-position:0 -1560px}
# .d_service{border-bottom:1px solid #888}
# .d_service .inner_service{position:relative;width:990px;height:50px;margin:0 auto}
# .menu_service{float:left;position:relative;width:570px}
# .menu_service .link_more{overflow:hidden;float:left;width:60px;height:20px;padding:15px 0;line-height:20px;background-position:-469px -350px;background-color:transparent;text-align:center}
# .menu_on .link_more{background-position:-530px -350px}
# .list_mainsvc{float:left}
# .list_mainsvc li{float:left;height:50px}
# .list_mainsvc .txt_pctop{display:block;height:20px;padding:15px 0;font-weight:bold;font-size:13px;line-height:20px;background-color:transparent;text-align:center}
# .list_mainsvc .link_cafe{width:28px;background-position:0 -350px}
# .list_mainsvc .link_mail{width:35px;background-position:-28px -350px}
# .list_mainsvc .link_news{width:35px;background-position:-63px -350px}
# .list_mainsvc .link_map{width:34px;background-position:-98px -350px}
# .list_mainsvc .link_stock{width:35px;background-position:-132px -350px}
# .list_mainsvc .link_shopping{width:34px;background-position:-167px -350px}
# .list_mainsvc .link_kakaotv{width:63px;background-position:-201px -350px}
# .list_mainsvc .link_webtoon{width:33px;background-position:-264px -350px}
# .list_mainsvc .link_brunch{width:46px;background-position:-297px -350px}
# .list_mainsvc .link_dic{width:35px;background-position:-343px -350px}
# .list_mainsvc .link_game{width:34px;background-position:-378px -350px}
# .list_mainsvc .link_together{width:57px;background-position:-412px -350px}
# .service_layer{display:none;position:absolute;top:50px;left:0;width:653px;border:1px solid #888;background-color:#fff}
# .menu_on .service_layer{display:block}
# .service_layer .layer_body{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_line.gif) repeat-y 0 0}
# .service_layer .sort_service{float:left;width:94px;padding:0 0 15px 15px}
# .service_layer .sort_service.fst{padding-left:14px}
# .service_layer .sort_service dt{margin:11px 0 4px;font-weight:bold;font-size:12px}
# .service_layer .sort_service dt.tit_split{float:left;margin-top:22px;padding-right:9px;background-position:100% 5px}
# .service_layer .sort_service dd{clear:both;font-size:12px;line-height:22px}
# .service_layer .sort_service .link_svc{color:#555}
# .service_layer .sort_service .link_svc:hover{color:#118eff}
# .service_layer .sort_service .ico_new{display:inline-block;width:11px;height:11px;margin:3px 0 0 2px;font-size:0;line-height:0;background-position:-160px -80px;vertical-align:top;text-indent:-9999px}
# .service_layer .layer_foot{overflow:hidden;height:32px;border-top:1px solid #ececec;background-color:#fbfbfb}
# .service_layer .layer_foot .link_total{float:left;padding-right:8px;margin-left:13px;font-size:11px;line-height:29px;color:#555;background-position:100% -12px}
# .service_layer .layer_foot .btn_close{float:right;padding:0 13px;margin:2px;font-size:11px;line-height:24px;color:#888}
# .os_mac .service_layer .sort_service{padding-bottom:12px}
# .os_mac .service_layer .sort_service dt{margin:14px 0 4px}
# .os_mac .service_layer .sort_service dt.tit_split{background-position:100% 3px}
# .os_mac .service_layer .layer_foot .link_total{padding-right:10px;margin-left:14px;line-height:32px;background-position:100% -12px}
# .os_mac .service_layer .layer_foot .btn_close{padding:0 12px;line-height:28px}
# .foot_daum{border-top:1px solid #888}
# .foot_daum .inner_foot{overflow:hidden;position:relative;width:990px;margin:0 auto;padding:37px 0 78px}
# .foot_daum .link_logo{float:left}
# .foot_daum .info_notice{overflow:hidden;padding:0 250px 0 30px}
# .foot_daum .tit_notice{float:left;font-size:13px}
# .foot_daum .link_notice{display:block;padding-right:9px;background-position:100% -169px}
# .foot_daum .link_notice:hover{color:#222}
# .foot_daum .list_notice{overflow:hidden;width:542px;height:19px;padding-left:9px}
# .foot_daum .list_notice .link_info{display:block;overflow:hidden;text-overflow:ellipsis;white-space:nowrap}
# .foot_daum .list_notice .link_info:hover{color:#222}
# .foot_daum .search_foot{position:absolute;top:32px;right:0}
# .foot_daum .box_search{position:relative;z-index:1;width:209px;height:28px;border:1px solid #c8c8c8}
# .foot_daum .search_on{border-color:#0089ff}
# .foot_daum .tf_keyword{float:left;width:164px;margin:5px 0 0 9px;border:1px solid transparent;line-height:19px;outline:0}
# .foot_daum .btn_search{float:right;width:32px;height:28px;line-height:28px;background-position:-160px -230px;background-color:transparent}
# .foot_daum .link_svcall{position:absolute;top:81px;right:0;padding-right:10px;font-weight:bold;color:#888;background-position:100% -194px}
# .foot_daum .info_policy{padding:23px 250px 0 0}
# .foot_daum .info_policy .link_policy{font-size:12px;color:#888}
# .foot_daum .info_policy .txt_dot{padding:0 2px;font-size:12px;color:#888}
# .foot_daum .txt_copyright{display:block;padding-top:6px;font-size:11px;color:#888}
# .foot_daum .txt_copyright .link_kakao{color:#888}
# .os_mac .foot_daum .info_notice{padding:3px 250px 0 31px}
# .os_mac .foot_daum .link_notice{padding-right:12px;background-position-y:-172px}
# .os_mac .foot_daum .tf_keyword{margin-top:4px}
# .os_mac .foot_daum .link_svcall{top:83px;background-position-y:-196px}
# .os_mac .foot_daum .info_policy{padding-top:24px}
# .os_mac .foot_daum .txt_copyright{padding-top:5px}
# .today_base{float:right;position:relative;height:50px}
# .today_base .comp_base{display:inline-block;vertical-align:top}
# .today_base .img_weather{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/img_weather.png);background-repeat:no-repeat;font-size:0;line-height:0;text-indent:-9999px}
# .info_today{float:left}
# .info_today .date_today{float:left;height:24px;padding:13px 0;font-size:12px;line-height:19px;letter-spacing:0}
# .info_today .txt_part{float:left;font-weight:bold;font-size:12px;line-height:24px}
# .info_today .link_weather{float:left;height:24px;margin-left:20px;padding:11px 0;line-height:23px;text-align:right}
# .info_today .link_weather:hover{color:#222;text-decoration:none}
# .info_today .link_weather .txt_temper{float:left;font-family:tahoma,arial,sans-serif;letter-spacing:0}
# .os_mac .info_today .date_today{line-height:25px}
# .os_mac .info_today .txt_part{line-height:29px}
# .os_mac .info_today .link_weather{height:28px;line-height:27px}
# .os_mac .info_today .link_weather .txt_temper{font-family:helvetica,arial,sans-serif}
# .info_today .img_weather{float:left;width:26px;height:26px;margin:1px 0 0 2px;vertical-align:top}
# .os_mac .info_today .img_weather{margin-left:4px}
# .info_today .ico_wm01{background-position:0 -240px}
# .info_today .night .ico_wm01{background-position:-30px -240px}
# .info_today .ico_wm02{background-position:-60px -240px}
# .info_today .night .ico_wm02{background-position:-90px -240px}
# .info_today .ico_wm03{background-position:0 -270px}
# .info_today .night .ico_wm03{background-position:-30px -270px}
# .info_today .ico_wm04{background-position:-60px -270px}
# .info_today .ico_wm07{background-position:-90px -270px}
# .info_today .ico_wm09{background-position:0 -300px}
# .info_today .ico_wm10{background-position:-30px -300px}
# .info_today .night .ico_wm10{background-position:-60px -300px}
# .info_today .ico_wm11{background-position:-90px -300px}
# .info_today .ico_wm14{background-position:0 -330px}
# .info_today .ico_wm17{background-position:-30px -330px}
# .info_today .ico_wm18{background-position:-60px -330px}
# .info_today .ico_wm19{background-position:-90px -330px}
# .info_today .ico_degree{float:left;width:17px;height:15px;margin:5px 0 0;font-size:12px;line-height:17px;background-position:-210px -270px;background-color:transparent;text-align:center;text-indent:0}
# .os_mac .info_today .ico_degree{margin:6px 0 0}
# .info_today .link_stock{float:left;height:28px;margin-left:14px;padding:11px 0;line-height:23px;text-align:right}
# .info_today .link_stock:hover{color:#222;text-decoration:none}
# .info_today .num_stock{float:left;padding:0 3px;font-weight:normal;font-family:tahoma,arial,sans-serif}
# .info_today .num_status{font-size:11px;line-height:25px;letter-spacing:0}
# .info_today .num_status .ico_arrow{display:inline-block;width:9px;height:10px;margin:8px 3px 0 0;font-size:10px;line-height:11px;background-color:transparent;vertical-align:top}
# .info_today .stock_up .num_status{color:#e30000}
# .info_today .stock_down .num_status{color:#118eff}
# .info_today .stock_up .num_status .ico_arrow{background-position:-120px -150px}
# .info_today .stock_down .num_status .ico_arrow{background-position:-130px -150px}
# .info_today .stock_stay .num_status .ico_arrow{background-position:-140px -150px}
# .os_mac .info_today .link_stock{margin-left:17px;line-height:25px}
# .os_mac .info_today .num_stock{padding-top:1px;font-family:helvetica,arial,sans-serif}
# .os_mac .info_today .num_status{line-height:27px}
# .os_mac .info_today .num_status .ico_arrow{margin:9px 4px 0 0}
# .today_layer{position:absolute;top:50px;right:0;width:298px;border:1px solid #888;background-color:#fff}
# .today_layer .layer_body{overflow:hidden}
# .today_layer .weather_part{float:left;position:relative;width:148px;height:126px;border-right:1px solid #ececec}
# .today_layer .btn_locate{position:absolute;top:12px;right:10px;width:19px;height:19px;font-size:0;line-height:0;background-position: -190px -240px;text-indent:-9999px}
# .today_layer .btn_locate.on{background-position:-190px -260px}
# .today_layer .link_weather{display:block;overflow:hidden;height:126px}
# .today_layer .link_weather:hover{color:#222;text-decoration:none}
# .today_layer .txt_place{display:block;margin:11px 0 0 14px;font-weight:bold;font-size:12px;line-height:18px}
# .today_layer .txt_place .txt_local{display:block}
# .today_layer .link_weather .img_weather{float:left;margin:7px 0 0 15px;width:56px;height:56px;vertical-align:top}
# .today_layer .ico_wm01{background-position:0 0}
# .today_layer .night .ico_wm01{background-position:-60px 0}
# .today_layer .ico_wm02{background-position:-120px 0}
# .today_layer .night .ico_wm02{background-position:-180px 0}
# .today_layer .ico_wm03{background-position:0 -60px}
# .today_layer .night .ico_wm03{background-position:-60px -60px}
# .today_layer .ico_wm04{background-position:-120px -60px}
# .today_layer .ico_wm07{background-position:-180px -60px}
# .today_layer .ico_wm09{background-position:0 -120px}
# .today_layer .ico_wm10{background-position:-60px -120px}
# .today_layer .night .ico_wm10{background-position:-120px -120px}
# .today_layer .ico_wm11{background-position:-180px -120px}
# .today_layer .ico_wm14{background-position:0 -180px}
# .today_layer .ico_wm17{background-position:-60px -180px}
# .today_layer .ico_wm18{background-position:-120px -180px}
# .today_layer .ico_wm19{background-position:-180px -180px}
# .today_layer .info_temper{float:left;margin:24px 0 0 4px;font-family:tahoma,arial,sans-serif}
# .today_layer .info_temper .img_weather{float:left;width:14px;height:20px;margin:0}
# .today_layer .info_temper .num0{background-position:-240px 0}
# .today_layer .info_temper .num1{background-position:-240px -30px}
# .today_layer .info_temper .num2{background-position:-240px -60px}
# .today_layer .info_temper .num3{background-position:-240px -90px}
# .today_layer .info_temper .num4{background-position:-240px -120px}
# .today_layer .info_temper .num5{background-position:-240px -150px}
# .today_layer .info_temper .num6{background-position:-240px -180px}
# .today_layer .info_temper .num7{background-position:-240px -210px}
# .today_layer .info_temper .num8{background-position:-240px -240px}
# .today_layer .info_temper .num9{background-position:-240px -270px}
# .today_layer .info_temper .ico_minus{width:8px;height:20px;margin-top:1px;background-position:-240px -300px}
# .today_layer .info_temper .ico_degree{width:23px;height:20px;background-position:-210px -240px}
# .os_mac .today_layer .txt_place{margin-top:14px}
# .today_layer .stock_part{float:left;width:148px;height:126px}
# .today_layer .link_stock{display:block;overflow:hidden;height:43px;padding:13px 14px 0;line-height:26px}
# .today_layer .link_stock:hover{color:#222;text-decoration:none}
# .today_layer .link_stock + .link_stock{height:57px}
# .today_layer .tit_stock{display:block;margin-bottom:1px;font-weight:bold;font-size:12px;line-height:16px}
# .today_layer .num_stock{font-weight:normal;font-size:16px;font-family:tahoma,arial,sans-serif;letter-spacing:-0.03em}
# .today_layer .num_status{padding-left:3px;font-size:12px;letter-spacing:0}
# .today_layer .num_status .ico_arrow{display:inline-block;width:9px;height:10px;margin:10px 3px 0 0;font-size:0;line-height:0;text-indent:-9999px;vertical-align:top}
# .today_layer .stock_up .num_status{color:#e30000}
# .today_layer .stock_down .num_status{color:#118eff}
# .today_layer .stock_up .num_status .ico_arrow{background-position:-120px -150px}
# .today_layer .stock_down .num_status .ico_arrow{background-position:-130px -150px}
# .today_layer .stock_stay .num_status .ico_arrow{background-position:-140px -150px}
# .today_layer .layer_foot{overflow:hidden;padding-right:14px;height:32px;border-top:1px solid #ececec;background-color:#fbfbfb;text-align:right}
# .today_layer .layer_foot .link_today{display:inline-block;height:32px;padding-right:8px;margin-left:8px;font-size:11px;line-height:29px;color:#888;background-position:100% -12px}
# .os_mac .today_layer .link_stock{padding-top:14px}
# .os_mac .today_layer .num_stock{font-family:helvetica,arial,sans-serif}
# .os_mac .today_layer .num_status .ico_arrow{margin:9px 4px 0 0}
# .os_mac .today_layer .layer_foot .link_today{padding-right:7px;margin-left:7px;line-height:31px;background-position:100% -13px}
# .advert_tmp{float:left;position:relative;width:655px;height:120px;margin-right:35px}
# .advert_tmp .bg_line{position:absolute;top:0;left:0;z-index:-1;width:653px;height:118px;border:1px solid #ececec}
# .advert_station{display:inline-block;position:relative;width:300px;height:150px;margin-top:20px;font-size:0;line-height:0;vertical-align:top}
# .advert_station .bg_line{position:absolute;top:0;left:0;z-index:-1;width:298px;height:148px;border:1px solid #ececec}
# .box_shopping{display:inline-block;position:relative;width:300px;height:1193px;margin-top:20px;vertical-align:top}
# .box_shopping .bg_line1{position:absolute;top:0;left:0;z-index:-1;width:298px;height:781px;border:1px solid #ececec}
# .box_shopping .bg_line2{position:absolute;top:802px;left:0;z-index:-1;width:298px;height:389px;border:1px solid #ececec}
# .advert_svcbnr{margin-top:20px}
# .advert_svcbnr .link_bnr{display:block;position:relative;height:60px}
# .advert_svcbnr .frame_g{width:298px;height:58px}
# .advert_bnr{margin-top:20px}
# .advert_bnr .link_bnr{display:block;position:relative;height:272px}
# .advert_bnr .frame_g{width:298px;height:270px}
# .wrap_tiercont{position:relative;z-index:99;width:990px;margin:0 auto}
# .login_tmp{position:absolute;top:0;right:0;z-index:0;width:300px;height:120px;letter-spacing:-1px}
# .login_my{z-index:10;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat 0 0}
# .login_my .wrap_my{width:285px;height:45px;padding:15px 0 17px 15px}
# .login_my .info_my{float:left;padding:1px 0 0 10px}
# .login_my .rel_my{float:right;padding-right:15px}
# .login_my .name_user{float:left;margin-right:4px;font-weight:bold}
# .login_my .link_myinfo{float:left;font-size:11px;margin:2px 2px 0 0;line-height:14px;color:#555;text-decoration:underline}
# .login_my .profile_img{float:left;position:relative;width:45px;height:45px;margin-top:1px;background-position:-310px -150px}
# .login_my .profile_img .bg_frame{position:absolute;left:0;top:0;width:45px;height:45px;background-position:-360px -150px}
# .login_my .link_privacy{float:left;width:13px;height:15px;margin-top:3px;background-position:-160px -40px;text-indent:-9999px}
# .login_my .link_empathy{float:left;margin:5px 8px 0 0;font-size:11px;line-height:14px;color:#5b6473}
# .login_my .btn_logout{float:left;width:56px;height:24px;font-size:11px;line-height:24px;background-position:-180px -30px;background-color:transparent}
# .login_my .list_basis{overflow:hidden;position:absolute;left:70px;top:42px;height:31px;letter-spacing:-0.12em}
# .login_my .list_basis li{float:left;padding-right:8px;line-height:15px}
# .login_my .list_basis .link_basis{float:left;font-size:12px;color:#555}
# .login_my .list_basis .num_basis{margin-left:3px;color:#118eff}
# .login_my .list_basis .num_msg{width:30px}
# .login_my .list_basis .link_num{font-weight:bold;color:#118eff}
# .login_my .my_mileage .link_basis{margin-right:8px}
# .login_my .wrap_mysvc{position:relative;z-index:10;width:300px}
# .mysvc_list{position:relative;width:300px;height:43px}
# .list_mysvc{display:inline-block;position:relative;width:300px;height:43px;vertical-align:top;letter-spacing:-1px}
# .list_mysvc li{position:relative;float:left;width:100px;height:43px}
# .list_mysvc .link_mysvc{display:block;overflow:hidden;height:31px;padding-top:12px;font-size:12px;line-height:18px;text-align:center;color:#555}
# .list_mysvc .link_mysvc:hover{text-decoration:none}
# .list_mysvc .cafe_g .link_mysvc{height:30px;padding-top:13px;line-height:16px}
# .list_mysvc .txt_mysvc{display:inline-block;height:26px;color:#555;vertical-align:top}
# .list_mysvc .cafe_g .txt_mysvc{padding-left:24px;background-position:0 -80px}
# .list_mysvc .stock_g .txt_mysvc{padding-left:27px;background-position:0 -109px}
# .list_mysvc .blog_g .txt_mysvc{padding-left:29px;background-position:0 -139px}
# .list_mysvc .ico_new{display:none;width:11px;height:11px;margin:5px 0 0 4px;background-position:-160px -80px;text-indent:-9999px;vertical-align:top}
# .list_mysvc .new_g .ico_new{display:inline-block}
# .list_mysvc .cafe_g .ico_new{margin-top:4px}
# .mycafe_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px 0}
# .mystock_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px -50px}
# .myblog_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px -100px}
# .layer_mycont{position:absolute;top:120px;left:0;width:300px;height:353px;background-position:0 -130px}
# .layer_mycont .btn_close{position:absolute;top:320px;right:0;width:46px;height:32px;padding:3px 0 4px;font-size:11px;line-height:18px;color:#888}
# .os_mac .login_tmp{letter-spacing:0}
# .os_mac .login_my .info_my{padding-top:4px}
# .os_mac .login_my .name_user{margin-right:6px}
# .os_mac .login_my .link_privacy{margin-top:0}
# .os_mac .login_my .list_basis{top:45px;letter-spacing:0}
# .os_mac .list_basis li{padding-right:9px}
# .os_mac .list_mysvc .link_mysvc{line-height:21px}
# .os_mac .cafe_g .link_mysvc{line-height:20px}
# .os_mac .list_mysvc .ico_new{margin-top:4px}
# .os_mac .cafe_g .ico_new{margin-top:3px}
# .os_mac .layer_mycont .btn_close{padding-top:5px}
# .tag_live{width:30px;height:15px;background-position:-120px -70px}
# .tag_new{width:31px;height:15px;background-position:-120px -90px}
# .tag_event{width:40px;height:15px;background-position:-120px -110px}
# .tag_issue{width:37px;height:15px;background-position:-120px -130px}
# .list_thumb{overflow:hidden}
# .list_thumb li{float:left;width:152px;height:160px;margin-left:16px}
# .list_thumb .fst{margin-left:0}
# .list_thumb .lst{margin-left:15px}
# .list_thumb .link_item{display:block}
# .list_thumb .thumb_g{width:152px;height:100px}
# .list_thumb .frame_g{width:150px;height:98px}
# .list_thumb .cont_item{margin:6px 2px 0}
# .list_thumb .tit_item{display:block;overflow:hidden;max-height:36px;font-weight:normal;line-height:18px;word-break:keep-all;word-wrap:break-word}
# .list_txt{float:left}
# .list_txt li{overflow:hidden;height:20px;padding-top:3px;white-space:nowrap;text-overflow:ellipsis}
# .list_txt .split_txt{padding-left:10px;margin-left:10px;color:#888;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_vert.png) 0 -50px}
# .list_txt .split_txt:hover{color:#118eff}
# .list_txt .part_mid{padding-top:13px;line-height:16px}
# .list_txt .part_mid .split_part{display:inline-block;overflow:hidden;vertical-align:top}
# .list_txt .part_mid .ico_pctop{display:inline-block;margin:3px 4px 0 0;text-indent:-9999px;vertical-align:top}
# .list_txt .part_mid .link_txt{margin-right:3px}
# .os_mac .list_thumb .cont_item{margin-top:7px}
# .os_mac .list_txt li{line-height:20px}
# .os_mac .list_txt .part_mid{line-height:22px}
# .os_mac .list_txt .part_mid .split_part{letter-spacing:-0.03em}
# .os_mac .list_txt .part_mid .link_txt{margin-right:7px}
# .news_prime .list_txt li{width:318px;padding-left:2px}
# .group_news{display:inline-block;height:320px;vertical-align:top}
# .box_issue{float:left;position:relative;width:320px;height:290px;margin-right:15px}
# .box_issue .link_issue{display:block;position:relative;height:290px}
# .box_issue .frame_g{width:318px;height:288px}
# .box_issue .cover_g{position:absolute;left:0;bottom:0;width:320px;height:128px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate1.png) 0 100%}
# .box_issue .cont_item{overflow:hidden;position:absolute;left:0;width:320px}
# .box_issue .link_issue .cont_item{bottom:20px}
# .box_issue .link_issue .tit_item{display:block;overflow:hidden;max-height:44px;padding:0 21px;font-weight:normal;font-size:16px;line-height:22px;color:#fff}
# .special_issue .tit_issue{overflow:hidden;position:absolute;top:25px;left:21px;max-height:60px;padding-right:20px;font-size:22px;color:#fff}
# .special_issue .cont_item{bottom:22px}
# .special_issue .list_item li{overflow:hidden;margin:3px 20px 0;font-size:13px}
# .special_issue .list_item li.fst{font-weight:bold;font-size:16px;line-height:26px}
# .special_issue .list_item .link_item{display:block;overflow:hidden;color:#fff;white-space:nowrap;text-overflow:ellipsis}
# .os_mac .box_issue .link_issue .cont_item{bottom:16px}
# .os_mac .special_issue .cont_item{bottom:19px}
# .box_sector{float:left;width:320px;margin-right:15px}
# .link_sector{display:block;position:relative;width:320px;height:136px;margin-bottom:24px}
# .link_sector .frame_g{width:318px;height:134px}
# .link_sector .ico_label{height:22px;font-size:11px;line-height:19px}
# .link_sector .cont_item{position:absolute;left:0;bottom:0;width:320px;height:100px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate2.png) no-repeat 0 100%}
# .link_sector .tit_item{overflow:hidden;position:absolute;left:0;bottom:18px;right:0;padding:0 21px;font-weight:normal;font-size:13px;color:#fff;white-space:nowrap;text-overflow:ellipsis}
# .os_mac .link_sector .ico_label{line-height:23px}
# .os_mac .link_sector .tit_item{bottom:16px}
# .section_media{position:relative}
# .media_bloc{position:relative;width:655px;height:522px;padding-top:58px}
# .media_bloc .wrap_tabcont{width:655px;height:522px}
# .media_bloc .news_prime{width:655px;height:480px}
# .media_bloc .tit_tabcont{top:11px;left:0}
# .media_bloc .tit_news{left:-10px}
# .media_bloc .tit_entertain{left:70px}
# .media_bloc .tit_sports{left:120px}
# .media_bloc .tit_movie{left:180px}
# .media_bloc .tit_auto{left:227px}
# .media_bloc .tit_realestate{left:287px}
# .media_bloc .tit_tabcont .link_tit{display:block;height:36px;line-height:36px;background-color:transparent;text-align:center}
# .media_bloc .tit_news .link_tit{width:43px;background-position:0 0}
# .media_bloc .tit_entertain .link_tit{width:50px;background-position:-50px 0}
# .media_bloc .tit_sports .link_tit{width:60px;background-position:-100px 0}
# .media_bloc .tit_movie .link_tit{width:47px;background-position:-160px 0}
# .media_bloc .tit_auto .link_tit{width:60px;background-position:-207px 0}
# .media_bloc .tit_realestate .link_tit{width:60px;background-position:-267px 0}
# .news_on .tit_news .link_tit{background-position:0 -40px}
# .entertain_on .tit_entertain .link_tit{background-position:-50px -40px}
# .sports_on .tit_sports .link_tit{background-position:-100px -40px}
# .movie_on .tit_movie .link_tit{background-position:-160px -40px}
# .auto_on .tit_auto .link_tit{background-position:-207px -40px}
# .realestate_on .tit_realestate .link_tit{background-position:-267px -40px}
# .news_on .wrap_news, .entertain_on .wrap_entertain, .sports_on .wrap_sports, .movie_on .wrap_movie, .auto_on .wrap_auto, .realestate_on .wrap_realestate{display:block}
# .news_flow{overflow:hidden;position:relative;width:655px;height:40px;border-top:1px solid #ececec;border-bottom:1px solid #ececec;line-height:35px}
# .unit_home{float:left}
# .unit_home .tit_home{float:left;margin-right:12px}
# .unit_home .tit_home .link_home{padding-right:7px;background-position:100% 6px}
# .unit_home .list_home{float:left}
# .unit_home .list_home li{float:left;padding:0 7px}
# .unit_home .list_home .link_home{color:#555}
# .unit_home .link_home:hover{color:#118eff}
# .unit_live{float:left;padding-left:25px}
# .unit_live .ico_pctop{float:left;margin:12px 6px 0 0;text-indent:-9999px}
# .unit_live .link_live{margin-right:5px;color:#555}
# .unit_live .link_live:hover{color:#118eff}
# .news_flow .link_hash{padding:0 7px;color:#118eff}
# .page_pctop{position:absolute;right:0;bottom:11px}
# .page_pctop .info_page{float:left;padding:1px 8px 0 0;line-height:16px;color:#888;font-family:tahoma,arial,sans-serif}
# .page_pctop .info_page .num_index{font-weight:normal;color:#555}
# .page_pctop .info_page .txt_slash{padding:0 2px}
# .page_pctop .btn_page{float:left;width:20px;height:20px;line-height:20px;background-color:transparent;background-position:-160px 0}
# .page_pctop .btn_next{width:19px;background-position:-180px 0}
# .page_tabcont{position:absolute;z-index:1;top:23px;left:34px}
# .page_tabcont .btn_page{overflow:hidden;float:left;width:10px;height:10px;margin:0 1px;font-size:10px;line-height:12px;background-position:-100px -170px;background-color:transparent}
# .page_tabcont .on{position:relative;background-position:-100px -180px}
# .os_mac .news_flow{line-height:40px}
# .os_mac .unit_home .tit_home{margin-right:16px}
# .os_mac .unit_home .tit_home .link_home{padding-right:9px;background-position:100% 3px}
# .os_mac .page_pctop .info_page{line-height:19px;font-family:helvetica,arial,sans-serif}
# .ranking_news{overflow:hidden;padding-top:23px}
# .ranking_news.fst{padding-top:35px;border-top:1px solid #ececec}
# .ranking_news .box_ranking{float:left;width:320px}
# .ranking_news .box_ranking.fst{margin-right:15px}
# .ranking_news .tit_ranking{height:21px;font-size:14px;line-height:21px;color:#118eff}
# .ranking_news .tit_ranking .ico_pctop{display:inline-block;font-size:0;line-height:0;text-indent:-9999px;vertical-align:top}
# .ranking_news .tit_ranking .ico_chat{width:15px;height:12px;margin:5px 0 0 4px;background-position:-170px -140px}
# .ranking_news .tit_ranking .ico_share{width:14px;height:12px;margin:6px 0 0 4px;background-position:-170px -160px}
# .tab_ranking{overflow:hidden;margin:10px 0 2px}
# .tab_ranking li{float:left;margin-right:6px}
# .tab_ranking .link_tit{display:block;overflow:hidden;padding-left:10px;height:26px;font-size:12px;line-height:24px;color:#888;background-position:-510px -150px;background-color:#fff;text-align:center;cursor:pointer;white-space:nowrap}
# .tab_ranking .link_tit .inner_tit{display:inline-block;height:26px;padding-right:10px;background-position:100% -150px;background-color:#fff;vertical-align:top}
# .tab_ranking .on .link_tit{font-weight:bold;color:#222;background-position:-510px -180px}
# .tab_ranking .on .link_tit .inner_tit{background-position:100% -180px}
# .tab_ranking .tab_click1 .inner_tit{width:30px}
# .tab_ranking .tab_click2 .inner_tit{width:30px}
# .tab_ranking .tab_click3 .link_tit{padding-left:4px}
# .tab_ranking .tab_click3 .inner_tit{width:43px;padding-right:3px}
# .tab_ranking .tab_click4 .inner_tit{width:30px}
# .tab_ranking .tab_age1 .link_tit{padding-left:7px}
# .tab_ranking .tab_age1 .inner_tit{width:47px;padding-right:5px}
# .tab_ranking .tab_age2 .inner_tit{width:30px}
# .tab_ranking .tab_age3 .inner_tit{width:30px}
# .tab_ranking .tab_age4 .link_tit{padding-left:7px}
# .tab_ranking .tab_age4 .inner_tit{width:48px;padding-right:4px}
# .tab_ranking .tab_age5 .inner_tit{width:30px}
# .tab_ranking .link_tit .ico_pctop{display:inline-block;width:7px;height:10px;margin-top:8px;font-size:0;line-height:0;text-indent:-9999px;vertical-align:top}
# .tab_ranking .link_tit .ico_down{background-position:-70px -150px}
# .tab_ranking .link_tit .ico_up{background-position:-60px -150px}
# .tab_ranking .on .link_tit .ico_down{background-position:-90px -150px}
# .tab_ranking .on .link_tit .ico_up{background-position:-80px -150px}
# .cont_ranking{display:none;overflow:hidden}
# .cont_ranking.on{display:block}
# .ranking_news .list_ranking{margin-top:12px}
# .ranking_news .list_ranking li{height:16px;margin-bottom:12px;line-height:16px}
# .ranking_news .link_ranking{display:block;overflow:hidden}
# .ranking_news .txt_ranking{overflow:hidden;float:left;width:290px;white-space:nowrap;text-overflow:ellipsis}
# .ranking_news .num_pctop{float:left;width:16px;height:16px;margin:2px 6px 0 0;text-indent:-9999px;vertical-align:top}
# .ranking_news .num1{background-position:0 0}
# .ranking_news .num2{background-position:0 -20px}
# .ranking_news .num3{background-position:0 -40px}
# .ranking_news .num4{background-position:0 -60px}
# .ranking_news .num5{background-position:0 -80px}
# .os_mac .ranking_news .tit_ranking{line-height:25px}
# .os_mac .tab_ranking .link_tit{line-height:29px}
# .os_mac .ranking_news .list_ranking li{line-height:22px}
# .cast_sports{position:relative;width:320px;margin-bottom:20px}
# .cast_sports .head_cast{height:44px;border:1px solid #ececec;background-color:#fbfbfb}
# .cast_sports .tit_cast{font-size:13px;margin:10px 0 0 11px}
# .cast_sports .page_pctop{top:14px;right:14px;bottom:auto}
# .cast_sports .page_pctop .btn_page{width:16px;height:16px;line-height:16px;background-position:-210px 0}
# .cast_sports .page_pctop .btn_next{width:15px;background-position:-226px 0}
# .cast_sports .link_more{position:absolute;top:14px;right:14px;padding-right:7px;font-size:11px;color:#888;background-position:100% -18px}
# .list_relay{width:318px;border:1px solid #ececec;border-top:0 none}
# .list_relay li{overflow:hidden}
# .list_relay .link_relay:hover{color:#222;text-decoration:none}
# .list_relay .txt_team{overflow:hidden;font-size:12px;line-height:26px;white-space:nowrap;text-overflow:ellipsis}
# .list_relay .txt_time{float:left;font-size:11px;font-family:tahoma,arial,sans-serif;letter-spacing:0}
# .list_relay .txt_league{float:left;padding-left:3px;font-size:11px;color:#888}
# .list_relay .txt_score .inner_score{display:inline-block;vertical-align:top}
# .list_relay .txt_score .num_pctop{float:left;width:11px;height:16px;background-color:transparent}
# .list_relay .txt_score .num0{background-position:-60px 0}
# .list_relay .txt_score .num1{background-position:-60px -20px}
# ...
# .election_type2 .vote_dday .num3{width:9px;background-position:-80px 0}
# .election_type2 .vote_dday .num4{width:9px;background-position:-100px 0}
# .election_type2 .vote_dday .num5{width:9px;background-position:-120px 0}
# .election_type2 .vote_dday .num6{width:9px;background-position:-140px 0}
# .election_type2 .vote_dday .num7{width:9px;background-position:-160px 0}
# .election_type2 .vote_dday .num8{width:9px;background-position:-180px 0}
# .election_type2 .vote_dday .num9{width:9px;background-position:-200px 0}
# .election_type2 .tit_headline{width:138px;height:19px;background-position:0 -48px}
# .election_type2 .csat_notice{overflow:hidden;position:relative;height:22px;padding-top:43px}
# .election_type2 .csat_notice .link_notice{display:block;overflow:hidden;font-size:16px;line-height:22px;color:#fff;text-overflow:ellipsis;white-space:nowrap}
# .election_type2 .more_csat{padding-top:2px}
# .election_type2 .link_thumb,.election_type2 .link_thumb .cover_g{height:100px}
# .election_type2 .link_thumb .frame_g{height:98px}
# .election_type2 .list_img{height:100px}
# .election_type3{width:653px;min-height:289px;border:1px solid #dae2f6;border-top:0 none;background-color:#e7edfd}
# .election_type3:after{display:block;visibility:hidden;height:0;font-size:0;clear:both;content:''}
# .election_type3 .issue_head{overflow:hidden;height:51px;margin:0 -1px 17px;background-position:0 -140px}
# .election_type3 .tit_headline{overflow:hidden;width:auto;height:51px;padding:0}
# .election_type3 .txt_headline{float:left;width:154px;height:51px;background-position:0 -150px}
# .election_type3 .txt_win{overflow:hidden;float:left;width:66px;height:51px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/txt_win_s_170504.png) no-repeat;text-indent:-9999px}
# .election_type3 .txt_mji{background-position:0 0}
# .election_type3 .txt_acs{background-position:0 -60px}
# .election_type3 .txt_hjp{background-position:0 -120px}
# .election_type3 .more_csat{float:left;padding:14px 0 0 146px;letter-spacing:-0.05em}
# .os_mac .election_type3 .more_csat{padding-top:16px}
# .election_type3 .link_csat{color:#fff}
# .election_type3 .link_csat .ico_live{display:inline;float:left;width:30px;height:15px;margin:4px 6px 0 2px;background-position:0 -220px}
# .os_mac .election_type3 .link_csat .ico_live{margin-top:2px}
# .election_type3 .issue_thumb{float:left;padding:0 15px 19px 19px}
# .election_type3 .issue_thumb .list_img{width:300px;height:202px}
# .election_type3 .link_thumb{width:300px;height:202px}
# .election_type3 .link_thumb .frame_g{width:298px;height:200px}
# .election_type3 .link_thumb .cover_g{width:300px;height:202px;background-position:100% 100%}
# .election_type3 .link_thumb .cont_item{bottom:14px}
# .election_type3 .link_thumb .tit_item{padding-right:56px;padding-left:20px;font-size:16px;line-height:22px;white-space:normal}
# .election_type3 .link_thumb .ico_pctop{right:16px;bottom:16px}
# .election_type3 .list_txt li{width:300px}
# .election_type3 .list_txt .part_mid{padding-top:18px}
# .election_type3 .state_info{position:absolute;top:14px;right:20px;width:auto;height:22px;font-size:11px;line-height:19px;color:#fdee3a}
# .os_mac .election_type3 .state_info{line-height:25px}
# .election_type3 .state_info .link_state{display:inline-block;color:#fdee3a;text-decoration:none;vertical-align:top}
# .election_type3 .txt_time{color:#ebecff;opacity:0.5;filter:alpha(opacity=50)}
# .election_type3 .state_info .count_rate{display:inline-block;overflow:hidden;margin:1px 67px 0 3px;vertical-align:top}
# .election_type3 .state_info .count_rate .img_election{float:left;width:16px;height:21px}
# .election_type3 .state_info .count_rate .ico_dot{width:5px;margin:0 1px;background-position:-200px -280px}
# .election_type3 .state_info .count_rate .ico_per{width:12px;background-position:-220px -280px}
# .election_type3 .state_info .count_rate .num0{background-position:0 -280px}
# .election_type3 .state_info .count_rate .num1{width:12px;background-position:-21px -280px}
# .election_type3 .state_info .count_rate .num2{background-position:-39px -280px}
# .election_type3 .state_info .count_rate .num3{background-position:-59px -280px}
# .election_type3 .state_info .count_rate .num4{background-position:-80px -280px}
# .election_type3 .state_info .count_rate .num5{background-position:-99px -280px}
# .election_type3 .state_info .count_rate .num6{background-position:-119px -280px}
# .election_type3 .state_info .count_rate .num7{background-position:-139px -280px}
# .election_type3 .state_info .count_rate .num8{background-position:-159px -280px}
# .election_type3 .state_info .count_rate .num9{background-position:-179px -280px}
# .election_type3 .balloon_g{position:absolute;top:0;right:0}
# .election_type3 .balloon_g .img_election{height:22px}
# .election_type3 .balloon_info .img_election{width:62px;background-position:-260px 0}
# .election_type3 .balloon_start .img_election{width:62px;background-position:-260px -30px}
# .election_type3 .balloon_voting .img_election{width:54px;background-position:-260px -60px}
# .election_type3 .balloon_done .img_election{width:62px;background-position:-260px -90px}
# .election_type3 .balloon_rating .img_election{width:54px;background-position:-260px -120px}
# .election_type3 .balloon_end .img_election{width:62px;background-position:-330px 0}
# .election_type3 .balloon_win .img_election{width:62px;background-position:-330px -30px}
# .election_type3 .balloon_voting .count_rate, .election_type3 .balloon_rating .count_rate{margin-right:59px}
# .election_type3 .list_txt2{padding:16px 0 17px 17px}
# .os_mac .election_type3 .list_txt2{padding-top:18px}
# .election_type3 .list_txt2 li{float:left;width:305px;padding-right:9px}
# .election_type3 .issue_head2 .txt_headline{width:130px;margin-right:6px}
# .election_type3 .issue_head2 .more_csat{padding-left:194px}
# .issue_candidate{margin-top:-17px}
# .issue_candidate .link_state{display:block;overflow:hidden;height:90px;padding-top:21px}
# .info_rating{position:relative;z-index:0;height:90px;margin:0 19px}
# .info_rating dd{float:left;position:relative;z-index:0;width:307px;height:90px;color:#fff}
# .info_rating .item_rating {display:table;position:absolute;top:14px;right:0;z-index:1;width:67px;height:62px;margin-right:-34px;line-height:62px;text-align:center;background-color:#292b48;background-color:rgba(41,43,72,.9)}
# .info_rating .item_rating .inner_g{display:table-cell;min-width:59px;padding:6px 4px;line-height:1.12;vertical-align:middle}
# .os_mac .info_rating .item_rating .inner_g{padding-top:9px}
# .info_rating .item_rating .txt_info{display:block;line-height:15px;opacity:0.5;filter:alpha(opacity=50)}
# .info_rating .item_rating .txt_vote{padding-top:0;line-height:12px}
# .info_rating .tit_rating{display:block;padding-bottom:3px;font-weight:normal;font-size:14px;line-height:15px;color:#fdee3a}
# .info_rating .txt_info{font-size:11px;line-height:14px;color:#ebecff}
# .info_rating .txt_vote{display:block;font-size:12px;color:#fff}
# .info_rating .txt_perp{display:block;padding-top:4px;*padding-bottom:2px;font-size:11px;color:#fff;opacity:0.5;filter:alpha(opacity=50)}
# .info_rating .img_thumb{position:absolute;bottom:0}
# .info_rating .cont_rating{position:absolute;top:0;height:100%}
# .info_rating .inner_rating{display:inline-block;padding-top:16px;font-size:14px;line-height:17px;vertical-align:top}
# .info_rating .tit_name{display:inline;width:auto;padding-bottom:1px;white-space:nowrap;vertical-align:top;text-align:left}
# .info_rating .txt_party{display:inline-block;padding-top:1px;font-size:11px;opacity:0.7;filter:alpha(opacity=70);vertical-align:top}
# .info_rating .count_rate{display:block;height:32px;padding:3px 0 5px}
# .info_rating .count_rate .img_election{display:inline;float:left;width:21px;height:30px;text-align:left}
# .info_rating .count_rate .ico_dot{width:6px;margin:0 4px 0 3px;background-position:-300px -320px}
# .info_rating .count_rate .ico_per{width:13px;margin-left:1px;background-position:-330px -320px}
# .info_rating .count_rate .num0{background-position:0 -320px}
# .info_rating .count_rate .num1{background-position:-30px -320px}
# .info_rating .count_rate .num2{background-position:-60px -320px}
# .info_rating .count_rate .num3{background-position:-90px -320px}
# .info_rating .count_rate .num4{background-position:-120px -320px}
# .info_rating .count_rate .num5{background-position:-150px -320px}
# .info_rating .count_rate .num6{background-position:-180px -320px}
# .info_rating .count_rate .num7{background-position:-210px -320px}
# .info_rating .count_rate .num8{background-position:-240px -320px}
# .info_rating .count_rate .num9{background-position:-270px -320px}
# .info_rating .item_rate1{z-index:1;}
# .info_rating .item_rate1:after{position:absolute;top:0;right:0;width:1px;height:90px;background-color:#e7edfd;content:''}
# .info_rating .item_rate1 .count_rate{*width:160px}
# .info_rating .item_rate1 .img_thumb{left:0}
# .info_rating .item_rate1 .cont_rating{left:111px}
# .info_rating .item_rate1 .txt_party{padding-left:5px}
# .info_rating .item_rate1 .txt_g{float:left}
# .info_rating .item_rate2{text-align:right}
# .info_rating .item_rate2 .img_thumb{right:0}
# .info_rating .item_rate2 .cont_rating{right:105px}
# .info_rating .item_rate2 .txt_party{padding-right:5px;*padding-right:0}
# .info_rating .item_rate2 .txt_g{float:right}
# .info_rating2 .item_rating{width:87px;margin-right:-43px}
# .info_rating2 .count_rate{overflow:visible;position:absolute;top:19px;padding:0}
# .info_rating2 .inner_rating{display:block;padding-top:57px}
# .info_rating2 .inner_rating .txt_vote{padding-top:2px}
# .info_rating2 .item_rate1 .cont_rating{left:70px;right:54px}
# .info_rating2 .item_rate1 .count_rate{right:0}
# .info_rating2 .item_rate1 .inner_rating .txt_vote{float:right}
# .info_rating2 .item_rate2 .cont_rating{right:70px;left:54px}
# .info_rating2 .item_rate2 .count_rate{left:0}
# .info_rating2 .item_rate2 .inner_rating .txt_vote{float:left}
# .info_rating2 .item_rate1 .tit_name{float:left}
# .info_rating2 .item_rate2 .tit_name{float:right;max-width:82px}
# .info_rating .state_result{float:right;width:38px;height:38px;margin-left:10px}
# .info_rating .state_result .img_election{width:38px;height:38px;margin-top:-4px}
# .info_rating .state_result .ico_tour{background-position:-180px -150px}
# .info_rating .state_result .ico_sure{background-position:-225px -150px}
# .info_rating .state_result .ico_confirm{background-position:-270px -150px}
# .info_rating .state_result .ico_win{width:43px;height:43px;margin:-5px 0 0 -3px;background-position:-315px -150px}
# .info_rating2 .state_result{float:left;margin-left:0;margin-right:8px}
# .info_rating2 .state_result .img_election{margin-top:-5px}
# .info_rating2 .state_result .ico_win{margin-top:-6px;margin-left:-4px}
# .info_rating .party_win{width:338px}
# .info_rating .party_loss{width:277px}
# .state_local {overflow:hidden;height:49px;margin:0 19px -4px;border-bottom:1px solid #b9c1d6}
# .state_local .link_local{display:block;overflow:hidden;width:100%;height:49px}
# .state_local .local_head{float:left;width:90px;text-indent:2px}
# .state_local .tit_local{display:block;padding-top:11px;font-size:13px;line-height:17px;color:#222}
# .os_mac .state_local .tit_local{padding-top:13px}
# .state_local .txt_p{display:block;font-size:11px;color:#222;letter-spacing:-1px}
# .state_local .txt_p .num_p{letter-spacing:0}
# .state_local .list_rank{float:none;overflow:hidden}
# .state_local .list_rank li{float:left;width:175px}
# .state_local .rank_g{overflow:hidden;position:absolute;top:14px;left:0;width:15px;height:15px;border-radius:1px}
# .state_local .rank_g .img_election{width:15px;height:15px}
# .state_local .rank_g .ico_rank1{background-position:-40px -220px}
# .state_local .rank_g .ico_rank2{background-position:-60px -220px}
# .state_local .rank_g .ico_rank3{background-position:-80px -220px}
# .state_local .cont_local{display:block;position:relative;padding:0 4px 0 16px}
# .state_local .tit_name{display:block;overflow:hidden;padding:13px 0 2px;font-weight:normal;font-size:11px;line-height:15px;color:#222;white-space:nowrap;text-overflow:ellipsis}
# .state_local .txt_party{color:#9fa6b9}
# .state_local .img_thumb{float:left;margin-top:9px}
# .state_local .count_rate{display:block;overflow:hidden}
# .state_local .count_rate .img_election{display:inline;float:left;width:9px;height:13px}
# .state_local .count_rate .ico_dot{width:3px;margin:0 1px;background-position:-200px -250px}
# .state_local .count_rate .ico_per{background-position:-220px -250px}
# .state_local .count_rate .num0{background-position:0 -250px}
# .state_local .count_rate .num1{width:8px;background-position:-21px -250px}
# .state_local .count_rate .num2{background-position:-40px -250px}
# .state_local .count_rate .num3{background-position:-60px -250px}
# .state_local .count_rate .num4{background-position:-80px -250px}
# .state_local .count_rate .num5{background-position:-100px -250px}
# .state_local .count_rate .num6{background-position:-120px -250px}
# .state_local .count_rate .num7{background-position:-140px -250px}
# .state_local .count_rate .num8{background-position:-160px -250px}
# .state_local .count_rate .num9{background-position:-180px -250px}
# .election_result{overflow:visible;position:relative;z-index:0;border-color:transparent;border-bottom:0 none;background-color:#292b48;clear:both;*zoom:1}
# .election_result:after{display:block;visibility:hidden;height:0;font-size:0;clear:both;content:''}
# .election_result .issue_head{margin-bottom:0}
# .election_result .link_txt{color:#fff}
# .election_result .issue_result{float:left;width:316px;height:239px;padding-left:18px}
# .election_result .issue_result .thumb_result{position:absolute;top:51px;left:-1px;z-index:-1;width:655px;height:239px}
# .election_result .issue_result .tit_result{display:block;padding-top:18px}
# .election_result .issue_result .more_csat{position:absolute;bottom:43px;left:22px;padding:0}
# .election_result .issue_result .link_csat{color:#bec4ff;letter-spacing:0}
# .election_result .issue_result .txt_tiem{position:absolute;bottom:23px;left:22px;font-size:10px;color:#8c8fac}
# .election_result .issue_txt{padding-top:17px}
# .election_result2 .issue_result{height:290px}
# .election_result2 .tit_result{position:absolute;top:25px;left:17px}
# .election_result2 .more_csat{position:absolute;top:122px;left:21px;width:140px;padding:0}
# .election_result2 .link_csat{margin-bottom:3px;text-decoration:underline}
# .election_result2 .cont_item{bottom:13px}
# .election_result2 .list_item li{overflow:hidden;margin:0 21px;font-size:13px}
# .election_result2 .list_item li.fst{font-weight:bold;font-size:16px;line-height:26px}
# .election_result2 .list_item .link_item{display:block;overflow:hidden;color:#fff;white-space:nowrap;text-overflow:ellipsis}
# @media
# only screen and (-webkit-min-device-pixel-ratio: 1.5),
# only screen and (min-device-pixel-ratio: 1.5),
# only screen and (min-resolution: 1.5dppx) {
# .election_issue .img_election{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/img_election_170502_v2.png);background-size:400px 400px}
# .election_issue .link_csat{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/ico_election.png);background-size:6px 9px}
# .election_issue .list_txt .split_txt{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/ico_line.png);background-size:1px 12px}
# .election_type3 .txt_win{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/txt_win_s_170504.png);background-size:100px 200px}
# }
# </style>
# <script type="text/javascript">
# //<![CDATA[
# document.domain = 'daum.net';
# var gvConfGen = 'g0';
# var DT = DT || {};
# DT.SystemTime = 1495631407849;
# var _tiq = [];
# _tiq.push(['__setSection', 'HOME']);
# _tiq.push(['__addParam', 'puid', DT.SystemTime]);
# _tiq.push(['__trackPageview']);
# DT.endTime = new Date().getTime();
# DT.startTime = new Date().getTime();
# (function () {
# if (document.location.toString().indexOf('debug') === -1) {
# window.onerror = function (errorMsg, url, lineNumber) {
# return true;
# };
# }
# })();
# document.onkeydown = function () {
# DT.userAction = true;
# };
# document.onclick = function () {
# DT.userAction = true;
# };
# //]]>
# </script>
# </link></meta></meta></meta></meta></meta></meta></meta></meta></meta></head>

# %%
bsObj.html.title
# Out:
# <title>Daum</title>

# %%
bsObj.div
# Out:
# <div class="d_index" id="daumIndex">
# <a class="shortcut_g" href="#mainServiceTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">주요 서비스 바로가기</span>
# </a>
# <a class="shortcut_g" href="#todayInfoTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">오늘의 정보 바로가기</span>
# </a>
# <a class="shortcut_g" href="#mediaTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">미디어 바로가기</span>
# </a>
# <a class="shortcut_g" href="#liveIssueTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">실시간 이슈 바로가기</span>
# </a>
# <a class="shortcut_g" href="#multiMediaTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">멀티미디어 바로가기</span>
# </a>
# <a class="shortcut_g" href="#blogTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">블로그 정보 바로가기</span>
# </a>
# <a class="shortcut_g" href="#storyTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">유익한 정보 바로가기</span>
# </a>
# <a class="shortcut_g" href="#shoppingTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">쇼핑 바로가기</span>
# </a>
# <a class="shortcut_g" href="#photoClipTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">오늘의 포토&amp;영상 바로가기</span>
# </a>
# <a class="shortcut_g" href="/doc/top_accessibility.html" id="topAccessibility" tabindex="12">
# <span class="ico_vert inner_shortcut">웹 접근성 안내</span>
# </a>
# <a class="shortcut_g" href="/doc/top_accessibility.html#ad" id="topAdAccessibility" tabindex="12">
# <span class="ico_vert inner_shortcut">자동실행 광고 설정</span>
# </a>
# </div>

# %% [markdown]
# ## QUIZ 01
#
# 다음 문제를 해결하여 본문을 성공적으로 긁어오시고 렌더링하세요.
#
#
# 1. http://malware-traffic-analysis.net/2017/index.html 사이트에서 주요 본문 내용만 긁어온다.(메뉴, 사이드바 제외)
# 2. 해당 본문 데이터를 드라이브에 a.html 파일로 [저장](https://docs.python.org/2/tutorial/inputoutput.html)하고,
# 3. 이후 웹페이지를 자동으로 열리도록 [코딩](https://docs.python.org/2/library/webbrowser.html)하라.

# %%
## write your code!!

# %% [markdown]
# ## 2) find()와 findAll()

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen("https://www.naver.com")
bsObj = BeautifulSoup(html.read(), "html.parser")
bsObj.find("a")
# Out:
# <a href="#news_cast" onclick="document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"><span>뉴스스탠드 바로가기</span></a>

# %%
bsObj.findAll("a")
# Out:
# [<a href="#news_cast" onclick="document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"><span>뉴스스탠드 바로가기</span></a>,
#  <a href="#themecast" onclick="document.getElementById('themecast').tabIndex = -1;document.getElementById('themecast').focus();return false;"><span>주제별캐스트 바로가기</span></a>,
#  <a href="#time_square" onclick="document.getElementById('time_square').tabIndex = -1;document.getElementById('time_square').focus();return false;"><span>타임스퀘어 바로가기</span></a>,
#  <a href="#shop_cast" onclick="document.getElementById('shop_cast').tabIndex = -1;document.getElementById('shop_cast').focus();return false;"><span>쇼핑캐스트 바로가기</span></a>,
#  <a href="#account" onclick="document.getElementById('account').tabIndex = -1;document.getElementById('account').focus();return false;"><span>로그인 바로가기</span></a>,
#  <a data-clk="top.logo" href="/"><span class="naver_logo">네이버</span></a>,
#  <a class="al_favorite" data-clk="top.mkhome" href="http://help.naver.com/support/welcomePage/guide.nhn">네이버를 시작페이지로<span class="al_ico_link"></span></a>,
#  <a class="al_jr" data-clk="top.jrnaver" href="http://jr.naver.com"><span class="blind">쥬니어네이버</span><span class="al_ico"></span></a>,
#  <a class="al_happybean" data-clk="top.happybean" href="http://happybean.naver.com/main/SectionMain.nhn"><span class="blind">해피빈</span><span class="al_ico"></span></a>,
#  <a class="btn_arw _btn_arw fold" href="javascript:;" role="button" tabindex="2"><span class="blind _text">자동완성 펼치기</span><span class="ico_arr"></span></a>,
#  <a class="btn_keyboard" data-clk="sch.ime" href="javascript:;" id="ke_kbd_btn" onclick="nx_ime_load(this)" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>,
#  <a href="#" onclick="return false;">@txt@</a>,
#  <a class="spat ico_info" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=16658" onclick="__atcmpCR(event, this, 'plus.help', '','','');" target="_blank"><span class="blind">도움말 보기</span></a>,
#  <a class="btn_turnon active" href="#" onclick="__atcmpCR(event, this, 'plus.use', '','','');">ON<span class="blind">선택됨</span></a>,
#  <a class="btn_turnoff" href="#" onclick="__atcmpCR(event, this, 'plus.unuse', '','','');">OFF</a>,
#  <a class="btn btn_login" href="https://nid.naver.com/nidlogin.login" onclick="__atcmpCR(event, this, 'plus.login', '','','');">로그인</a>,
#  <a class="btn btn_view" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=16658" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>,
#  <a class="btn btn_view" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=16659" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>,
#  <a href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=2028" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=2028" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=2028" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a href="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1987" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=2028" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 켜기</a>,
#  <a href="javascript:;">최근검색어</a>,
#  <a href="javascript:;">내 검색어</a>,
#  <a class="t@my@ _star _myBtn" href="javascript:;" title="내 검색어 등록"><em class="spat">내 검색어 등록</em></a>,
#  <a class="keyword" href="javascript:;">@txt@</a>,
#  <a class="btn_delete spat _del" href="javascript:;" title="검색어삭제">삭제</a>,
#  <a class="ton _star _myBtn" href="javascript:;" title="내 검색어 해제"><em class="spat">내 검색어 해제</em></a>,
#  <a class="keyword" href="javascript:;">@txt@</a>,
#  <a class="_delMode" href="javascript:;">기록 삭제</a>,
#  <a class="_keywordOff" href="javascript:;">검색어저장 끄기</a>,
#  <a class="_acOff" href="javascript:;">자동완성 끄기</a>,
#  <a class="_delAll" href="javascript:;" title="최근 검색어 기록을 모두 삭제합니다.">기록 전체 삭제</a>,
#  <a class="_delDone" href="javascript:;">완료</a>,
#  <a class="_delAll" href="javascript:;" title="설정된 내 검색어를 모두 삭제합니다.">기록 전체 삭제</a>,
#  <a class="_keywordOff" href="javascript:;">검색어저장 끄기</a>,
#  <a class="_acOff" href="javascript:;">자동완성 끄기</a>,
#  <a class="btn_close _close" href="javascript:;"><i class="spat ico_close">닫기</i></a>,
#  <a href="http://naver_diary.blog.me/220982360603" onclick="clickcr(this,'sug.vote','','',event);" target="_blank">자세히보기</a>,
#  <a class="an_a mn_mail" data-clk="svc.mail" href="http://mail.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">메일</span>
#  </a>,
#  <a class="an_a mn_cafe" data-clk="svc.cafe" href="http://section.cafe.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">카페</span>
#  </a>,
#  <a class="an_a mn_blog" data-clk="svc.blog" href="http://section.blog.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">블로그</span>
#  </a>,
#  <a class="an_a mn_kin" data-clk="svc.kin" href="http://kin.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">지식인</span>
#  </a>,
#  <a class="an_a mn_shopping" data-clk="svc.shopping" href="http://shopping2.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">쇼핑</span>
#  </a>,
#  <a class="an_a mn_checkout" data-clk="svc.pay" href="http://pay.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">네이버페이</span>
#  </a>,
#  <a class="an_a mn_tvcast" data-clk="svc.tvcast" href="http://tv.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">네이버TV</span>
#  </a>,
#  <a class="an_a mn_dic" data-clk="svc.dic" href="http://dic.naver.com/"><span class="an_icon"></span><span class="an_txt">사전</span></a>,
#  <a class="an_a mn_news" data-clk="svc.news" href="http://news.naver.com/"><span class="an_icon"></span><span class="an_txt">뉴스</span></a>,
#  <a class="an_a mn_stock" data-clk="svc.stock" href="http://stock.naver.com/"><span class="an_icon"></span><span class="an_txt">증권(금융)</span></a>,
#  <a class="an_a mn_land" data-clk="svc.land" href="http://land.naver.com/"><span class="an_icon"></span><span class="an_txt">부동산</span></a>,
#  <a class="an_a mn_map" data-clk="svc.map" href="http://map.naver.com/"><span class="an_icon"></span><span class="an_txt">지도</span></a>,
#  <a class="an_a mn_movie" data-clk="svc.movie" href="http://movie.naver.com/"><span class="an_icon"></span><span class="an_txt">영화</span></a>,
#  <a class="an_a mn_music" data-clk="svc.music" href="http://music.naver.com"><span class="an_icon"></span><span class="an_txt">뮤직</span></a>,
#  <a class="an_a mn_book" data-clk="svc.book" href="http://book.naver.com/"><span class="an_icon"></span><span class="an_txt">책</span></a>,
#  <a class="an_a mn_comic" data-clk="svc.comic" href="http://comic.naver.com/"><span class="an_icon"></span><span class="an_txt">만화 / 웹툰</span></a>,
#  <a class="PM_CL_btnServiceMore an_btn_more" data-clk="svc.more" href="#" id="PM_ID_btnServiceMore" role="button"><span class="an_mtxt"><span class="blind">더보기</span></span><span class="ico_an_more"></span></a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">1</span>
#  <span class="ah_k">비인두암</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">2</span>
#  <span class="ah_k">김우빈</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">3</span>
#  <span class="ah_k">김무성</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">4</span>
#  <span class="ah_k">수목드라마</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">5</span>
#  <span class="ah_k">일본 우루과이</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">6</span>
#  <span class="ah_k">차우찬</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">7</span>
#  <span class="ah_k">박세리</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">8</span>
#  <span class="ah_k">김무성 캐리어</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">9</span>
#  <span class="ah_k">홍건희</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">10</span>
#  <span class="ah_k">크리샤츄</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">11</span>
#  <span class="ah_k">노 룩 패스</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">12</span>
#  <span class="ah_k">한혜진</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">13</span>
#  <span class="ah_k">캐리비안의 해적 죽은 자는 말이 없다</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">14</span>
#  <span class="ah_k">전국날씨</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">15</span>
#  <span class="ah_k">김무성 패러디</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">16</span>
#  <span class="ah_k">허재</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">17</span>
#  <span class="ah_k">라디오스타</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">18</span>
#  <span class="ah_k">연금복권</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">19</span>
#  <span class="ah_k">SK하이닉스</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">20</span>
#  <span class="ah_k">조현영</span>
#  </a>,
#  <a class="ah_ha" data-clk="lve.rankhistory" href="http://datalab.naver.com/keyword/realtimeList.naver?where=main"><span class="ah_ico_datalab">DataLab.</span>급상승 트래킹<span class="ah_ico_hlink"></span></a>,
#  <a class="ah_tab_btn ah_tab_on" data-clk="lve.tab1" data-tab="1to10" href="#" role="tab">1~10위</a>,
#  <a class="ah_tab_btn" data-clk="lve.tab2" data-tab="11to20" href="#" role="tab">11~20위</a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B9%84%EC%9D%B8%EB%91%90%EC%95%94&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B9%84%EC%9D%B8%EB%91%90%EC%95%94&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">1</span>
#  <span class="ah_k">비인두암</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EB%B9%84%EC%9D%B8%EB%91%90%EC%95%94&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EC%9A%B0%EB%B9%88&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EC%9A%B0%EB%B9%88&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">2</span>
#  <span class="ah_k">김우빈</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EA%B9%80%EC%9A%B0%EB%B9%88&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EB%AC%B4%EC%84%B1&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EB%AC%B4%EC%84%B1&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">3</span>
#  <span class="ah_k">김무성</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EA%B9%80%EB%AC%B4%EC%84%B1&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%88%98%EB%AA%A9%EB%93%9C%EB%9D%BC%EB%A7%88&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%88%98%EB%AA%A9%EB%93%9C%EB%9D%BC%EB%A7%88&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">4</span>
#  <span class="ah_k">수목드라마</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EC%88%98%EB%AA%A9%EB%93%9C%EB%9D%BC%EB%A7%88&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%9D%BC%EB%B3%B8+%EC%9A%B0%EB%A3%A8%EA%B3%BC%EC%9D%B4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%9D%BC%EB%B3%B8+%EC%9A%B0%EB%A3%A8%EA%B3%BC%EC%9D%B4&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">5</span>
#  <span class="ah_k">일본 우루과이</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EC%9D%BC%EB%B3%B8+%EC%9A%B0%EB%A3%A8%EA%B3%BC%EC%9D%B4&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%B0%A8%EC%9A%B0%EC%B0%AC&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%B0%A8%EC%9A%B0%EC%B0%AC&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">6</span>
#  <span class="ah_k">차우찬</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EC%B0%A8%EC%9A%B0%EC%B0%AC&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B0%95%EC%84%B8%EB%A6%AC&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B0%95%EC%84%B8%EB%A6%AC&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">7</span>
#  <span class="ah_k">박세리</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EB%B0%95%EC%84%B8%EB%A6%AC&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EB%AC%B4%EC%84%B1+%EC%BA%90%EB%A6%AC%EC%96%B4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EB%AC%B4%EC%84%B1+%EC%BA%90%EB%A6%AC%EC%96%B4&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">8</span>
#  <span class="ah_k">김무성 캐리어</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EA%B9%80%EB%AC%B4%EC%84%B1+%EC%BA%90%EB%A6%AC%EC%96%B4&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%ED%99%8D%EA%B1%B4%ED%9D%AC&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%ED%99%8D%EA%B1%B4%ED%9D%AC&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">9</span>
#  <span class="ah_k">홍건희</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%ED%99%8D%EA%B1%B4%ED%9D%AC&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%ED%81%AC%EB%A6%AC%EC%83%A4%EC%B8%84&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%ED%81%AC%EB%A6%AC%EC%83%A4%EC%B8%84&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">10</span>
#  <span class="ah_k">크리샤츄</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%ED%81%AC%EB%A6%AC%EC%83%A4%EC%B8%84&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%85%B8+%EB%A3%A9+%ED%8C%A8%EC%8A%A4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%85%B8+%EB%A3%A9+%ED%8C%A8%EC%8A%A4&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">11</span>
#  <span class="ah_k">노 룩 패스</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EB%85%B8+%EB%A3%A9+%ED%8C%A8%EC%8A%A4&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%ED%95%9C%ED%98%9C%EC%A7%84&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%ED%95%9C%ED%98%9C%EC%A7%84&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">12</span>
#  <span class="ah_k">한혜진</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%ED%95%9C%ED%98%9C%EC%A7%84&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%BA%90%EB%A6%AC%EB%B9%84%EC%95%88%EC%9D%98+%ED%95%B4%EC%A0%81+%EC%A3%BD%EC%9D%80+%EC%9E%90%EB%8A%94+%EB%A7%90%EC%9D%B4+%EC%97%86%EB%8B%A4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%BA%90%EB%A6%AC%EB%B9%84%EC%95%88%EC%9D%98+%ED%95%B4%EC%A0%81+%EC%A3%BD%EC%9D%80+%EC%9E%90%EB%8A%94+%EB%A7%90%EC%9D%B4+%EC%97%86%EB%8B%A4&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">13</span>
#  <span class="ah_k">캐리비안의 해적 죽은 자는 말이 없다</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EC%BA%90%EB%A6%AC%EB%B9%84%EC%95%88%EC%9D%98+%ED%95%B4%EC%A0%81+%EC%A3%BD%EC%9D%80+%EC%9E%90%EB%8A%94+%EB%A7%90%EC%9D%B4+%EC%97%86%EB%8B%A4&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A0%84%EA%B5%AD%EB%82%A0%EC%94%A8&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A0%84%EA%B5%AD%EB%82%A0%EC%94%A8&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">14</span>
#  <span class="ah_k">전국날씨</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EC%A0%84%EA%B5%AD%EB%82%A0%EC%94%A8&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EB%AC%B4%EC%84%B1+%ED%8C%A8%EB%9F%AC%EB%94%94&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EB%AC%B4%EC%84%B1+%ED%8C%A8%EB%9F%AC%EB%94%94&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">15</span>
#  <span class="ah_k">김무성 패러디</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EA%B9%80%EB%AC%B4%EC%84%B1+%ED%8C%A8%EB%9F%AC%EB%94%94&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%ED%97%88%EC%9E%AC&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%ED%97%88%EC%9E%AC&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">16</span>
#  <span class="ah_k">허재</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%ED%97%88%EC%9E%AC&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%9D%BC%EB%94%94%EC%98%A4%EC%8A%A4%ED%83%80&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%9D%BC%EB%94%94%EC%98%A4%EC%8A%A4%ED%83%80&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">17</span>
#  <span class="ah_k">라디오스타</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EB%9D%BC%EB%94%94%EC%98%A4%EC%8A%A4%ED%83%80&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%97%B0%EA%B8%88%EB%B3%B5%EA%B6%8C&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%97%B0%EA%B8%88%EB%B3%B5%EA%B6%8C&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">18</span>
#  <span class="ah_k">연금복권</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EC%97%B0%EA%B8%88%EB%B3%B5%EA%B6%8C&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=SK%ED%95%98%EC%9D%B4%EB%8B%89%EC%8A%A4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=SK%ED%95%98%EC%9D%B4%EB%8B%89%EC%8A%A4&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">19</span>
#  <span class="ah_k">SK하이닉스</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=SK%ED%95%98%EC%9D%B4%EB%8B%89%EC%8A%A4&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A1%B0%ED%98%84%EC%98%81&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A1%B0%ED%98%84%EC%98%81&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">20</span>
#  <span class="ah_k">조현영</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-05-24T22:10:00&amp;query=%EC%A1%B0%ED%98%84%EC%98%81&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_btn_help" data-clk="lve.help" data-ssl="https://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1989" href="http://help.naver.com/support/service/main.nhn?serviceNo=606&amp;categoryNo=1989">도움말</a>,
#  <a class="cf_ta" data-clk="ncy.newsflash" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y"><span class="blind">연합뉴스</span></a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009289389">이낙연 도덕성 집중공세…위장전입 인정·아들 병역의혹 부인</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009289542">文대통령, 4强외교 틀 복원…정상회담 준비태세</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009289419">정부조직개편 결국 '최소화'…국정 안정에 방점</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009288925">경찰·소방 등 공무원 1만2천명 연내 더 뽑는다</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009289497">세월호 3층 진흙서 뼛조각 3점 추가 발견</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009288941">'파죽지세' 코스피 3일 연속 사상 최고가 마감</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009289429">교황-트럼프 첫 회동…트럼프 "평화 이용 가능"</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009289632">최순실 "檢, 너무 많은 의혹 제기해 내가 괴물됐다"</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009289573">25일 대구 31도 등 낮에 더워…오후 일부 비</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009289540">진에어 국제선, 전화예약 수수료 5천원…고객불만</a>,
#  <a class="cl_a cl_news" data-clk="ncy.newshome" href="http://news.naver.com/">
#  <span class="blind">네이버뉴스</span>
#  </a>,
#  <a class="cl_a cl_ent" data-clk="ncy.entertainment" href="http://entertain.naver.com/home">
#  <span class="blind">연예</span>
#  </a>,
#  <a class="cl_a cl_sports" data-clk="ncy.sports" href="http://sports.news.naver.com/">
#  <span class="blind">스포츠</span>
#  </a>,
#  <a class="cl_a cl_finance" data-clk="ncy.economy" href="http://news.naver.com/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101">
#  <span class="blind">경제</span>
#  </a>,
#  <a class="cl_a cl_ranking" data-clk="ncy.special2" href="http://news.naver.com/main/ranking/popularDay.nhn?mid=etc&amp;sid1=111">
#  <span class="blind">랭킹</span>
#  </a>,
#  <a class="an_ta" data-clk="nsd.title" href="http://newsstand.naver.com/" target="_blank"><span class="blind">뉴스스탠드</span></a>,
#  <a aria-selected="true" class="as_btn_press _PM_newsstand_total_type is_selected" data-clk="nsd.all" href="#" role="tab"><span class="blind">전체 언론사</span></a>,
#  <a aria-selected="false" class="as_btn_my _PM_newsstand_my_type" data-clk="nsd.my" href="#" role="tab"><span class="blind">MY 뉴스</span></a>,
#  <a aria-selected="true" class="as2_btn _PM_newsstand_thumb_type is_selected" data-clk="nsd.pressview" href="#" role="tab"><i class="as2_btn_ico ico_image"></i><span class="blind">이미지형</span></a>,
#  <a aria-selected="false" class="as2_btn _PM_newsstand_list_type" data-clk="nsd.articleview" href="#" role="tab"><i class="as2_btn_ico ico_list"></i><span class="blind">리스트형</span></a>,
#  <a class="as2_btn" data-clk="nsd.set" href="http://newsstand.naver.com/config.html" target="_blank"><i class="as2_btn_ico ico_setting"></i><span class="blind">설정</span></a>,
#  <a class="ap_btn _PM_newsstand_prev" data-clk="nsd.prev" href="#"><i class="ap_btn_ico ico_left"></i><span class="blind">이전 페이지</span></a>,
#  <a class="ap_btn _PM_newsstand_next" data-clk="nsd.next" href="#"><i class="ap_btn_ico ico_right"></i><span class="blind">다음 페이지</span></a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=020" target="_blank">
#  <img alt="동아일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd14479875.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="020" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="020" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=020" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=025" target="_blank">
#  <img alt="중앙일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd164240664.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="025" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="025" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=025" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=018" target="_blank">
#  <img alt="이데일리" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd154426359.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="018" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="018" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=018" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=277" target="_blank">
#  <img alt="아시아경제" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd153432228.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="277" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="277" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=277" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=076" target="_blank">
#  <img alt="스포츠조선" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd183553864.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="076" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="076" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=076" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=081" target="_blank">
#  <img alt="서울신문" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd145738195.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="081" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="081" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=081" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=008" target="_blank">
#  <img alt="머니투데이" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd145214517.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="008" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="008" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=008" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=057" target="_blank">
#  <img alt="MBN" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd173223533.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="057" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="057" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=057" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=014" target="_blank">
#  <img alt="파이낸셜뉴스" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd172557496.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="014" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="014" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=014" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=368" target="_blank">
#  <img alt="데일리안" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd14463367.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="368" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="368" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=368" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=038" target="_blank">
#  <img alt="한국일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd172837200.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="038" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="038" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=038" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=021" target="_blank">
#  <img alt="문화일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd19245981.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="021" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="021" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=021" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct2&amp;pcode=921" target="_blank">
#  <img alt="아주경제" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd154016764.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="921" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="921" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct2&amp;pcode=921" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct6&amp;pcode=311" target="_blank">
#  <img alt="엑스포츠뉴스" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd154117.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="311" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="311" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct6&amp;pcode=311" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct3&amp;pcode=902" target="_blank">
#  <img alt="TV조선" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd1735138.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="902" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="902" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct3&amp;pcode=902" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct2&amp;pcode=243" target="_blank">
#  <img alt="이코노미스트" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd15444742.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="243" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="243" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct2&amp;pcode=243" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct8&amp;pcode=387" target="_blank">
#  <img alt="인천일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd154558680.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="387" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="387" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct8&amp;pcode=387" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct8&amp;pcode=926" target="_blank">
#  <img alt="중부일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd162931439.png">
#  </img></a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="926" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="926" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct8&amp;pcode=926" role="button" target="_blank">기사보기</a>,
#  <a class="aplc_link is_selected" data-category="ct2" data-clk="nsd_all.daei" href="#"><span class="aplc_name">종합/경제</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct3" data-clk="nsd_all.dtvcom" href="#"><span class="aplc_name">방송/통신</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct4" data-clk="nsd_all.dit" href="#"><span class="aplc_name">IT</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct5" data-clk="nsd_all.deng" href="#"><span class="aplc_name">영자지</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct6" data-clk="nsd_all.dsporent" href="#"><span class="aplc_name">스포츠/연예</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct7" data-clk="nsd_all.magtec" href="#"><span class="aplc_name">매거진/전문지</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct8" data-clk="nsd_all.loc" href="#"><span class="aplc_name">지역</span><span class="aplc_paging"></span></a>,
#  <a class="anv_btn" data-clk="nsd_myn*a.thum" href="http://newsstand.naver.com/config.html" role="button" target="_blank">언론사 추가</a>,
#  <a class="lg_global_btn" data-clk="log_off.pad" href="https://nid.naver.com/nidlogin.login?url=https%3A%2F%2Fwww.naver.com" role="button">
#  <i class="ico_global_login lang_en_v1"><span class="blind">NAVER Sign in</span></i>
#  </a>,
#  <a class="lg_link_join" data-clk="log_off.registration" href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com">Sign up</a>,
#  <a class="lg_find_text_en" data-clk="log_off.searchid" href="https://nid.naver.com/user/help.nhn?todo=idinquiry">Username</a>,
#  <a class="lg_find_text_en" data-clk="log_off.searchpass" href="https://nid.naver.com/nidreminder.form">Password?</a>,
#  <a class="hi_date" data-clk="squ.date" href="https://calendar.naver.com"><span class="hi_dnum">05.24.</span><span class="hi_day">(수)</span></a>,
#  <a class="header_btn_prev _PM_timesquare_prev" data-clk="squ.pre" href="#"><i aria-hidden="true" class="ico_btn_prev"></i><span class="blind">앞의 목록으로 이동</span></a>,
#  <a class="header_btn_next _PM_timesquare_next" data-clk="squ.next" href="#"><i aria-hidden="true" class="ico_btn_next"></i><span class="blind">뒤의 목록으로 이동</span></a>,
#  <a class="tnb_link tnb_cate" data-clk="squ_spo.tit1" href="http://sports.news.naver.com/kbaseball/index.nhn">야구</a>,
#  <a class="tnb_link tnb_text" data-clk="squ_spo.con1" href="javascript:window.open('http://sports.news.naver.com/tv/index.nhn?category=kbo&amp;gameId=20170524KTSS02017','', 'scrollbars=yes, toolbar=no, location=0, directories=0, status=0, menubar=0,  resizable=1, left=100,top=75,width=1024,height=620');void(0);"><i class="tnh_ico_live"><span class="tnh_ico_text">LIVE</span></i>[KBO리그 TV중계] kt vs 삼성</a>,
#  <a class="tnb_link tnb_cate" data-clk="squ_spo.tit2" href="http://sports.news.naver.com/wfootball/index.nhn">해외축구</a>,
#  <a class="tnb_link tnb_text" data-clk="squ_spo.con2" href="http://sports.news.naver.com/worldfootballetc/news/read.nhn?oid=413&amp;aid=0000050698">우루과이, 일본 2:0 격파…16강행</a>,
#  <a class="tnb_link tnb_cate" data-clk="squ_spo.tit3" href="http://sports.news.naver.com/kfootball/index.nhn">축구</a>,
#  <a class="tnb_link tnb_text" data-clk="squ_spo.con3" href="http://sports.news.naver.com/afc/news/read.nhn?oid=139&amp;aid=0002075220">제주, 우라와에 2:0 승…8강 청신호</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_livinghome" data-clk="tct.lif" data-id="LIVINGHOME" href="#LIVINGHOME" role="tab"><span class="blind">리빙</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_living" data-clk="tct.fod" data-id="LIVING" href="#LIVING" role="tab"><span class="blind">푸드</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_sports" data-clk="tct.spo" data-id="SPORTS" href="#SPORTS" role="tab"><span class="blind">스포츠</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_cargame" data-clk="tct.aut" data-id="CARGAME" href="#CARGAME" role="tab"><span class="blind">차·테크</span><span class="ac_icon"></span></a>,
#  <a aria-selected="true" class="PM_CL_themeItem ac_a tcc_beauty" data-clk="tct.bty" data-id="BEAUTY" href="#BEAUTY" role="tab"><span class="blind">패션뷰티</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_momkids" data-clk="tct.mom" data-id="MOMKIDS" href="#MOMKIDS" role="tab"><span class="blind">맘·키즈</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_health" data-clk="tct.hea" data-id="HEALTH" href="#HEALTH" role="tab"><span class="blind">건강</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_bboom" data-clk="tct.web" data-id="BBOOM" href="#BBOOM" role="tab"><span class="blind">웹툰</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_gameapp" data-clk="tct.gam" data-id="GAMEAPP" href="#GAMEAPP" role="tab"><span class="blind">게임</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_video" data-clk="tct.tvc" data-id="VIDEO" href="#VIDEO" role="tab"><span class="blind">TV연예</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_music" data-clk="tct.muc" data-id="MUSIC" href="#MUSIC" role="tab"><span class="blind">뮤직</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_movie" data-clk="tct.mov" data-id="MOVIE" href="#MOVIE" role="tab"><span class="blind">영화</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_culture" data-clk="tct.bok" data-id="CULTURE" href="#CULTURE" role="tab"><span class="blind">책·문화</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_with" data-clk="tct.pub" data-id="WITH" href="#WITH" role="tab"><span class="blind">함께N</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_travel" data-clk="tct.tra" data-id="TRAVEL" href="#TRAVEL" role="tab"><span class="blind">여행+</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_design" data-clk="tct.des" data-id="DESIGN" href="#DESIGN" role="tab"><span class="blind">디자인</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_finance" data-clk="tct.fin" data-id="FINANCE" href="#FINANCE" role="tab"><span class="blind">경제M</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_job" data-clk="tct.job" data-id="JOB" href="#JOB" role="tab"><span class="blind">JOB&amp;</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_science" data-clk="tct.sci" data-id="SCIENCE" href="#SCIENCE" role="tab"><span class="blind">과학</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_knowledge" data-clk="tct.ncc" data-id="KNOWLEDGE" href="#KNOWLEDGE" role="tab"><span class="blind">지식·교양</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_china" data-clk="tct.chn" data-id="CHINA" href="#CHINA" role="tab"><span class="blind">중국</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_business" data-clk="tct.bsn" data-id="BUSINESS" href="#BUSINESS" role="tab"><span class="blind">비즈니스</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_farm" data-clk="tct.far" data-id="FARM" href="#FARM" role="tab"><span class="blind">FARM</span><span class="ac_icon"></span></a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_school" data-clk="tct.scl" data-id="SCHOOL" href="#SCHOOL" role="tab"><span class="blind">스쿨잼</span><span class="ac_icon"></span></a>,
#  <a class="ac_btn_cate PM_CL_btnThemeEdit" data-clk="tct.menu" href="#" role="button"><span class="blind">전체 주제 열기</span><span class="ac_bicon"></span></a>,
#  <a class="ac_btn_prev PM_CL_btnThemePrev" data-clk="tct.prev" href="#" role="button"><span class="blind">이전 주제</span><span class="ac_bicon"></span></a>,
#  <a class="ac_btn_next PM_CL_btnThemeNext" data-clk="tct.next" href="#" role="button"><span class="blind">다음 주제</span><span class="ac_bicon"></span></a>,
#  <a class="at_btn_close PM_CL_btnThemeEdit" data-clk="tca.close" href="#" role="button"><span class="blind">전체 주제 목록 닫기</span><span class="at_bicon"></span></a>,
#  <a class="at_btn_setting PM_CL_btnThemeEditShow" data-clk="tca.like" href="#" role="button"><span class="at_bicon"></span>관심주제 설정</a>,
#  <a class="at_btn_import PM_CL_btnThemeImport" data-clk="tca.mobile" data-login-url="https://nid.naver.com/nidlogin.login?url=http%3A%2F%2Fwww.naver.com" href="#" role="button"><span class="at_bicon"></span>모바일 관심 주제 가져오기</a>,
#  <a class="at_btn_cancel PM_CL_btnThemeEditCancel" data-clk="tca*l.cancel" href="#" role="button">취소</a>,
#  <a class="at_btn_confirm PM_CL_btnThemeEditOk" data-clk="tca*l.ok" href="#" role="button">확인</a>,
#  <a class="at_btn_reset PM_CL_btnThemeEditInit" data-clk="tca*l.reset" href="#" role="button"><span class="at_bicon"></span>초기화</a>,
#  <a class="at_btn_all PM_CL_btnThemeSelectAll" data-clk="" href="#" role="button">전체선택</a>,
#  <a class="at_btn_import PM_CL_btnThemeImport" data-clk="tca.mobile" data-login-url="https://nid.naver.com/nidlogin.login?url=http%3A%2F%2Fwww.naver.com" href="#" role="button"><span class="at_bicon"></span>모바일 관심 주제 가져오기</a>,
#  <a class="tt_la" data-clk="tcc_bty.link" data-gdid="UAT_1293603" href="http://m.naver.com/naverapp/?version=1&amp;cmd=onMenu&amp;menuCode=BEAUTY">모바일 뷰티</a>,
#  <a class="tt_la" data-clk="tcc_bty.link" data-gdid="UAT_1300920" href="http://campaign.naver.com/v/beaustar2/introduce/ko/">뷰스타</a>,
#  <a class="tt_la" data-clk="tcc_bty.link" data-gdid="UAT_1293604" href="http://tv.naver.com/p/beauty">뷰티TV</a>,
#  <a class="tt_la" data-clk="tcc_bty.link" data-gdid="UAT_1293605" href="http://channels.vlive.tv/FA39F/video">V뷰티</a>,
#  <a class="tt_la" data-clk="tcc_bty.link" data-gdid="UAT_1293606" href="http://www.pholar.co/gallery/postTag?tag=%EB%84%A4%EC%9D%B4%EB%B2%84%ED%97%A4%EC%96%B4%EB%A9%98%ED%86%A0">헤어멘토</a>,
#  <a class="tt_la" data-clk="tcc_bty.link" data-gdid="UAT_1300915" href="http://blog.naver.com/naver_beauty">공식 블로그</a>,
#  <a class="tb_a" data-clk="tcc_bty.two" data-gdid="UAT_1486047" href="http://tv.naver.com/v/1703593">
#  <div class="tb_mw">
#  <img alt="데님과 어울리는 화사한 오렌지 메이크업" class="tb_m" height="185" src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/mobile_150427905857.jpg" width="346">
#  <span class="tb_bd"></span>
#  </img></div>
#  <div class="tb_ow">
#  <span class="tb_bg"></span>
#  <span class="tb_omw">
#  <span class="tb_ico_video"><span class="blind">ëìì</span></span>
#  </span>
#  <span class="tb_tw">
#  <span class="tb_d">시크함 폭발!</span>
#  <span class="tb_t">데님과 어울리는 화사한 오렌지 메이크업</span>
#  </span>
#  <span class="tb_align"></span>
#  </div>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1486602" href="http://tv.naver.com/v/1693659">
#  <span class="td_mw">
#  <img alt="놀러갈 때 딱이지&lt;br&gt;반다나 헤어 3가지로 연출하기" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/cropImg_166x108_96013322743283817.jpeg" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">놀러갈 때 딱이지<br>반다나 헤어 3가지로 연출하기</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1487355" href="http://m.post.naver.com/viewer/postView.nhn?volumeNo=7715809&amp;memberNo=24216069&amp;mainMenu=BEAUTY">
#  <span class="td_mw">
#  <img alt="어떻게 해야 키스한 후에도 지워지지 않는 게 가능해?" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/cropImg_166x108_96014081216414197.gif" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">어떻게 해야 키스한 후에도 지워지지 않는 게 가능해?</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1483454" href="http://tv.naver.com/v/1700634">
#  <span class="td_mw">
#  <img alt="티 안 나게 촉촉한&lt;br&gt; 남자 메이크업" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0522/mobile_170652150634.jpg" width="166">
#  <span class="td_bd"></span>
#  <span class="td_ico_video"><span class="blind">ëìì</span><span class="td_bg"></span><span class="td_icon"></span></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">티 안 나게 촉촉한<br> 남자 메이크업</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1486593" href="http://www.pholar.co/post/1333930/10668009">
#  <span class="td_mw">
#  <img alt="동그란 얼굴 보완해주는&lt;br&gt;A라인 단발펌 추천해" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/mobile_222033353805.png" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">동그란 얼굴 보완해주는<br>A라인 단발펌 추천해</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1487358" href="http://post.naver.com/viewer/postView.nhn?volumeNo=7787603&amp;memberNo=4066560&amp;mainMenu=BEAUTY">
#  <span class="td_mw">
#  <img alt="55 vs. 66 vs.77&lt;br&gt;래시가드 선택법과 체형별 핏 비교" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/cropImg_166x108_96013830254476156.jpeg" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">55 vs. 66 vs.77<br>래시가드 선택법과 체형별 핏 비교</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1487351" href="http://m.post.naver.com/viewer/postView.nhn?volumeNo=7378852&amp;memberNo=4689357&amp;vType=VERTICAL&amp;mainMenu=BEAUTY">
#  <span class="td_mw">
#  <img alt="제일 좋은 건 뭔데?&lt;br&gt;블랙헤드 박멸 코팩 Best 6" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/cropImg_166x108_96013698299503526.jpeg" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">제일 좋은 건 뭔데?<br>블랙헤드 박멸 코팩 Best 6</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1487350" href="http://m.blog.naver.com/neriia/220993852242">
#  <span class="td_mw">
#  <img alt="맥 루비우 포함&lt;br&gt;레드 립스틱 12종 추천 및 발색" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/cropImg_166x108_96013585878887037.jpeg" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">맥 루비우 포함<br>레드 립스틱 12종 추천 및 발색</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1486145" href="http://tv.naver.com/v/1703619">
#  <span class="td_mw">
#  <img alt="평범한 단발머리 지겹다면&lt;br&gt;귀여운 단발 웨이브 어때?" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/mobile_15190569720.jpg" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166">
#  <span class="td_bd"></span>
#  <span class="td_ico_video"><span class="blind">ëìì</span><span class="td_bg"></span><span class="td_icon"></span></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">평범한 단발머리 지겹다면<br>귀여운 단발 웨이브 어때?</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1486584" href="http://www.pholar.co/post/1386645/10953211">
#  <span class="td_mw">
#  <img alt="사랑스러움 뿜뿜~!&lt;br&gt;소녀소녀한 애쉬핑크 염색" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/cropImg_166x108_96012607863401915.jpeg" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">사랑스러움 뿜뿜~!<br>소녀소녀한 애쉬핑크 염색</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1486058" href="http://tv.naver.com/v/1704818">
#  <span class="td_mw">
#  <img alt="기초부터 색조까지 다 있어&lt;br&gt;여행 파우치템&amp;면세점 하울" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/mobile_150537364472.jpg" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166">
#  <span class="td_bd"></span>
#  <span class="td_ico_video"><span class="blind">ëìì</span><span class="td_bg"></span><span class="td_icon"></span></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">기초부터 색조까지 다 있어<br>여행 파우치템&amp;면세점 하울</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1487349" href="http://post.naver.com/viewer/postView.nhn?volumeNo=7724714&amp;memberNo=6876190&amp;mainMenu=BEAUTY">
#  <span class="td_mw">
#  <img alt="궁금했지? SNS에서 봤던 설리 수영복 찾아냈어" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/mobile_170910885217c.JPG" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">궁금했지? SNS에서 봤던 설리 수영복 찾아냈어</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1486595" href="http://www.pholar.co/post/942422/10753737">
#  <span class="td_mw">
#  <img alt="여자들이 가장 좋아하는 &lt;br&gt;남자 헤어 스타일 리젠트컷" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/mobile_163711174971.png" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">여자들이 가장 좋아하는 <br>남자 헤어 스타일 리젠트컷</br></span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_bty.contents" data-gdid="UAT_1487357" href="http://m.post.naver.com/viewer/postView.nhn?volumeNo=7736118&amp;memberNo=9781&amp;mainMenu=BEAUTY">
#  <span class="td_mw">
#  <img alt="잘못 신은 거 아니라니까!&lt;br&gt;패피들의 미스매치 슈즈 코디" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0523/cropImg_166x108_96014177095190234.jpeg" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166">
#  <span class="td_bd"></span>
#  </img></span>
#  <span class="td_tw">
#  <span class="td_t">잘못 신은 거 아니라니까!<br>패피들의 미스매치 슈즈 코디</br></span>
#  </span>
#  </a>,
#  <a href="https://castbox.shopping.naver.com/shopbox/main.nhn?svgless=true">https://castbox.shopping.naver.com/shopbox/main.nhn?svgless=true</a>,
#  <a class="bl_a" data-clk="mcb.left" href="http://boostcamp.connect.or.kr/" target="_blank">
#  <div class="bl_mw">
#  <img alt="커넥트재단 SW교육 부스트캠프 모집 예비 신입 개발자를 위한 실무 역량 강화 프로젝트!" class="bl_m" height="88" src="https://s.pstatic.net/static/www/mobile/edit/2017/0518/mobile_183742888397.png" title="커넥트재단 SW교육 부스트캠프 모집 예비 신입 개발자를 위한 실무 역량 강화 프로젝트!" width="166">
#  <span class="bl_bd"></span>
#  </img></div>
#  <div class="bl_tw">
#  <span class="bl_s">커넥트재단 SW교육</span>
#  <strong class="bl_t">부스트캠프 모집</strong>
#  <span class="bl_d">예비 신입 개발자를 위한<br/>실무 역량 강화 프로젝트!</span>
#  </div>
#  </a>,
#  <a class="bl_a" data-clk="mcb.right" href="http://4th.sericeo.org/index.html?p_adv=nv" target="_blank">
#  <div class="bl_mw">
#  <img alt="SERICEO스페셜 4차 산업혁명 교육 변화하는 미래 산업, 그 주인공이 될 당신에게!" class="bl_m" height="88" src="https://s.pstatic.net/static/www/mobile/edit/2017/0519/mobile_155927842710.jpg" title="SERICEO스페셜 4차 산업혁명 교육 변화하는 미래 산업, 그 주인공이 될 당신에게!" width="166">
#  <span class="bl_bd"></span>
#  </img></div>
#  <div class="bl_tw">
#  <span class="bl_s">SERICEO스페셜</span>
#  <strong class="bl_t">4차 산업혁명 교육</strong>
#  <span class="bl_d">변화하는 미래 산업,<br/>그 주인공이 될 당신에게!</span>
#  </div>
#  </a>,
#  <a class="an_ta" data-clk="ntc.notice" href="http://www.naver.com/NOTICE">공지사항</a>,
#  <a class="an_a" data-clk="ntc.notice" href="http://www.naver.com/NOTICE/read/1100001014/10000000000030652719">네이버 PC 페이지 악성코드 의심 페이지 노출 증가 안내</a>,
#  <a class="as_a" data-clk="ntc.svcmap" href="more.html">서비스 전체보기<span class="as_ico_all"></span></a>,
#  <a data-clk="nad.ios" href="https://itunes.apple.com/us/app/neibeo-naver/id393499958?mt=8">아이폰</a>,
#  <a data-clk="nad.android" href="https://play.google.com/store/apps/details?id=com.nhn.android.search">안드로이드</a>,
#  <a class="aw_a" data-clk="wbd.bt" href="http://whale.naver.com/">다운받기</a>,
#  <a class="aw_qr" data-clk="wbd.bt" href="http://whale.naver.com/"><span class="blind">네이버웨일</span></a>,
#  <a class="at_a" data-clk="plc.intronhn" href="http://www.navercorp.com/">회사소개</a>,
#  <a class="at_a" data-clk="plc.adinfo" href="http://mktg.naver.com/">비즈니스ㆍ광고</a>,
#  <a class="at_a" data-clk="plc.search" href="https://submit.naver.com/">지역업체 등록</a>,
#  <a class="at_a" data-clk="plc.contact" href="https://www.navercorp.com/ko/company/proposalGuide.nhn">제휴제안</a>,
#  <a class="at_a" data-clk="plc.service" href="/policy/service.html">이용약관</a>,
#  <a class="at_a" data-clk="plc.privacy" href="/policy/privacy.html"><strong class="at_st">개인정보처리방침</strong></a>,
#  <a class="at_a" data-clk="plc.youth" href="/policy/youthpolicy.html">청소년보호정책</a>,
#  <a class="at_a" data-clk="plc.policy" href="/policy/spamcheck.html">네이버 정책</a>,
#  <a class="at_a" data-clk="plc.helpcenter" href="https://help.naver.com/">고객센터</a>,
#  <a class="at_ca" data-clk="plc.nhn" href="http://www.navercorp.com/" target="_blank">NAVER Corp.</a>]

# %%
bsObj.findAll("a",{"href":"#news_cast"})
# Out:
# [<a href="#news_cast" onclick="document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"><span>뉴스스탠드 바로가기</span></a>]

# %%
bsObj.findAll("a",{"href":"#news_cast"})[0].get_text()
# Out:
# '뉴스스탠드 바로가기'

# %%
bsObj.findAll("a",{"href":"#news_cast"})[0]["onclick"]
# Out:
# "document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"

# %% [markdown]
# ## QUIZ 02
#
# [다음 메인 페이지](http://www.daum.net/)의 DIV 요소를 분석하고 레인아웃이 어떤 형태로 이루어져있는지 확인하라.
#
# - DIV 에 대한 학습은 다음 링크를 참고하자. [의미없는 요소 div와 span 그리고 class 속성](http://webberstudy.com/html-css/html-1/div-span-and-class-attr/)

# %%
# 다음 메인 페이지에서 DIV 요소 찾기


from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen("http://www.daum.net/")
bsObj = BeautifulSoup(html.read(), "html.parser")

## TODO : write your code!!
divlist = None 
print(divlist)

"""
Output :
[<div class="d_index" id="daumIndex">
 <a class="shortcut_g" href="#mainServiceTitle" rel="bookmark" tabindex="12">
 <span class="ico_vert inner_shortcut">주요 서비스 바로가기</span>
 </a>
 <a class="shortcut_g" href="#todayInfoTitle" rel="bookmark" tabindex="12">
 <span class="ico_vert inner_shortcut">오늘의 정보 바로가기</span>
 </a>
 <a class="shortcut_g" href="#mediaTitle" rel="bookmark" tabindex="12">
 <span class="ico_vert inner_shortcut">미디어 바로가기</span>
 </a>
 <a class="shortcut_g" href="#liveIssueTitle" rel="bookmark" tabindex="12">
 <span class="ico_vert inner_shortcut">실시간 이슈 바로가기</span>
 ....
 """
# Out:
# None
# '\nOutput :\n[<div class="d_index" id="daumIndex">\n <a class="shortcut_g" href="#mainServiceTitle" rel="bookmark" tabindex="12">\n <span class="ico_vert inner_shortcut">주요 서비스 바로가기</span>\n </a>\n <a class="shortcut_g" href="#todayInfoTitle" rel="bookmark" tabindex="12">\n <span class="ico_vert inner_shortcut">오늘의 정보 바로가기</span>\n </a>\n <a class="shortcut_g" href="#mediaTitle" rel="bookmark" tabindex="12">\n <span class="ico_vert inner_shortcut">미디어 바로가기</span>\n </a>\n <a class="shortcut_g" href="#liveIssueTitle" rel="bookmark" tabindex="12">\n <span class="ico_vert inner_shortcut">실시간 이슈 바로가기</span>\n ....\n '

# %%
# div의 개수 확인

# Output : 
#196

# %% [markdown]
# - div의 id가 "news"인 것을 검색

# %%
import re

# id=re.compile("news")

"""
Output:
[<div class="wrap_tabcont wrap_news" id="news">
 <div class="news_prime news_tab1 #newsbox #news1">
 <div class="group_news">
 <div class="box_issue">
 <a class="link_issue #img @1-1 ?c_id=20170612183126024" href="http://media.daum.net/photo-viewer?cid=318190#20170612183126024">
 <img alt="" class="img_thumb" height="290" src="//img2.daumcdn.net/thumb/C640x580/?fname=http://t1.daumcdn.net/alvolo/_thumbnails_cutter/media_mobile/20170612GMT/20170612_094552GMT_n97vARW5LLKK6h3rLKLv" width="320">
 <span class="frame_g"></span>
 <span class="cover_g"></span>
 <div class="cont_item">"""
# Out:
# [<div class="wrap_tabcont wrap_news" id="news">
#  <div class="news_prime news_tab1 #newsbox #news1">
#  <div class="group_news">
#  <div class="box_issue">
#  <a class="link_issue #img @1-1 ?c_id=20170612183126024" href="http://media.daum.net/photo-viewer?cid=318190#20170612183126024">
#  <img alt="" class="img_thumb" height="290" src="//img2.daumcdn.net/thumb/C640x580/?fname=http://t1.daumcdn.net/alvolo/_thumbnails_cutter/media_mobile/20170612GMT/20170612_094552GMT_n97vARW5LLKK6h3rLKLv" width="320">
#  <span class="frame_g"></span>
#  <span class="cover_g"></span>
#  <div class="cont_item">
#  <strong class="tit_item">일본 총리 특사와 악수하는 문 대통령</strong>
#  </div>
#  </img></a>
#  </div>
#  <h4 class="screen_out">일반뉴스</h4>
#  <ul class="list_txt">
#  <li><a class="link_txt #txt @1-1 ?c_id=20170612184834336" href="http://media.daum.net/issue/263643?selectedNewsId=20170612184834336">前전경련 임원 "삼성, 전경련 통해 친박 단체 지원"</a>
#  </li>
#  <li><a class="link_txt #txt @1-2 ?c_id=20170612184138209" href="http://media.daum.net/issue/326574?selectedNewsId=20170612184138209">칼 빼든 공정위..통신비 인하 압박 '지원사격'</a>
#  </li>
#  <li><a class="link_txt #txt @1-3 ?c_id=20170612184004187" href="http://v.media.daum.net/v/20170612184004187">보수야당 당권경쟁 레이스..한국당, 3파전으로 출발</a>
#  </li>
#  <li><a class="link_txt #txt @1-4 ?c_id=20170612185306395" href="http://v.media.daum.net/v/20170612185306395">"트럼프호텔등서 외국정상대상 사업경영은 사익"</a>
#  </li>
#  <li><a class="link_txt #txt @1-5 ?c_id=20170612184950354" href="http://media.daum.net/issue/190547?selectedNewsId=20170612184950354">AI 한고비 넘겼나..의심신고 이틀 연속 '0'</a>
#  </li>
#  <li><a class="link_txt #txt @1-6 ?c_id=20170612190441557" href="http://media.daum.net/issue/338092?selectedNewsId=20170612190441557">文대통령 사상 첫 추경 시정연설..절박성·시급성 강조</a>
#  </li>
#  <li class="part_mid"><a class="link_txt #txt @1-7 ?c_id=20170612190300543" href="http://v.media.daum.net/v/20170612190300543">안민석 '최순실 재산몰수법' 여야 의원모임 제안</a>
#  </li>
#  <li><a class="link_txt #txt @1-8 ?c_id=20170612190048509" href="http://v.media.daum.net/v/20170612190048509">러 전역서 야권 지지자 수천명, 反푸틴 시위</a>
#  </li>
#  <li><a class="link_txt #txt @1-9 ?c_id=20170612185542436" href="http://v.media.daum.net/v/20170612185542436">北 "南, 김련희와 북한억류 국민 송환 연계 시도" 주장</a>
#  </li>
#  <li><a class="link_txt #txt @1-10 ?c_id=20170612191059659" href="http://v.media.daum.net/v/20170612191059659">한국계 신예 디자이너 죽음에 뉴욕 패션계 애도</a>
#  </li>
#  <li><a class="link_txt #txt @1-11 ?c_id=20170612191045657" href="http://media.daum.net/issue/321033?selectedNewsId=20170612191045657">"朴재판 증인신문만 1년 걸릴라" 재판부 곤혹</a>
#  </li>
#  <li><a class="link_txt #txt @1-12 ?c_id=20170612190907622" href="http://v.media.daum.net/v/20170612190907622">北통신 "북남관계 개선 출로는 6·15 선언 이행"</a>
#  </li>
#  </ul>
#  </div>
#  <ul class="list_thumb">
#  <li class="fst">
#  <a class="link_item #img @1-2 ?c_id=20170612191405713" href="http://media.daum.net/photo-viewer?cid=3962#20170612191405713">
#  <span class="thumb_g">
#  <img alt="" class="img_thumb" height="100" src="//img1.daumcdn.net/thumb/C304x200/?fname=http://t1.daumcdn.net/alvolo/_thumbnails_cutter/media_mobile/20170612GMT/20170612_102503GMT_DMGmLnscMQDslsUAlWtr" width="152">
#  <span class="frame_g"></span>
#  </img></span>
#  <div class="cont_item">
#  <strong class="tit_item">아래층 연기..위층선 담뱃재 '이웃이 원수'</strong>
#  </div>
#  </a>
#  </li>
#  <li>
#  <a class="link_item #img @1-3 ?c_id=20170612192708886" href="http://media.daum.net/photo-viewer?cid=87991#20170612192708886">
#  <span class="thumb_g">
#  <img alt="" class="img_thumb" height="100" src="//img1.daumcdn.net/thumb/C304x200/?fname=http://t1.daumcdn.net/alvolo/_thumbnails_cutter/media_mobile/20170612GMT/20170612_103023GMT_P21Zv00BP107Js2IAbdQ" width="152">
#  <span class="frame_g"></span>
#  </img></span>
#  <div class="cont_item">
#  <strong class="tit_item">문 대통령 첫 시정연설 '피곤한 野'</strong>
#  </div>
#  </a>
#  </li>
#  <li>
#  <a class="link_item #img @1-4 ?c_id=20170612202503759" href="http://media.daum.net/photo-viewer?cid=318190#20170612202503759">
#  <span class="thumb_g">
#  <img alt="" class="img_thumb" height="100" src="//img1.daumcdn.net/thumb/C304x200/?fname=http://t1.daumcdn.net/alvolo/_thumbnails_cutter/media_pc/20170612GMT/20170612_112810GMT_9wbDhjI2xFxfqOQN4AhF" width="152">
#  <span class="frame_g"></span>
#  </img></span>
#  <div class="cont_item">
#  <strong class="tit_item">PPT 활용한 감성 호소..한국당 '싸늘'</strong>
#  </div>
#  </a>
#  </li>
#  <li class="lst">
#  <a class="link_item #img @1-5 ?c_id=20170612202724807" href="http://media.daum.net/photo-viewer?cid=197083#20170612202724807">
#  <span class="thumb_g">
#  <img alt="" class="img_thumb" height="100" src="//img1.daumcdn.net/thumb/C304x200/?fname=http://t1.daumcdn.net/alvolo/_thumbnails_cutter/media_pc/20170612GMT/20170612_113215GMT_FPQaeooSDvzJOKN5yL0o" width="152">
#  <span class="frame_g"></span>
#  </img></span>
#  <div class="cont_item">
#  <strong class="tit_item">"전화번호 건네며" 朴, 崔뇌물 직접 개입 정황</strong>
#  </div>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div class="news_flow #newsbox #news1 #home">
#  <div class="unit_home">
#  <strong class="tit_home"><a class="ico_vert link_home" href="http://media.daum.net/">뉴스홈</a></strong>
#  <ul class="list_home">
#  <li><a class="link_home #issue" href="http://media.daum.net/issue/">이슈</a></li>
#  <li><a class="link_home #series" href="http://media.daum.net/series/">연재</a></li>
#  <li><a class="link_home #ranking" href="http://media.daum.net/ranking/popular/">랭킹</a></li>
#  <li><a class="link_home #life" href="http://media.daum.net/life">라이프</a></li>
#  <li><a class="link_home #tv" href="http://media.daum.net/tv/">TV</a></li>
#  <li><a class="link_home #photo" href="http://media.daum.net/photo/">포토</a></li>
#  <li><a class="link_home #schedule" href="http://search.daum.net/search?w=tot&amp;q=%ED%8E%B8%EC%84%B1%ED%91%9C&amp;DA=TMZ">TV편성표</a></li>
#  </ul>
#  </div>
#  </div>
#  </div>]

# %% [markdown]
# # 03 Sites Crawling
#
# ## 1) 하이퍼 링크 조사

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re

host = "https://www.naver.com/"
html = urlopen(host)
bsObj = BeautifulSoup(html, "html.parser")

# %%
linkList = set()

a = bsObj.findAll("a", href=re.compile("^https?://[a-z,.]*naver\.com"))

for link in a:
    linkList.add(link["href"])
    
set(linkList)
# Out:
# {'http://blog.naver.com/businessinsight',
#  'http://blog.naver.com/businessinsight/220990558288',
#  'http://blog.naver.com/businessinsight/221017481118',
#  'http://blog.naver.com/businessinsight/221023403412',
#  'http://blog.naver.com/businessinsight/221023457959',
#  'http://blog.naver.com/businessinsight/221024306446',
#  'http://blog.naver.com/businessinsight/221024488760',
#  'http://blog.naver.com/businessinsight/221024575062',
#  'http://blog.naver.com/businessinsight/221025084012',
#  'http://blog.naver.com/businessinsight/221025084628',
#  'http://blog.naver.com/businessinsight/221025172965',
#  'http://blog.naver.com/businessinsight?Redirect=ThumbnailView&logNo=220962680914&categoryNo=26&isAfterWrite=true',
#  'http://blog.naver.com/insightors/221025072442',
#  'http://blog.naver.com/naver_business/220964064035',
#  'http://book.naver.com/',
#  'http://comic.naver.com/',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EA%B5%AD%EA%B0%80%EC%9E%A5%ED%95%99%EA%B8%88&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EA%B8%B0%EC%A3%BC%EB%B4%89&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EA%B9%80%EC%A0%95%ED%99%94&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EB%85%B8%EB%B8%94%EB%A0%88%EC%8A%A4&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EB%AF%B8%ED%82%A4%EC%A0%95&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EB%B3%91%EB%AC%B4%EC%B2%AD&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EB%B9%84%EC%A0%95%EC%83%81%ED%9A%8C%EB%8B%B4&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%86%A1%EB%82%A8%EC%98%81&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%8C%88+%EB%A7%88%EC%9D%B4%EC%9B%A8%EC%9D%B4&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%8D%A8%ED%81%B4&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%98%A5%EC%9E%90&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%9B%94%ED%99%94%EB%93%9C%EB%9D%BC%EB%A7%88&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%9D%B4%EB%9E%80+%EC%9A%B0%EC%A6%88%EB%B2%A1&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%9D%B4%EB%B9%84%EC%97%90%EC%8A%A4%EC%95%84%EC%9D%B4&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%9E%84%EC%9E%AC%EB%B2%94&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%9E%A5%EB%AF%B8%EC%9D%B8%EC%95%A0&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%EC%B5%9C%EC%9A%B0%EC%8B%9D&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%ED%8C%8C%EC%88%98%EA%BE%BC&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%ED%95%98%EB%A6%AC%EC%88%98&where=main',
#  'http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-06-13T00:55:30&query=%ED%95%9C%EA%B5%AD%EC%9E%A5%ED%95%99%EC%9E%AC%EB%8B%A8&where=main',
#  'http://datalab.naver.com/keyword/realtimeList.naver?where=main',
#  'http://dic.naver.com/',
#  'http://entertain.naver.com/home',
#  'http://happybean.naver.com/main/SectionMain.nhn',
#  'http://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1989',
#  'http://help.naver.com/support/welcomePage/guide.nhn',
#  'http://jr.naver.com',
#  'http://kin.naver.com/',
#  'http://land.naver.com/',
#  'http://mail.naver.com/',
#  'http://map.naver.com/',
#  'http://mktg.naver.com/',
#  'http://movie.naver.com/',
#  'http://music.naver.com',
#  'http://news.naver.com/',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331160',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331209',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331234',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331267',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331319',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331338',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331370',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331396',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331398',
#  'http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0009331399',
#  'http://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101',
#  'http://news.naver.com/main/ranking/popularDay.nhn?mid=etc&sid1=111',
#  'http://newsstand.naver.com/',
#  'http://newsstand.naver.com/?list=ct1&pcode=002',
#  'http://newsstand.naver.com/?list=ct1&pcode=015',
#  'http://newsstand.naver.com/?list=ct1&pcode=038',
#  'http://newsstand.naver.com/?list=ct1&pcode=040',
#  'http://newsstand.naver.com/?list=ct1&pcode=044',
#  'http://newsstand.naver.com/?list=ct1&pcode=117',
#  'http://newsstand.naver.com/?list=ct1&pcode=139',
#  'http://newsstand.naver.com/?list=ct1&pcode=241',
#  'http://newsstand.naver.com/?list=ct1&pcode=314',
#  'http://newsstand.naver.com/?list=ct1&pcode=326',
#  'http://newsstand.naver.com/?list=ct1&pcode=327',
#  'http://newsstand.naver.com/?list=ct1&pcode=366',
#  'http://newsstand.naver.com/?list=ct2&pcode=536',
#  'http://newsstand.naver.com/?list=ct2&pcode=923',
#  'http://newsstand.naver.com/?list=ct2&pcode=942',
#  'http://newsstand.naver.com/?list=ct7&pcode=364',
#  'http://newsstand.naver.com/?list=ct8&pcode=338',
#  'http://newsstand.naver.com/?list=ct8&pcode=387',
#  'http://newsstand.naver.com/config.html',
#  'http://pay.naver.com/',
#  'http://phrasebook.naver.com/detail.nhn?bigCategoryNo=11&middleCategoryNo=83&smallCategoryNo=364&targetLanguage=en',
#  'http://post.naver.com/viewer/postView.nhn?volumeNo=7886582&memberNo=960960&mainMenu=BUSINESS',
#  'http://post.naver.com/viewer/postView.nhn?volumeNo=7943974&memberNo=29381200&mainMenu=BUSINESS',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EA%B5%AD%EA%B0%80%EC%9E%A5%ED%95%99%EA%B8%88&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EA%B8%B0%EC%A3%BC%EB%B4%89&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EA%B9%80%EC%A0%95%ED%99%94&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EB%85%B8%EB%B8%94%EB%A0%88%EC%8A%A4&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EB%AF%B8%ED%82%A4%EC%A0%95&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EB%B3%91%EB%AC%B4%EC%B2%AD&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EB%B9%84%EC%A0%95%EC%83%81%ED%9A%8C%EB%8B%B4&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%86%A1%EB%82%A8%EC%98%81&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%8C%88+%EB%A7%88%EC%9D%B4%EC%9B%A8%EC%9D%B4&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%8D%A8%ED%81%B4&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%98%A5%EC%9E%90&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%9B%94%ED%99%94%EB%93%9C%EB%9D%BC%EB%A7%88&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%9D%B4%EB%9E%80+%EC%9A%B0%EC%A6%88%EB%B2%A1&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%9D%B4%EB%B9%84%EC%97%90%EC%8A%A4%EC%95%84%EC%9D%B4&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%9E%84%EC%9E%AC%EB%B2%94&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%9E%A5%EB%AF%B8%EC%9D%B8%EC%95%A0&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%EC%B5%9C%EC%9A%B0%EC%8B%9D&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%ED%8C%8C%EC%88%98%EA%BE%BC&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%ED%95%98%EB%A6%AC%EC%88%98&sm=top_lve&ie=utf8',
#  'http://search.naver.com/search.naver?where=nexearch&query=%ED%95%9C%EA%B5%AD%EC%9E%A5%ED%95%99%EC%9E%AC%EB%8B%A8&sm=top_lve&ie=utf8',
#  'http://section.blog.naver.com/',
#  'http://section.cafe.naver.com/',
#  'http://sports.news.naver.com/',
#  'http://stock.naver.com/',
#  'http://tv.naver.com/',
#  'http://whale.naver.com/',
#  'http://www.naver.com/NOTICE',
#  'http://www.naver.com/NOTICE/read/1100001014/10000000000030655144',
#  'https://calendar.naver.com',
#  'https://castbox.shopping.naver.com/shopbox/main.nhn?svgless=true',
#  'https://help.naver.com/',
#  'https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16658',
#  'https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16659',
#  'https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=2028',
#  'https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987',
#  'https://nid.naver.com/nidlogin.login',
#  'https://nid.naver.com/nidlogin.login?url=https%3A%2F%2Fwww.naver.com',
#  'https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com',
#  'https://nid.naver.com/nidreminder.form',
#  'https://nid.naver.com/user/help.nhn?todo=idinquiry',
#  'https://submit.naver.com/'}

# %%
linkList = set()

a = bsObj.findAll("a", href=re.compile("^\/"))

for link in a:
    linkList.add(host[:-1] + link["href"])

linkList
# Out:
# {'https://www.naver.com/',
#  'https://www.naver.com/policy/privacy.html',
#  'https://www.naver.com/policy/service.html',
#  'https://www.naver.com/policy/spamcheck.html',
#  'https://www.naver.com/policy/youthpolicy.html'}

# %%
linkList = set()

a = bsObj.findAll("a", href=re.compile("^[^http,\/]"))

for link in a:
    linkList.add(host + link["href"])

linkList
# Out:
# {'https://www.naver.com/#',
#  'https://www.naver.com/#BBOOM',
#  'https://www.naver.com/#BEAUTY',
#  'https://www.naver.com/#BUSINESS',
#  'https://www.naver.com/#CARGAME',
#  'https://www.naver.com/#CHINA',
#  'https://www.naver.com/#CULTURE',
#  'https://www.naver.com/#DESIGN',
#  'https://www.naver.com/#FARM',
#  'https://www.naver.com/#FINANCE',
#  'https://www.naver.com/#GAMEAPP',
#  'https://www.naver.com/#HEALTH',
#  'https://www.naver.com/#JOB',
#  'https://www.naver.com/#KNOWLEDGE',
#  'https://www.naver.com/#LIVING',
#  'https://www.naver.com/#LIVINGHOME',
#  'https://www.naver.com/#MOMKIDS',
#  'https://www.naver.com/#MOVIE',
#  'https://www.naver.com/#MUSIC',
#  'https://www.naver.com/#SCHOOL',
#  'https://www.naver.com/#SCIENCE',
#  'https://www.naver.com/#SPORTS',
#  'https://www.naver.com/#TRAVEL',
#  'https://www.naver.com/#VIDEO',
#  'https://www.naver.com/#WITH',
#  'https://www.naver.com/#account',
#  'https://www.naver.com/#news_cast',
#  'https://www.naver.com/#shop_cast',
#  'https://www.naver.com/#themecast',
#  'https://www.naver.com/#time_square',
#  'https://www.naver.com/javascript:;',
#  'https://www.naver.com/more.html'}

# %% [markdown]
# ## QUIZ 01
#
# 다음 조건에 맞춰 [보안 뉴스](http://www.boannews.com/media/t_list.asp?kind=0)의 페이지의 기사 링크를 수집하세요.
# - 사이트의 하이퍼링크 조사
# - 사이트 링크 정규화(/abc.html --> www.xxx.com/abc.html)
# - /ad-info/, /custom/, /guest/, /media/ 중 기사를 포스팅하는 디렉터리만 출력

# %%
# write your code

from bs4 import BeautifulSoup
from urllib.request import urlopen
import re

host = "http://www.boannews.com/media/t_list.asp?kind=0"
html = urlopen(host)
bsObj = BeautifulSoup(html, "html.parser")

newsLink = None

# wirte your code

print("")
        
"""
Output:
http://www.boannews.com/media/list.asp?kind=4
http://www.boannews.com/media/view.asp?idx=55202&skind=5
http://www.boannews.com/media/view.asp?idx=55230&kind=14
http://www.boannews.com/media/view.asp?idx=55229&skind=O
http://www.boannews.com/media/view.asp?idx=55228&kind=1
http://www.boannews.com/media/view.asp?idx=55243&page=1&kind=3
http://www.boannews.com/media/view.asp?idx=55124
http://www.boannews.com/media/view.asp?idx=55160
http://www.boannews.com/media/view.asp?idx=55228&skind=O
http://www.boannews.com/media/view.asp?idx=55244
"""
# Out:
# http://www.boannews.com/media/view.asp?idx=55226&page=1&kind=2
# http://www.boannews.com/media/view.asp?idx=55202
# http://www.boannews.com/media/view.asp?idx=55230&page=1&kind=1
# http://www.boannews.com/media/s_list.asp?skind=5
# http://www.boannews.com/media/view.asp?idx=55229&kind=1
# http://www.boannews.com/media/view.asp?idx=55228&kind=1
# http://www.boannews.com/media/view.asp?idx=55229&skind=O
# http://www.boannews.com/media/view.asp?idx=55227&page=1&kind=2
# http://www.boannews.com/media/view.asp?idx=55219&skind=O
# http://www.boannews.com/media/list.asp?kind=6
# http://www.boannews.com/media/view.asp?idx=55231&page=1&kind=3
# http://www.boannews.com/media/view.asp?idx=55124
# http://www.boannews.com/media/view.asp?idx=55245&skind=5
# http://www.boannews.com/media/view.asp?idx=55239&page=1&kind=1
# http://www.boannews.com/media/list.asp?kind=3
# http://www.boannews.com/media/list.asp?kind=4
# http://www.boannews.com/media/view.asp?idx=55222&page=1&kind=2
# http://www.boannews.com/media/view.asp?idx=55207
# http://www.boannews.com/media/view.asp?idx=55219&skind=5
# http://www.boannews.com/media/view.asp?idx=55245
# http://www.boannews.com/media/view.asp?idx=55215&skind=O
# http://www.boannews.com/media/view.asp?idx=55190&page=1&kind=3
# http://www.boannews.com/media/view.asp?idx=55224&page=1&kind=2
# http://www.boannews.com/media/view.asp?idx=55192&skind=O
# http://www.boannews.com/media/view.asp?idx=55225&page=1&kind=2
# http://www.boannews.com/media/view.asp?idx=55244
# http://www.boannews.com/media/view.asp?idx=55217&skind=O
# http://www.boannews.com/media/view.asp?idx=55217&skind=5
# http://www.boannews.com/media/view.asp?idx=55215&kind=1
# http://www.boannews.com/media/view.asp?idx=55202&skind=5
# http://www.boannews.com/media/view.asp?idx=55229&page=1&kind=1
# http://www.boannews.com/media/view.asp?idx=55242&page=1&kind=3
# http://www.boannews.com/media/view.asp?idx=55223&page=1&kind=2
# http://www.boannews.com/media/view.asp?idx=55177
# http://www.boannews.com/media/view.asp?idx=55240&page=1&kind=1
# http://www.boannews.com/media/view.asp?idx=55160
# http://www.boannews.com/media/view.asp?idx=55211&kind=14
# http://www.boannews.com/media/view.asp?idx=55243&page=1&kind=3
# http://www.boannews.com/media/view.asp?idx=55131&skind=O
# http://www.boannews.com/media/view.asp?idx=55188&page=1&kind=3
# http://www.boannews.com/media/view.asp?idx=55215&skind=5
# http://www.boannews.com/media/view.asp?idx=55230&kind=14
# http://www.boannews.com/media/view.asp?idx=55234&page=1&kind=1
# http://www.boannews.com/media/poll_02.asp?idx=165
# http://www.boannews.com/media/view.asp?idx=55245&page=1&kind=1
# http://www.boannews.com/media/list.asp?kind=1
# http://www.boannews.com/media/s_list.asp?skind=i
# http://www.boannews.com/media/list.asp?kind=5
# http://www.boannews.com/media/view.asp?idx=55244&page=1&kind=3
# http://www.boannews.com/media/view.asp?idx=55165&skind=O
# http://www.boannews.com/media/view.asp?idx=55141&skind=O
# http://www.boannews.com/media/o_list.asp?kind=B
# http://www.boannews.com/media/list.asp?kind=2
# http://www.boannews.com/media/view.asp?idx=55210&kind=14
# http://www.boannews.com/media/t_list.asp?kind=0
# http://www.boannews.com/media/view.asp?idx=55213&page=1&kind=5
# http://www.boannews.com/media/view.asp?idx=55127&skind=O
# http://www.boannews.com/media/view.asp?idx=55240&kind=14
# http://www.boannews.com/media/view.asp?idx=55189&page=1&kind=3
# http://www.boannews.com/media/view.asp?idx=55243&kind=35
# http://www.boannews.com/media/view.asp?idx=55228&skind=O
# '\nOutput:\nhttp://www.boannews.com/media/list.asp?kind=4\nhttp://www.boannews.com/media/view.asp?idx=55202&skind=5\nhttp://www.boannews.com/media/view.asp?idx=55230&kind=14\nhttp://www.boannews.com/media/view.asp?idx=55229&skind=O\nhttp://www.boannews.com/media/view.asp?idx=55228&kind=1\nhttp://www.boannews.com/media/view.asp?idx=55243&page=1&kind=3\nhttp://www.boannews.com/media/view.asp?idx=55124\nhttp://www.boannews.com/media/view.asp?idx=55160\nhttp://www.boannews.com/media/view.asp?idx=55228&skind=O\nhttp://www.boannews.com/media/view.asp?idx=55244\n'

# %% [markdown]
# ## 2) Robots.txt
#
# 웹 크롤링을 하기 전에 알아둘 것!
# - 웹 사이트 루트에는 Robots.txt가 있다.
# - 웹 사이트에서 크롤링돼서는 안되는 부분들을 표시함으로 웹 보안을 유지
# - disallow한 항목들은 들어가서는 안됨!

# %%
host = "https://www.naver.com/robots.txt"
html = urlopen(host)
bsObj = BeautifulSoup(html, "html.parser")

bsObj
# Out:
# User-agent: *
# Disallow: /

# %%
host = "https://www.whitehouse.gov/"
hostRobot = host + "robots.txt"
html = urlopen(hostRobot)
bsObj = BeautifulSoup(html, "html.parser")

bsObj
# Out:
# #
# # robots.txt
# #
# # This file is to prevent the crawling and indexing of certain parts
# # of your site by web crawlers and spiders run by sites like Yahoo!
# # and Google. By telling these "robots" where not to go on your site,
# # you save bandwidth and server resources.
# #
# # This file will be ignored unless it is at the root of your host:
# # Used:    http://example.com/robots.txt
# # Ignored: http://example.com/site/robots.txt
# #
# # For more information about the robots.txt standard, see:
# # http://www.robotstxt.org/wc/robots.html
# #
# # For syntax checking, see:
# # http://www.sxw.org.uk/computing/robots/check.html
#
# Sitemap: https://www.whitehouse.gov/sitemap-full.xml
#
# User-agent: *
# Crawl-delay: 10
# # CSS, JS, Images
# Allow: /misc/*.css$
# Allow: /misc/*.css?
# Allow: /misc/*.js$
# Allow: /misc/*.js?
# Allow: /misc/*.gif
# Allow: /misc/*.jpg
# Allow: /misc/*.jpeg
# Allow: /misc/*.png
# Allow: /modules/*.css$
# Allow: /modules/*.css?
# Allow: /modules/*.js$
# Allow: /modules/*.js?
# Allow: /modules/*.gif
# Allow: /modules/*.jpg
# Allow: /modules/*.jpeg
# Allow: /modules/*.png
# Allow: /profiles/*.css$
# Allow: /profiles/*.css?
# Allow: /profiles/*.js$
# Allow: /profiles/*.js?
# Allow: /profiles/*.gif
# Allow: /profiles/*.jpg
# Allow: /profiles/*.jpeg
# Allow: /profiles/*.png
# Allow: /themes/*.css$
# Allow: /themes/*.css?
# Allow: /themes/*.js$
# Allow: /themes/*.js?
# Allow: /themes/*.gif
# Allow: /themes/*.jpg
# Allow: /themes/*.jpeg
# Allow: /themes/*.png
# # Directories
# Disallow: /includes/
# Disallow: /misc/
# Disallow: /modules/
# Disallow: /profiles/
# Disallow: /scripts/
# Disallow: /themes/
# # Files
# Disallow: /CHANGELOG.txt
# Disallow: /cron.php
# Disallow: /INSTALL.mysql.txt
# Disallow: /INSTALL.pgsql.txt
# Disallow: /INSTALL.sqlite.txt
# Disallow: /install.php
# Disallow: /INSTALL.txt
# Disallow: /LICENSE.txt
# Disallow: /MAINTAINERS.txt
# Disallow: /update.php
# Disallow: /UPGRADE.txt
# Disallow: /xmlrpc.php
# # Paths (clean URLs)
# Disallow: /admin/
# Disallow: /comment/reply/
# Disallow: /filter/tips/
# Disallow: /node/add/
# Disallow: /search/
# Disallow: /user/register/
# Disallow: /user/password/
# Disallow: /user/login/
# Disallow: /user/logout/
# Disallow: /experiments/
# # Paths (no clean URLs)
# Disallow: /?q=admin/
# Disallow: /?q=comment/reply/
# Disallow: /?q=filter/tips/
# Disallow: /?q=node/add/
# Disallow: /?q=search/
# Disallow: /?q=user/password/
# Disallow: /?q=user/register/
# Disallow: /?q=user/login/
# Disallow: /?q=user/logout/
# Disallow: /?q=experiments/

# %%
data = bsObj.string

for line in data.split("\n"):
    if line.find("Disallow: ") == 0:
        print(line)
# Out:
# Disallow: /includes/
# Disallow: /misc/
# Disallow: /modules/
# Disallow: /profiles/
# Disallow: /scripts/
# Disallow: /themes/
# Disallow: /CHANGELOG.txt
# Disallow: /cron.php
# Disallow: /INSTALL.mysql.txt
# Disallow: /INSTALL.pgsql.txt
# Disallow: /INSTALL.sqlite.txt
# Disallow: /install.php
# Disallow: /INSTALL.txt
# Disallow: /LICENSE.txt
# Disallow: /MAINTAINERS.txt
# Disallow: /update.php
# Disallow: /UPGRADE.txt
# Disallow: /xmlrpc.php
# Disallow: /admin/
# Disallow: /comment/reply/
# Disallow: /filter/tips/
# Disallow: /node/add/
# Disallow: /search/
# Disallow: /user/register/
# Disallow: /user/password/
# Disallow: /user/login/
# Disallow: /user/logout/
# Disallow: /experiments/
# Disallow: /?q=admin/
# Disallow: /?q=comment/reply/
# Disallow: /?q=filter/tips/
# Disallow: /?q=node/add/
# Disallow: /?q=search/
# Disallow: /?q=user/password/
# Disallow: /?q=user/register/
# Disallow: /?q=user/login/
# Disallow: /?q=user/logout/
# Disallow: /?q=experiments/

# %%
data = bsObj.string

robots = set()

for line in data.split("\n"):
    if line.find("Disallow: ") == 0:
        robots.add(host[:-1] + line.split("Disallow: ")[1])
        
robots
# Out:
# {'https://www.whitehouse.gov/?q=admin/',
#  'https://www.whitehouse.gov/?q=comment/reply/',
#  'https://www.whitehouse.gov/?q=experiments/',
#  'https://www.whitehouse.gov/?q=filter/tips/',
#  'https://www.whitehouse.gov/?q=node/add/',
#  'https://www.whitehouse.gov/?q=search/',
#  'https://www.whitehouse.gov/?q=user/login/',
#  'https://www.whitehouse.gov/?q=user/logout/',
#  'https://www.whitehouse.gov/?q=user/password/',
#  'https://www.whitehouse.gov/?q=user/register/',
#  'https://www.whitehouse.gov/CHANGELOG.txt',
#  'https://www.whitehouse.gov/INSTALL.mysql.txt',
#  'https://www.whitehouse.gov/INSTALL.pgsql.txt',
#  'https://www.whitehouse.gov/INSTALL.sqlite.txt',
#  'https://www.whitehouse.gov/INSTALL.txt',
#  'https://www.whitehouse.gov/LICENSE.txt',
#  'https://www.whitehouse.gov/MAINTAINERS.txt',
#  'https://www.whitehouse.gov/UPGRADE.txt',
#  'https://www.whitehouse.gov/admin/',
#  'https://www.whitehouse.gov/comment/reply/',
#  'https://www.whitehouse.gov/cron.php',
#  'https://www.whitehouse.gov/experiments/',
#  'https://www.whitehouse.gov/filter/tips/',
#  'https://www.whitehouse.gov/includes/',
#  'https://www.whitehouse.gov/install.php',
#  'https://www.whitehouse.gov/misc/',
#  'https://www.whitehouse.gov/modules/',
#  'https://www.whitehouse.gov/node/add/',
#  'https://www.whitehouse.gov/profiles/',
#  'https://www.whitehouse.gov/scripts/',
#  'https://www.whitehouse.gov/search/',
#  'https://www.whitehouse.gov/themes/',
#  'https://www.whitehouse.gov/update.php',
#  'https://www.whitehouse.gov/user/login/',
#  'https://www.whitehouse.gov/user/logout/',
#  'https://www.whitehouse.gov/user/password/',
#  'https://www.whitehouse.gov/user/register/',
#  'https://www.whitehouse.gov/xmlrpc.php'}

# %% [markdown]
# ## QUIZ 02
#
# 보안뉴스 사이트의 robots.txt의 규정에 맞춰 **newsLink** 링크 검사하기
# - Disallow 링크 수집

# %%
host = "http://www.boannews.com/"
hostRobot = host + "robots.txt"
html = urlopen(hostRobot)
bsObj = BeautifulSoup(html, "html.parser")

data = bsObj.string
robots = set()

## write your code for robots

print(robots)


"""
Output:
{'http://www.boannews.com/secu_admin/'}
"""
# Out:
# {'http://www.boannews.com/secu_admin/'}

# %% [markdown]
# - Disallow 링크를 사용하여 적합성 확인

# %%
newsLink.add("http://www.boannews.com/secu_admin/")

## write your code for robots
        
        
"""
Output:
http://www.boannews.com/media/list.asp?kind=2 is allowed
http://www.boannews.com/custom/news_jebo.asp is allowed
http://www.boannews.com/media/view.asp?idx=55240&kind=14 is allowed
http://www.boannews.com/media/view.asp?idx=55211&kind=14 is allowed
http://www.boannews.com/media/view.asp?idx=55190&page=1&kind=3 is allowed
http://www.boannews.com/ad_info/ad_info02.asp?kind=02 is allowed
http://www.boannews.com/media/view.asp?idx=55245&page=1&kind=1 is allowed
http://www.boannews.com/media/view.asp?idx=55227&page=1&kind=2 is allowed
http://www.boannews.com/media/view.asp?idx=55222&page=1&kind=2 is allowed
http://www.boannews.com/media/s_list.asp?skind=i is allowed
http://www.boannews.com/media/view.asp?idx=55223&page=1&kind=2 is allowed
http://www.boannews.com/secu_admin/ isn't allowed
"""
# Out:
# http://www.boannews.com/custom/member_join.asp is allowed
# http://www.boannews.com/ad_info/ad_info04.asp?kind=04 is allowed
# http://www.boannews.com/media/view.asp?idx=55226&page=1&kind=2 is allowed
# http://www.boannews.com/media/view.asp?idx=55202 is allowed
# http://www.boannews.com/media/view.asp?idx=55230&page=1&kind=1 is allowed
# http://www.boannews.com/media/s_list.asp?skind=5 is allowed
# http://www.boannews.com/ is allowed
# http://www.boannews.com/media/view.asp?idx=55229&kind=1 is allowed
# http://www.boannews.com/media/view.asp?idx=55228&kind=1 is allowed
# http://www.boannews.com/media/view.asp?idx=55229&skind=O is allowed
# http://www.boannews.com/media/view.asp?idx=55227&page=1&kind=2 is allowed
# http://www.boannews.com/media/view.asp?idx=55219&skind=O is allowed
# http://www.boannews.com/media/list.asp?kind=6 is allowed
# http://www.boannews.com/custom/banner_page.asp?idx=484 is allowed
# http://www.boannews.com/media/view.asp?idx=55231&page=1&kind=3 is allowed
# http://www.boannews.com/media/view.asp?idx=55124 is allowed
# http://www.boannews.com/media/view.asp?idx=55245&skind=5 is allowed
# http://www.boannews.com/media/view.asp?idx=55239&page=1&kind=1 is allowed
# http://www.boannews.com/custom/scrap_list.asp is allowed
# http://www.boannews.com/media/list.asp?kind=3 is allowed
# http://www.boannews.com/custom/banner_page.asp?idx=506 is allowed
# http://www.boannews.com/custom/banner_page.asp?idx=501 is allowed
# http://www.boannews.com/media/list.asp?kind=4 is allowed
# http://www.boannews.com/media/view.asp?idx=55222&page=1&kind=2 is allowed
# http://www.boannews.com/custom/banner_page.asp?idx=437 is allowed
# http://www.boannews.com/media/view.asp?idx=55207 is allowed
# http://www.boannews.com/media/view.asp?idx=55219&skind=5 is allowed
# http://www.boannews.com/ad_info/ad_info02.asp?kind=02 is allowed
# http://www.boannews.com/ad_info/ad_info03.asp?kind=03 is allowed
# http://www.boannews.com/media/view.asp?idx=55245 is allowed
# http://www.boannews.com/guest/guest_login.asp is allowed
# http://www.boannews.com/media/view.asp?idx=55215&skind=O is allowed
# http://www.boannews.com/search/news_list.asp?search=title&find=%B9%F6%B1%D7%B8%AE%C6%F7%C6%AE is allowed
# http://www.boannews.com/media/view.asp?idx=55190&page=1&kind=3 is allowed
# http://www.boannews.com/media/view.asp?idx=55224&page=1&kind=2 is allowed
# http://www.boannews.com/media/view.asp?idx=55192&skind=O is allowed
# http://www.boannews.com/custom/company_info05.asp?kind=10 is allowed
# http://www.boannews.com/media/view.asp?idx=55225&page=1&kind=2 is allowed
# http://www.boannews.com/media/view.asp?idx=55244 is allowed
# http://www.boannews.com/default.asp is allowed
# http://www.boannews.com/media/view.asp?idx=55217&skind=O is allowed
# http://www.boannews.com/media/view.asp?idx=55217&skind=5 is allowed
# http://www.boannews.com/media/view.asp?idx=55215&kind=1 is allowed
# http://www.boannews.com/media/view.asp?idx=55202&skind=5 is allowed
# http://www.boannews.com/media/view.asp?idx=55229&page=1&kind=1 is allowed
# http://www.boannews.com/media/view.asp?idx=55242&page=1&kind=3 is allowed
# http://www.boannews.com/media/view.asp?idx=55223&page=1&kind=2 is allowed
# http://www.boannews.com/media/view.asp?idx=55177 is allowed
# http://www.boannews.com/custom/news_jebo.asp is allowed
# http://www.boannews.com/media/view.asp?idx=55240&page=1&kind=1 is allowed
# http://www.boannews.com/media/view.asp?idx=55160 is allowed
# http://www.boannews.com/media/view.asp?idx=55211&kind=14 is allowed
# http://www.boannews.com/media/view.asp?idx=55243&page=1&kind=3 is allowed
# http://www.boannews.com/media/view.asp?idx=55131&skind=O is allowed
# http://www.boannews.com/media/view.asp?idx=55188&page=1&kind=3 is allowed
# http://www.boannews.com/media/view.asp?idx=55215&skind=5 is allowed
# http://www.boannews.com/media/view.asp?idx=55230&kind=14 is allowed
# http://www.boannews.com/custom/customer_center.asp?kind=8 is allowed
# http://www.boannews.com/media/view.asp?idx=55234&page=1&kind=1 is allowed
# http://www.boannews.com/secu_admin/ isn't allowed
# http://www.boannews.com/media/poll_02.asp?idx=165 is allowed
# http://www.boannews.com/media/view.asp?idx=55245&page=1&kind=1 is allowed
# http://www.boannews.com/media/list.asp?kind=1 is allowed
# http://www.boannews.com/media/s_list.asp?skind=i is allowed
# http://www.boannews.com/media/list.asp?kind=5 is allowed
# http://www.boannews.com/media/view.asp?idx=55244&page=1&kind=3 is allowed
# http://www.boannews.com/media/view.asp?idx=55165&skind=O is allowed
# http://www.boannews.com/media/view.asp?idx=55141&skind=O is allowed
# http://www.boannews.com/media/o_list.asp?kind=B is allowed
# http://www.boannews.com/media/list.asp?kind=2 is allowed
# http://www.boannews.com/media/view.asp?idx=55210&kind=14 is allowed
# http://www.boannews.com/custom/news_rss.asp is allowed
# http://www.boannews.com/media/t_list.asp?kind=0 is allowed
# http://www.boannews.com/media/view.asp?idx=55213&page=1&kind=5 is allowed
# http://www.boannews.com/media/view.asp?idx=55127&skind=O is allowed
# http://www.boannews.com/media/view.asp?idx=55240&kind=14 is allowed
# http://www.boannews.com/custom/ad_info01.asp?kind=9 is allowed
# http://www.boannews.com/custom/member_login.asp is allowed
# http://www.boannews.com/media/view.asp?idx=55189&page=1&kind=3 is allowed
# http://www.boannews.com/media/view.asp?idx=55243&kind=35 is allowed
# http://www.boannews.com/media/view.asp?idx=55228&skind=O is allowed
# "\nOutput:\nhttp://www.boannews.com/media/list.asp?kind=2 is allowed\nhttp://www.boannews.com/custom/news_jebo.asp is allowed\nhttp://www.boannews.com/media/view.asp?idx=55240&kind=14 is allowed\nhttp://www.boannews.com/media/view.asp?idx=55211&kind=14 is allowed\nhttp://www.boannews.com/media/view.asp?idx=55190&page=1&kind=3 is allowed\nhttp://www.boannews.com/ad_info/ad_info02.asp?kind=02 is allowed\nhttp://www.boannews.com/media/view.asp?idx=55245&page=1&kind=1 is allowed\nhttp://www.boannews.com/media/view.asp?idx=55227&page=1&kind=2 is allowed\nhttp://www.boannews.com/media/view.asp?idx=55222&page=1&kind=2 is allowed\nhttp://www.boannews.com/media/s_list.asp?skind=i is allowed\nhttp://www.boannews.com/media/view.asp?idx=55223&page=1&kind=2 is allowed\nhttp://www.boannews.com/secu_admin/ isn't allowed\n"

# %% [markdown]
# ## 3) 전체 사이트 내부를 모두 조사
#
# - 재귀적 구성
# - 중복 링크와 robots.txt에 대해서 제외
# - 실행하지 않음

# %%
실행하지 마세요!



linkList = set()
robots = set()

def crawling(host):
    if host[-1] != "/":
        host + "/"
    html = urlopen(host)
    bsObj = BeautifulSoup(html, "html.parser")
    hostname = host.split("://")[1]
    hostname.replace(".", "\\.")
    
    a = bsObj.findAll("a", href=re.compile("^http[s]+://[a-z,.]*" + host.replace(".", "\.")))
    
    for link in a:
        if (link not in linkList) and (link not in robots):
            crwaling()
            linkList.add(link["href"])
        
    a = bsObj.findAll("a", href=re.compile("^\/"))

    for link in a:
        link = host + link
        if (link not in linkList) and (link not in robots):
            crwaling(link)
            linkList.add(host + link["href"])
        
    a = bsObj.findAll("a", href=re.compile("^[^http,\/]"))

    for link in a:
        if (link not in linkList) and (link not in robots):
            crwaling(link)
            linkList.add(host + link["href"])
        
host = "https://www.whitehouse.gov/"
crawling(host)
# Out:
#   File "<ipython-input-12-99517ad6e12c>", line 1
#     실행하지 마세요!
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## QUIZ 03
#
# 다음 조건에 맞춰서 보안뉴스 기사 링크에 대한 정보를 저장하자.
# - 링크에 대하여 dict 형태로 저장할 것
# - 저장하는 데이터는 html 형태로 저장할 것
# - newLink의 최초 10개의 데이터만 테스트할 것

# %%
allowlist = {}
newsList = list(newsLink)

for a in newsList[:10]:
    ## write your code 
    pass

# %% [markdown]
# - 결과는 아래와 같이 출력되어야 함

# %%
print(allowlist.keys())

"""
Output:
dict_keys(['http://www.boannews.com/media/poll_02.asp?idx=165', 'http://www.boannews.com/media/list.asp?kind=1', 'http://www.boannews.com/media/s_list.asp?skind=i', 'http://www.boannews.com/custom/ad_info01.asp?kind=9', 'http://www.boannews.com/media/view.asp?idx=55219&skind=5', 'http://www.boannews.com/media/view.asp?idx=55177', 'http://www.boannews.com/custom/news_rss.asp', 'http://www.boannews.com/media/view.asp?idx=55230&kind=14', 'http://www.boannews.com/media/list.asp?kind=4'])
"""
# Out:
# dict_keys(['http://www.boannews.com/custom/member_join.asp', 'http://www.boannews.com/ad_info/ad_info04.asp?kind=04', 'http://www.boannews.com/media/view.asp?idx=55226&page=1&kind=2', 'http://www.boannews.com/media/view.asp?idx=55202', 'http://www.boannews.com/media/view.asp?idx=55230&page=1&kind=1', 'http://www.boannews.com/media/s_list.asp?skind=5', 'http://www.boannews.com/', 'http://www.boannews.com/media/view.asp?idx=55229&kind=1', 'http://www.boannews.com/media/view.asp?idx=55228&kind=1', 'http://www.boannews.com/media/view.asp?idx=55229&skind=O'])
# "\nOutput:\ndict_keys(['http://www.boannews.com/media/poll_02.asp?idx=165', 'http://www.boannews.com/media/list.asp?kind=1', 'http://www.boannews.com/media/s_list.asp?skind=i', 'http://www.boannews.com/custom/ad_info01.asp?kind=9', 'http://www.boannews.com/media/view.asp?idx=55219&skind=5', 'http://www.boannews.com/media/view.asp?idx=55177', 'http://www.boannews.com/custom/news_rss.asp', 'http://www.boannews.com/media/view.asp?idx=55230&kind=14', 'http://www.boannews.com/media/list.asp?kind=4'])\n"

# %%
for (index, key) in enumerate(allowlist):
    print("Index : {}".format(index))
    print("Key : {}".format(key))
    print("value : {}".format(allowlist[key]))
    break

"""
Output:
Index : 0
Key : http://www.boannews.com/custom/member_join.asp
value : <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
<head>
<title>보안뉴스</title>
<meta content="http://www.boannews.com/images/top/boannews_icon2.png" itemprop="image">
"""
# Out:
# Index : 0
# Key : http://www.boannews.com/custom/member_join.asp
# value : <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>보안뉴스</title>
# <meta content="http://www.boannews.com/images/top/boannews_icon2.png" itemprop="image">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <link href="http://www.boannews.com" rel="canonical">
# <meta content="국내 최대 보안 언론/커뮤니티-보안뉴스" name="description">
# <meta content="website" property="og:type">
# <meta content="보안뉴스" property="og:title">
# <meta content="국내 최대 보안 언론/커뮤니티-보안뉴스" property="og:description">
# <meta content="http://www.boannews.com/images/top/logo.png" property="og:image">
# <meta content="www.boannews.com" property="og:url">
# <meta content="5bLNClj6UIZeIR58-jooPOBw2eKomfQJXIyOmVbv0pk" name="google-site-verification"/>
# <link href="http://www.boannews.com/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="http://www.boannews.com/images/top/logo.png" rel="image_src"/>
# <link href="css/main.css" rel="stylesheet" type="text/css"/>
# <script src="/JS/activex_load.js" type="text/javascript"></script>
# <script src="js/osAjaxSample.js" type="text/javascript"></script>
# <script src="include/chkForm.js" type="text/javascript"></script>
# </meta></meta></meta></meta></meta></meta></link></meta></meta></head>
# <body>
# <!--Include virtual="/secu_admin/ad_log/log.asp"-->
# <link href="http://www.boannews.com/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="/JS/activex_load.js" type="text/javascript"></script>
# <script type="text/javascript">
# function MM_swapImgRestore() { //v3.0
#   var i,x,a=document.MM_sr; for(i=0;a&&i<a.length&&(x=a[i])&&x.oSrc;i++) x.src=x.oSrc;
# }
#
# function MM_preloadImages() { //v3.0
#   var d=document; if(d.images){ if(!d.MM_p) d.MM_p=new Array();
#     var i,j=d.MM_p.length,a=MM_preloadImages.arguments; for(i=0; i<a.length; i++)
#     if (a[i].indexOf("#")!=0){ d.MM_p[j]=new Image; d.MM_p[j++].src=a[i];}}
# }
#
# function MM_findObj(n, d) { //v4.01
#   var p,i,x;  if(!d) d=document; if((p=n.indexOf("?"))>0&&parent.frames.length) {
#     d=parent.frames[n.substring(p+1)].document; n=n.substring(0,p);}
#   if(!(x=d[n])&&d.all) x=d.all[n]; for (i=0;!x&&i<d.forms.length;i++) x=d.forms[i][n];
#   for(i=0;!x&&d.layers&&i<d.layers.length;i++) x=MM_findObj(n,d.layers[i].document);
#   if(!x && d.getElementById) x=d.getElementById(n); return x;
# }
#
# function MM_swapImage() { //v3.0
#   var i,j=0,x,a=MM_swapImage.arguments; document.MM_sr=new Array; for(i=0;i<(a.length-2);i+=3)
#    if ((x=MM_findObj(a[i]))!=null){document.MM_sr[j++]=x; if(!x.oSrc) x.oSrc=x.src; x.src=a[i+2];}
# }
#
# function searchForm(){
# 	if(!document.form_search.find.value){
# 		alert("검색어를 입력하세요!");
# 		document.form_search.find.focus();
# 		return false;
# 	}
# 	document.form_search.q.value=document.form_search.find.value;
# 	return true;
# }
#
# function inputCheckTopSearch(f){
# 	re = /[~!@\#$%^&*\()\-=+_"><:|']/gi;
# 	if(re.test(f.find.value)){
# 		alert("특수문자는 입력하실 수 없습니다.");
# 		f.find.value=f.find.value.replace(re,"");
# 		f.find.focus();
# 	}
# }
#
# function add_favorites(){
# 	var favorite_url = "http://www.boannews.com"   //즐겨찾기에 추가할 홈 주소
# 	var favorite_title = "안전한 세상을 위한 뉴스 -보안뉴스"   // 즐겨찾기에 기록할 이름(제목)을 기록
# 	if (document.all){
# 		window.external.AddFavorite(favorite_url,favorite_title)
# 	}
# }
#
#
# // 구글 로그분석 Start
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-9071708-4']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
# // 구글 로그분석 end
#
#
# /* 레이어 팝업 전체 페이지 배너
# //쿠키설정
# function setCookie( name, value, expiredays ) {
# 	var todayDate = new Date();
# 	todayDate.setDate( todayDate.getDate() + expiredays );
# 	document.cookie = name + "=" + escape( value ) + "; path=/; expires=" + todayDate.toGMTString() + ";"
# }
#
# //쿠키가져오기
# function getCookie( name ) {
# 	var nameOfCookie = name + "=";
# 	var x = 0;
# 	while ( x <= document.cookie.length ){
# 	var y = (x+nameOfCookie.length);
# 	if ( document.cookie.substring( x, y ) == nameOfCookie ) {
# 		if ( (endOfCookie=document.cookie.indexOf( ";", y )) == -1 )
# 			endOfCookie = document.cookie.length;
# 			return unescape( document.cookie.substring( y, endOfCookie ) );
# 		}
# 		x = document.cookie.indexOf( " ", x ) + 1;
# 		if ( x == 0 )
# 		break;
# 	}
# 	return "";
# }
#
# //쿠키 설정여부체크
# function cookieChk(){
# 	if ( getCookie( "event_pop") != "done" ) {
# 		document.getElementById("div_popup").style.display ="block";
# 	}else{
# 		document.getElementById("div_popup").style.display ="none";
# 	}
# }
#
# //윈도우창을 닫음
# function closeWin() {
# 	if ( document.notice_form.chkbox.checked ){
# 		setCookie( "event_pop", "done" , 1 );
# 	}
# 	document.getElementById("div_popup").style.display ="none";
# }
# */
# </script>
# <!--
# <div id="div_popup" style="position:absolute; z-index:200; display:none; width: 400; height: 300; left: 50%; margin-left:165px; top: 166px;background-color:#EE4300;">
# <table border="0" cellspacing="0" cellpadding="0">
# 	<tr>
# 		<td><a href="http://www.isecconference.org/2014/kor/visit/isec_write.asp" target="_blank" onFocus="this.blur();"><img src="/images/pop/isec_400_270.jpg" border="0"></a></td>
# 	</tr>
# </table>
#
# <TABLE cellSpacing=0 cellPadding=0 width="400" height="30" border="0" bgcolor="#EE4300">
# <form name="notice_form">
# 	<tr>
# 		<td height="30" align="right">
# 			<input type="checkbox" name="chkbox" value="checkbox" align="absmiddle">
# 			<font color="#ffffff" face="돋움" style="font-size:10pt">하루동안 이 창 띄우지 않음</font>&nbsp;&nbsp;<a href="javascript:closeWin();">
# 			<font color="#ffffff" face="돋움" style="font-size:10pt"><b>창닫기</b></font></a>&nbsp;&nbsp;&nbsp;</td>
# 	</tr>
# </form>
# </TABLE>
# </div>
# -->
# <script language="JavaScript">
# window.onload = function(){
# //	cookieChk();
# }
# </script>
# <div id="top_moveIcon">
# <div style="font-size:11px; float:left; padding-left:20px;">
# <img border="0" src="http://www.boannews.com/images/family/tm14.gif">
# <img border="0" src="http://www.boannews.com/images/family/tm13.gif">
# 		<a href="http://www.boannews.com" onfocus="this.blur();" target="_blank"><img border="0" src="http://www.boannews.com/images/family/tm00.gif"/></a>
# 		<a href="http://www.securityworldmag.co.kr" onfocus="this.blur();" target="_blank"><img border="0" src="http://www.boannews.com/images/family/tm02.gif"/></a>
# 		<a href="http://www.solartodaymag.com" onfocus="this.blur();" target="_blank"><img border="0" src="http://www.boannews.com/images/family/tm05.gif"/></a>
# 		<a href="http://www.fajournal.com" onfocus="this.blur();" target="_blank"><img border="0" src="http://www.boannews.com/images/family/tm07.gif"/></a>
# 		<a href="http://www.health-news.co.kr" onfocus="this.blur();" target="_blank"><img border="0" src="http://www.boannews.com/images/family/tm03.gif"/></a>
# <img alt="" height="1" src="/images/arrow_white.gif" width="110"/>
# </img></img></div>
# <div style="font-size:11px; float:right; padding-right:20px;">
# <a href="http://www.seconexpo.com/" onfocus="this.blur();" target="_blank"><img alt="세계 보안 엑스포" border="0" src="http://www.boannews.com/images/family/tm10.gif"/></a>
# 		 <a href="http://www.egisec.org" onfocus="this.blur();" target="_blank"><img alt="전자정부 솔루션 페어" border="0" src="http://www.boannews.com/images/family/tm17.gif"/></a>
# 		 <a href="http://www.pisfair.org" onfocus="this.blur();" target="_blank"><img alt="개인정보보호 페어" border="0" src="http://www.boannews.com/images/family/tm09.gif"/></a>
# 		 <a href="http://www.isecconference.org" onfocus="this.blur();" target="_blank"><img alt="국제 사이버 시큐리티 컨퍼런스" border="0" src="http://www.boannews.com/images/family/tm08.gif"/></a>
# 		 <a href="http://www.exposolar.org" onfocus="this.blur();" target="_blank"><img alt="세계 태양에너지 엑스포" border="0" src="http://www.boannews.com/images/family/tm12.gif"/></a>
# 		 <a href="http://www.smartfactorykorea.com" onfocus="this.blur();" target="_blank"><img alt="스마트팩토리" border="0" src="http://www.boannews.com/images/family/tm18.gif"/></a>
# 		 <a href="http://www.dietexpo.co.kr" onfocus="this.blur();" target="_blank"><img alt="세계 다이어트 엑스포" border="0" src="http://www.boannews.com/images/family/tm15.gif"/></a>
# 		 <a href="http://www.info-con.org" onfocus="this.blur();" target="_blank"><img alt="INFO-CON" border="0" src="http://www.boannews.com/images/family/tm16.gif"/></a>
# </div>
# </div>
# <div id="wrap">
# <div id="top_category">
# <div id="top_banner"><iframe frameborder="0" height="65" id="main_top" name="main_top" src="/main_files/top_banner.asp" width="200"></iframe></div>
# <div id="top_logo"><a href="/default.asp" onfocus="this.blur();"><img alt="" height="65" src="/pds/main/default_logo.gif" width="440"/></a></div>
# <!--
# 		<div id="top_menu">
# 		<a href="/media/t_list.asp?kind=0" onfocus="this.blur();"><img src="/images/new/top01.gif" alt="" /></a>
# 		<a href="/security_contents/info/list.asp" onfocus="this.blur();"><img src="/images/new/top02.gif" alt="" /></a>
# 		</div>
# 		-->
# <div id="search">
# <form action="/search/list.asp" id="cse-search-box" method="get" name="form_search" onsubmit="return searchForm()">
# <input name="cx" type="hidden" value="partner-pub-9930086282638035:g8e0u1-r8xa">
# <input name="cof" type="hidden" value="FORID:9">
# <input name="ie" type="hidden" value="EUC-KR">
# <input name="q" size="12" type="hidden">
# <input name="sa" type="hidden" value="검색">
# <div class="find01">
# <select name="search" size="1" style="font-size:9pt;">
# <option value="">통합검색</option>
# <option value="media">뉴스</option>
# <option value="writer">기자명</option>
# <option value="content">컨텐츠</option>
# <option value="community">커뮤니티</option>
# <option value="tv">TV</option>
# <option value="c_company">상호검색</option>
# <option value="c_product">제품검색</option>
# </select>
# </div>
# <div class="find02"><input class="find" maxlength="20" name="find" onkeyup="inputCheckTopSearch(document.form_search);" type="text"/></div>
# <div class="find03"><input alt="검색" height="27" src="/images/new02/find.gif" type="image" width="36"/></div>
# </input></input></input></input></input></form>
# </div>
# </div>
# <div id="MainMenu_area">
# <div id="MainMenu">
# <div class="menu"><a href="/media/t_list.asp?kind=0" onfocus="this.blur();"><img alt="" height="45" src="/images/new/menu01.gif" width="90"/></a></div>
# <div class="menu"><a href="/media/list.asp?kind=1" onfocus="this.blur();"><img alt="" height="45" src="/images/new/menu02.gif" width="90"/></a></div>
# <div class="menu"><a href="/media/list.asp?kind=2" onfocus="this.blur();"><img alt="" height="45" src="/images/new/menu03.gif" width="90"/></a></div>
# <div class="menu"><a href="/media/list.asp?kind=3" onfocus="this.blur();"><img alt="" height="45" src="/images/new/menu04.gif" width="90"/></a></div>
# <div class="menu"><a href="/media/list.asp?kind=4" onfocus="this.blur();"><img alt="" height="45" src="/images/new/menu05.gif" width="90"/></a></div>
# <div class="menu"><a href="/media/list.asp?kind=5" onfocus="this.blur();"><img alt="" height="45" src="/images/new/menu06.gif" width="90"/></a></div>
# <div class="menu"><a href="/media/list.asp?kind=6" onfocus="this.blur();"><img alt="" height="45" src="/images/new/menu07.gif" width="90"/></a></div>
# </div>
# <div id="SubMenu">
# <ul>
# <li>
# <a href="/custom/member_login.asp" style="font-size:9pt;color:#494F67;font-weight:bold;">로그인</a>
# <img alt="" src="/images/new/bar01.gif"/>
# </li>
# <li>
# <a href="/custom/member_join.asp" style="font-size:9pt;color:#494F67;font-weight:bold;">회원가입</a>
# <img alt="" src="/images/new/bar01.gif"/>
# </li>
# <li>
# <a href="/guest/guest_login.asp" style="font-size:9pt;color:#494F67;font-weight:bold;">객원기자</a>
# <img alt="" src="/images/new/bar01.gif"/>
# </li>
# <li>
# <a href="/custom/news_jebo.asp" style="font-size:9pt;color:#494F67;font-weight:bold;">기사제보</a>
# <img alt="" src="/images/new/bar01.gif"/>
# </li>
# <li>
# <a href="/custom/scrap_list.asp" style="font-size:9pt;color:#494F67;font-weight:bold;">스크랩</a>
# 			</li>
# </ul>
# </div>
# </div>
# <div id="body">
# <div id="body_left">
# <div id="headline">
# <div id="head1">
# <div style="width:600px; height:45px;"><a href="/media/view.asp?idx=55243" onfocus="this.blur();"><img alt="" height="40" src="/pds/main/20170612mainword2.jpg" width="600"/></a></div>
# <div style="width:225px; float:left;"><a href="/media/view.asp?idx=55243"><img alt="" height="130" src="/pds/main/20170612smart.jpg" style="border:1px solid #DDDDDD;" width="210"/></a></div>
# <div style="width:370px; float:left;font-size:13px;text-align:justify;"><a href="/media/view.asp?idx=55243"><font color="#868890">최근 스마트폰은 일반적인 정보 검색을 넘어 금융 등 사회적인 활용성이 넓어지면서 스마트폰 이용률도 증가한 반면, 악성코드 수도 증가하는 추세다. 스마트폰이 악성코드에 감염되면 알아차리기 쉽지 않고 스마트폰 보안에 관심이 있는 사람이 아니라면 백신 이외에 떠오르는 방법도 없다. 그리고 스마트폰 악성코드 감염 여부를...</font></a><br>
# <img alt="" height="12" src="/images/icon_a.gif" style="margin-top:2px;" width="12"/>
# <a href="/media/view.asp?idx=55132&amp;kind=36" style="font-size:14px;color:#4D576C;font-weight:bold;">[대중문화와 사이버 개념 이해] 14화. 사이버 기밀성..</a><br>
# <img alt="" height="12" src="/images/icon_a.gif" style="margin-top:2px;" width="12"/>
# <a href="/media/view.asp?idx=53620&amp;kind=3" style="font-size:14px;color:#4D576C;font-weight:bold;">대중문화로 사이버 개념 쉽게 이해하기   </a><br>
# </br></br></br></div>
# </div>
# <iframe frameborder="0" height="26" id="hit_news" name="hit_news" src="/main_files/main_loop1.asp" width="625"></iframe>
# <div id="head2">
# <div style="width:600px; height:45px;margin-top:5px;"><a href="/media/view.asp?idx=55240" onfocus="this.blur();"><img alt="" height="40" src="/pds/main/honey-text.jpg" width="600"/></a></div>
# <div style="width:225px; float:left;"><a href="/media/view.asp?idx=55240"><img alt="" height="130" src="/pds/main/honey-thumb.jpg" style="border:1px solid #DDDDDD;" width="210"/></a></div>
# <div style="width:370px; float:left;font-size:13px;text-align:justify;"><a href="/media/view.asp?idx=55240"><font color="#868890">전쟁 시에 교란 작전이나 속임수를 활용하는 전략은 태고부터 존재해온 것이었다. 수천 년전, 중국의 손자는 “군사작전은 속임수로 이루어진다(병자궤도야)”고까지 썼다. IT 업계에서도 해커들을 방어하기 위해 속임수를 도입한 게 새롭지 않다. 가장 먼저 속임수를 사용한 건 클리포드 스톨(Clifford Stoll)이라는...</font></a><br>
# <img alt="" height="12" src="/images/icon_a.gif" style="margin-top:2px;" width="12"/>
# <a href="/media/view.asp?idx=47335&amp;kind=4" style="font-size:14px;color:#4D576C;font-weight:bold;">석유 게이지 노리는 해커들, 허니팟으로 유인 성공</a><br>
# <img alt="" height="12" src="/images/icon_a.gif" style="margin-top:2px;" width="12"/>
# <a href="/media/view.asp?idx=47288&amp;kind=4" style="font-size:14px;color:#4D576C;font-weight:bold;">슬슬 한계에 봉착한 허니팟, 그들이 가야할 방향은?</a><br>
# </br></br></br></div>
# </div>
# </div>
# <iframe frameborder="0" height="26" id="clipping_news" name="clipping_news" src="/main_files/main_loop2.asp" width="625"></iframe>
# <div id="body_left_wrap">
# <div id="body_left_01">
# <!--########## body_left_01 Start ##########-->
# <!--<IFRAME NAME="main_left_banner" id="main_left_banner" width="210" height="160" SRC="/main_files/main_right.asp" frameborder="0"></IFRAME>-->
# <div id="set_title"><span>개인정보보호 페어 2017 미리보기</span></div>
# <div id="set">
# <div id="set_item">
# <a href="/media/view.asp?idx=55190" onfocus="this.blur()"><img alt="" height="50" src="/media/upfiles/그림2(0).jpg" width="66"/></a>
# <p>
# <a href="/media/view.asp?idx=55190" onfocus="this.blur()"><font color="#4B586B"><b>가장 얇은 두께 그러나 보안은 최고!...</b></font></a><br>
# </br></p>
# </div>
# <div id="set_item">
# <a href="/media/view.asp?idx=55189" onfocus="this.blur()"><img alt="" height="50" src="/media/upfiles/20170612innerbus.jpg" width="66"/></a>
# <p>
# <a href="/media/view.asp?idx=55189" onfocus="this.blur()"><font color="#4B586B"><b>통합로그관리 등 원스톱 모니터링 체계...</b></font></a><br>
# </br></p>
# </div>
# <div id="set_item">
# <a href="/media/view.asp?idx=55188" onfocus="this.blur()"><img alt="" height="50" src="/media/upfiles/그림1(1).jpg" width="66"/></a>
# <p>
# <a href="/media/view.asp?idx=55188" onfocus="this.blur()"><font color="#4B586B"><b>개인정보 상시 모니터링 및 분석 솔루...</b></font></a><br>
# </br></p>
# </div>
# <div id="set_item">
# <a href="/media/view.asp?idx=55178" onfocus="this.blur()"><img alt="" height="50" src="/media/upfiles/20170608_184734.jpg" width="66"/></a>
# <p>
# <a href="/media/view.asp?idx=55178" onfocus="this.blur()"><font color="#4B586B"><b>데이터 유통관리 전문기업, 알엔비랩</b></font></a><br>
# </br></p>
# </div>
# <div id="set_item">
# <a href="/media/view.asp?idx=55140" onfocus="this.blur()"><img alt="" height="50" src="/media/upfiles/20170609jirans.jpg" width="66"/></a>
# <p>
# <a href="/media/view.asp?idx=55140" onfocus="this.blur()"><font color="#4B586B"><b>보안 컨설팅부터 솔루션 공급까지 원스...</b></font></a><br>
# </br></p>
# </div>
# </div>
# <div id="powerbiz">
# <img alt="" height="23" src="/images/new/main_title01.gif" width="210"/>
# <a href="/custom/banner_page.asp?idx=505" onfocus="this.blur();" target="_blank"><img alt="" border="0" height="65" id="powerbiz01" src="/images/banner/isc2_210x65.gif" width="210"/><a href="/custom/banner_page.asp?idx=500" onfocus="this.blur();" target="_blank"><img alt="" border="0" height="65" id="powerbiz02" src="/images/banner/cososys_main.gif" width="210"/><a href="/custom/banner_page.asp?idx=485" onfocus="this.blur();" target="_blank"><img alt="엔시큐어" border="0" height="65" id="powerbiz03" src="/images/banner/Arxan_210x65.jpg" width="210"/><a href="/custom/banner_page.asp?idx=434" onfocus="this.blur();" target="_blank"><img alt="" border="0" height="65" id="powerbiz04" src="/images/banner/powerbiz_CISO[1].jpg" width="210"/>
# </a></a></a></a></div>
# <div id="alarm_title"><a href="/media/s_list.asp?skind=5"><img alt="" src="/images/new/main_title02.gif"/></a>
# <div id="alarm">
# <div id="alarm_top"><a href="/media/view.asp?idx=55245&amp;skind=5" onfocus="this.blur()"><b>[6.12 버그리포트] CVE...</b></a></div>
# <div id="alarm_item1"><a href="/media/view.asp?idx=55245&amp;skind=5" onfocus="this.blur()"><img alt="" height="50" src="/media/upfiles/bug-thumb(274).jpg" width="66"/></a></div>
# <div id="alarm_item2"><a href="/media/view.asp?idx=55245&amp;skind=5" onfocus="this.blur()">현지 시각으로 6월 11일, 우리나라 시간으로는 대략 ...</a></div>
# <div id="alarm_dot"><img alt="" src="/images/new/line02.gif"/></div>
# <div id="alarm_title1"><a href="/media/view.asp?idx=55219&amp;skind=5" onfocus="this.blur()"><b>심상정 정의당 대표 홈피 등 ...</b></a></div>
# <div id="alarm_dot1"><img alt="" src="/images/new/line02.gif"/></div>
# <div id="alarm_title2"><a href="/media/view.asp?idx=55217&amp;skind=5" onfocus="this.blur()"><b>웹호스팅 업체 랜섬웨어 감염으...</b></a></div>
# </div>
# </div>
# <div id="GlobalReport_title"><a href="/media/s_list.asp?skind=d"><img alt="" src="/images/new/main_title03.gif"/></a>
# <div id="GlobalReport">
# <div id="GlobalReport_top"><a href="/media/view.asp?idx=55245&amp;skind=D" onfocus="this.blur()"><b>[6.12 버그리포트] CVE...</b></a></div>
# <div id="GlobalReport_item1"><a href="/media/view.asp?idx=55245&amp;skind=D" onfocus="this.blur()"><img alt="" height="50" src="/media/upfiles/bug-thumb(274).jpg" width="66"/></a></div>
# <div id="GlobalReport_item2"><a href="/media/view.asp?idx=55245&amp;skind=D" onfocus="this.blur()">현지 시각으로 6월 11일, 우리나라 시간으로는 대략 ...</a></div>
# <div id="GlobalReport_dot"><img alt="" src="/images/new/line02.gif"/></div>
# <div id="GlobalReport_title1"><a href="/media/view.asp?idx=55240&amp;skind=D" onfocus="this.blur()"><b>허니팟, 보안의 둘도 없는 보...</b></a></div>
# <div id="GlobalReport_dot1"><img alt="" src="/images/new/line02.gif"/></div>
# <div id="GlobalReport_title2"><a href="/media/view.asp?idx=55211&amp;skind=D" onfocus="this.blur()"><b>정보는 해킹당하는 게 아니라 ...</b></a></div>
# </div>
# </div>
# <div id="cyber_front_title"><a href="/media/s_list.asp?skind=6"><img alt="" src="/images/new/main_title13.gif"/></a>
# <div id="cyber_front">
# <div id="cyber_front_top"><a href="/media/view.asp?idx=55169&amp;skind=6" onfocus="this.blur()"><b>KISA, 개인정보 비식별조치...</b></a></div>
# <div id="cyber_front_item1"><a href="/media/view.asp?idx=55169&amp;skind=6" onfocus="this.blur()"><img alt="" height="50" src="/media/upfiles/20170608kisa1.jpg" width="66"/></a></div>
# <div id="cyber_front_item2"><a href="/media/view.asp?idx=55169&amp;skind=6" onfocus="this.blur()">한국인터넷진흥원(KISA, 원장 백기승)은 4차 산업혁...</a></div>
# <div id="cyber_front_dot"><img alt="" src="/images/new/line02.gif"/></div>
# <div id="cyber_front_title1"><a href="/media/view.asp?idx=55126&amp;skind=6" onfocus="this.blur()"><b>증가하는 IoT 보안 위협, ...</b></a></div>
# <div id="cyber_front_dot1"><img alt="" src="/images/new/line02.gif"/></div>
# <div id="cyber_front_title2"><a href="/media/view.asp?idx=55125&amp;skind=6" onfocus="this.blur()"><b>영국 런던 테러를 통해 본 사...</b></a></div>
# </div>
# </div>
# <div id="swm_title"><a href="http://www.securityworldmag.co.kr" target="_blank"><img alt="" src="/images/new/main_title08.gif"/></a>
# <div id="swm">
# <div id="swm_top"><a href="/media/view.asp?idx=55213" onfocus="this.blur()"><b>[보안카툰] 당신의 비밀번호도...</b></a></div>
# <div id="swm_item1"><a href="/media/view.asp?idx=55213" onfocus="this.blur()"><img alt="" height="50" src="/media/upfiles/001(759).jpg" width="66"/></a></div>
# <div id="swm_item2"><a href="/media/view.asp?idx=55213" onfocus="this.blur()">[카툰] 구멍보안! 블랙홀 상사 4. 당신의 비밀번호도...</a></div>
# <div id="swm_dot"><img alt="" src="/images/new/line02.gif"/></div>
# <div id="swm_title1"><a href="/media/view.asp?idx=55209" onfocus="this.blur()"><b>중남미 시장 노리는 기업, 보...</b></a></div>
# <div id="swm_dot1"><img alt="" src="/images/new/line02.gif"/></div>
# <div id="swm_title2"><a href="/media/view.asp?idx=55116" onfocus="this.blur()"><b>북미의 중심 뉴욕의 보안정책,...</b></a></div>
# </div>
# </div>
# <!--########## body_left_01 End ##########-->
# </div>
# <div id="body_left_02">
# <!--########## body_left_02 Start ##########-->
# <div id="main_list01">
# <ul>
# <li><a href="/media/view.asp?idx=55245&amp;kind=15"><b>[6.12 버그리포트] CVE-2017-9543 外</b></a></li><li><a href="/media/view.asp?idx=55242&amp;kind=3"><b>[인사] 서울미디어그룹 </b></a></li><li><a href="/media/view.asp?idx=55239&amp;kind=1"><b>[카드뉴스] 인터넷나야나 랜섬웨어 이슈, 육하원칙으로 알아..</b></a></li><li><a href="/media/view.asp?idx=55234&amp;kind=1"><b>인터넷나야나, 복구비용 마련 위해 자금 확보 중</b></a></li><li><a href="/media/view.asp?idx=55231&amp;kind=3"><b>네이버 이준호 前 CISO, 센스톤 공동대표로 책임 경영 </b></a></li><li><a href="/media/view.asp?idx=55213&amp;kind=5"><b>[보안카툰] 당신의 비밀번호도 혹시 111?</b></a></li><li><a href="/media/view.asp?idx=55190&amp;kind=35"><b>가장 얇은 두께 그러나 보안은 최고! 3M 프라이버시 필터</b></a></li><li><a href="/media/view.asp?idx=55189&amp;kind=35"><b>통합로그관리 등 원스톱 모니터링 체계는 이너버스의 LogC..</b></a></li><li><a href="/media/view.asp?idx=55229&amp;kind=1"><b>인터넷나야나 랜섬웨어 사태, 돈 내고 복구한 업체 나왔다</b></a></li><li><a href="/media/view.asp?idx=55230&amp;kind=14"><b>해킹 통한 가짜 뉴스가 일으킨 외교 비화, 국가 역할은?</b></a></li>
# </ul>
# </div>
# <iframe frameborder="0" height="120" id="main_banner_B" name="main_banner_B" src="/main_files/main_banner_1.asp" width="375"></iframe>
# <div id="main_list02">
# <ul>
# <li><a href="/media/view.asp?idx=55227&amp;kind=2"><b>6월 주의해야 할 생활 속 안전사고 예방대책 알아두세요!</b></a></li><li><a href="/media/view.asp?idx=55226&amp;kind=2"><b>조달청장, 우기철 집중 폭우 대비 ‘안전 점검’</b></a></li><li><a href="/media/view.asp?idx=55225&amp;kind=2"><b>대한민국 로봇산업 기술로드맵 공청회 개최</b></a></li><li><a href="/media/view.asp?idx=55224&amp;kind=2"><b>하천 분야 드론 기술, 국제 경쟁력 확인</b></a></li><li><a href="/media/view.asp?idx=55223&amp;kind=2"><b>사회재난 대응의 전문성을 키운다</b></a></li><li><a href="/media/view.asp?idx=55222&amp;kind=2"><b>비영리 협회·단체, 개인정보보호 실태 집중적으로 살핀다</b></a></li><li><a href="/media/view.asp?idx=55188&amp;kind=35"><b>개인정보 상시 모니터링 및 분석 솔루션으로 승부 ‘엔소프테..</b></a></li><li><a href="/media/view.asp?idx=55178&amp;kind=35"><b>데이터 유통관리 전문기업, 알엔비랩</b></a></li><li><a href="/media/view.asp?idx=55211&amp;kind=14"><b>정보는 해킹당하는 게 아니라 방치되고 있을 뿐</b></a></li><li><a href="/media/view.asp?idx=55228&amp;kind=1"><b>인터넷나야나 공격 해커, 26억 원 상당의 비트코인 요구 </b></a></li><li><a href="/media/view.asp?idx=55221&amp;kind=1"><b>한국은행, 어나니머스 공격 첩보 입수...비상태세 만전</b></a></li><li><a href="/media/view.asp?idx=55220&amp;kind=1"><b>국방부 장관에 송영무 전 해군참모총장 지명...국방개혁 적..</b></a></li><li><a href="/media/view.asp?idx=55212&amp;kind=3"><b>국내 대표 쇼핑몰·게임사 인터파크와 엔씨소프트, 보안인력 ..</b></a></li><li><a href="/media/view.asp?idx=55219&amp;kind=1"><b>심상정 정의당 대표 홈피 등 수천여개 사이트 랜섬웨어 피해..</b></a></li><li><a href="/media/view.asp?idx=55218&amp;kind=1"><b>[부고] 최진혁 경찰대학 법학과장 부친상</b></a></li><li><a href="/media/view.asp?idx=55217&amp;kind=1"><b>웹호스팅 업체 랜섬웨어 감염으로 언론사·대학 등 피해 속출..</b></a></li><li><a href="/media/view.asp?idx=55215&amp;kind=1"><b>[긴급] 웹호스팅 업체 랜섬웨어 감염! 중소 웹사이트로 피..</b></a></li><li><a href="/media/view.asp?idx=55210&amp;kind=14"><b>이젠 마우스 호버링 통해서도 멀웨어 감염된다</b></a></li><li><a href="/media/view.asp?idx=55208&amp;kind=14"><b>[주말판] 보안 까막눈은 사업도 못하는 때가 온다</b></a></li><li><a href="/media/view.asp?idx=55209&amp;kind=1"><b>중남미 시장 노리는 기업, 보안 키워드는 신변보호와 인증 ..</b></a></li><li><a href="/media/view.asp?idx=55206&amp;kind=3"><b>금융권 간편인증 서비스, 음성 뱅킹이 대세 되나    </b></a></li><li><a href="/media/view.asp?idx=55205&amp;kind=2"><b>서울시여성능력개발원, 비밀번호 초기화 문제 빠르게 보완</b></a></li><li><a href="/media/view.asp?idx=55204&amp;kind=1"><b>[카드뉴스] 멀웨어 유포, 폐쇄...SNS에 생긴 일들</b></a></li><li><a href="/media/view.asp?idx=55201&amp;kind=14"><b>[기자수첩] 듣고 싶지 않은 말 두 가지</b></a></li><li><a href="/media/view.asp?idx=55200&amp;kind=14"><b>IP 카메라의 위기 : 네 가지 멀웨어가 경쟁한다</b></a></li><li><a href="/media/view.asp?idx=55202&amp;kind=15"><b>[6.9 버그리포트] CVE-2016-9991 外</b></a></li><li><a href="/media/view.asp?idx=55199&amp;kind=14"><b>소프트웨어 보안, 생산업계에게서 배워야 할 게 있다</b></a></li><li><a href="/media/view.asp?idx=55192&amp;kind=1"><b>서울고속버스터미널 전광판 ‘랜섬웨어’ 감염! 대중교통 ‘비..</b></a></li><li><a href="/media/view.asp?idx=55140&amp;kind=35"><b>보안 컨설팅부터 솔루션 공급까지 원스탑 서비스 ‘지란지교에..</b></a></li><li><a href="/media/view.asp?idx=55187&amp;kind=2"><b>핀테크 기업, 금융전문가 1:1 자문 신청하세요!</b></a></li><li><a href="/media/view.asp?idx=55186&amp;kind=2"><b>취약계층 일자리 문제, 빅데이터가 도와준다</b></a></li><li><a href="/media/view.asp?idx=55185&amp;kind=2"><b>‘융합보안 시범사업’에 AI, 블록체인, 홈·가전, 데이터..</b></a></li><li><a href="/media/view.asp?idx=55184&amp;kind=2"><b>미래부, 정보보호 R&amp;D; 간담회 개최</b></a></li><li><a href="/media/view.asp?idx=55182&amp;kind=2"><b>민·관 합동 위기관리 매뉴얼 작동 실태 점검</b></a></li><li><a href="/media/view.asp?idx=55183&amp;kind=2"><b>안산시·제천시·여주시 지역 특색에 맞는 ICT 신규 서비스..</b></a></li>
# </ul>
# </div>
# <!--########## body_left_02 End ##########-->
# </div>
# </div>
# </div>
# <div id="body_right">
# <div id="right_top_banner"><iframe frameborder="0" height="120" id="main_banner_A" name="main_banner_A" src="/main_files/main_banner.asp" style="margin-bottom:8px;" width="345"></iframe></div>
# <div id="main_top4_area">
# <div id="main_top4">
# <div class="top_news" style="margin-right:20px;">
# <div class="top_news_item"><a href="/media/view.asp?idx=55239"><b>[카드뉴스] 인터넷나야나 랜섬웨어 이슈, 육...</b></a></div>
# <div class="top_news_item1"><a href="/media/view.asp?idx=55239"><img alt="" height="65" src="/pds/main/20170612nayna.JPG" width="70"/></a></div>
# <div class="top_news_item2"><a href="/media/view.asp?idx=55239">평온한 주말, 보안 담당자들을 깜놀하게 한 ...</a></div>
# </div>
# <div class="top_news">
# <div class="top_news_item"><a href="/media/view.asp?idx=55234"><b>인터넷나야나, 복구비용 마련 위해 자금 확보...</b></a></div>
# <div class="top_news_item1"><a href="/media/view.asp?idx=55234"><img alt="" height="65" src="/pds/main/20170612mirae.jpg" width="70"/></a></div>
# <div class="top_news_item2"><a href="/media/view.asp?idx=55234">에레보스 랜섬웨어로 큰 피해를 입고 있는 웹...</a></div>
# </div>
# <div class="top_news" style="margin-right:20px;">
# <div class="top_news_item"><a href="/media/view.asp?idx=55211"><b>정보는 해킹당하는 게 아니라 방치되고 있을 ...</b></a></div>
# <div class="top_news_item1"><a href="/media/view.asp?idx=55211"><img alt="" height="65" src="/pds/main/hood-thumb.jpg" width="70"/></a></div>
# <div class="top_news_item2"><a href="/media/view.asp?idx=55211">어두운 방, 검은 실루엣이 앉아 있다. 작은...</a></div>
# </div>
# <div class="top_news">
# <div class="top_news_item"><a href="/media/view.asp?idx=55213"><b>[보안카툰] 당신의 비밀번호도 혹시 111?</b></a></div>
# <div class="top_news_item1"><a href="/media/view.asp?idx=55213"><img alt="" height="65" src="/pds/main/20170612CARTOON.JPG" width="70"/></a></div>
# <div class="top_news_item2"><a href="/media/view.asp?idx=55213">구멍보안! 블랙홀 상사 4. 당신의 비밀번호...</a></div>
# </div>
# </div>
# </div>
# <div id="main_clipping_area">
# <div id="main_clipping">
# <a href="/media/s_list.asp?skind=i"><img alt="" height="26" src="/images/new/main_title14_1.gif" width="364"/></a>
# <ul>
# <li><img src="/search/images/directory/directory_dot02.gif"> <a href="/media/view.asp?idx=55244">퀀텀, 가상화 데이터 백업 지원 스토리지 솔루션 발...</a></img></li>
# <li><img src="/search/images/directory/directory_dot02.gif"> <a href="/media/view.asp?idx=55207">이스트시큐리티, 워너크라이 사태로 알약 매출 300...</a></img></li>
# <li><img src="/search/images/directory/directory_dot02.gif"> <a href="/media/view.asp?idx=55177">안랩, ‘안랩샘(SEM)’ 4기 수료식 개최 外</a></img></li>
# <li><img src="/search/images/directory/directory_dot02.gif"> <a href="/media/view.asp?idx=55160">이스트소프트, 오픈소스 권리단체 ‘OIN’ 회원사 ...</a></img></li>
# <li><img src="/search/images/directory/directory_dot02.gif"> <a href="/media/view.asp?idx=55124">안랩,  의료기관 대상 보안전략세미나 ‘안랩 ISF...</a></img></li>
# </ul>
# </div>
# <div id="main_clipping">
# <a href="/search/news_list.asp?search=title&amp;find=%B9%F6%B1%D7%B8%AE%C6%F7%C6%AE"><img alt="" height="26" src="/images/new/main_title14_4.gif" width="364"/></a>
# <ul>
# <li><img src="/search/images/directory/directory_dot02.gif"> <b>[2017-06-12]</b> <a href="/media/view.asp?idx=55245">[6.12 버그리포트] CVE-2017-...</a></img></li>
# <li><img src="/search/images/directory/directory_dot02.gif"> <b>[2017-06-09]</b> <a href="/media/view.asp?idx=55202">[6.9 버그리포트] CVE-2016-9...</a></img></li>
# </ul>
# </div>
# </div>
# <script language="javascript">
# function photo_news(num){
# 	if (num==1){
# 		photo0.style.display="";
# 		photo1.style.display="none";
# 		photo2.style.display="none";
#
# 		document.getElementsByName("news_img1")[0].style.border="3px solid #B71E1E";
# 		document.getElementsByName("news_img2")[0].style.border="3px solid #CCCCCC";
# 		document.getElementsByName("news_img3")[0].style.border="3px solid #CCCCCC";
# 	}
# 	if (num==2){
# 		photo0.style.display="none";
# 		photo1.style.display="";
# 		photo2.style.display="none";
#
# 		document.getElementsByName("news_img1")[1].style.border="3px solid #CCCCCC";
# 		document.getElementsByName("news_img2")[1].style.border="3px solid #B71E1E";
# 		document.getElementsByName("news_img3")[1].style.border="3px solid #CCCCCC";
# 	}
# 	if (num==3){
# 		photo0.style.display="none";
# 		photo1.style.display="none";
# 		photo2.style.display="";
#
# 		document.getElementsByName("news_img1")[2].style.border="3px solid #CCCCCC";
# 		document.getElementsByName("news_img2")[2].style.border="3px solid #CCCCCC";
# 		document.getElementsByName("news_img3")[2].style.border="3px solid #B71E1E";
# 	}
# }
# </script>
# <div id="photo_area">
# <a href="/media/s_list.asp?skind=H"><img border="0" height="26" src="/images/new/main_title14_6.gif" width="364"/></a>
# <div id="photo0">
# <div class="big_img"><a href="/media/view.asp?idx=55204&amp;skind=H"><img alt="" border="0" height="166" src="/media/upFiles/thumb(59).jpg" width="260"/></a></div>
# <ul class="small_img">
# <li><a href="/media/view.asp?idx=55204&amp;skind=H"><img alt="" border="0" height="50" name="news_img1" onmouseover="photo_news(1);" src="/media/upFiles/thumb(59).jpg" width="83"/></a></li>
# <li><a href="/media/view.asp?idx=55171&amp;skind=H"><img alt="" border="0" height="50" name="news_img2" onmouseover="photo_news(2);" src="/media/upFiles/000(441).jpg" width="83"/></a></li>
# <li><a href="/media/view.asp?idx=55102&amp;skind=H"><img alt="" border="0" height="50" name="news_img3" onmouseover="photo_news(3);" src="/media/upFiles/20170604DRONE1.jpg" width="83"/></a></li>
# </ul>
# <div class="photo_title">  <img align="absmiddle" alt="" src="/images/icon_a.gif"> <a href="/media/view.asp?idx=55204&amp;skind=H"><b>[카드뉴스] 멀웨어 유포, 폐쇄...SNS에 생...</b></a></img></div>
# </div>
# <div id="photo1">
# <div class="big_img"><a href="/media/view.asp?idx=55171&amp;skind=H"><img alt="" border="0" height="166" src="/media/upFiles/000(441).jpg" width="260"/></a></div>
# <ul class="small_img">
# <li><a href="/media/view.asp?idx=55204&amp;skind=H"><img alt="" border="0" height="50" name="news_img1" onmouseover="photo_news(1);" src="/media/upFiles/thumb(59).jpg" width="83"/></a></li>
# <li><a href="/media/view.asp?idx=55171&amp;skind=H"><img alt="" border="0" height="50" name="news_img2" onmouseover="photo_news(2);" src="/media/upFiles/000(441).jpg" width="83"/></a></li>
# <li><a href="/media/view.asp?idx=55102&amp;skind=H"><img alt="" border="0" height="50" name="news_img3" onmouseover="photo_news(3);" src="/media/upFiles/20170604DRONE1.jpg" width="83"/></a></li>
# </ul>
# <div class="photo_title">  <img align="absmiddle" alt="" src="/images/icon_a.gif"> <a href="/media/view.asp?idx=55171&amp;skind=H"><b>[포토뉴스] 2017 제4회 방산보안 워크샵 개...</b></a></img></div>
# </div>
# <div id="photo2">
# <div class="big_img"><a href="/media/view.asp?idx=55102&amp;skind=H"><img alt="" border="0" height="166" src="/media/upFiles/20170604DRONE1.jpg" width="260"/></a></div>
# <ul class="small_img">
# <li><a href="/media/view.asp?idx=55204&amp;skind=H"><img alt="" border="0" height="50" name="news_img1" onmouseover="photo_news(1);" src="/media/upFiles/thumb(59).jpg" width="83"/></a></li>
# <li><a href="/media/view.asp?idx=55171&amp;skind=H"><img alt="" border="0" height="50" name="news_img2" onmouseover="photo_news(2);" src="/media/upFiles/000(441).jpg" width="83"/></a></li>
# <li><a href="/media/view.asp?idx=55102&amp;skind=H"><img alt="" border="0" height="50" name="news_img3" onmouseover="photo_news(3);" src="/media/upFiles/20170604DRONE1.jpg" width="83"/></a></li>
# </ul>
# <div class="photo_title">  <img align="absmiddle" alt="" src="/images/icon_a.gif"> <a href="/media/view.asp?idx=55102&amp;skind=H"><b>[직접해보니] 고프로의 드론 ‘카르마’ 직접 조...</b></a></img></div>
# </div>
# </div>
# <script language="JavaScript">
# 	photo_news(1);
#
# 	j=1;
# 	var interval = setInterval(function () {
# 		photo_news(j);
# 		j++;
#
# 		if (j>3){
# 			j=1;
# 		}
# 	}, 2000);
# </script>
# <div id="main_HitNews_area">
# <div id="main_HitNews">
# <a href="/media/o_list.asp?kind=B"><img alt="" height="19" src="/images/new/main_title05.gif" width="120"/></a>
# <ul>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/1.gif" width="13"/> <a href="/media/view.asp?idx=55165&amp;skind=O">[단독] 서울시여성능력개발원, 회원 계정 같은 비번으로...</a></li>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/2.gif" width="13"/> <a href="/media/view.asp?idx=55229&amp;skind=O">인터넷나야나 랜섬웨어 사태, 돈 내고 복구한 업체 나왔...</a></li>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/3.gif" width="13"/> <a href="/media/view.asp?idx=55228&amp;skind=O">인터넷나야나 공격 해커, 26억 원 상당의 비트코인 요...</a></li>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/4.gif" width="13"/> <a href="/media/view.asp?idx=55192&amp;skind=O">서울고속버스터미널 전광판 ‘랜섬웨어’ 감염! 대중교통 ...</a></li>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/5.gif" width="13"/> <a href="/media/view.asp?idx=55215&amp;skind=O">[긴급] 웹호스팅 업체 랜섬웨어 감염! 중소 웹사이트로...</a></li>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/6.gif" width="13"/> <a href="/media/view.asp?idx=55217&amp;skind=O">웹호스팅 업체 랜섬웨어 감염으로 언론사·대학 등 피해 ...</a></li>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/7.gif" width="13"/> <a href="/media/view.asp?idx=55141&amp;skind=O">문재인 정부의 사이버안보 정책, 정보보호산업 육성과 병...</a></li>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/8.gif" width="13"/> <a href="/media/view.asp?idx=55131&amp;skind=O">애플 WWDC, AI 홈스피커 ’홈팟‘으로 스타트! 그...</a></li>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/9.gif" width="13"/> <a href="/media/view.asp?idx=55127&amp;skind=O">클라우드 확산과 함께 CASB에도 인공지능 접목</a></li>
# <li><img alt="" class="HitNews_img" height="13" src="/images/new/10.gif" width="13"/> <a href="/media/view.asp?idx=55219&amp;skind=O">심상정 정의당 대표 홈피 등 수천여개 사이트 랜섬웨어 ...</a></li>
# </ul>
# </div>
# </div>
# <div id="main_contents_area">
# <div id="main_contents_body">
# <a href="/security_contents/info/list.asp" onfocus="this.blur();"><img class="main_contents_title" height="29" src="/images/new/main_title16.gif" width="345"/></a>
# <div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=700&amp;code=01013" onfocus="this.blur();">Q&amp;A; 형식으로 알아보는 WannaCry 랜섬웨어 대응..</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=698&amp;code=06046" onfocus="this.blur();">소프트웨어 개발보안 가이드 </a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=697&amp;code=02016" onfocus="this.blur();">개인정보의 암호화 조치 안내서 </a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=696&amp;code=02018" onfocus="this.blur();">美 민주당 해킹 그룹 ‘APT28’ 분석 보고서</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=695&amp;code=01005" onfocus="this.blur();">금융회사 침해사고 준비도 가이드</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=694&amp;code=01010" onfocus="this.blur();">민간부문 침해사고 대응 안내서</a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=693&amp;code=01013" onfocus="this.blur();">중앙 관리 소프트웨어 보안 가이드 </a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=692&amp;code=02019" onfocus="this.blur();">2016년 3분기 사이버 위협 동향 보고서 </a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=691&amp;code=01001" onfocus="this.blur();">금융회사 경영진을 위한 정보보안 경영 가이드 </a></div><div id="main_contents_list"><span class="main_contents_icon"><img '="" src="/security_contents/img/pdf.gif"/></span><a class="main_contents_txt" href="/security_contents/info/view.asp?idx=685&amp;code=01004" onfocus="this.blur();">사이버 침해사고 정보공유 세미나 자료집(16년 3분기)..</a></div>
# </div>
# </div><script type="text/JavaScript">
# function fncChkSurvey() {
# var check=0;
# for(i=0;i<poll.poll_chek.length;i++) {
# if(poll.poll_chek[i].checked) {check=1;}
# }
# if(check<1) {alert('투표할 메뉴를 선택하세요'); return false;}
# return true;
# }
# </script>
# <div id="poll_title"><img alt="" src="/images/new/main_title07.gif"/></div>
# <form action="/media/poll_ok.asp?idx=165" method="post" name="poll" onsubmit="return fncChkSurvey()">
# <table id="poll_table">
# <tr><td class="poll_q" colspan="2"><b>GDPR(유럽 개인정보보호법) 시행이 1년 앞으로 다가왔습니다. 여러분의 회사는 얼마나 준비를 하고 계신가요?  </b></td></tr>
# <tr><td><input name="poll_chek" type="radio" value="1"/></td>
# <td class="poll_item">GDPR에 대한 모든 준비를 끝마쳤다</td></tr>
# <tr><td><input name="poll_chek" type="radio" value="2"/></td>
# <td class="poll_item">부족하지만 어느 정도 준비를 마쳤다 </td></tr>
# <tr><td><input name="poll_chek" type="radio" value="3"/></td>
# <td class="poll_item">이대로는 어렵다. 전문가의 손길이 필요하다</td></tr>
# <tr><td><input name="poll_chek" type="radio" value="4"/></td>
# <td class="poll_item">전혀 준비가 안됐다. 차라리 유럽관련 사업을 접겠다 </td></tr>
# <tr><td><input name="poll_chek" type="radio" value="5"/></td>
# <td class="poll_item">전혀 준비가 안됐다. GDPR 컨설팅 업체는 없는 건가? </td></tr>
# <tr><td><input name="poll_chek" type="radio" value="6"/></td>
# <td class="poll_item">GDPR이 뭐지? 잘 모른다 </td></tr>
# <tr><td><input name="poll_chek" type="radio" value="7"/></td>
# <td class="poll_item">기타(댓글로)</td></tr>
# <tr><td colspan="2">
# <input alt="투표하기" src="/media/images/right/poll_btn01.gif" type="image"/>      <a href="/media/poll_02.asp?idx=165"><img alt="" src="/media/images/right/poll_btn02.gif"/></a></td></tr>
# </table>
# </form>
# <script type="text/javascript">
# 			function inputCheckemail(form){
# 				re = /[~!\#$%^&*\()\=+"><:|']/gi;
# 				if(re.test(form.m_email.value)){
# 					alert("특수문자는 입력하실 수 없습니다.");
# 					form.m_email.value=form.m_email.value.replace(re,"");
# 					form.m_email.focus();
# 				}
# 			}
# 		</script>
# <form action="/jebo/newsletterOk.asp" method="post" name="frmLetter">
# <div id="newsletter_area">
# <a href="/newsletter/"><img alt="" class="newsletter_title" src="/images/new/main_title10.gif"/></a>
# <div id="newsletter">
# <div class="letter_txt">매일 다양한 보안뉴스 뉴스레터 및 최신 정보보호관련<br>정보 수신과 친구에게 추천을 원하시면 클릭해주세요.</br></div>
# <div class="letter1"><input class="text" id="m_email" maxlength="80" name="m_email" onclick="location.href='/newsletter/';" onkeyup="inputCheckemail(document.frmLetter)" type="text" value="E-mail"/></div>
# <div class="letter2"><a href="javascript:fncChkEmail();"><img alt="" src="images/body/letter_icon.gif"/></a></div>
# </div>
# </div>
# </form>
# </div>
# <div id="bottom_box_banner">
# <iframe frameborder="0" height="250" id="bottom_banner" name="bottom_banner" src="/include/bottom_banner.asp" width="990"></iframe>
# </div>
# </div>
# </div>
# <div id="bottom">
# <div id="main_news">
# <ul>
# <li><a href="/media/view.asp?idx=55243&amp;kind=35"><img alt="" height="140" src="/media/upfiles/20170612smart.jpg" width="220"/></a>
# <p><a href="/media/view.asp?idx=55243&amp;kind=35"><font color="#091545">[대중문화와 사이버 개념 이해] 15화. 스마트폰도...</font></a></p></li>
# <li> </li>
# <li><a href="/media/view.asp?idx=55240&amp;kind=14"><img alt="" height="140" src="/media/upfiles/honey-thumb.jpg" width="220"/></a>
# <p><a href="/media/view.asp?idx=55240&amp;kind=14"><font color="#091545">허니팟, 보안의 둘도 없는 보약이긴 하지만</font></a></p></li>
# <li> </li>
# <li><a href="/media/view.asp?idx=55229&amp;kind=1"><img alt="" height="140" src="/media/upfiles/000(448).jpg" width="220"/></a>
# <p><a href="/media/view.asp?idx=55229&amp;kind=1"><font color="#091545">인터넷나야나 랜섬웨어 사태, 돈 내고 복구한 업체 ...</font></a></p></li>
# <li> </li>
# <li><a href="/media/view.asp?idx=55230&amp;kind=14"><img alt="" height="140" src="/media/upfiles/fake-thumb.jpg" width="220"/></a>
# <p><a href="/media/view.asp?idx=55230&amp;kind=14"><font color="#091545">해킹 통한 가짜 뉴스가 일으킨 외교 비화, 국가 역...</font></a></p></li>
# </ul>
# </div>
# <div id="main_news">
# <ul>
# <li><a href="/media/view.asp?idx=55211&amp;kind=14"><img alt="" height="140" src="/media/upfiles/hood-thumb.jpg" width="220"/></a>
# <p><a href="/media/view.asp?idx=55211&amp;kind=14"><font color="#091545">정보는 해킹당하는 게 아니라 방치되고 있을 뿐</font></a></p></li>
# <li> </li>
# <li><a href="/media/view.asp?idx=55228&amp;kind=1"><img alt="" height="140" src="/media/upfiles/0100.jpg" width="220"/></a>
# <p><a href="/media/view.asp?idx=55228&amp;kind=1"><font color="#091545">인터넷나야나 공격 해커, 26억 원 상당의 비트코인...</font></a></p></li>
# <li> </li>
# <li><a href="/media/view.asp?idx=55215&amp;kind=1"><img alt="" height="140" src="/media/upfiles/20170610RAN1.jpg" width="220"/></a>
# <p><a href="/media/view.asp?idx=55215&amp;kind=1"><font color="#091545">[긴급] 웹호스팅 업체 랜섬웨어 감염! 중소 웹사이...</font></a></p></li>
# <li> </li>
# <li><a href="/media/view.asp?idx=55210&amp;kind=14"><img alt="" height="140" src="/media/upfiles/mouse-thumb.jpg" width="220"/></a>
# <p><a href="/media/view.asp?idx=55210&amp;kind=14"><font color="#091545">이젠 마우스 호버링 통해서도 멀웨어 감염된다</font></a></p></li>
# </ul>
# </div>
# </div>
# <div id="copyright">
# <ul>
# <li><a href="http://www.mediadot.co.kr" target="_blank">회사소개</a><span>|</span></li>
# <li><a href="/custom/ad_info01.asp?kind=9">광고안내</a><span>|</span></li>
# <li><a href="/ad_info/ad_info02.asp?kind=02">이용약관</a><span>|</span></li>
# <li class="bottom_menu1"><a href="/ad_info/ad_info03.asp?kind=03">개인정보 취급방침</a><span>|</span></li>
# <li><a href="/ad_info/ad_info04.asp?kind=04">청소년 보호정책</a><span>|</span></li>
# <li><a href="/custom/customer_center.asp?kind=8">고객센터</a><span>|</span></li>
# <li><a href="/custom/company_info05.asp?kind=10">제휴안내</a><span>|</span></li>
# <li><a href="http://www.infothebooks.com" target="_blank">관련서적</a><span>|</span></li>
# <li><img alt="" src="/images/new/rss.gif"/> <a href="/custom/news_rss.asp" onfocus="this.blur();">RSS 서비스</a><span>|</span></li>
# <li><img alt="" id="inc" src="/images/new/inc.jpg"/></li>
# <li><img alt="" id="kina" src="/images/new/kina02.jpg"/></li>
# <!--<li><img src="/images/bottom/bottom_icon01.gif" alt="" /> <a href="/search/direc_record.asp">기업 등록하기</a></li>-->
# </ul>
# <div id="address1">
# 	등록번호 : 서울 아00181 | 등록연월일 : 2006년 3월 17일 | 사업자등록번호 : 407-86-00506 | 대표 : 최정식 | 한국인터넷신문위원회 이사社, 한국인터넷신문협회 이사社<br>
# 	주소 : 서울시 마포구 마포대로 25 (마포동, 신한디엠빌딩 13층) (우. 04167) | 전화 : 02-719-6931 | 팩스 : 02-715-8245 | E-mail : <a href="mailto:helpdesk@boannews.com">helpdesk@boannews.com</a>
# </br></div>
# <div id="address2">
# 	Copyrightⓒ 2005 <a href="http://www.mediadot.co.kr" target="_blank"><b>Mediadot Corp.</b></a> All rights reserved.
# 	</div>
# </div>
# <div id="scroll_banner1" style="top:165px;left:50%;margin-left:-605px;width:100px;height:800px;position:absolute;z-index:200">
# <a href="https://www.s1.co.kr" target="_blank"><img border="0" height="350" src="/images/banner/new_S1.jpg" width="100"/></a>
# <a href="http://weeds.co.kr/" target="_blank"><img border="0" height="350" src="/images/banner/new_weeds.gif" style="margin-top:10px;" width="100"/></a>
# </div>
# <div id="scroll_banner2" style="top:165px;left:50%;margin-left:505px;width:100px;height:800px;position:absolute;z-index:200">
# <a href="http://www.hanwha-security.com/index.do" target="_blank"><img border="0" height="350" src="/images/banner/new_hanwha.jpg" width="100"/></a>
# <a href="http://pisfair.org/2017/" target="_blank"><img border="0" height="350" src="/images/banner/banner100x350_PISFAIR.jpg" style="margin-top:10px;" width="100"/></a>
# </div>
# </body>
# </html>
# '\nOutput:\n<a href="/media/view.asp?idx=55213&amp;kind=5"><b>[보안카툰] 당신의 비밀번호도 혹시 111?</b></a></li><li><a href="/media/view.asp?idx=55190&amp;kind=35"><b>가장 얇은 두께 그러나 보안은 최고! 3M 프라이버시 필터</b></a></li><li><a href="/media/view.asp?idx=55189&amp;kind=35"><b>통합로그관리 등 원스톱 모니터링 체계는 이너버스의 LogC..</b></a></li><li><a href="/media/view.asp?idx=55229&amp;kind=1"><b>인터넷나야나 랜섬웨어 사태, 돈 내고 복구한 업체 나왔다</b></a></li><li><a href="/media/view.asp?idx=55230&amp;kind=14"><b>해킹 통한 가짜 뉴스가 일으킨 외교 비화, 국가 역할은?</b></a></li>\n</ul>\n</div>\n<iframe frameborder="0" height="120" id="main_banner_B" name="main_banner_B" src="/main_files/main_banner_1.asp" width="375"></iframe>\n<div id="main_list02">\n'

# %% [markdown]
# # 02 Beautilful Soup
#
# ## 1) url 요청하기

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen("http://www.daum.net")
bsObj = BeautifulSoup(html.read(), "html.parser")
print(bsObj.h1)
# Out:
# <h1 class="tit_daum #logosearch">
# <a class="link_daum #logo" href="http://www.daum.net/" rel="home">
# <img alt="Daum" class="img_thumb" height="94" id="daum" src="https://t1.daumcdn.net/daumtop_chanel/op/20170315064553027.png" width="180"/>
# </a>
# </h1>

# %%
bsObj.html
# Out:
# <html class="" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta content="https://www.daum.net/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Daum" property="og:title"/>
# <meta content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" property="og:image"/>
# <meta content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum" property="og:description"/>
# <meta content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico" name="msapplication-task"/>
# <meta content="name=미디어다음;action-uri=http://media.daum.net/;icon-uri=/media_favicon.ico" name="msapplication-task"/>
# <meta content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico" name="msapplication-task"/>
# <meta content="origin" name="referrer"/>
# <link href="//t1.daumcdn.net/daumtop_chanel/op/OpenSearch.xml" rel="search" title="다음" type="application/opensearchdescription+xml"/>
# <style type="text/css">
# @charset "utf-8";
# body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,button{margin:0;padding:0}
# fieldset,img{border:0 none}
# dl,ul,ol,menu,li{list-style:none}
# blockquote, q{quotes: none}
# blockquote:before, blockquote:after,q:before, q:after{content:'';content:none}
# input,select,textarea,button{vertical-align:middle}
# input::-ms-clear{display:none}
# button{border:0 none;background-color:transparent;cursor:pointer}
# body{background:#fff;direction:ltr;-webkit-text-size-adjust:none}
# body,th,td,input,select,textarea,button{font-size:13px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,'Malgun Gothic','맑은 고딕',dotum,'돋움',sans-serif;color:#222;letter-spacing:-1px}
# .os_mac body,.os_mac th,.os_mac td,.os_mac input,.os_mac select,.os_mac textarea,.os_mac button{letter-spacing:0}
# a{color:#222;text-decoration:none}
# a:hover{color:#118eff;text-decoration:underline}
# a:active{background-color:transparent}
# address,caption,cite,code,dfn,em,var{font-style:normal;font-weight:normal}
# .ir_pm{display:block;overflow:hidden;font-size:1px;line-height:0;text-indent:-9999px}
# .ir_wa{display:block;overflow:hidden;position:relative;width:100%;height:100%;z-index:-1}
# .screen_out{overflow:hidden;position:absolute;width:0;height:0;line-height:0;text-indent:-9999px}
# .show{display:block}
# .hide{display:none}
# .d_index{position:relative;width:100%}
# .d_index .shortcut_g{position:absolute;top:-34px;left:0;height:33px;padding:0 20px 0 26px;border-bottom:1px solid #3f4243;font-size:11px;line-height:14px;background-color:#26292a;color:#fff;letter-spacing:-1px;text-align:center}
# .d_index .shortcut_g:active,
# .d_index .shortcut_g:focus{overflow:hidden;top:0;text-decoration:none;z-index:101}
# .d_index .shortcut_g:active,
# .d_index .shortcut_g:hover{color:#fff}
# .d_index .shortcut_g .inner_shortcut{display:inline-block;padding-right:10px;margin-top:8px;background-position:100% -220px;vertical-align:top}
# .os_mac .d_index .shortcut_g .inner_shortcut{margin-top:11px;background-position:100% -223px}
# .ico_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_170828.png) no-repeat 0 0}
# .ico_vert{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_vert_170724.png) no-repeat 0 0}
# .txt_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/txt_pctop_170711.png) no-repeat 0 0;letter-spacing:-1px;white-space:nowrap}
# .bg_pctop{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat 0 0}
# .num_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/num_pctop_170405.png) no-repeat 0 0}
# .img_thumb{display:block;vertical-align:top}
# .frame_g{position:absolute;top:0;left:0;border:1px solid #000;opacity:0.08;filter:alpha(opacity=8)}
# .thumb_g{display:block;position:relative}
# #daumWrap{position:relative;min-width:1080px}
# .os_mac #daumWrap{transform:translate3d(0px, 0px, 0px)}
# .head_daum{position:relative;z-index:100}
# .cont_main{position:relative;width:990px;margin:15px auto 0}
# .cont_topic{overflow:hidden;position:relative;z-index:0;width:100%;border-top:1px solid #ececec;background-color:#fbfbfc;background-position:50% 100%;background-repeat:no-repeat}
# .feature_tmp{display:inline-block;vertical-align:top}
# .wrap_main{padding-bottom:40px;clear:both;*zoom:1}
# .wrap_main:after{display:block;visibility:hidden;height:0;font-size:0;clear:both;content:''}
# .cmain_tmp{float:left;width:655px;margin-right:35px}
# .wing_tmp{float:left;width:300px}
# .foot_daum{border-top:1px solid #888}
# .foot_daum .inner_foot{overflow:hidden;position:relative;width:990px;margin:0 auto;padding:37px 0 78px}
# .foot_daum .link_logo{float:left}
# .foot_daum .info_notice{overflow:hidden;padding:0 250px 0 30px}
# .foot_daum .tit_notice{float:left;font-size:13px}
# .foot_daum .link_notice{display:block;padding-right:9px;background-position:100% -169px}
# .foot_daum .link_notice:hover{color:#222}
# .foot_daum .list_notice{overflow:hidden;width:542px;height:19px;padding-left:9px}
# .foot_daum .list_notice .link_info{display:block;overflow:hidden;text-overflow:ellipsis;white-space:nowrap}
# .foot_daum .list_notice .link_info:hover{color:#222}
# .foot_daum .search_foot{position:absolute;top:32px;right:0}
# .foot_daum .box_search{position:relative;z-index:1;width:209px;height:28px;border:1px solid #c8c8c8}
# .foot_daum .search_on{border-color:#0089ff}
# .foot_daum .tf_keyword{float:left;width:164px;margin:5px 0 0 9px;border:1px solid transparent;line-height:19px;outline:0}
# .foot_daum .btn_search{float:right;width:32px;height:28px;line-height:28px;background-position:0 -230px;background-color:transparent}
# .foot_daum .link_svcall{position:absolute;top:81px;right:0;padding-right:10px;font-weight:bold;color:#888;background-position:100% -194px}
# .foot_daum .info_policy{padding:23px 250px 0 0}
# .foot_daum .info_policy .link_policy{font-size:12px;color:#888}
# .foot_daum .info_policy .txt_dot{padding:0 2px;font-size:12px;color:#888}
# .foot_daum .txt_copyright{display:block;padding-top:6px;font-size:11px;color:#888}
# .foot_daum .txt_copyright .link_kakao{color:#888}
# .os_mac .foot_daum .info_notice{padding:3px 250px 0 31px}
# .os_mac .foot_daum .link_notice{padding-right:12px;background-position-y:-172px}
# .os_mac .foot_daum .tf_keyword{margin-top:4px}
# .os_mac .foot_daum .link_svcall{top:83px;background-position-y:-196px}
# .os_mac .foot_daum .info_policy{padding-top:24px}
# .os_mac .foot_daum .txt_copyright{padding-top:5px}
# .d_head{border-bottom:1px solid #ececec}
# .d_head .inner_head{position:relative;z-index:1;width:1080px;height:150px;margin:0 auto}
# .tit_daum{overflow:hidden;float:left;width:180px;height:150px;text-align:center}
# .link_daum{overflow:hidden;display:block;margin:28px auto}
# .link_launch{position:absolute;top:6px;left:45px;padding-right:8px;font-size:11px;color:#888;background-position:100% -18px}
# .os_mac .link_launch{top:9px;background-position:100% -21px}
# .wrap_search{float:left;position:relative;margin-top:50px}
# .wrap_search .d_sch{background-color:#fff}
# .head_daum .box_search{position:relative;height:44px;margin:1px 1px 0 0;border:1px solid #0089ff;border-radius:1px}
# .head_daum .box_search .inner_search{position:relative;z-index:1;height:44px;padding:0 60px 0 14px}
# .head_daum .box_search::before, .head_daum .box_search .inner_search::before, .head_daum .box_search::after{position:absolute;left:0;right:100%;height:1px;content:'';background-color:#0089ff}
# .head_daum .box_search::before{top:-1px}
# .head_daum .box_search::after{bottom:-1px}
# .head_daum .box_search:hover::before, .head_daum .box_search:hover::after{right:0;transition-property:right;transition-duration:0.8s;background:linear-gradient(to right, #86aaff, #70bc4c, #ffbe00, #f46e85)}
# .head_daum .box_search:hover .inner_search::before{top:-1px;bottom:-1px;left:auto;right:-1px;width:1px;height:46px;background-color:#f46e85;transition-property:height;transition-delay:0.8s}
# .head_daum .tf_keyword{float:left;width:442px;margin-top:7px;border:1px solid transparent;font-size:18px;line-height:24px;background-color:transparent;outline:0;ime-mode:active;-webkit-appearance:none}
# .head_daum .btn_search{position:absolute;top:0;right:0;width:49px;height:42px;margin:1px;line-height:44px;background-position:-40px -231px;background-color:transparent}
# .slide_favorsch{overflow:hidden;width:480px;height:28px}
# .list_favorsch{overflow:hidden;padding-top:7px}
# .list_favorsch li{float:left;padding-right:10px}
# .list_favorsch .link_favorsch{display:block;font-size:12px;color:#555}
# .head_daum .page_pctop{z-index:1;right:1px;bottom:3px}
# .head_bnr{position:absolute;top:33px;right:45px}
# .head_bnr .link_headbnr{display:block}
# .os_mac .head_daum .box_search{margin-top:0}
# .os_mac .head_daum .tf_keyword{margin-top:11px}
# .os_mac .list_favorsch{padding-top:10px}
# .os_mac .list_favorsch li{padding-right:14px}
# .daumSuggestWrap{position:relative;margin-right:90px;clear:both}
# .suggestBox{position:absolute;top:45px;left:0;z-index:9999;width:520px;padding:0;background:none}
# .baseBox{border-top:1px solid #dcdcdc;font-size:12px;line-height:17px;font-family:'굴림',gulim,sans-serif;background-color:#fff}
# .os_mac .baseBox{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .list{padding:7px 0 13px;border-left:1px solid #dcdcdc;border-right:1px solid #dcdcdc;color:#333;background-color:#fff}
# .suggestBox.reverseType .list{padding:3px 0 7px;color:#333}
# .suggestBox .baseBox li{overflow:hidden;height:26px;padding:0 16px;line-height:26px;text-align:left;cursor:pointer}
# .suggestBox li .item{display:block;height:100%}
# .suggestBox li .item:hover{text-decoration:none}
# .suggestBox .list .on{background-color:#f6f6f6}
# .suggestBox li strong{font-weight:normal;color:#0089ff}
# .suggestBox .line{overflow:hidden;height:1px;margin:7px 0px 6px;padding:0;font-size:1px;line-height:1px;background-color:#e5e5e5}
# .suggestBox .guide{padding:15px 10px;color:#555}
# .suggestBox .footer{position:relative;height:20px;padding:8px 12px 4px 7px;border:1px solid #dcdcdc;border-top:1px solid #ececec;font-size:11px;background-color:#fbfbfb;letter-spacing:-1px;clear:both}
# .suggestBox.reverseType .footer{border-top-color:#dcdcdc;border-bottom-color:#ededed}
# .suggestBox .footer .fl{float:left}
# .suggestBox .footer .fr{float:right}
# .suggestBox .footer .btn_close{padding-left:12px;background-position:0 -939px}
# .suggestBox .footer .bar{display:none;padding:0 2px;color:#ddd}
# .suggestBox .footer .fl .bar{padding:0 2px 0 1px}
# .suggestBox .footer .offGuide{display:none;position:absolute;right:0;bottom:19px;width:211px;height:27px;background:url(//search1.daumcdn.net/search/statics/common/pi/suggest_service.gif) no-repeat;text-indent:-999em}
# .suggestBox .footer .offSuggest{display:none}
# .os_mac .suggestBox .list{padding:9px 0 11px}
# .os_mac .suggestBox .baseBox li{padding:0 17px}
# .suggestBox a{color:#777}
# .suggestBox .answer{border-left:1px solid #dcdcdc;border-right:1px solid #dcdcdc}
# .suggestBox .answer span{cursor:pointer}
# .suggestBox .baseBox li a{font-size:14px;color:#333;font-family:'돋움',dotum,sans-serif;text-decoration:none}
# .os_mac .suggestBox .baseBox li a{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .line{display:block;overflow:hidden;clear:both}
# .suggestBox .b_line{border-bottom:1px solid #ededed}
# .suggestBox .suggest_exact{display:block;overflow:hidden;height:40px;padding:12px 0 11px 18px}
# .suggestBox .suggest_exact:hover{text-decoration:none}
# .suggestBox .e_on{background-color:#f8f8f8;text-decoration:none}
# .suggestBox .suggest_exact .txt_exact{overflow:hidden;float:left;height:44px;margin-top:0;background-position:0 0}
# .suggestBox .suggest_exact .txt_unit{font-size:14px;font-family:arial,sans-serif}
# .suggestBox .suggest_exact .tit{margin-left:-1px;font-weight:normal;font-size:12px;line-height:18px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .cont{display:block}
# .suggestBox .suggest_exact .txt_cont{margin-right:4px;font-weight:bold;font-size:14px;line-height:16px;font-family:'돋움',dotum,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num1{font-size:18px;line-height:20px;font-family:tahoma,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num2{margin-left:3px;font-size:12px;line-height:14px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num3{font-size:20px;line-height:23px;font-family:arial,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num4{margin-left:-3px;font-size:12px;line-height:14px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_exact .ico_suggest2{background:url(//search1.daumcdn.net/search/statics/common/pi/ico/ico_suggest_20110721.gif) no-repeat 0 0}
# .suggestBox .suggest_exact .txt_exact .ico_celsius{background:none}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_up{padding-left:11px;background-position:0 -58px}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_down{padding-left:11px;background-position:0 -98px}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_equal{padding-left:11px;background-position:0 -75px}
# .suggestBox .suggest_exact .txt_blue{color:#007aff}
# .suggestBox .suggest_exact .txt_blue2{color:#007aff}
# .suggestBox .suggest_exact .txt_red{color:#e52d38}
# .suggestBox .suggest_exact .txt_red2{color:#e52d38}
# .suggestBox .suggest_exact .txt_time{float:right;margin:25px 16px 0 0;font-size:11px;font-family:'돋움',dotum,sans-serif;color:#a1a1a1}
# .suggestBox .suggest_exact .ico_celsius{width:12px;height:13px;font-family:arial,sans-serif;background-position:right 5px}
# .suggestBox .suggest_exact .bar{font-size:14px;color:#dedede}
# .suggestBox .wrap_today{overflow:hidden;height:21px;padding:4px 10px 2px 9px;line-height:21px}
# .suggestBox .wrap_today .cont{font-size:14px;color:#333;text-decoration:none}
# .suggestBox .wrap_today .cont_import{font-weight:normal;color:#ea570a}
# .os_mac .suggestBox .suggest_exact .tit{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_num2{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_num4{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_time{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .ico_lotto{float:left;width:28px;height:28px;margin:6px 5px 0 0;border-radius:20px;text-align:center}
# .suggestBox .ico_lotto .txt_num{display:inline-block;margin-top:7px;font-size:14px;line-height:1;font-family:arial,sans-serif;color:#fff;vertical-align:top}
# .suggestBox .num1{background-color:#f6a800}
# .suggestBox .num10{background-color:#4155cb}
# .suggestBox .num20{background-color:#f64d61}
# .suggestBox .num30{background-color:#585d6e}
# .suggestBox .num40{background-color:#f6a800}
# .suggestBox .plus{width:8px;height:8px;margin:16px 8px 0 4px;background:url(//search1.daumcdn.net/search/statics/common/pi/ico/ico_suggest_20110721.gif) no-repeat 0 -40px;text-indent:-9999px;opacity:0.5}
# .suggestBox .suggest_exact .ico_suggest{padding-left:59px;color:#555;background:url(//search1.daumcdn.net/search/statics/common/pi/weather/ico_weather_m.png) no-repeat}
# .suggestBox .ico_suggest .cont .screen_out{position:static;font-size:14px;font-family:arial,sans-serif;text-indent:0}
# .suggestBox .suggest_exact .txt_exact{overflow:hidden;float:left;height:44px;margin-top:0}
# .suggestBox .suggest_exact .ico_w00{background-position:0 -1620px}
# .suggestBox .suggest_exact .ico_w01{background-position:0 0}
# .suggestBox .suggest_exact .night .ico_w01{background-position:0 -60px}
# .suggestBox .suggest_exact .ico_w02{background-position:0 -120px}
# .suggestBox .suggest_exact .night .ico_w02{background-position:0 -180px}
# .suggestBox .suggest_exact .ico_w03{background-position:0 -240px}
# .suggestBox .suggest_exact .night .ico_w03{background-position:0 -300px}
# .suggestBox .suggest_exact .ico_w04{background-position:0 -360px}
# .suggestBox .suggest_exact .ico_w05{background-position:0 -420px}
# .suggestBox .suggest_exact .night .ico_w05{background-position:0 -480px}
# .suggestBox .suggest_exact .ico_w06{background-position:0 -540px}
# .suggestBox .suggest_exact .night .ico_w06{background-position:0 -600px}
# .suggestBox .suggest_exact .ico_w07{background-position:0 -660px}
# .suggestBox .suggest_exact .ico_w08{background-position:0 -720px}
# .suggestBox .suggest_exact .ico_w09{background-position:0 -780px}
# .suggestBox .suggest_exact .ico_w10{background-position:0 -840px}
# .suggestBox .suggest_exact .night .ico_w10{background-position:0 -900px}
# .suggestBox .suggest_exact .ico_w11{background-position:0 -960px}
# .suggestBox .suggest_exact .ico_w12{background-position:0 -1020px}
# .suggestBox .suggest_exact .ico_w13{background-position:0 -1080px}
# .suggestBox .suggest_exact .night .ico_w13{background-position:0 -1140px}
# .suggestBox .suggest_exact .ico_w14{background-position:0 -1200px}
# .suggestBox .suggest_exact .ico_w15{background-position:0 -1260px}
# .suggestBox .suggest_exact .ico_w16{background-position:0 -1320px}
# .suggestBox .suggest_exact .night .ico_w16{background-position:0 -1380px}
# .suggestBox .suggest_exact .ico_w17{background-position:0 -1440px}
# .suggestBox .suggest_exact .ico_w18{background-position:0 -1500px}
# .suggestBox .suggest_exact .ico_w19{background-position:0 -1560px}
# #daumSuggestWrap{display:none}
# .d_service{border-bottom:1px solid #888}
# .d_service .inner_service{position:relative;width:990px;height:45px;margin:0 auto}
# .menu_service{float:left;position:relative;width:660px}
# .menu_service .link_more{overflow:hidden;float:left;width:60px;height:25px;padding:10px 0 9px;line-height:20px;background-position:0 8px;background-color:transparent;text-align:center}
# .menu_on .link_more{background-position:-60px 8px}
# .list_mainsvc{float:left}
# .list_mainsvc li{float:left;height:45px}
# .list_mainsvc .txt_pctop{display:block;height:25px;padding:10px 0;font-weight:bold;font-size:13px;line-height:25px;background-color:transparent;text-align:center}
# .list_mainsvc .link_cafe{width:30px;background-position:0 -30px}
# .list_mainsvc .link_mail{width:36px;background-position:-30px -30px}
# .list_mainsvc .link_news{width:37px;background-position:-66px -30px}
# .list_mainsvc .link_map{width:36px;background-position:-103px -30px}
# .list_mainsvc .link_stock{width:37px;background-position:-139px -30px}
# .list_mainsvc .link_shopping{width:36px;background-position:-176px -30px}
# .list_mainsvc .link_kakaotv{width:64px;background-position:-212px -30px}
# .list_mainsvc .link_webtoon{width:37px;background-position:-276px -30px}
# .list_mainsvc .link_blog{width:48px;background-position:-313px -30px}
# .list_mainsvc .link_brunch{width:47px;background-position:-361px -30px}
# .list_mainsvc .link_dic{width:36px;background-position:-408px -30px}
# .list_mainsvc .link_game{width:37px;background-position:-444px -30px}
# .list_mainsvc .link_starplay{width:59px;background-position:-481px -30px}
# .list_mainsvc .link_together{width:59px;background-position:-540px -30px}
# .service_layer{display:none;position:absolute;top:45px;left:0;width:653px;border:1px solid #888;background-color:#fff}
# .menu_on .service_layer{display:block}
# .service_layer .layer_body{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_line.gif) repeat-y 0 0}
# .service_layer .sort_service{float:left;width:94px;padding:0 0 15px 15px}
# .service_layer .sort_service.fst{padding-left:14px}
# .service_layer .sort_service dt{margin:11px 0 4px;font-weight:bold;font-size:12px}
# .service_layer .sort_service dt.tit_split{float:left;margin-top:22px;padding-right:9px;background-position:100% 5px}
# .service_layer .sort_service dd{clear:both;font-size:12px;line-height:22px}
# .service_layer .sort_service .link_svc{color:#555}
# .service_layer .sort_service .link_svc:hover{color:#118eff}
# .service_layer .sort_service .ico_new{display:inline-block;width:11px;height:11px;margin:3px 0 0 2px;font-size:0;line-height:0;background-position:-160px -80px;vertical-align:top;text-indent:-9999px}
# .service_layer .layer_foot{overflow:hidden;height:32px;border-top:1px solid #ececec;background-color:#fbfbfb}
# .service_layer .layer_foot .link_total{float:left;padding-right:8px;margin-left:13px;font-size:11px;line-height:29px;color:#555;background-position:100% -12px}
# .service_layer .layer_foot .btn_close{float:right;padding:0 13px;margin:2px;font-size:11px;line-height:24px;color:#888}
# .os_mac .service_layer .sort_service{padding-bottom:12px}
# .os_mac .service_layer .sort_service dt{margin:14px 0 4px}
# .os_mac .service_layer .sort_service dt.tit_split{background-position:100% 3px}
# .os_mac .service_layer .layer_foot .link_total{padding-right:10px;margin-left:14px;line-height:32px;background-position:100% -12px}
# .os_mac .service_layer .layer_foot .btn_close{padding:0 12px;line-height:28px}
# .today_base{float:right;position:relative;height:45px}
# .today_base .comp_base{display:inline-block;vertical-align:top}
# .today_base .img_weather{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/img_weather_170628.png);background-repeat:no-repeat;font-size:0;line-height:0;text-indent:-9999px}
# .today_base .txt_temper{float:left;font-size:14px;font-family:tahoma,arial,sans-serif;letter-spacing:0}
# .os_mac .today_base .txt_temper{font-family:helvetica,arial,sans-serif}
# .info_today{float:left;font-size:13px}
# .info_today .date_today{float:left;height:24px;padding-top:10px;line-height:20px;letter-spacing:0}
# .info_today .txt_part{float:left;margin-right:5px;font-weight:bold;line-height:24px}
# .info_today .link_weather{float:left;height:25px;margin-left:16px;padding:8px 0 12px;line-height:24px;text-align:right}
# .info_today .link_weather:hover{color:#222;text-decoration:none}
# .info_today .list_weather{float:left;overflow:hidden;height:25px}
# .info_today .list_weather li{overflow:hidden;height:25px}
# .os_mac .info_today .date_today{line-height:26px}
# .os_mac .info_today .txt_part{line-height:30px}
# .os_mac .info_today .link_weather{line-height:26px}
# .os_mac .info_today .link_weather .ico_more{margin-top:10px}
# .info_today .img_weather{float:left;width:26px;height:26px;margin:1px 4px 0 0;vertical-align:top}
# .info_today .ico_wm01{background-position:0 -240px}
# .info_today .night .ico_wm01{background-position:-30px -240px}
# .info_today .ico_wm02{background-position:-60px -240px}
# .info_today .night .ico_wm02{background-position:-90px -240px}
# .info_today .ico_wm03{background-position:0 -270px}
# .info_today .night .ico_wm03{background-position:-30px -270px}
# .info_today .ico_wm04{background-position:-60px -270px}
# .info_today .ico_wm07{background-position:-90px -270px}
# .info_today .ico_wm09{background-position:0 -300px}
# .info_today .ico_wm10{background-position:-30px -300px}
# .info_today .night .ico_wm10{background-position:-60px -300px}
# .info_today .ico_wm11{background-position:-90px -300px}
# .info_today .ico_wm14{background-position:0 -330px}
# .info_today .ico_wm17{background-position:-30px -330px}
# .info_today .ico_wm18{background-position:-60px -330px}
# .info_today .ico_wm19{background-position:-90px -330px}
# .info_today .txt_temper{margin-top:1px}
# .info_today .ico_degree{float:left;width:17px;height:15px;margin:7px 0 0;font-size:12px;line-height:17px;background-position:-210px -270px;background-color:transparent;text-align:center;text-indent:0}
# .info_today .link_weather .ico_more{width:13px;height:9px;margin:9px 0 0 1px;background-position:-138px -292px}
# .today_on .link_weather .ico_more{background-position:-138px -304px}
# .today_layer{display:none;position:absolute;top:45px;right:0;width:298px;border:1px solid #888;background-color:#fff}
# .today_layer .ico_wm{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_wm.png);background-repeat:no-repeat;font-size:0;line-height:0;text-indent:-9999px}
# .today_layer .layer_body{overflow:hidden}
# .today_layer .layer_body:after{position:absolute;top:0;right:0;width:42px;height:42px;content:''}
# .today_layer .weather_part{position:relative;height:135px}
# .today_layer .btn_locate{position:absolute;top:17px;left:18px;width:21px;height:21px;font-size:0;line-height:0;background-position:-176px -246px;text-indent:-9999px}
# .today_layer .btn_locate.on{background-position:-176px -286px}
# .today_layer .link_weather{display:block;overflow:hidden;height:135px}
# .today_layer .link_weather:hover{color:#222;text-decoration:none}
# .today_layer .txt_place{display:block;height:20px;margin:17px 0 0 22px;font-weight:bold;font-size:13px;line-height:19px}
# .today_layer .txt_place .txt_local{display:inline-block}
# .today_layer .link_weather .ico_wm{float:left;width:90px;height:90px;margin-left:22px}
# .today_layer .ico_wm01{background-position:0 0}
# .today_layer .night .ico_wm01{background-position:-100px 0}
# .today_layer .ico_wm02{background-position:-200px 0}
# .today_layer .night .ico_wm02{background-position:-300px 0}
# .today_layer .ico_wm03{background-position:0 -100px}
# .today_layer .night .ico_wm03{background-position:-100px -100px}
# .today_layer .ico_wm04{background-position:-200px -100px}
# .today_layer .ico_wm07{background-position:-300px -100px}
# .today_layer .ico_wm09{background-position:0 -200px}
# .today_layer .ico_wm10{background-position:-100px -200px}
# .today_layer .night .ico_wm10{background-position:-200px -200px}
# .today_layer .ico_wm11{background-position:-300px -200px}
# .today_layer .ico_wm14{background-position:0 -300px}
# .today_layer .ico_wm17{background-position:-100px -300px}
# .today_layer .ico_wm18{background-position:-200px -300px}
# .today_layer .ico_wm19{background-position:-300px -300px}
# .today_layer .info_temper{display:block;overflow:hidden;height:32px;margin:19px 0 0 130px;font-family:tahoma,arial,sans-serif}
# .today_layer .info_temper .img_weather{float:left;width:22px;height:32px;margin:0}
# .today_layer .info_temper .num0{background-position:-260px 0}
# .today_layer .info_temper .num1{background-position:-260px -40px}
# .today_layer .info_temper .num2{background-position:-260px -80px}
# .today_layer .info_temper .num3{background-position:-260px -120px}
# .today_layer .info_temper .num4{background-position:-260px -160px}
# .today_layer .info_temper .num5{background-position:-260px -200px}
# .today_layer .info_temper .num6{background-position:-260px -240px}
# .today_layer .info_temper .num7{background-position:-260px -280px}
# .today_layer .info_temper .num8{background-position:-260px -320px}
# .today_layer .info_temper .num9{background-position:-260px -360px}
# .today_layer .info_temper .ico_minus{width:22px;height:32px;background-position:-260px -400px}
# .today_layer .info_temper .ico_degree{width:39px;height:32px;background-position:-210px -292px}
# .today_layer .state_desc{display:block;overflow:hidden;margin:7px 0 0 130px;line-height:16px}
# .today_layer .state_desc .ico_degree{float:left;width:14px;height:12px;margin:3px 1px 0 0;background-position:-240px -208px}
# .today_layer .state_desc .txt_desc{float:left;margin-right:2px}
# .today_layer .layer_foot{overflow:hidden;border-top:1px solid #ececec;background-color:#fbfbfb}
# .today_layer .link_state{float:left;overflow:hidden;width:50%;height:39px;color:#101010;text-decoration:none}
# .today_layer .info_wm{overflow:hidden;height:22px;padding-top:8px;line-height:21px}
# .today_layer .info_wm dt{float:left;padding-right:9px}
# .today_layer .info_wm dd{float:left}
# .today_layer .info_wm .img_weather{display:inline-block;vertical-align:top}
# .today_layer .info_dust{padding-left:18px}
# .today_layer .ico_dust{width:20px;height:20px;margin-top:3px;margin-right:6px;background-position:-140px -240px}
# .today_layer .ico_air{width:21px;height:21px;margin:1px 7px 0 2px;background-position:-140px -264px}
# .today_layer .state_good{color:#0078ff}
# .today_layer .state_normal{color:#27aa1d}
# .today_layer .state_bad{color:#fecc3d}
# .today_layer .state_worst{color:#e30000}
# .today_layer .btn_close{position:absolute;top:18px;right:18px;width:16px;height:16px;background-position:0 -200px}
# .os_mac .today_layer .txt_place{margin-top:20px;line-height:18px}
# .os_mac .today_layer .info_temper{margin-top:15px}
# .os_mac .today_layer .state_desc{margin-top:10px}
# .os_mac .today_layer .state_desc .txt_temper{margin-top:-1px}
# .os_mac .today_layer .state_desc .ico_degree{margin-top:1px}
# .os_mac .today_layer .info_wm{padding-top:11px}
# .os_mac .today_layer .info_wm .ico_dust{margin-top:0}
# .os_mac .today_layer .info_wm .ico_air{margin-top:-2px}
# .today_on .today_layer{display:block}
# .advert_tmp{float:left;position:relative;width:655px;height:120px;margin-right:35px}
# .advert_tmp .bg_line{position:absolute;top:0;left:0;z-index:-1;width:653px;height:118px;border:1px solid #ececec}
# .advert_station{display:inline-block;position:relative;width:300px;height:150px;margin-top:15px;font-size:0;line-height:0;vertical-align:top}
# .advert_station .bg_line{position:absolute;top:0;left:0;z-index:-1;width:298px;height:148px;border:1px solid #ececec}
# .box_shopping{display:inline-block;position:relative;width:300px;height:1177px;margin-top:15px;vertical-align:top}
# .box_shopping .bg_line1{position:absolute;top:0;left:0;z-index:-1;width:298px;height:775px;border:1px solid #ececec}
# .box_shopping .bg_line2{position:absolute;top:792px;left:0;z-index:-1;width:298px;height:383px;border:1px solid #ececec}
# .advert_svcbnr{margin-top:15px}
# .advert_svcbnr .link_bnr{display:block;position:relative;height:60px}
# .advert_svcbnr .frame_g{width:298px;height:58px}
# .advert_bnr{margin-top:15px}
# .advert_bnr .link_bnr{display:block;overflow:hidden;position:relative;height:143px}
# .advert_bnr .frame_g{width:298px;height:141px}
# .wrap_tiercont{position:relative;z-index:99;width:990px;margin:0 auto}
# .login_tmp{float:right;position:relative;z-index:0;width:300px;height:120px;letter-spacing:-1px}
# .login_my{z-index:10;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat 0 0}
# .login_my .wrap_my{width:285px;height:45px;padding:15px 0 17px 15px}
# .login_my .info_my{float:left;padding:1px 0 0 0}
# .login_my .rel_my{float:right;padding-right:15px}
# .login_my .name_user{float:left;margin-right:4px;font-weight:bold}
# .login_my .link_myinfo{float:left;font-size:11px;margin:2px 2px 0 0;line-height:14px;color:#555;text-decoration:underline}
# .login_my .link_sso{position:absolute;top:41px;left:15px;width:68px;height:22px;font-size:11px;line-height:22px;background-position:-100px -235px;white-space:nowrap}
# .login_my .link_ssoing{background-position:-100px -205px}
# .login_my .link_ssohelp{position:absolute;top:41px;left:85px;width:6px;height:22px;padding:0 6px;font-size:12px;line-height:22px;background-position:-180px -235px;white-space:nowrap}
# .layer_sso{position:absolute;top:77px;left:0;z-index:11;width:298px;height:82px;border:1px solid #118eff;background-color:#fff}
# .layer_sso .box_help{display:table;width:100%;height:100%}
# .layer_sso .txt_help{display:table-cell;padding:0 16px 2px;font-size:12px;line-height:16px;color:#555;vertical-align:middle}
# .layer_sso .btn_close{position:absolute;top:5px;right:5px;width:21px;height:21px;padding:0 6px;background-position:-210px -235px}
# .login_my .link_empathy{float:left;margin:5px 8px 0 0;font-size:11px;line-height:14px;color:#5b6473}
# .login_my .btn_logout{float:left;width:56px;height:24px;font-size:11px;line-height:24px;background-position:-180px -30px;background-color:transparent}
# .login_my .list_basis{overflow:hidden;position:absolute;top:43px;right:9px;height:30px;letter-spacing:-0.12em}
# .login_my .list_basis li{float:left;padding-right:8px;line-height:15px}
# .login_my .list_basis .link_basis{float:left;font-size:12px;color:#555}
# .login_my .list_basis .num_basis{margin-left:3px;color:#118eff}
# .login_my .list_basis .num_msg{width:30px}
# .login_my .list_basis .link_num{font-weight:bold;color:#118eff}
# .login_my .my_mileage .link_basis{margin-right:8px}
# .login_my .wrap_mysvc{position:relative;z-index:10;width:300px}
# .mysvc_list{position:relative;width:300px;height:43px}
# .list_mysvc{display:inline-block;position:relative;width:300px;height:43px;vertical-align:top;letter-spacing:-1px}
# .list_mysvc li{position:relative;float:left;width:100px;height:43px}
# .list_mysvc .link_mysvc{display:block;overflow:hidden;height:31px;padding-top:12px;font-size:12px;line-height:18px;text-align:center;color:#555}
# .list_mysvc .link_mysvc:hover{text-decoration:none}
# .list_mysvc .cafe_g .link_mysvc{height:30px;padding-top:13px;line-height:16px}
# .list_mysvc .txt_mysvc{display:inline-block;height:26px;color:#555;vertical-align:top}
# .list_mysvc .cafe_g .txt_mysvc{padding-left:24px;background-position:0 -80px}
# .list_mysvc .stock_g .txt_mysvc{padding-left:27px;background-position:0 -109px}
# .list_mysvc .blog_g .txt_mysvc{padding-left:29px;background-position:0 -139px}
# .list_mysvc .ico_new{display:none;width:11px;height:11px;margin:5px 0 0 4px;background-position:-160px -80px;text-indent:-9999px;vertical-align:top}
# .list_mysvc .new_g .ico_new{display:inline-block}
# .list_mysvc .cafe_g .ico_new{margin-top:4px}
# .mycafe_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px 0}
# .mystock_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px -50px}
# .myblog_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px -100px}
# .layer_mycont{position:absolute;top:120px;left:0;width:300px;height:353px;background-position:0 -130px}
# .layer_mycont .btn_close{position:absolute;top:320px;right:0;width:46px;height:32px;padding:3px 0 4px;font-size:11px;line-height:18px;color:#888}
# .os_mac .layer_sso .txt_help{padding-top:2px;padding-bottom:0}
# .os_mac .login_tmp{letter-spacing:0}
# .os_mac .login_my .info_my{padding-top:4px}
# .os_mac .login_my .name_user{margin-right:7px}
# .os_mac .login_my .link_privacy{margin-top:0}
# .os_mac .login_my .list_basis{top:45px;right:6px;letter-spacing:0}
# .os_mac .list_basis li{padding-right:9px}
# .os_mac .list_mysvc .link_mysvc{line-height:21px}
# .os_mac .cafe_g .link_mysvc{line-height:20px}
# .os_mac .list_mysvc .ico_new{margin-top:4px}
# .os_mac .cafe_g .ico_new{margin-top:3px}
# .os_mac .layer_mycont .btn_close{padding-top:5px}
# .panel_bloc{position:relative;padding-top:61px}
# .tit_tabcont{position:absolute;top:15px;font-size:16px}
# .tit_tabcont .link_tit{display:block;height:36px;line-height:36px;background-color:transparent;text-align:center}
# .wrap_tabcont{display:none;width:655px}
# .ico_view{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-40px 0;text-indent:-9999px;cursor:pointer}
# .ico_video{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-70px 0;text-indent:-9999px;cursor:pointer}
# .ico_live{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-130px 0;text-indent:-9999px;cursor:pointer}
# .color_g1{color:#e30000}
# .color_g2{color:#118eff}
# .ico_label{overflow:hidden;position:absolute;top:15px;left:15px;height:22px;padding:0 8px;font-size:11px;line-height:19px;color:#fff;background-color:#118eff}
# .ico_label2{overflow:hidden;position:absolute;top:0;left:0;height:20px;padding:0 7px;font-size:11px;line-height:17px;color:#fff;background-color:rgba(0,0,0,0.6);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#99000000',endColorstr='#99000000',GradientType=0)}
# .ico_label3{overflow:hidden;position:absolute;top:15px;left:15px;height:22px;padding:0 8px;font-size:11px;line-height:19px;color:#fff;background-color:#e8493d}
# .os_mac .ico_label,.os_mac .ico_label3{line-height:23px}
# .os_mac .ico_label2{line-height:21px}
# .tag_live{width:30px;height:15px;background-position:-120px -70px}
# .tag_new{width:31px;height:15px;background-position:-120px -90px}
# .tag_event{width:40px;height:15px;background-position:-120px -110px}
# .tag_issue{width:37px;height:15px;background-position:-120px -130px}
# .page_pctop{position:absolute;width:auto;height:16px}
# .page_pctop .btn_page{float:left;width:16px;height:16px;line-height:16px;background-color:transparent;background-position:-210px 0}
# .page_pctop .btn_next{width:15px;background-position:-226px 0}
# .page_pctop .info_page{float:left;padding:2px 5px 0 0;font-size:12px;line-height:16px;color:#555;font-family:tahoma,arial,sans-serif}
# .page_pctop .info_page .txt_slash{padding:0 1px}
# .os_mac .page_pctop .info_page{line-height:16px;font-family:helvetica,arial,sans-serif}
# .page_btype{top:20px;right:0;height:26px}
# .page_btype .btn_page{width:26px;height:26px;line-height:26px;background-position:-110px -170px;text-indent:10px}
# .page_btype .btn_next{width:25px;background-position:-136px -170px}
# .page_btype .info_page{padding-top:1px;padding-right:8px;font-size:14px;line-height:22px}
# .os_mac .page_btype .info_page{line-height:24px}
# .page_tabcont{position:absolute;z-index:1;top:16px;left:30px;cursor:pointer}
# .page_tabcont .btn_page{overflow:hidden;float:left;width:7px;height:7px;margin:9px 0;font-size:10px;line-height:7px;background-position:-100px -170px;background-color:transparent}
# .page_tabcont .on{position:relative;background-position:-100px -177px}
# .list_thumb{overflow:hidden}
# .list_thumb li{float:left;width:154px;height:146px;margin-left:13px}
# .list_thumb .fst{margin-left:0}
# .list_thumb .link_item{display:block}
# .list_thumb .thumb_g{width:154px;height:94px}
# .list_thumb .frame_g{width:152px;height:92px}
# .list_thumb .cont_item{padding:4px 2px 0}
# .list_thumb .tit_item{display:block;overflow:hidden;max-height:36px;padding-right:12px;font-weight:normal;line-height:18px;word-break:keep-all;word-wrap:break-word}
# .os_mac .list_thumb .cont_item{padding-top:6px}
# .os_mac .list_thumb .tit_item{padding-right:14px}
# .list_txt{float:left}
# .list_txt li{overflow:hidden;height:20px;padding:4px 0 2px;white-space:nowrap;text-overflow:ellipsis}
# .list_txt .ico_pctop{display:inline-block;margin:3px 4px 0 0;text-indent:-9999px;vertical-align:top}
# .list_txt .split_txt{padding-left:10px;margin-left:10px;color:#888;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_vert_170724.png) 0 -46px}
# .list_txt .split_txt:hover{color:#118eff}
# .list_txt .part_mid{padding-top:18px;line-height:16px}
# .list_txt .split_part{display:inline-block;overflow:hidden;vertical-align:top}
# .list_txt .split_part .link_txt{margin-right:3px}
# .list_txt .split_fst{float:left;overflow:hidden;max-width:222px;text-overflow:ellipsis}
# .os_mac .list_txt li{line-height:20px}
# .os_mac .list_txt .split_txt{background-position:0 -49px}
# .os_mac .list_txt .part_mid{line-height:22px}
# .os_mac .list_txt .split_part .split_part{letter-spacing:-0.03em}
# .os_mac .list_txt .split_part .link_txt{margin-right:7px}
# .list_stxt{margin-top:7px}
# .list_stxt li{overflow:hidden;padding-bottom:4px;line-height:19px;white-space:nowrap;text-overflow:ellipsis}
# .list_stxt .txt_mark{font-size:12px;color:#888}
# .link_sector{display:block;position:relative;z-index:0;width:321px;height:131px}
# .link_sector .frame_g{width:319px;height:129px}
# .link_sector .cont_item{position:absolute;right:0;left:0;bottom:0;width:100%;height:100px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate2.png) no-repeat 0 100%}
# .link_sector .tit_item{overflow:hidden;position:absolute;left:0;bottom:13px;right:0;padding:0 15px;font-weight:normal;font-size:14px;line-height:20px;color:#fff}
# .link_sector .ico_label,
# .link_sector .ico_label2,
# .link_sector .ico_label3,
# .link_sector .ico_pctop{z-index:1}
# .os_mac .link_sector .tit_item{bottom:10px}
# .list_ranking li{height:20px;padding-bottom:5px}
# .list_ranking .link_ranking{display:block;overflow:hidden;line-height:18px}
# .list_ranking .txt_ranking{overflow:hidden;float:left;width:288px;white-space:nowrap;text-overflow:ellipsis}
# .list_ranking .link_ranking:hover .txt_ranking{text-decoration:underline}
# .list_ranking .num_pctop{float:left;width:16px;height:16px;margin:3px 7px 0 0;text-indent:-9999px;vertical-align:top}
# .list_ranking .num1{background-position:0 0}
# .list_ranking .num2{background-position:0 -20px}
# .list_ranking .num3{background-position:0 -40px}
# .list_ranking .num4{background-position:0 -60px}
# .list_ranking .num5{background-position:0 -80px}
# .os_mac .list_ranking .num_pctop{margin-top:0}
# .os_mac .list_ranking li{line-height:22px}
# .box_story{overflow:hidden;border:1px solid #ececec;background-color:#fbfbfc}
# .box_story .tit_subject{overflow:hidden;margin-top:7px;font-size:13px}
# .box_story .tit_subject .link_tit{float:left;padding-right:9px;background-position:100% 7px}
# .os_mac .box_story .tit_subject{margin-top:10px}
# .os_mac .box_story .tit_subject .link_tit{background-position:100% 4px}
# .os_mac .box_story .list_stxt{margin-top:10px}
# .section_media{position:relative}
# .section_media .page_btype{top:15px}
# .section_media .panel_bloc{padding:57px 0 25px}
# .section_media .tit_tabcont{top:11px;left:0}
# .panel_bloc .tit_news{left:-5px}
# .panel_bloc .tit_entertain{left:55px}
# .panel_bloc .tit_sports{left:94px}
# .panel_bloc .tit_movie{left:147px}
# .panel_bloc .tit_auto{left:186px}
# .panel_bloc .tit_realestate{left:240px}
# .panel_bloc .tit_news .link_tit{width:36px;background-position:0 -130px}
# .panel_bloc .tit_entertain .link_tit{width:36px;background-position:-36px -130px}
# .panel_bloc .tit_sports .link_tit{width:50px;background-position:-72px -130px}
# .panel_bloc .tit_movie .link_tit{width:36px;background-position:-122px -130px}
# .panel_bloc .tit_auto .link_tit{width:51px;background-position:-158px -130px}
# .panel_bloc .tit_realestate .link_tit{width:48px;background-position:-209px -130px}
# .news_on .tit_news .link_tit{background-position:0 -166px}
# .entertain_on .tit_entertain .link_tit{background-position:-36px -166px}
# .sports_on .tit_sports .link_tit{background-position:-72px -166px}
# .movie_on .tit_movie .link_tit{background-position:-122px -166px}
# .auto_on .tit_auto .link_tit{background-position:-158px -166px}
# .realestate_on .tit_realestate .link_tit{background-position:-209px -166px}
# .news_on .wrap_news, .entertain_on .wrap_entertain, .sports_on .wrap_sports, .movie_on .wrap_movie, .auto_on .wrap_auto, .realestate_on .wrap_realestate{display:block}
# .section_media .wrap_tabcont{height:480px}
# .group_news{display:inline-block;height:292px;vertical-align:top}
# .news_prime{height:438px}
# .news_prime .list_txt{width:316px;padding-left:4px}
# .news_prime .list_thumb .tit_item{word-break:normal}
# .box_sector{overflow:hidden;float:left;width:321px;margin-right:13px}
# .box_sector .list_thumb{width:334px;margin-left:-13px}
# .box_sector .link_sector{margin-bottom:15px}
# .news_flow{overflow:hidden;position:relative;height:40px;border:1px solid #ececec;line-height:35px;background-color:#fbfbfb}
# .unit_home{float:left;padding-left:12px}
# .unit_home .tit_home{float:left;margin-right:10px}
# .unit_home .tit_home .link_home{padding-right:7px;background-position:100% 6px}
# .unit_home .list_home{float:left}
# .unit_home .list_home li{float:left;padding:0 7px}
# .unit_home .list_home .link_home{color:#555}
# .unit_home .link_home:hover{color:#118eff}
# .unit_live{float:left;padding-left:25px}
# .unit_live .ico_pctop{float:left;margin:12px 6px 0 0;text-indent:-9999px}
# .unit_live .link_live{margin-right:5px;color:#555}
# .unit_live .link_live:hover{color:#118eff}
# .news_flow .link_hash{padding:0 7px;color:#118eff}
# .os_mac .news_flow{line-height:40px}
# .os_mac .unit_home .tit_home .link_home{padding-right:9px;background-position:100% 3px}
# .box_issue{float:left;position:relative;margin-right:13px}
# .box_issue .link_issue{display:block;overflow:hidden;position:relative;width:321px;height:277px}
# .box_issue .cover_g{position:absolute;left:0;bottom:0;width:100%;height:132px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate8.png) 0 100%}
# .box_issue .frame_g{width:319px;height:275px}
# .box_issue .ico_label{height:27px;font-size:14px;line-height:25px;background-color:rgba(17,142,255,.9)}
# .box_issue .cont_item{overflow:hidden;position:absolute;right:0;bottom:14px;left:0}
# .box_issue .cont_item .tit_item{display:block;overflow:hidden;max-height:44px;padding:0 16px;font-weight:normal;font-size:16px;line-height:22px;color:#fff}
# .os_mac .box_issue .ico_label{line-height:29px}
# .os_mac .box_issue .cont_item{bottom:10px}
# .special_issue .tit_issue{overflow:hidden;position:absolute;top:25px;left:21px;max-height:60px;padding-right:20px;font-size:22px;color:#fff}
# .special_issue .cont_item{bottom:12px}
# .special_issue .list_item{padding:0 16px}
# .special_issue .list_item li{overflow:hidden;margin-top:3px;font-size:14px}
# .special_issue .list_item .fst{font-size:16px;line-height:26px}
# .special_issue .list_item .link_item{display:block;overflow:hidden;color:#fff;white-space:nowrap;text-overflow:ellipsis}
# .os_mac .special_issue .list_item .fst{line-height:23px}
# .wrap_news .news_prime{float:left;width:501px;height:438px}
# .wrap_news .news_flow{clear:both}
# .wrap_news .box_sector{width:154px}
# .wrap_news .box_sector .list_thumb{width:auto;margin-left:0}
# .wrap_news .box_sector .list_thumb li{float:none;margin-left:0}
# .wrap_news .link_sector{width:154px;height:277px;margin-bottom:0}
# .wrap_news .link_sector .frame_g{width:152px;height:275px}
# .ranking_news{overflow:hidden;position:relative;height:148px;padding:0 14px 0 148px}
# .ranknews_tit{position:absolute;top:3px;left:0;width:148px}
# .ranknews_tit .tit_ranking{float:left;line-height:17px;color:#118eff}
# .ranknews_tit .link_tit{color:#118eff}
# .help_part{display:inline;float:left;margin:3px 0 0 4px}
# .help_part .link_help{display:block;width:31px;height:15px;font-size:11px;background-color:transparent;background-position:0 -265px}
# .help_layer{overflow:hidden;position:absolute;top:27px;left:0;width:126px;height:48px;border:1px solid #888;background-color:#fbfbfb}
# .help_layer .txt_help{padding:8px 13px 0 13px;font-size:11px;line-height:15px;color:#888}
# .help_layer .btn_close{position:absolute;top:8px;right:8px;width:16px;height:16px;background-position:0 -200px}
# .ranking_news .list_ranking{margin-top:3px}
# .tab_ranking{position:absolute;top:30px;left:0;width:64px}
# .tab_ranking li{margin-bottom:3px}
# .tab_ranking .link_tab{display:inline-block;overflow:hidden;font-weight:bold;line-height:16px;color:#888}
# .tab_ranking .on .link_tab{color:#222;text-decoration:underline}
# .tab_ranking .ico_pctop{float:left;width:6px;height:6px;margin:6px 8px 0 0;background-position:-100px -190px}
# .cont_ranking{display:none;overflow:hidden}
# .cont_ranking.on{display:block}
# .os_mac .help_part{margin-top:0}
# .os_mac .help_layer{top:25px}
# .os_mac .ranknews_tit{top:6px}
# .os_mac .ranking_news .list_ranking{margin-top:5px}
# .os_mac .tab_ranking{top:33px}
# .os_mac .tab_ranking li{margin-bottom:1px}
# .os_mac .tab_ranking .ico_pctop{margin-top:4px}
# .cast_sports{position:relative;width:321px;margin-bottom:15px}
# .cast_sports .head_cast{height:35px;border:1px solid #ececec;background-color:#fbfbfb}
# .cast_sports .tit_cast{margin:6px 0 0 11px;font-size:13px}
# .cast_sports .page_pctop{top:11px;right:14px;bottom:auto}
# .cast_sports .page_pctop .btn_page{width:16px;height:16px;line-height:16px;background-position:-210px 0}
# .cast_sports .page_pctop .btn_next{width:15px;background-position:-226px 0}
# .cast_sports .link_more{position:absolute;top:9px;right:13px;padding-right:7px;font-size:11px;color:#888;background-position:100% -18px}
# .list_relay{border:1px solid #ececec;border-top:0 none}
# .list_relay li{overflow:hidden}
# .list_relay .link_relay:hover{color:#222;text-decoration:none}
# .list_relay .txt_team{overflow:hidden;font-size:12px;line-height:26px;white-space:nowrap;text-overflow:ellipsis}
# .list_relay .txt_time{float:left;font-size:11px;font-family:tahoma,arial,sans-serif;letter-spacing:0}
# .list_relay .txt_league{float:left;padding-left:3px;font-size:11px;color:#888}
# .list_relay .txt_score .inner_score{display:inline-block;vertical-align:top}
# .list_relay .txt_score .num_pctop{float:left;width:11px;height:16px;background-color:transparent}
# .list_relay .txt_score .num0{background-position:-60px 0}
# .list_relay .txt_score .num1{background-position:-60px -20px}
# .list_relay .txt_score .num2{background-position:-60px -40px}
# .list_relay .txt_score .num3{background-position:-60px -60px}
# .list_relay .txt_score .num4{background-position:-60px -80px}
# .list_relay .txt_score .num5{background-position:-60px -100px}
# .list_relay .txt_score .num6{background-position:-60px -120px}
# .list_relay .txt_score .num7{background-position:-60px -140px}
# .list_relay .txt_score .num8{background-position:-60px -160px}
# .list_relay .txt_score .num9{background-position:-60px -180px}
# ...
# </span>
# </li>
# </ul>
# <div class="detail_photo" id="photoView">
# <span class="frame_g"></span>
# <a class="link_photo #photoslide #gallary #subtitle" href="http://media.daum.net/photo/">
# <h3 class="tit_gallery"></h3>
# <span class="desc_source"></span>
# </a>
# </div>
# <a class="btn_preview btn_prev #function #photoslide_top #preBtn" href="#prevPhoto">
# <span class="frame_g"></span>
# <span class="ico_pctop ico_prev">이전 포토 보기</span>
# <span class="txt_gallery">추천갤러리<br/>바로가기</span>
# </a>
# <a class="btn_preview btn_next #function #photoslide_top #nextBtn" href="#nextPhoto">
# <span class="frame_g"></span>
# <span class="ico_pctop ico_next">다음 포토 보기</span>
# <span class="txt_gallery">추천갤러리<br/>바로가기</span>
# </a>
# </div>
# <div class="view_slide">
# <ul class="list_thumbnail #photoslide #gallery #img" style="width:1858px;">
# <li class="fst @1"> <a class="link_thumb" href="#pic0">
# <img alt="[포토] 선미, '예쁘다는 말로는 부족해~'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/ked/20170926193202919anot.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @2"> <a class="link_thumb" href="#pic1">
# <img alt="[포토엔HD]위키미키 김도연 '예쁜 도연이 두고 가시나~'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/newsen/20170926184845441tnnc.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @3"> <a class="link_thumb" href="#pic2">
# <img alt="[포토친구] 가을 이미지" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/kppa/20170926175422001nhrk.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @4"> <a class="link_thumb" href="#pic3">
# <img alt="마포대교 안전점검" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/yonhap/20170926164936143cocn.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @5"> <a class="link_thumb" href="#pic4">
# <img alt="허리케인 마리아의 피해현장" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/newsis/20170926163812967ipxd.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @6"> <a class="link_thumb" href="#pic5">
# <img alt="[포토] 현아, 빛나는 미모로" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/startoday/20170926162902985usui.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @7"> <a class="link_thumb" href="#pic6">
# <img alt="정세균 국회의장, 우즈베키스탄 타슈켄트 독립광장 방문" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/newsis/20170926160919054jknb.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @8"> <a class="link_thumb" href="#pic7">
# <img alt="꽃다발 받은 송영무 국방부장관" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926160655577cges.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @9"> <a class="link_thumb" href="#pic8">
# <img alt="멕시코, 지진 피해 이웃과 생필품 나누는 사람들" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/reuters/20170926155842993pdap.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @10"> <a class="link_thumb" href="#pic9">
# <img alt="상인들과 국밥 먹는 유영민 장관" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/newsis/20170926152021799hjcc.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @11"> <a class="link_thumb" href="#pic10">
# <img alt='"앞으로 어떻게 해야.." 황영철 정치자금법 위반 혐의 첫 공판' class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/newsis/20170926151604525dtcm.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @12"> <a class="link_thumb" href="#pic11">
# <img alt="검찰, '화이트리스트 의혹' 보수단체 압수수색" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926151536790glvc.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @13"> <a class="link_thumb" href="#pic12">
# <img alt="노동계 블랙리스트 진상조사단 결과발표" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926145640546cxzf.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @14"> <a class="link_thumb" href="#pic13">
# <img alt="출마 기자회견하는 설정스님" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/newsis/20170926145323133rrgh.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @15"> <a class="link_thumb" href="#pic14">
# <img alt="우원식 원내대표, 국감 SNS 제보 시연" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/newsis/20170926144759702zpsr.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @16"> <a class="link_thumb" href="#pic15">
# <img alt="박원순 시장-김영주 노동부장관 '현장노동청 찾아 이야기 들어'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926144712003dcnw.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @17"> <a class="link_thumb" href="#pic16">
# <img alt="운동장에 울려 퍼진 유치원 원아들의 '강강술래'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/ohmynews/20170926144203385xolc.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @18"> <a class="link_thumb" href="#pic17">
# <img alt='연합뉴스 노조 "박노황 사장과 경영진은 물러나라"' class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926142655549qbrc.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @19"> <a class="link_thumb" href="#pic18">
# <img alt="가을바람 맞이하는 코스모스" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926142400544pzte.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @20"> <a class="link_thumb" href="#pic19">
# <img alt="전병헌 정무수석, 여야 지도부 회동 관련 브리핑" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/newsis/20170926142358932qtef.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @21"> <a class="link_thumb" href="#pic20">
# <img alt="'가을 햇살이 좋아요'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926142352592wwsa.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @22"> <a class="link_thumb" href="#pic21">
# <img alt="김명수 신임 대법원장 취임식" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926142217188zcjh.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @23"> <a class="link_thumb" href="#pic22">
# <img alt='"신라시대 화장실입니다"' class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926141504105dewd.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @24"> <a class="link_thumb" href="#pic23">
# <img alt="취임 100일 기자간담회 하는 도종환 장관" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/newsis/20170926141441991tvvk.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @25"> <a class="link_thumb" href="#pic24">
# <img alt="[경향포토]'수능 D-50, 꽃으로 花이팅'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/khan/20170926141424978zfqg.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @26"> <a class="link_thumb" href="#pic25">
# <img alt="안철수 울산과학기술 대학생들과 '잔디밭 토크'" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926140352903dckn.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @27"> <a class="link_thumb" href="#pic26">
# <img alt="이곳에 가면 나도 드라마의 주인공이 될 수 있다" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/ohmynews/20170926140316191hsjk.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @28"> <a class="link_thumb" href="#pic27">
# <img alt="전통시장 안전점검 나선 이인호 차관" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926134336259xgdv.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @29"> <a class="link_thumb" href="#pic28">
# <img alt="전북 순창서 트럭과 오토바이 충돌..1명 사망" class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926134145041uwnu.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# <li class=" @30"> <a class="link_thumb" href="#pic29">
# <img alt='"쾌적한 마을 우리 손으로"..고창, 행복홀씨 입양사업' class="img_thumb" data-src="//img2.daumcdn.net/thumb/S60x60/?fname=https://t1.daumcdn.net/news/201709/26/NEWS1/20170926134112348cswf.jpg" height="60" src="//t1.daumcdn.net/daumtop_deco/images/op/noimg_1x1.png" width="60"/>
# <span class="cover_g"></span>
# <span class="frame_g"></span>
# </a>
# </li>
# </ul>
# <a class="btn_move btn_prev #function #photoslide_bottom #preBtn" href="#prevPhotoList"><span class="ico_pctop">이전 이미지 목록 보기</span></a>
# <a class="btn_move btn_next #function #photoslide_bottom #nextBtn" href="#nextPhotoList"><span class="ico_pctop">다음 이미지 목록 보기</span></a>
# </div>
# </div>
# </div>
# </main>
# <!-- // daumContent -->
# <hr class="hide"/>
# <footer class="foot_daum #footer" id="daumFoot">
# <div class="inner_foot">
# <a class="link_logo #logo" href="https://www.daum.net/"><img alt="다음" class="img_thumb" height="22" src="//t1.daumcdn.net/daumtop_deco/images/top/2017/logo_foot.gif" width="52"/></a>
# <div class="info_notice">
# <h2 class="tit_notice"><a class="ico_vert link_notice #title" href="http://m.daum.net/channel/noticePC?order=recent">공지사항</a></h2>
# <ul class="list_notice">
# <li>
# <a class="link_info #notice" href="https://channel.daum.net/content/619979?dmp_channel=noticePC&amp;dmp_id=619979">개인정보처리방침 변경 사전 안내</a>
# </li>
# </ul>
# </div>
# <div class="search_foot">
# <h2 class="screen_out">검색</h2>
# <form accept-charset="utf-8" action="//search.daum.net/search" method="get" role="search">
# <input name="w" type="hidden" value="tot">
# <input name="DA" type="hidden" value="YZR"/>
# <input name="t__nil_searchbox" type="hidden" value="btn"/>
# <input name="sug" type="hidden"/>
# <input name="sugo" type="hidden"/>
# <input name="sq" type="hidden"/>
# <input name="o" type="hidden"/>
# <fieldset>
# <legend class="screen_out">통합 검색</legend>
# <div class="box_search" id="searchMiniBar">
# <input autocapitalize="off" autocomplete="off" autocorrect="off" class="tf_keyword" id="qMini" name="q" spellcheck="false" title="검색어 입력" type="text"/>
# <button class="ico_pctop btn_search" id="qMiniBtn" type="submit">
# <span class="ir_wa">검색</span>
# </button>
# </div>
# </fieldset>
# </input></form>
# </div>
# <a class="ico_vert link_svcall #sitemap" href="sitemap/index.html">서비스 전체보기</a>
# <h2 class="screen_out">다음 소개 및 약관</h2>
# <div class="info_policy">
# <a class="link_policy #kakaocorp" href="http://www.kakaocorp.com/main" target="_blank">회사소개</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #biz" href="http://ad.kakaocorp.com/" target="_blank">광고안내</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #search" href="https://register.search.daum.net/index.daum">검색등록</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #propose" href="http://with.kakao.com/" target="_blank">제휴문의</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #recruit" href="http://www.kakaocorp.com/recruit/recruitprocess.html" target="_blank">인재채용</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #servicepolicy" href="http://policy.daum.net/info/info">서비스약관</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #youthpolicy" href="http://policy.daum.net/youthpolicy/youthpolicy">청소년보호정책</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #infopolicy" href="http://policy.daum.net/info_protection/info_protection"><strong>개인정보처리방침</strong></a>
# <span class="txt_dot">·</span>
# <a class="link_policy #top_accessibility" href="https://www.daum.net/doc/top_accessibility.html">웹접근성안내</a>
# <span class="txt_dot">·</span>
# <a class="link_policy #cs" href="http://cs.daum.net/">고객센터</a>
# </div>
# <small class="txt_copyright">Copyright © <a class="link_kakao #copyright" href="http://www.kakaocorp.com/">Kakao Corp.</a> All rights reserved.</small>
# </div>
# </footer>
# </div>
# <script src="//t1.daumcdn.net/daumtop_deco/scripts/201709201928/top.js" type="text/javascript"></script>
# <script src="//t1.daumcdn.net/daumtop_deco/scripts/201707061408/daum_pctop.tm.min.js" type="text/javascript"></script>
# </body>
# </html>

# %%
bsObj.html.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Daum</title>
# <meta content="https://www.daum.net/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Daum" property="og:title"/>
# <meta content="//i1.daumcdn.net/svc/image/U03/common_icon/5587C4E4012FCD0001" property="og:image"/>
# <meta content="나의 관심 콘텐츠를 가장 즐겁게 볼 수 있는 Daum" property="og:description"/>
# <meta content="name=Daum;action-uri=https://www.daum.net/;icon-uri=/favicon.ico" name="msapplication-task"/>
# <meta content="name=미디어다음;action-uri=http://media.daum.net/;icon-uri=/media_favicon.ico" name="msapplication-task"/>
# <meta content="name=메일;action-uri=http://mail.daum.net;icon-uri=/mail_favicon.ico" name="msapplication-task"/>
# <meta content="origin" name="referrer"/>
# <link href="//t1.daumcdn.net/daumtop_chanel/op/OpenSearch.xml" rel="search" title="다음" type="application/opensearchdescription+xml"/>
# <style type="text/css">
# @charset "utf-8";
# body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,button{margin:0;padding:0}
# fieldset,img{border:0 none}
# dl,ul,ol,menu,li{list-style:none}
# blockquote, q{quotes: none}
# blockquote:before, blockquote:after,q:before, q:after{content:'';content:none}
# input,select,textarea,button{vertical-align:middle}
# input::-ms-clear{display:none}
# button{border:0 none;background-color:transparent;cursor:pointer}
# body{background:#fff;direction:ltr;-webkit-text-size-adjust:none}
# body,th,td,input,select,textarea,button{font-size:13px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,'Malgun Gothic','맑은 고딕',dotum,'돋움',sans-serif;color:#222;letter-spacing:-1px}
# .os_mac body,.os_mac th,.os_mac td,.os_mac input,.os_mac select,.os_mac textarea,.os_mac button{letter-spacing:0}
# a{color:#222;text-decoration:none}
# a:hover{color:#118eff;text-decoration:underline}
# a:active{background-color:transparent}
# address,caption,cite,code,dfn,em,var{font-style:normal;font-weight:normal}
# .ir_pm{display:block;overflow:hidden;font-size:1px;line-height:0;text-indent:-9999px}
# .ir_wa{display:block;overflow:hidden;position:relative;width:100%;height:100%;z-index:-1}
# .screen_out{overflow:hidden;position:absolute;width:0;height:0;line-height:0;text-indent:-9999px}
# .show{display:block}
# .hide{display:none}
# .d_index{position:relative;width:100%}
# .d_index .shortcut_g{position:absolute;top:-34px;left:0;height:33px;padding:0 20px 0 26px;border-bottom:1px solid #3f4243;font-size:11px;line-height:14px;background-color:#26292a;color:#fff;letter-spacing:-1px;text-align:center}
# .d_index .shortcut_g:active,
# .d_index .shortcut_g:focus{overflow:hidden;top:0;text-decoration:none;z-index:101}
# .d_index .shortcut_g:active,
# .d_index .shortcut_g:hover{color:#fff}
# .d_index .shortcut_g .inner_shortcut{display:inline-block;padding-right:10px;margin-top:8px;background-position:100% -220px;vertical-align:top}
# .os_mac .d_index .shortcut_g .inner_shortcut{margin-top:11px;background-position:100% -223px}
# .ico_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_170828.png) no-repeat 0 0}
# .ico_vert{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_vert_170724.png) no-repeat 0 0}
# .txt_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/txt_pctop_170711.png) no-repeat 0 0;letter-spacing:-1px;white-space:nowrap}
# .bg_pctop{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat 0 0}
# .num_pctop{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/num_pctop_170405.png) no-repeat 0 0}
# .img_thumb{display:block;vertical-align:top}
# .frame_g{position:absolute;top:0;left:0;border:1px solid #000;opacity:0.08;filter:alpha(opacity=8)}
# .thumb_g{display:block;position:relative}
# #daumWrap{position:relative;min-width:1080px}
# .os_mac #daumWrap{transform:translate3d(0px, 0px, 0px)}
# .head_daum{position:relative;z-index:100}
# .cont_main{position:relative;width:990px;margin:15px auto 0}
# .cont_topic{overflow:hidden;position:relative;z-index:0;width:100%;border-top:1px solid #ececec;background-color:#fbfbfc;background-position:50% 100%;background-repeat:no-repeat}
# .feature_tmp{display:inline-block;vertical-align:top}
# .wrap_main{padding-bottom:40px;clear:both;*zoom:1}
# .wrap_main:after{display:block;visibility:hidden;height:0;font-size:0;clear:both;content:''}
# .cmain_tmp{float:left;width:655px;margin-right:35px}
# .wing_tmp{float:left;width:300px}
# .foot_daum{border-top:1px solid #888}
# .foot_daum .inner_foot{overflow:hidden;position:relative;width:990px;margin:0 auto;padding:37px 0 78px}
# .foot_daum .link_logo{float:left}
# .foot_daum .info_notice{overflow:hidden;padding:0 250px 0 30px}
# .foot_daum .tit_notice{float:left;font-size:13px}
# .foot_daum .link_notice{display:block;padding-right:9px;background-position:100% -169px}
# .foot_daum .link_notice:hover{color:#222}
# .foot_daum .list_notice{overflow:hidden;width:542px;height:19px;padding-left:9px}
# .foot_daum .list_notice .link_info{display:block;overflow:hidden;text-overflow:ellipsis;white-space:nowrap}
# .foot_daum .list_notice .link_info:hover{color:#222}
# .foot_daum .search_foot{position:absolute;top:32px;right:0}
# .foot_daum .box_search{position:relative;z-index:1;width:209px;height:28px;border:1px solid #c8c8c8}
# .foot_daum .search_on{border-color:#0089ff}
# .foot_daum .tf_keyword{float:left;width:164px;margin:5px 0 0 9px;border:1px solid transparent;line-height:19px;outline:0}
# .foot_daum .btn_search{float:right;width:32px;height:28px;line-height:28px;background-position:0 -230px;background-color:transparent}
# .foot_daum .link_svcall{position:absolute;top:81px;right:0;padding-right:10px;font-weight:bold;color:#888;background-position:100% -194px}
# .foot_daum .info_policy{padding:23px 250px 0 0}
# .foot_daum .info_policy .link_policy{font-size:12px;color:#888}
# .foot_daum .info_policy .txt_dot{padding:0 2px;font-size:12px;color:#888}
# .foot_daum .txt_copyright{display:block;padding-top:6px;font-size:11px;color:#888}
# .foot_daum .txt_copyright .link_kakao{color:#888}
# .os_mac .foot_daum .info_notice{padding:3px 250px 0 31px}
# .os_mac .foot_daum .link_notice{padding-right:12px;background-position-y:-172px}
# .os_mac .foot_daum .tf_keyword{margin-top:4px}
# .os_mac .foot_daum .link_svcall{top:83px;background-position-y:-196px}
# .os_mac .foot_daum .info_policy{padding-top:24px}
# .os_mac .foot_daum .txt_copyright{padding-top:5px}
# .d_head{border-bottom:1px solid #ececec}
# .d_head .inner_head{position:relative;z-index:1;width:1080px;height:150px;margin:0 auto}
# .tit_daum{overflow:hidden;float:left;width:180px;height:150px;text-align:center}
# .link_daum{overflow:hidden;display:block;margin:28px auto}
# .link_launch{position:absolute;top:6px;left:45px;padding-right:8px;font-size:11px;color:#888;background-position:100% -18px}
# .os_mac .link_launch{top:9px;background-position:100% -21px}
# .wrap_search{float:left;position:relative;margin-top:50px}
# .wrap_search .d_sch{background-color:#fff}
# .head_daum .box_search{position:relative;height:44px;margin:1px 1px 0 0;border:1px solid #0089ff;border-radius:1px}
# .head_daum .box_search .inner_search{position:relative;z-index:1;height:44px;padding:0 60px 0 14px}
# .head_daum .box_search::before, .head_daum .box_search .inner_search::before, .head_daum .box_search::after{position:absolute;left:0;right:100%;height:1px;content:'';background-color:#0089ff}
# .head_daum .box_search::before{top:-1px}
# .head_daum .box_search::after{bottom:-1px}
# .head_daum .box_search:hover::before, .head_daum .box_search:hover::after{right:0;transition-property:right;transition-duration:0.8s;background:linear-gradient(to right, #86aaff, #70bc4c, #ffbe00, #f46e85)}
# .head_daum .box_search:hover .inner_search::before{top:-1px;bottom:-1px;left:auto;right:-1px;width:1px;height:46px;background-color:#f46e85;transition-property:height;transition-delay:0.8s}
# .head_daum .tf_keyword{float:left;width:442px;margin-top:7px;border:1px solid transparent;font-size:18px;line-height:24px;background-color:transparent;outline:0;ime-mode:active;-webkit-appearance:none}
# .head_daum .btn_search{position:absolute;top:0;right:0;width:49px;height:42px;margin:1px;line-height:44px;background-position:-40px -231px;background-color:transparent}
# .slide_favorsch{overflow:hidden;width:480px;height:28px}
# .list_favorsch{overflow:hidden;padding-top:7px}
# .list_favorsch li{float:left;padding-right:10px}
# .list_favorsch .link_favorsch{display:block;font-size:12px;color:#555}
# .head_daum .page_pctop{z-index:1;right:1px;bottom:3px}
# .head_bnr{position:absolute;top:33px;right:45px}
# .head_bnr .link_headbnr{display:block}
# .os_mac .head_daum .box_search{margin-top:0}
# .os_mac .head_daum .tf_keyword{margin-top:11px}
# .os_mac .list_favorsch{padding-top:10px}
# .os_mac .list_favorsch li{padding-right:14px}
# .daumSuggestWrap{position:relative;margin-right:90px;clear:both}
# .suggestBox{position:absolute;top:45px;left:0;z-index:9999;width:520px;padding:0;background:none}
# .baseBox{border-top:1px solid #dcdcdc;font-size:12px;line-height:17px;font-family:'굴림',gulim,sans-serif;background-color:#fff}
# .os_mac .baseBox{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .list{padding:7px 0 13px;border-left:1px solid #dcdcdc;border-right:1px solid #dcdcdc;color:#333;background-color:#fff}
# .suggestBox.reverseType .list{padding:3px 0 7px;color:#333}
# .suggestBox .baseBox li{overflow:hidden;height:26px;padding:0 16px;line-height:26px;text-align:left;cursor:pointer}
# .suggestBox li .item{display:block;height:100%}
# .suggestBox li .item:hover{text-decoration:none}
# .suggestBox .list .on{background-color:#f6f6f6}
# .suggestBox li strong{font-weight:normal;color:#0089ff}
# .suggestBox .line{overflow:hidden;height:1px;margin:7px 0px 6px;padding:0;font-size:1px;line-height:1px;background-color:#e5e5e5}
# .suggestBox .guide{padding:15px 10px;color:#555}
# .suggestBox .footer{position:relative;height:20px;padding:8px 12px 4px 7px;border:1px solid #dcdcdc;border-top:1px solid #ececec;font-size:11px;background-color:#fbfbfb;letter-spacing:-1px;clear:both}
# .suggestBox.reverseType .footer{border-top-color:#dcdcdc;border-bottom-color:#ededed}
# .suggestBox .footer .fl{float:left}
# .suggestBox .footer .fr{float:right}
# .suggestBox .footer .btn_close{padding-left:12px;background-position:0 -939px}
# .suggestBox .footer .bar{display:none;padding:0 2px;color:#ddd}
# .suggestBox .footer .fl .bar{padding:0 2px 0 1px}
# .suggestBox .footer .offGuide{display:none;position:absolute;right:0;bottom:19px;width:211px;height:27px;background:url(//search1.daumcdn.net/search/statics/common/pi/suggest_service.gif) no-repeat;text-indent:-999em}
# .suggestBox .footer .offSuggest{display:none}
# .os_mac .suggestBox .list{padding:9px 0 11px}
# .os_mac .suggestBox .baseBox li{padding:0 17px}
# .suggestBox a{color:#777}
# .suggestBox .answer{border-left:1px solid #dcdcdc;border-right:1px solid #dcdcdc}
# .suggestBox .answer span{cursor:pointer}
# .suggestBox .baseBox li a{font-size:14px;color:#333;font-family:'돋움',dotum,sans-serif;text-decoration:none}
# .os_mac .suggestBox .baseBox li a{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .line{display:block;overflow:hidden;clear:both}
# .suggestBox .b_line{border-bottom:1px solid #ededed}
# .suggestBox .suggest_exact{display:block;overflow:hidden;height:40px;padding:12px 0 11px 18px}
# .suggestBox .suggest_exact:hover{text-decoration:none}
# .suggestBox .e_on{background-color:#f8f8f8;text-decoration:none}
# .suggestBox .suggest_exact .txt_exact{overflow:hidden;float:left;height:44px;margin-top:0;background-position:0 0}
# .suggestBox .suggest_exact .txt_unit{font-size:14px;font-family:arial,sans-serif}
# .suggestBox .suggest_exact .tit{margin-left:-1px;font-weight:normal;font-size:12px;line-height:18px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .cont{display:block}
# .suggestBox .suggest_exact .txt_cont{margin-right:4px;font-weight:bold;font-size:14px;line-height:16px;font-family:'돋움',dotum,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num1{font-size:18px;line-height:20px;font-family:tahoma,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num2{margin-left:3px;font-size:12px;line-height:14px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num3{font-size:20px;line-height:23px;font-family:arial,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_num4{margin-left:-3px;font-size:12px;line-height:14px;font-family:'굴림',gulim,sans-serif;color:#333}
# .suggestBox .suggest_exact .txt_exact .ico_suggest2{background:url(//search1.daumcdn.net/search/statics/common/pi/ico/ico_suggest_20110721.gif) no-repeat 0 0}
# .suggestBox .suggest_exact .txt_exact .ico_celsius{background:none}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_up{padding-left:11px;background-position:0 -58px}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_down{padding-left:11px;background-position:0 -98px}
# .suggestBox .suggest_exact .txt_exact .ico_arrow_equal{padding-left:11px;background-position:0 -75px}
# .suggestBox .suggest_exact .txt_blue{color:#007aff}
# .suggestBox .suggest_exact .txt_blue2{color:#007aff}
# .suggestBox .suggest_exact .txt_red{color:#e52d38}
# .suggestBox .suggest_exact .txt_red2{color:#e52d38}
# .suggestBox .suggest_exact .txt_time{float:right;margin:25px 16px 0 0;font-size:11px;font-family:'돋움',dotum,sans-serif;color:#a1a1a1}
# .suggestBox .suggest_exact .ico_celsius{width:12px;height:13px;font-family:arial,sans-serif;background-position:right 5px}
# .suggestBox .suggest_exact .bar{font-size:14px;color:#dedede}
# .suggestBox .wrap_today{overflow:hidden;height:21px;padding:4px 10px 2px 9px;line-height:21px}
# .suggestBox .wrap_today .cont{font-size:14px;color:#333;text-decoration:none}
# .suggestBox .wrap_today .cont_import{font-weight:normal;color:#ea570a}
# .os_mac .suggestBox .suggest_exact .tit{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_num2{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_num4{font-family:'Apple SD Gothic Neo',sans-serif}
# .os_mac .suggestBox .suggest_exact .txt_time{font-family:'Apple SD Gothic Neo',sans-serif}
# .suggestBox .ico_lotto{float:left;width:28px;height:28px;margin:6px 5px 0 0;border-radius:20px;text-align:center}
# .suggestBox .ico_lotto .txt_num{display:inline-block;margin-top:7px;font-size:14px;line-height:1;font-family:arial,sans-serif;color:#fff;vertical-align:top}
# .suggestBox .num1{background-color:#f6a800}
# .suggestBox .num10{background-color:#4155cb}
# .suggestBox .num20{background-color:#f64d61}
# .suggestBox .num30{background-color:#585d6e}
# .suggestBox .num40{background-color:#f6a800}
# .suggestBox .plus{width:8px;height:8px;margin:16px 8px 0 4px;background:url(//search1.daumcdn.net/search/statics/common/pi/ico/ico_suggest_20110721.gif) no-repeat 0 -40px;text-indent:-9999px;opacity:0.5}
# .suggestBox .suggest_exact .ico_suggest{padding-left:59px;color:#555;background:url(//search1.daumcdn.net/search/statics/common/pi/weather/ico_weather_m.png) no-repeat}
# .suggestBox .ico_suggest .cont .screen_out{position:static;font-size:14px;font-family:arial,sans-serif;text-indent:0}
# .suggestBox .suggest_exact .txt_exact{overflow:hidden;float:left;height:44px;margin-top:0}
# .suggestBox .suggest_exact .ico_w00{background-position:0 -1620px}
# .suggestBox .suggest_exact .ico_w01{background-position:0 0}
# .suggestBox .suggest_exact .night .ico_w01{background-position:0 -60px}
# .suggestBox .suggest_exact .ico_w02{background-position:0 -120px}
# .suggestBox .suggest_exact .night .ico_w02{background-position:0 -180px}
# .suggestBox .suggest_exact .ico_w03{background-position:0 -240px}
# .suggestBox .suggest_exact .night .ico_w03{background-position:0 -300px}
# .suggestBox .suggest_exact .ico_w04{background-position:0 -360px}
# .suggestBox .suggest_exact .ico_w05{background-position:0 -420px}
# .suggestBox .suggest_exact .night .ico_w05{background-position:0 -480px}
# .suggestBox .suggest_exact .ico_w06{background-position:0 -540px}
# .suggestBox .suggest_exact .night .ico_w06{background-position:0 -600px}
# .suggestBox .suggest_exact .ico_w07{background-position:0 -660px}
# .suggestBox .suggest_exact .ico_w08{background-position:0 -720px}
# .suggestBox .suggest_exact .ico_w09{background-position:0 -780px}
# .suggestBox .suggest_exact .ico_w10{background-position:0 -840px}
# .suggestBox .suggest_exact .night .ico_w10{background-position:0 -900px}
# .suggestBox .suggest_exact .ico_w11{background-position:0 -960px}
# .suggestBox .suggest_exact .ico_w12{background-position:0 -1020px}
# .suggestBox .suggest_exact .ico_w13{background-position:0 -1080px}
# .suggestBox .suggest_exact .night .ico_w13{background-position:0 -1140px}
# .suggestBox .suggest_exact .ico_w14{background-position:0 -1200px}
# .suggestBox .suggest_exact .ico_w15{background-position:0 -1260px}
# .suggestBox .suggest_exact .ico_w16{background-position:0 -1320px}
# .suggestBox .suggest_exact .night .ico_w16{background-position:0 -1380px}
# .suggestBox .suggest_exact .ico_w17{background-position:0 -1440px}
# .suggestBox .suggest_exact .ico_w18{background-position:0 -1500px}
# .suggestBox .suggest_exact .ico_w19{background-position:0 -1560px}
# #daumSuggestWrap{display:none}
# .d_service{border-bottom:1px solid #888}
# .d_service .inner_service{position:relative;width:990px;height:45px;margin:0 auto}
# .menu_service{float:left;position:relative;width:660px}
# .menu_service .link_more{overflow:hidden;float:left;width:60px;height:25px;padding:10px 0 9px;line-height:20px;background-position:0 8px;background-color:transparent;text-align:center}
# .menu_on .link_more{background-position:-60px 8px}
# .list_mainsvc{float:left}
# .list_mainsvc li{float:left;height:45px}
# .list_mainsvc .txt_pctop{display:block;height:25px;padding:10px 0;font-weight:bold;font-size:13px;line-height:25px;background-color:transparent;text-align:center}
# .list_mainsvc .link_cafe{width:30px;background-position:0 -30px}
# .list_mainsvc .link_mail{width:36px;background-position:-30px -30px}
# .list_mainsvc .link_news{width:37px;background-position:-66px -30px}
# .list_mainsvc .link_map{width:36px;background-position:-103px -30px}
# .list_mainsvc .link_stock{width:37px;background-position:-139px -30px}
# .list_mainsvc .link_shopping{width:36px;background-position:-176px -30px}
# .list_mainsvc .link_kakaotv{width:64px;background-position:-212px -30px}
# .list_mainsvc .link_webtoon{width:37px;background-position:-276px -30px}
# .list_mainsvc .link_blog{width:48px;background-position:-313px -30px}
# .list_mainsvc .link_brunch{width:47px;background-position:-361px -30px}
# .list_mainsvc .link_dic{width:36px;background-position:-408px -30px}
# .list_mainsvc .link_game{width:37px;background-position:-444px -30px}
# .list_mainsvc .link_starplay{width:59px;background-position:-481px -30px}
# .list_mainsvc .link_together{width:59px;background-position:-540px -30px}
# .service_layer{display:none;position:absolute;top:45px;left:0;width:653px;border:1px solid #888;background-color:#fff}
# .menu_on .service_layer{display:block}
# .service_layer .layer_body{overflow:hidden;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_line.gif) repeat-y 0 0}
# .service_layer .sort_service{float:left;width:94px;padding:0 0 15px 15px}
# .service_layer .sort_service.fst{padding-left:14px}
# .service_layer .sort_service dt{margin:11px 0 4px;font-weight:bold;font-size:12px}
# .service_layer .sort_service dt.tit_split{float:left;margin-top:22px;padding-right:9px;background-position:100% 5px}
# .service_layer .sort_service dd{clear:both;font-size:12px;line-height:22px}
# .service_layer .sort_service .link_svc{color:#555}
# .service_layer .sort_service .link_svc:hover{color:#118eff}
# .service_layer .sort_service .ico_new{display:inline-block;width:11px;height:11px;margin:3px 0 0 2px;font-size:0;line-height:0;background-position:-160px -80px;vertical-align:top;text-indent:-9999px}
# .service_layer .layer_foot{overflow:hidden;height:32px;border-top:1px solid #ececec;background-color:#fbfbfb}
# .service_layer .layer_foot .link_total{float:left;padding-right:8px;margin-left:13px;font-size:11px;line-height:29px;color:#555;background-position:100% -12px}
# .service_layer .layer_foot .btn_close{float:right;padding:0 13px;margin:2px;font-size:11px;line-height:24px;color:#888}
# .os_mac .service_layer .sort_service{padding-bottom:12px}
# .os_mac .service_layer .sort_service dt{margin:14px 0 4px}
# .os_mac .service_layer .sort_service dt.tit_split{background-position:100% 3px}
# .os_mac .service_layer .layer_foot .link_total{padding-right:10px;margin-left:14px;line-height:32px;background-position:100% -12px}
# .os_mac .service_layer .layer_foot .btn_close{padding:0 12px;line-height:28px}
# .today_base{float:right;position:relative;height:45px}
# .today_base .comp_base{display:inline-block;vertical-align:top}
# .today_base .img_weather{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/img_weather_170628.png);background-repeat:no-repeat;font-size:0;line-height:0;text-indent:-9999px}
# .today_base .txt_temper{float:left;font-size:14px;font-family:tahoma,arial,sans-serif;letter-spacing:0}
# .os_mac .today_base .txt_temper{font-family:helvetica,arial,sans-serif}
# .info_today{float:left;font-size:13px}
# .info_today .date_today{float:left;height:24px;padding-top:10px;line-height:20px;letter-spacing:0}
# .info_today .txt_part{float:left;margin-right:5px;font-weight:bold;line-height:24px}
# .info_today .link_weather{float:left;height:25px;margin-left:16px;padding:8px 0 12px;line-height:24px;text-align:right}
# .info_today .link_weather:hover{color:#222;text-decoration:none}
# .info_today .list_weather{float:left;overflow:hidden;height:25px}
# .info_today .list_weather li{overflow:hidden;height:25px}
# .os_mac .info_today .date_today{line-height:26px}
# .os_mac .info_today .txt_part{line-height:30px}
# .os_mac .info_today .link_weather{line-height:26px}
# .os_mac .info_today .link_weather .ico_more{margin-top:10px}
# .info_today .img_weather{float:left;width:26px;height:26px;margin:1px 4px 0 0;vertical-align:top}
# .info_today .ico_wm01{background-position:0 -240px}
# .info_today .night .ico_wm01{background-position:-30px -240px}
# .info_today .ico_wm02{background-position:-60px -240px}
# .info_today .night .ico_wm02{background-position:-90px -240px}
# .info_today .ico_wm03{background-position:0 -270px}
# .info_today .night .ico_wm03{background-position:-30px -270px}
# .info_today .ico_wm04{background-position:-60px -270px}
# .info_today .ico_wm07{background-position:-90px -270px}
# .info_today .ico_wm09{background-position:0 -300px}
# .info_today .ico_wm10{background-position:-30px -300px}
# .info_today .night .ico_wm10{background-position:-60px -300px}
# .info_today .ico_wm11{background-position:-90px -300px}
# .info_today .ico_wm14{background-position:0 -330px}
# .info_today .ico_wm17{background-position:-30px -330px}
# .info_today .ico_wm18{background-position:-60px -330px}
# .info_today .ico_wm19{background-position:-90px -330px}
# .info_today .txt_temper{margin-top:1px}
# .info_today .ico_degree{float:left;width:17px;height:15px;margin:7px 0 0;font-size:12px;line-height:17px;background-position:-210px -270px;background-color:transparent;text-align:center;text-indent:0}
# .info_today .link_weather .ico_more{width:13px;height:9px;margin:9px 0 0 1px;background-position:-138px -292px}
# .today_on .link_weather .ico_more{background-position:-138px -304px}
# .today_layer{display:none;position:absolute;top:45px;right:0;width:298px;border:1px solid #888;background-color:#fff}
# .today_layer .ico_wm{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_wm.png);background-repeat:no-repeat;font-size:0;line-height:0;text-indent:-9999px}
# .today_layer .layer_body{overflow:hidden}
# .today_layer .layer_body:after{position:absolute;top:0;right:0;width:42px;height:42px;content:''}
# .today_layer .weather_part{position:relative;height:135px}
# .today_layer .btn_locate{position:absolute;top:17px;left:18px;width:21px;height:21px;font-size:0;line-height:0;background-position:-176px -246px;text-indent:-9999px}
# .today_layer .btn_locate.on{background-position:-176px -286px}
# .today_layer .link_weather{display:block;overflow:hidden;height:135px}
# .today_layer .link_weather:hover{color:#222;text-decoration:none}
# .today_layer .txt_place{display:block;height:20px;margin:17px 0 0 22px;font-weight:bold;font-size:13px;line-height:19px}
# .today_layer .txt_place .txt_local{display:inline-block}
# .today_layer .link_weather .ico_wm{float:left;width:90px;height:90px;margin-left:22px}
# .today_layer .ico_wm01{background-position:0 0}
# .today_layer .night .ico_wm01{background-position:-100px 0}
# .today_layer .ico_wm02{background-position:-200px 0}
# .today_layer .night .ico_wm02{background-position:-300px 0}
# .today_layer .ico_wm03{background-position:0 -100px}
# .today_layer .night .ico_wm03{background-position:-100px -100px}
# .today_layer .ico_wm04{background-position:-200px -100px}
# .today_layer .ico_wm07{background-position:-300px -100px}
# .today_layer .ico_wm09{background-position:0 -200px}
# .today_layer .ico_wm10{background-position:-100px -200px}
# .today_layer .night .ico_wm10{background-position:-200px -200px}
# .today_layer .ico_wm11{background-position:-300px -200px}
# .today_layer .ico_wm14{background-position:0 -300px}
# .today_layer .ico_wm17{background-position:-100px -300px}
# .today_layer .ico_wm18{background-position:-200px -300px}
# .today_layer .ico_wm19{background-position:-300px -300px}
# .today_layer .info_temper{display:block;overflow:hidden;height:32px;margin:19px 0 0 130px;font-family:tahoma,arial,sans-serif}
# .today_layer .info_temper .img_weather{float:left;width:22px;height:32px;margin:0}
# .today_layer .info_temper .num0{background-position:-260px 0}
# .today_layer .info_temper .num1{background-position:-260px -40px}
# .today_layer .info_temper .num2{background-position:-260px -80px}
# .today_layer .info_temper .num3{background-position:-260px -120px}
# .today_layer .info_temper .num4{background-position:-260px -160px}
# .today_layer .info_temper .num5{background-position:-260px -200px}
# .today_layer .info_temper .num6{background-position:-260px -240px}
# .today_layer .info_temper .num7{background-position:-260px -280px}
# .today_layer .info_temper .num8{background-position:-260px -320px}
# .today_layer .info_temper .num9{background-position:-260px -360px}
# .today_layer .info_temper .ico_minus{width:22px;height:32px;background-position:-260px -400px}
# .today_layer .info_temper .ico_degree{width:39px;height:32px;background-position:-210px -292px}
# .today_layer .state_desc{display:block;overflow:hidden;margin:7px 0 0 130px;line-height:16px}
# .today_layer .state_desc .ico_degree{float:left;width:14px;height:12px;margin:3px 1px 0 0;background-position:-240px -208px}
# .today_layer .state_desc .txt_desc{float:left;margin-right:2px}
# .today_layer .layer_foot{overflow:hidden;border-top:1px solid #ececec;background-color:#fbfbfb}
# .today_layer .link_state{float:left;overflow:hidden;width:50%;height:39px;color:#101010;text-decoration:none}
# .today_layer .info_wm{overflow:hidden;height:22px;padding-top:8px;line-height:21px}
# .today_layer .info_wm dt{float:left;padding-right:9px}
# .today_layer .info_wm dd{float:left}
# .today_layer .info_wm .img_weather{display:inline-block;vertical-align:top}
# .today_layer .info_dust{padding-left:18px}
# .today_layer .ico_dust{width:20px;height:20px;margin-top:3px;margin-right:6px;background-position:-140px -240px}
# .today_layer .ico_air{width:21px;height:21px;margin:1px 7px 0 2px;background-position:-140px -264px}
# .today_layer .state_good{color:#0078ff}
# .today_layer .state_normal{color:#27aa1d}
# .today_layer .state_bad{color:#fecc3d}
# .today_layer .state_worst{color:#e30000}
# .today_layer .btn_close{position:absolute;top:18px;right:18px;width:16px;height:16px;background-position:0 -200px}
# .os_mac .today_layer .txt_place{margin-top:20px;line-height:18px}
# .os_mac .today_layer .info_temper{margin-top:15px}
# .os_mac .today_layer .state_desc{margin-top:10px}
# .os_mac .today_layer .state_desc .txt_temper{margin-top:-1px}
# .os_mac .today_layer .state_desc .ico_degree{margin-top:1px}
# .os_mac .today_layer .info_wm{padding-top:11px}
# .os_mac .today_layer .info_wm .ico_dust{margin-top:0}
# .os_mac .today_layer .info_wm .ico_air{margin-top:-2px}
# .today_on .today_layer{display:block}
# .advert_tmp{float:left;position:relative;width:655px;height:120px;margin-right:35px}
# .advert_tmp .bg_line{position:absolute;top:0;left:0;z-index:-1;width:653px;height:118px;border:1px solid #ececec}
# .advert_station{display:inline-block;position:relative;width:300px;height:150px;margin-top:15px;font-size:0;line-height:0;vertical-align:top}
# .advert_station .bg_line{position:absolute;top:0;left:0;z-index:-1;width:298px;height:148px;border:1px solid #ececec}
# .box_shopping{display:inline-block;position:relative;width:300px;height:1177px;margin-top:15px;vertical-align:top}
# .box_shopping .bg_line1{position:absolute;top:0;left:0;z-index:-1;width:298px;height:775px;border:1px solid #ececec}
# .box_shopping .bg_line2{position:absolute;top:792px;left:0;z-index:-1;width:298px;height:383px;border:1px solid #ececec}
# .advert_svcbnr{margin-top:15px}
# .advert_svcbnr .link_bnr{display:block;position:relative;height:60px}
# .advert_svcbnr .frame_g{width:298px;height:58px}
# .advert_bnr{margin-top:15px}
# .advert_bnr .link_bnr{display:block;overflow:hidden;position:relative;height:143px}
# .advert_bnr .frame_g{width:298px;height:141px}
# .wrap_tiercont{position:relative;z-index:99;width:990px;margin:0 auto}
# .login_tmp{float:right;position:relative;z-index:0;width:300px;height:120px;letter-spacing:-1px}
# .login_my{z-index:10;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat 0 0}
# .login_my .wrap_my{width:285px;height:45px;padding:15px 0 17px 15px}
# .login_my .info_my{float:left;padding:1px 0 0 0}
# .login_my .rel_my{float:right;padding-right:15px}
# .login_my .name_user{float:left;margin-right:4px;font-weight:bold}
# .login_my .link_myinfo{float:left;font-size:11px;margin:2px 2px 0 0;line-height:14px;color:#555;text-decoration:underline}
# .login_my .link_sso{position:absolute;top:41px;left:15px;width:68px;height:22px;font-size:11px;line-height:22px;background-position:-100px -235px;white-space:nowrap}
# .login_my .link_ssoing{background-position:-100px -205px}
# .login_my .link_ssohelp{position:absolute;top:41px;left:85px;width:6px;height:22px;padding:0 6px;font-size:12px;line-height:22px;background-position:-180px -235px;white-space:nowrap}
# .layer_sso{position:absolute;top:77px;left:0;z-index:11;width:298px;height:82px;border:1px solid #118eff;background-color:#fff}
# .layer_sso .box_help{display:table;width:100%;height:100%}
# .layer_sso .txt_help{display:table-cell;padding:0 16px 2px;font-size:12px;line-height:16px;color:#555;vertical-align:middle}
# .layer_sso .btn_close{position:absolute;top:5px;right:5px;width:21px;height:21px;padding:0 6px;background-position:-210px -235px}
# .login_my .link_empathy{float:left;margin:5px 8px 0 0;font-size:11px;line-height:14px;color:#5b6473}
# .login_my .btn_logout{float:left;width:56px;height:24px;font-size:11px;line-height:24px;background-position:-180px -30px;background-color:transparent}
# .login_my .list_basis{overflow:hidden;position:absolute;top:43px;right:9px;height:30px;letter-spacing:-0.12em}
# .login_my .list_basis li{float:left;padding-right:8px;line-height:15px}
# .login_my .list_basis .link_basis{float:left;font-size:12px;color:#555}
# .login_my .list_basis .num_basis{margin-left:3px;color:#118eff}
# .login_my .list_basis .num_msg{width:30px}
# .login_my .list_basis .link_num{font-weight:bold;color:#118eff}
# .login_my .my_mileage .link_basis{margin-right:8px}
# .login_my .wrap_mysvc{position:relative;z-index:10;width:300px}
# .mysvc_list{position:relative;width:300px;height:43px}
# .list_mysvc{display:inline-block;position:relative;width:300px;height:43px;vertical-align:top;letter-spacing:-1px}
# .list_mysvc li{position:relative;float:left;width:100px;height:43px}
# .list_mysvc .link_mysvc{display:block;overflow:hidden;height:31px;padding-top:12px;font-size:12px;line-height:18px;text-align:center;color:#555}
# .list_mysvc .link_mysvc:hover{text-decoration:none}
# .list_mysvc .cafe_g .link_mysvc{height:30px;padding-top:13px;line-height:16px}
# .list_mysvc .txt_mysvc{display:inline-block;height:26px;color:#555;vertical-align:top}
# .list_mysvc .cafe_g .txt_mysvc{padding-left:24px;background-position:0 -80px}
# .list_mysvc .stock_g .txt_mysvc{padding-left:27px;background-position:0 -109px}
# .list_mysvc .blog_g .txt_mysvc{padding-left:29px;background-position:0 -139px}
# .list_mysvc .ico_new{display:none;width:11px;height:11px;margin:5px 0 0 4px;background-position:-160px -80px;text-indent:-9999px;vertical-align:top}
# .list_mysvc .new_g .ico_new{display:inline-block}
# .list_mysvc .cafe_g .ico_new{margin-top:4px}
# .mycafe_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px 0}
# .mystock_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px -50px}
# .myblog_on{background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_pctop_170328.png) no-repeat -310px -100px}
# .layer_mycont{position:absolute;top:120px;left:0;width:300px;height:353px;background-position:0 -130px}
# .layer_mycont .btn_close{position:absolute;top:320px;right:0;width:46px;height:32px;padding:3px 0 4px;font-size:11px;line-height:18px;color:#888}
# .os_mac .layer_sso .txt_help{padding-top:2px;padding-bottom:0}
# .os_mac .login_tmp{letter-spacing:0}
# .os_mac .login_my .info_my{padding-top:4px}
# .os_mac .login_my .name_user{margin-right:7px}
# .os_mac .login_my .link_privacy{margin-top:0}
# .os_mac .login_my .list_basis{top:45px;right:6px;letter-spacing:0}
# .os_mac .list_basis li{padding-right:9px}
# .os_mac .list_mysvc .link_mysvc{line-height:21px}
# .os_mac .cafe_g .link_mysvc{line-height:20px}
# .os_mac .list_mysvc .ico_new{margin-top:4px}
# .os_mac .cafe_g .ico_new{margin-top:3px}
# .os_mac .layer_mycont .btn_close{padding-top:5px}
# .panel_bloc{position:relative;padding-top:61px}
# .tit_tabcont{position:absolute;top:15px;font-size:16px}
# .tit_tabcont .link_tit{display:block;height:36px;line-height:36px;background-color:transparent;text-align:center}
# .wrap_tabcont{display:none;width:655px}
# .ico_view{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-40px 0;text-indent:-9999px;cursor:pointer}
# .ico_video{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-70px 0;text-indent:-9999px;cursor:pointer}
# .ico_live{overflow:hidden;position:absolute;right:8px;bottom:8px;width:23px;height:23px;background-position:-130px 0;text-indent:-9999px;cursor:pointer}
# .color_g1{color:#e30000}
# .color_g2{color:#118eff}
# .ico_label{overflow:hidden;position:absolute;top:15px;left:15px;height:22px;padding:0 8px;font-size:11px;line-height:19px;color:#fff;background-color:#118eff}
# .ico_label2{overflow:hidden;position:absolute;top:0;left:0;height:20px;padding:0 7px;font-size:11px;line-height:17px;color:#fff;background-color:rgba(0,0,0,0.6);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#99000000',endColorstr='#99000000',GradientType=0)}
# .ico_label3{overflow:hidden;position:absolute;top:15px;left:15px;height:22px;padding:0 8px;font-size:11px;line-height:19px;color:#fff;background-color:#e8493d}
# .os_mac .ico_label,.os_mac .ico_label3{line-height:23px}
# .os_mac .ico_label2{line-height:21px}
# .tag_live{width:30px;height:15px;background-position:-120px -70px}
# .tag_new{width:31px;height:15px;background-position:-120px -90px}
# .tag_event{width:40px;height:15px;background-position:-120px -110px}
# .tag_issue{width:37px;height:15px;background-position:-120px -130px}
# .page_pctop{position:absolute;width:auto;height:16px}
# .page_pctop .btn_page{float:left;width:16px;height:16px;line-height:16px;background-color:transparent;background-position:-210px 0}
# .page_pctop .btn_next{width:15px;background-position:-226px 0}
# .page_pctop .info_page{float:left;padding:2px 5px 0 0;font-size:12px;line-height:16px;color:#555;font-family:tahoma,arial,sans-serif}
# .page_pctop .info_page .txt_slash{padding:0 1px}
# .os_mac .page_pctop .info_page{line-height:16px;font-family:helvetica,arial,sans-serif}
# .page_btype{top:20px;right:0;height:26px}
# .page_btype .btn_page{width:26px;height:26px;line-height:26px;background-position:-110px -170px;text-indent:10px}
# .page_btype .btn_next{width:25px;background-position:-136px -170px}
# .page_btype .info_page{padding-top:1px;padding-right:8px;font-size:14px;line-height:22px}
# .os_mac .page_btype .info_page{line-height:24px}
# .page_tabcont{position:absolute;z-index:1;top:16px;left:30px;cursor:pointer}
# .page_tabcont .btn_page{overflow:hidden;float:left;width:7px;height:7px;margin:9px 0;font-size:10px;line-height:7px;background-position:-100px -170px;background-color:transparent}
# .page_tabcont .on{position:relative;background-position:-100px -177px}
# .list_thumb{overflow:hidden}
# .list_thumb li{float:left;width:154px;height:146px;margin-left:13px}
# .list_thumb .fst{margin-left:0}
# .list_thumb .link_item{display:block}
# .list_thumb .thumb_g{width:154px;height:94px}
# .list_thumb .frame_g{width:152px;height:92px}
# .list_thumb .cont_item{padding:4px 2px 0}
# .list_thumb .tit_item{display:block;overflow:hidden;max-height:36px;padding-right:12px;font-weight:normal;line-height:18px;word-break:keep-all;word-wrap:break-word}
# .os_mac .list_thumb .cont_item{padding-top:6px}
# .os_mac .list_thumb .tit_item{padding-right:14px}
# .list_txt{float:left}
# .list_txt li{overflow:hidden;height:20px;padding:4px 0 2px;white-space:nowrap;text-overflow:ellipsis}
# .list_txt .ico_pctop{display:inline-block;margin:3px 4px 0 0;text-indent:-9999px;vertical-align:top}
# .list_txt .split_txt{padding-left:10px;margin-left:10px;color:#888;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/ico_pctop_vert_170724.png) 0 -46px}
# .list_txt .split_txt:hover{color:#118eff}
# .list_txt .part_mid{padding-top:18px;line-height:16px}
# .list_txt .split_part{display:inline-block;overflow:hidden;vertical-align:top}
# .list_txt .split_part .link_txt{margin-right:3px}
# .list_txt .split_fst{float:left;overflow:hidden;max-width:222px;text-overflow:ellipsis}
# .os_mac .list_txt li{line-height:20px}
# .os_mac .list_txt .split_txt{background-position:0 -49px}
# .os_mac .list_txt .part_mid{line-height:22px}
# .os_mac .list_txt .split_part .split_part{letter-spacing:-0.03em}
# .os_mac .list_txt .split_part .link_txt{margin-right:7px}
# .list_stxt{margin-top:7px}
# .list_stxt li{overflow:hidden;padding-bottom:4px;line-height:19px;white-space:nowrap;text-overflow:ellipsis}
# .list_stxt .txt_mark{font-size:12px;color:#888}
# .link_sector{display:block;position:relative;z-index:0;width:321px;height:131px}
# .link_sector .frame_g{width:319px;height:129px}
# .link_sector .cont_item{position:absolute;right:0;left:0;bottom:0;width:100%;height:100px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate2.png) no-repeat 0 100%}
# .link_sector .tit_item{overflow:hidden;position:absolute;left:0;bottom:13px;right:0;padding:0 15px;font-weight:normal;font-size:14px;line-height:20px;color:#fff}
# .link_sector .ico_label,
# .link_sector .ico_label2,
# .link_sector .ico_label3,
# .link_sector .ico_pctop{z-index:1}
# .os_mac .link_sector .tit_item{bottom:10px}
# .list_ranking li{height:20px;padding-bottom:5px}
# .list_ranking .link_ranking{display:block;overflow:hidden;line-height:18px}
# .list_ranking .txt_ranking{overflow:hidden;float:left;width:288px;white-space:nowrap;text-overflow:ellipsis}
# .list_ranking .link_ranking:hover .txt_ranking{text-decoration:underline}
# .list_ranking .num_pctop{float:left;width:16px;height:16px;margin:3px 7px 0 0;text-indent:-9999px;vertical-align:top}
# .list_ranking .num1{background-position:0 0}
# .list_ranking .num2{background-position:0 -20px}
# .list_ranking .num3{background-position:0 -40px}
# .list_ranking .num4{background-position:0 -60px}
# .list_ranking .num5{background-position:0 -80px}
# .os_mac .list_ranking .num_pctop{margin-top:0}
# .os_mac .list_ranking li{line-height:22px}
# .box_story{overflow:hidden;border:1px solid #ececec;background-color:#fbfbfc}
# .box_story .tit_subject{overflow:hidden;margin-top:7px;font-size:13px}
# .box_story .tit_subject .link_tit{float:left;padding-right:9px;background-position:100% 7px}
# .os_mac .box_story .tit_subject{margin-top:10px}
# .os_mac .box_story .tit_subject .link_tit{background-position:100% 4px}
# .os_mac .box_story .list_stxt{margin-top:10px}
# .section_media{position:relative}
# .section_media .page_btype{top:15px}
# .section_media .panel_bloc{padding:57px 0 25px}
# .section_media .tit_tabcont{top:11px;left:0}
# .panel_bloc .tit_news{left:-5px}
# .panel_bloc .tit_entertain{left:55px}
# .panel_bloc .tit_sports{left:94px}
# .panel_bloc .tit_movie{left:147px}
# .panel_bloc .tit_auto{left:186px}
# .panel_bloc .tit_realestate{left:240px}
# .panel_bloc .tit_news .link_tit{width:36px;background-position:0 -130px}
# .panel_bloc .tit_entertain .link_tit{width:36px;background-position:-36px -130px}
# .panel_bloc .tit_sports .link_tit{width:50px;background-position:-72px -130px}
# .panel_bloc .tit_movie .link_tit{width:36px;background-position:-122px -130px}
# .panel_bloc .tit_auto .link_tit{width:51px;background-position:-158px -130px}
# .panel_bloc .tit_realestate .link_tit{width:48px;background-position:-209px -130px}
# .news_on .tit_news .link_tit{background-position:0 -166px}
# .entertain_on .tit_entertain .link_tit{background-position:-36px -166px}
# .sports_on .tit_sports .link_tit{background-position:-72px -166px}
# .movie_on .tit_movie .link_tit{background-position:-122px -166px}
# .auto_on .tit_auto .link_tit{background-position:-158px -166px}
# .realestate_on .tit_realestate .link_tit{background-position:-209px -166px}
# .news_on .wrap_news, .entertain_on .wrap_entertain, .sports_on .wrap_sports, .movie_on .wrap_movie, .auto_on .wrap_auto, .realestate_on .wrap_realestate{display:block}
# .section_media .wrap_tabcont{height:480px}
# .group_news{display:inline-block;height:292px;vertical-align:top}
# .news_prime{height:438px}
# .news_prime .list_txt{width:316px;padding-left:4px}
# .news_prime .list_thumb .tit_item{word-break:normal}
# .box_sector{overflow:hidden;float:left;width:321px;margin-right:13px}
# .box_sector .list_thumb{width:334px;margin-left:-13px}
# .box_sector .link_sector{margin-bottom:15px}
# .news_flow{overflow:hidden;position:relative;height:40px;border:1px solid #ececec;line-height:35px;background-color:#fbfbfb}
# .unit_home{float:left;padding-left:12px}
# .unit_home .tit_home{float:left;margin-right:10px}
# .unit_home .tit_home .link_home{padding-right:7px;background-position:100% 6px}
# .unit_home .list_home{float:left}
# .unit_home .list_home li{float:left;padding:0 7px}
# .unit_home .list_home .link_home{color:#555}
# .unit_home .link_home:hover{color:#118eff}
# .unit_live{float:left;padding-left:25px}
# .unit_live .ico_pctop{float:left;margin:12px 6px 0 0;text-indent:-9999px}
# .unit_live .link_live{margin-right:5px;color:#555}
# .unit_live .link_live:hover{color:#118eff}
# .news_flow .link_hash{padding:0 7px;color:#118eff}
# .os_mac .news_flow{line-height:40px}
# .os_mac .unit_home .tit_home .link_home{padding-right:9px;background-position:100% 3px}
# .box_issue{float:left;position:relative;margin-right:13px}
# .box_issue .link_issue{display:block;overflow:hidden;position:relative;width:321px;height:277px}
# .box_issue .cover_g{position:absolute;left:0;bottom:0;width:100%;height:132px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate8.png) 0 100%}
# .box_issue .frame_g{width:319px;height:275px}
# .box_issue .ico_label{height:27px;font-size:14px;line-height:25px;background-color:rgba(17,142,255,.9)}
# .box_issue .cont_item{overflow:hidden;position:absolute;right:0;bottom:14px;left:0}
# .box_issue .cont_item .tit_item{display:block;overflow:hidden;max-height:44px;padding:0 16px;font-weight:normal;font-size:16px;line-height:22px;color:#fff}
# .os_mac .box_issue .ico_label{line-height:29px}
# .os_mac .box_issue .cont_item{bottom:10px}
# .special_issue .tit_issue{overflow:hidden;position:absolute;top:25px;left:21px;max-height:60px;padding-right:20px;font-size:22px;color:#fff}
# .special_issue .cont_item{bottom:12px}
# .special_issue .list_item{padding:0 16px}
# .special_issue .list_item li{overflow:hidden;margin-top:3px;font-size:14px}
# .special_issue .list_item .fst{font-size:16px;line-height:26px}
# .special_issue .list_item .link_item{display:block;overflow:hidden;color:#fff;white-space:nowrap;text-overflow:ellipsis}
# .os_mac .special_issue .list_item .fst{line-height:23px}
# .wrap_news .news_prime{float:left;width:501px;height:438px}
# .wrap_news .news_flow{clear:both}
# .wrap_news .box_sector{width:154px}
# .wrap_news .box_sector .list_thumb{width:auto;margin-left:0}
# .wrap_news .box_sector .list_thumb li{float:none;margin-left:0}
# .wrap_news .link_sector{width:154px;height:277px;margin-bottom:0}
# .wrap_news .link_sector .frame_g{width:152px;height:275px}
# .ranking_news{overflow:hidden;position:relative;height:148px;padding:0 14px 0 148px}
# .ranknews_tit{position:absolute;top:3px;left:0;width:148px}
# .ranknews_tit .tit_ranking{float:left;line-height:17px;color:#118eff}
# .ranknews_tit .link_tit{color:#118eff}
# .help_part{display:inline;float:left;margin:3px 0 0 4px}
# .help_part .link_help{display:block;width:31px;height:15px;font-size:11px;background-color:transparent;background-position:0 -265px}
# .help_layer{overflow:hidden;position:absolute;top:27px;left:0;width:126px;height:48px;border:1px solid #888;background-color:#fbfbfb}
# .help_layer .txt_help{padding:8px 13px 0 13px;font-size:11px;line-height:15px;color:#888}
# .help_layer .btn_close{position:absolute;top:8px;right:8px;width:16px;height:16px;background-position:0 -200px}
# .ranking_news .list_ranking{margin-top:3px}
# .tab_ranking{position:absolute;top:30px;left:0;width:64px}
# .tab_ranking li{margin-bottom:3px}
# .tab_ranking .link_tab{display:inline-block;overflow:hidden;font-weight:bold;line-height:16px;color:#888}
# .tab_ranking .on .link_tab{color:#222;text-decoration:underline}
# .tab_ranking .ico_pctop{float:left;width:6px;height:6px;margin:6px 8px 0 0;background-position:-100px -190px}
# .cont_ranking{display:none;overflow:hidden}
# .cont_ranking.on{display:block}
# .os_mac .help_part{margin-top:0}
# .os_mac .help_layer{top:25px}
# .os_mac .ranknews_tit{top:6px}
# .os_mac .ranking_news .list_ranking{margin-top:5px}
# .os_mac .tab_ranking{top:33px}
# .os_mac .tab_ranking li{margin-bottom:1px}
# .os_mac .tab_ranking .ico_pctop{margin-top:4px}
# .cast_sports{position:relative;width:321px;margin-bottom:15px}
# .cast_sports .head_cast{height:35px;border:1px solid #ececec;background-color:#fbfbfb}
# .cast_sports .tit_cast{margin:6px 0 0 11px;font-size:13px}
# .cast_sports .page_pctop{top:11px;right:14px;bottom:auto}
# .cast_sports .page_pctop .btn_page{width:16px;height:16px;line-height:16px;background-position:-210px 0}
# .cast_sports .page_pctop .btn_next{width:15px;background-position:-226px 0}
# .cast_sports .link_more{position:absolute;top:9px;right:13px;padding-right:7px;font-size:11px;color:#888;background-position:100% -18px}
# .list_relay{border:1px solid #ececec;border-top:0 none}
# .list_relay li{overflow:hidden}
# .list_relay .link_relay:hover{color:#222;text-decoration:none}
# .list_relay .txt_team{overflow:hidden;font-size:12px;line-height:26px;white-space:nowrap;text-overflow:ellipsis}
# .list_relay .txt_time{float:left;font-size:11px;font-family:tahoma,arial,sans-serif;letter-spacing:0}
# .list_relay .txt_league{float:left;padding-left:3px;font-size:11px;color:#888}
# .list_relay .txt_score .inner_score{display:inline-block;vertical-align:top}
# .list_relay .txt_score .num_pctop{float:left;width:11px;height:16px;background-color:transparent}
# .list_relay .txt_score .num0{background-position:-60px 0}
# .list_relay .txt_score .num1{background-position:-60px -20px}
# .list_relay .txt_score .num2{background-position:-60px -40px}
# .list_relay .txt_score .num3{background-position:-60px -60px}
# .list_relay .txt_score .num4{background-position:-60px -80px}
# .list_relay .txt_score .num5{background-position:-60px -100px}
# .list_relay .txt_score .num6{background-position:-60px -120px}
# .list_relay .txt_score .num7{background-position:-60px -140px}
# .list_relay .txt_score .num8{background-position:-60px -160px}
# .list_relay .txt_score .num9{background-position:-60px -180px}
# ...
# .box_recomm .list_recomm li{float:left;width:140px;height:30px;margin:0 16px 7px 0}
# .box_recomm .list_recomm .link_recomm{display:inline-block;overflow:hidden;max-width:100%;line-height:30px;white-space:nowrap;text-overflow:ellipsis}
# .box_recomm .list_recomm .thumb_recomm{float:left;width:30px;height:30px;margin-right:6px;vertical-align:top}
# .box_recomm .list_recomm .thumb_recomm .img_thumb{border-radius:30px}
# .os_mac .box_recomm .list_recomm{margin-top:9px}
# .box_best .list_ranking{margin-top:7px}
# .box_best .list_ranking .txt_ranking{width:270px}
# .box_best .list_ranking li{padding-bottom:3px}
# .box_best .list_ranking .num_pctop{margin-top:2px}
# .os_mac .box_best .list_ranking .num_pctop{margin-top:0}
# .group_recomm .box_game{margin-right:0}
# .group_recomm .box_infobnr{height:159px;margin-bottom:0}
# .group_recomm .box_infobnr .thumb_g{height:159px}
# .group_recomm .box_infobnr .frame_g{height:157px}
# .group_recomm .box_infobnr .txt_info{margin:0 0 4px}
# .box_wtrank{position:relative}
# .box_wtrank .tit_subject{position:absolute;top:0;left:11px;z-index:1}
# .list_wtrank{margin-top:13px}
# .list_wtrank li{margin-bottom:3px}
# .list_wtrank .fst{overflow:hidden;position:relative;height:62px;margin-bottom:9px;padding-top:20px;border-bottom:1px solid #ececec}
# .list_wtrank .img_thumb{position:absolute;top:0;right:0;width:auto;height:83px;pointer-events:none}
# .list_wtrank .link_ranking{display:inline-block;overflow:hidden;line-height:18px;vertical-align:top}
# .list_wtrank .cont_item{overflow:hidden;width:140px}
# .list_wtrank .txt_ranking{display:block;overflow:hidden;max-width:200px;white-space:nowrap;text-overflow:ellipsis}
# .list_wtrank .link_ranking:hover .txt_ranking{color:#118eff;text-decoration:underline}
# .list_wtrank .cont_item .txt_ranking{max-height:36px;white-space:normal;word-break:keep-all;word-wrap:break-word}
# .list_wtrank .txt_mark{font-size:12px;color:#888}
# .list_wtrank .num_pctop{float:left;width:16px;height:16px;margin:3px 7px 0 0;text-indent:-9999px;vertical-align:top}
# .list_wtrank .num1{background-position:0 0}
# .list_wtrank .num2{background-position:0 -20px}
# .list_wtrank .num3{background-position:0 -40px}
# .os_mac .list_wtrank li{margin-bottom:4px}
# .os_mac .list_wtrank .fst{height:59px;margin-bottom:9px;padding-top:23px}
# .os_mac .list_wtrank .num_pctop{margin-top:0}
# .box_music{padding-left:12px;height:157px}
# .box_music .head_item{overflow:hidden;padding:7px 0 11px;line-height:18px}
# .box_music .head_item .tit_subject{float:left;margin:0 4px 0 0}
# .box_music .head_item .txt_standard{float:left;font-size:11px;color:#888}
# .box_music .head_item .txt_num{font-family:tahoma,arial,sans-serif;letter-spacing:0}
# .list_music{overflow:hidden;width:646px}
# .list_music li{float:left;position:relative;width:70px;margin-right:36px;padding-left:22px}
# .list_music .link_item{display:block;width:70px}
# .list_music .thumb_g{width:70px;height:70px}
# .list_music .frame_g{width:68px;height:68px}
# .list_music .cont_item{display:block;padding-top:4px}
# .list_music .tit_item{display:block;overflow:hidden;margin:0;font-weight:normal;line-height:16px;white-space:nowrap;text-overflow:ellipsis}
# .list_music .tit_item:hover{color:#118eff;text-decoration:underline}
# .list_music .origin_item{display:block;overflow:hidden;font-size:12px;line-height:16px;color:#888;white-space:nowrap;text-overflow:ellipsis}
# .list_music .origin_item .link_singer{color:#888}
# .list_music .num_pctop{position:absolute;top:0;left:0;width:16px;height:16px;text-indent:-9999px;vertical-align:top}
# .list_music .num1{background-position:0 0}
# .list_music .num2{background-position:0 -20px}
# .list_music .num3{background-position:0 -40px}
# .list_music .num4{background-position:0 -60px}
# .list_music .num5{background-position:0 -80px}
# .os_mac .box_music .head_item{padding:10px 0 8px}
# .os_mac .box_music .head_item .txt_num{font-family:helvetica,arial,sans-serif}
# .os_mac .list_music .cont_item{padding-top:6px}
# .wrap_topic{width:990px;margin:0 auto;padding:29px 0 45px}
# .wrap_topic .tit_photo{display:inline-block;overflow:hidden;height:36px;font-size:16px;line-height:33px;vertical-align:top;}
# .wrap_topic .link_photoclip{display:inline-block;padding-right:11px;background-position:100% -242px;white-space:nowrap;vertical-align:top;}
# .wrap_topic .link_phototheme{display:inline-block;margin-right:6px;color:#118eff;vertical-align:top;}
# .view_photo{overflow:hidden;position:relative;width:990px;height:400px;margin-top:20px}
# .view_photo .list_photo{overflow:hidden;position:absolute;top:0}
# .view_photo .list_photo li{float:left}
# .view_photo .box_photo{display:block;overflow:hidden;width:682px;height:400px;background-color:#333;text-decoration:none;text-align:center}
# .view_photo .box_photo .img_thumb{display:inline}
# .view_photo .detail_photo{display:none;position:absolute;top:0;left:50%;width:682px;margin-left:-341px;padding-top:330px}
# .view_photo .detail_photo .frame_g{width:680px;height:398px}
# .view_photo .link_photo{display:block;overflow:hidden;position:relative;height:70px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate_slide.png) 0 0 no-repeat}
# .view_photo .link_photo:hover{text-decoration:none}
# .view_photo .link_photo .ico_photo{position:absolute;top:18px;right:20px;width:17px;height:15px;background-position:-160px -60px;text-indent:-9999px}
# .view_photo .link_photo .tit_gallery{overflow:hidden;margin:14px 57px 0 20px;font-weight:normal;font-size:14px;color:#f4f4f4;text-decoration:none;white-space:nowrap;text-overflow:ellipsis}
# .view_photo .link_photo .desc_source{display:block;padding:1px 0 0 20px;font-size:11px;color:#fff;opacity:0.6;filter:alpha(opacity=60)}
# .view_photo .link_photo .txt_date{margin-left:10px;font-family:Helvetica,tahoma,sans-serif}
# .view_photo .btn_preview{overflow:hidden;position:absolute;top:0;width:152px;height:400px;background:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/bg_plate_slide2.png) 0 0 no-repeat;text-decoration:none;cursor:pointer}
# .view_photo .btn_preview .frame_g{width:150px;height:398px}
# .view_photo .btn_preview .ico_pctop{position:absolute;top:170px;width:60px;height:60px;text-indent:-9999px}
# .view_photo .btn_prev{left:0;border-right:2px solid #fff}
# .view_photo .btn_prev .ico_pctop{left:0;background-position:-190px -60px}
# .view_photo .btn_next{right:0;border-left:2px solid #fff}
# .view_photo .btn_next .ico_pctop{right:0;background-position:-190px -130px}
# .view_photo .btn_gallery{background-color:#333}
# .view_photo .txt_gallery{display:none;padding:184px 0 0 71px;line-height:16px;color:#fff}
# .view_photo .btn_gallery .txt_gallery{display:block}
# .view_photo .btn_next .txt_gallery{padding-right:71px;padding-left:0;text-align:right}
# .view_slide{overflow:hidden;position:relative;height:60px;margin-top:20px}
# .view_slide .list_thumbnail{overflow:hidden}
# .view_slide .list_thumbnail li{float:left;padding-left:2px}
# .view_slide .list_thumbnail li.fst{padding-left:0}
# .view_slide .link_thumb{display:block;position:relative;width:60px;height:60px}
# .view_slide .link_thumb .frame_g{width:58px;height:58px;cursor:pointer}
# .view_slide .list_thumbnail .on .frame_g{width:56px;height:56px;border:2px solid #118eff;opacity:1;filter:alpha(opacity=100)}
# .view_slide .list_thumbnail .on .cover_g{position:absolute;top:0;bottom:0;left:0;right:0;background:#fff;opacity:0.6;filter:alpha(opacity=60)}
# .view_slide .btn_move{position:absolute;top:0;width:20px;height:60px}
# .view_slide .btn_prev{left:0}
# .view_slide .btn_next{right:0}
# .view_slide .btn_move .ico_pctop{display:block;width:20px;height:20px;margin-top:20px;text-indent:-9999px;cursor:pointer}
# .view_slide .btn_prev .ico_pctop{background-position:-190px -200px}
# .view_slide .btn_next .ico_pctop{background-position:-220px -200px}
# .os_mac .wrap_topic .tit_photo{line-height:39px}
# .os_mac .view_photo .tit_gallery{margin-top:16px}
# .os_mac .view_photo .desc_source{padding-top:2px}
# .os_mac .view_photo .txt_gallery{padding-top:186px}
# .vphoto_type2 .box_photo{width:990px;}
# .vphoto_type2 .detail_photo{width:990px;margin-left:-495px;}
# .vphoto_type2 .detail_photo .frame_g{width:988px;}
# .vphoto_type2 .link_photo{background-repeat: repeat-x;}
# .vphoto_type2 .btn_preview{top:140px;height:120px;border:0 none;background:none}
# .vphoto_type2 .btn_preview .frame_g{display:none;}
# .vphoto_type2 .btn_preview .ico_pctop{top:30px;}
# .vphoto_type2 .txt_gallery{padding-top:43px;}
# .view_slide .list_thumbnail2 .link_thumb{width:246px;}
# .view_slide .list_thumbnail2 .link_thumb .frame_g{width:244px;}
# .view_slide .list_thumbnail2 .on .frame_g{width:242px;}
# .view_slide .list_thumbnail3 .link_thumb{overflow:hidden;width:196px;}
# .view_slide .list_thumbnail3 .link_thumb .frame_g{width:194px;}
# .view_slide .list_thumbnail3 .on .frame_g{width:192px;}
# .view_slide .list_thumbnail3 .fst .link_thumb, .view_slide .list_thumbnail3 .lst .link_thumb{width:197px;}
# .view_slide .list_thumbnail3 .fst .link_thumb .frame_g, .view_slide .list_thumbnail3 .lst .link_thumb .frame_g{width:195px;}
# .view_slide .list_thumbnail3 .fst.on .frame_g, .view_slide .list_thumbnail3 .lst.on .frame_g{width:193px;}
# .os_mac .vphoto_type2 .txt_gallery{padding-top:46px;}
# .topic_spe{position:absolute;top:0;left:50%;width:990px;margin-left:-495px;background:red}
# .topic_spe .link_spe{overflow:hidden;position:absolute;top:0;width:464px;height:610px;font-size:1px;line-height:0;text-align:left;text-indent:-9999px}
# .topic_spe .link_spe_left{left:-465px}
# .topic_spe .link_spe_right{right:-465px}
# .notice_layer{overflow:hidden;width:100%;border-bottom:1px solid #ecf2f7;background-color:#f4faff}
# .inner_notice_layer{overflow:hidden;position:relative;width:990px;height:110px;margin:0 auto;background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/notice_start.png);background-repeat:no-repeat}
# .inner_notice_layer1{background-position:100% 100%}
# .inner_notice_layer .set_start{float:left;padding-top:29px}
# .inner_notice_layer .txt_news{display:block;font-weight:normal;font-size:20px}
# .inner_notice_layer .link_start{overflow:hidden;float:left;margin-top:3px;padding-right:9px;font-size:12px;color:#888;background-position:100% -197px;text-decoration:underline}
# .inner_notice_layer .btn_close{overflow:hidden;position:absolute;top:36px;right:0;width:20px;height:20px;background-position:-170px -180px;text-indent:-9999px}
# .os_mac .inner_notice_layer .set_start{padding-top:33px}
# .os_mac .inner_notice_layer .link_start{margin-top:0}
# .mobileweb_layer{overflow:hidden;width:100%;padding-bottom:29px;border-top:1px solid #ececec;background-color:#f2f2f2;text-align:center}
# .mobileweb_layer .txt_mobile{margin-top:18px;margin-left:13px;font-size:12px;color:#888}
# .mobileweb_layer .txt_mobile .ico_info{display:inline-block;width:13px;height:13px;margin:3px 8px 0 0;background-position:-170px -120px;vertical-align:top}
# .mobileweb_layer .link_mobile{display:block;width:100px;height:30px;margin:12px auto 0;border:1px solid #dadbdd;font-weight:bold;font-size:13px;line-height:28px;color:#222;background-color:#fff}
# .mobileweb_layer .link_mobile:hover{text-decoration:none}
# .os_mac .mobileweb_layer .txt_mobile{margin-top:22px;margin-left:-9px}
# .os_mac .mobileweb_layer .txt_mobile .ico_info{margin:1px 8px 0 0}
# .os_mac .mobileweb_layer .link_mobile{margin-top:9px;line-height:31px}
# @media
# only screen and (-webkit-min-device-pixel-ratio: 1.5),
# only screen and (min-device-pixel-ratio: 1.5),
# only screen and (min-resolution: 144dpi),
# only screen and (min-resolution: 1.5dppx) {
# .suggestBox .suggest_exact .ico_suggest{background-image:url(//search1.daumcdn.net/search/statics/common/pi/r2/weather/ico_weather_m.png);background-size:43px 1680px}
# .ico_pctop{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/ico_pctop_170828.png);background-size:250px 300px}
# .ico_vert{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/ico_pctop_vert_170724.png);background-size:100px 500px}
# .txt_pctop{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/txt_pctop_170711.png);background-size:600px 480px}
# .bg_pctop, .login_my{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/bg_pctop_170328.png);background-size:610px 490px}
# .num_pctop{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/num_pctop_170405.png);background-size:80px 220px}
# .inner_notice_layer{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/notice_start.png);background-size:300px 110px}
# .today_base .img_weather{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/img_weather_170628.png);background-size:300px 460px}
# .today_layer .ico_wm{background-image:url(//t1.daumcdn.net/daumtop_deco/images/top/2017/rtn/ico_wm.png);background-size:400px 400px}
# }
# .list_hotissue li .roll_txt {
# -webkit-transition: transform 0s linear;
# -moz-transition: transform 0s linear;
# -ms-transition: transform 0s linear;
# -o-transition: transform 0s linear;
# transition: transform 0s linear;
# -webkit-transform: translateY(0);
# -moz-transform: translateY(0);
# -ms-transform: translateY(0);
# -o-transform: translateY(0);
# transform: translateY(0);
# }
# .list_hotissue li.current .roll_txt {
# -webkit-transform: translateY(-20px);
# -moz-transform: translateY(-20px);
# -ms-transform: translateY(-20px);
# -o-transform: translateY(-20px);
# transform: translateY(-20px);
# -webkit-transition: transform .3s ease-out;
# -moz-transition: transform .3s ease-out;
# -ms-transition: transform .3s ease-out;
# -o-transition: transform .3s ease-out;
# transition: transform .3s ease-out;
# }
# .hotissue_mini .list_hotissue li.current .roll_txt {
# -webkit-transform: translateY(0px);
# -moz-transform: translateY(0px);
# -ms-transform: translateY(0px);
# -o-transform: translateY(0px);
# transform: translateY(0px);
# -webkit-transition: initial !important;
# -moz-transition: initial !important;
# -ms-transition: initial !important;
# -o-transition: initial !important;
# transition: initial !important;
# }
# .hotissue_mini .list_hotissue li {
# -webkit-transition: transform .3s ease-out;
# -moz-transition: transform .3s ease-out;
# -ms-transition: transform .3s ease-out;
# -o-transition: transform .3s ease-out;
# transition: transform .3s ease-out;
# }
# .hotissue_mini .list_hotissue li {
# position:absolute;
# background-color:#fff;
# -webkit-transform: translateY(-28px);
# -moz-transform: translateY(-28px);
# -ms-transform: translateY(-28px);
# -o-transform: translateY(-28px);
# transform: translateY(-28px);
# }
# .hotissue_mini .list_hotissue li.current {
# opacity:1;
# -webkit-transform: translateY(0px);
# -moz-transform: translateY(0px);
# -ms-transform: translateY(0px);
# -o-transform: translateY(0px);
# transform: translateY(0px);
# }
# .hotissue_mini .list_hotissue li.next {
# opacity:0;
# -webkit-transform: translateY(28px);
# -moz-transform: translateY(28px);
# -ms-transform: translateY(28px);
# -o-transform: translateY(28px);
# transform: translateY(28px);
# }
# #cEtc .view_slide .list_thumbnail{width:1858px}
# #cEtc .view_slide .list_thumbnail2{width:990px}
# #cEtc .list_photo{
# -webkit-transition: transform .3s ease;
# -moz-transition: transform .3s ease;
# -ms-transition: transform .3s ease;
# -o-transition: transform .3s ease;
# transition: transform .3s ease;
# -webkit-transform: translateX(0);
# -moz-transform: translateX(0);
# -ms-transform: translateX(0);
# -o-transform: translateX(0);
# transform: translateX(0);
# }</style>
# <script type="text/javascript">
# //<![CDATA[
# document.domain = 'daum.net';
# var gvConfGen = 'g0';
# var DT = DT || {};
# DT.SystemTime = 1506435471095;
# var _tiq = 'undefined' !== typeof _tiq ? _tiq : [];
# _tiq.push(['__clickOn']);
# _tiq.push(['__setConfig', {enableButton:true}]);
# _tiq.push(['__setSection', 'HOME']);
# _tiq.push(['__setPageName', 'default']);
# _tiq.push(['__setConfig', {enableButton:true, puid:DT.SystemTime }]);
# _tiq.push(['__trackPageview']);
# DT.endTime = new Date().getTime();
# DT.startTime = new Date().getTime();
# (function () {
# if (document.location.toString().indexOf('debug') === -1) {
# window.onerror = function (errorMsg, url, lineNumber) {
# return true;
# };
# }
# })();
# document.onkeydown = function () {
# DT.userAction = true;
# };
# document.onclick = function () {
# DT.userAction = true;
# };
# //]]>
# </script>
# </head>

# %%
bsObj.html.title
# Out:
# <title>Daum</title>

# %%
bsObj.div
# Out:
# <div class="d_index" id="daumIndex">
# <a class="shortcut_g" href="#mainServiceTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">주요 서비스 바로가기</span>
# </a>
# <a class="shortcut_g" href="#todayInfoTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">오늘의 정보 바로가기</span>
# </a>
# <a class="shortcut_g" href="#mediaTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">미디어 바로가기</span>
# </a>
# <a class="shortcut_g" href="#liveIssueTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">실시간 이슈 바로가기</span>
# </a>
# <a class="shortcut_g" href="#multiMediaTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">멀티미디어 바로가기</span>
# </a>
# <a class="shortcut_g" href="#blogTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">블로그 정보 바로가기</span>
# </a>
# <a class="shortcut_g" href="#storyTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">유익한 정보 바로가기</span>
# </a>
# <a class="shortcut_g" href="#shoppingTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">쇼핑 바로가기</span>
# </a>
# <a class="shortcut_g" href="#photoClipTitle" rel="bookmark" tabindex="12">
# <span class="ico_vert inner_shortcut">오늘의 포토&amp;영상 바로가기</span>
# </a>
# <a class="shortcut_g" href="/doc/top_accessibility.html" id="topAccessibility" tabindex="12">
# <span class="ico_vert inner_shortcut">웹 접근성 안내</span>
# </a>
# <a class="shortcut_g" href="/doc/top_accessibility.html#ad" id="topAdAccessibility" tabindex="12">
# <span class="ico_vert inner_shortcut">자동실행 광고 설정</span>
# </a>
# </div>

# %% [markdown]
# ## QUIZ 01
#
# 다음 문제를 해결하여 본문을 성공적으로 긁어오시고 렌더링하세요.
#
#
# 1. http://malware-traffic-analysis.net/2017/index.html 사이트에서 주요 본문 내용만 긁어온다.(메뉴, 사이드바 제외)
# 2. 해당 본문 데이터를 드라이브에 a.html 파일로 [저장](https://docs.python.org/2/tutorial/inputoutput.html)하고,
# 3. 이후 웹페이지를 자동으로 열리도록 [코딩](https://docs.python.org/2/library/webbrowser.html)하라.

# %%
## write your code!!
open('a.html', 'w', encoding="UTF8")

# %% [markdown]
# ## 2) find()와 findAll()

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen("https://www.naver.com")
bsObj = BeautifulSoup(html.read(), "html.parser")
bsObj.find("a")
# Out:
# <a href="#news_cast" onclick="document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"><span>뉴스스탠드 바로가기</span></a>

# %%
bsObj.findAll("a")
# Out:
# [<a href="#news_cast" onclick="document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"><span>뉴스스탠드 바로가기</span></a>,
#  <a href="#themecast" onclick="document.getElementById('themecast').tabIndex = -1;document.getElementById('themecast').focus();return false;"><span>주제별캐스트 바로가기</span></a>,
#  <a href="#time_square" onclick="document.getElementById('time_square').tabIndex = -1;document.getElementById('time_square').focus();return false;"><span>타임스퀘어 바로가기</span></a>,
#  <a href="#shop_cast" onclick="document.getElementById('shop_cast').tabIndex = -1;document.getElementById('shop_cast').focus();return false;"><span>쇼핑캐스트 바로가기</span></a>,
#  <a href="#account" onclick="document.getElementById('account').tabIndex = -1;document.getElementById('account').focus();return false;"><span>로그인 바로가기</span></a>,
#  <a data-clk="top.logo" href="/"><span class="naver_logo">네이버</span></a>,
#  <a class="al_favorite" data-clk="top.mkhome" href="http://help.naver.com/support/alias/contents2/naverhome/naverhome_1.naver">네이버를 시작페이지로<span class="al_ico_link"></span></a>,
#  <a class="al_jr" data-clk="top.jrnaver" href="http://jr.naver.com"><span class="blind">쥬니어네이버</span><span class="al_ico"></span></a>,
#  <a class="al_happybean" data-clk="top.happybean" href="http://happybean.naver.com/main/SectionMain.nhn"><span class="blind">해피빈</span><span class="al_ico"></span></a>,
#  <a class="btn_arw _btn_arw fold" href="javascript:;" role="button" tabindex="2"><span class="blind _text">자동완성 펼치기</span><span class="ico_arr"></span></a>,
#  <a class="btn_keyboard" data-clk="sch.ime" href="javascript:;" id="ke_kbd_btn" onclick="nx_ime_load(this)" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>,
#  <a href="#" onclick="return false;">@txt@</a>,
#  <a class="spat ico_info" href="https://help.naver.com/support/alias/search/word/word_16.naver" onclick="__atcmpCR(event, this, 'plus.help', '','','');" target="_blank"><span class="blind">도움말 보기</span></a>,
#  <a class="btn_turnon active" href="#" onclick="__atcmpCR(event, this, 'plus.use', '','','');">ON<span class="blind">선택됨</span></a>,
#  <a class="btn_turnoff" href="#" onclick="__atcmpCR(event, this, 'plus.unuse', '','','');">OFF</a>,
#  <a class="btn btn_login" href="https://nid.naver.com/nidlogin.login" onclick="__atcmpCR(event, this, 'plus.login', '','','');">로그인</a>,
#  <a class="btn btn_view" href="https://help.naver.com/support/alias/search/word/word_16.naver" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>,
#  <a class="btn btn_view" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=16659" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 켜기</a>,
#  <a href="javascript:;">최근검색어</a>,
#  <a href="javascript:;">내 검색어</a>,
#  <a class="t@my@ _star _myBtn" href="javascript:;" title="내 검색어 등록"><em class="spat">내 검색어 등록</em></a>,
#  <a class="keyword" href="javascript:;">@txt@</a>,
#  <a class="btn_delete spat _del" href="javascript:;" title="검색어삭제">삭제</a>,
#  <a class="ton _star _myBtn" href="javascript:;" title="내 검색어 해제"><em class="spat">내 검색어 해제</em></a>,
#  <a class="keyword" href="javascript:;">@txt@</a>,
#  <a class="_delMode" href="javascript:;">기록 삭제</a>,
#  <a class="_keywordOff" href="javascript:;">검색어저장 끄기</a>,
#  <a class="_acOff" href="javascript:;">자동완성 끄기</a>,
#  <a class="_delAll" href="javascript:;" title="최근 검색어 기록을 모두 삭제합니다.">기록 전체 삭제</a>,
#  <a class="_delDone" href="javascript:;">완료</a>,
#  <a class="_delAll" href="javascript:;" title="설정된 내 검색어를 모두 삭제합니다.">기록 전체 삭제</a>,
#  <a class="_keywordOff" href="javascript:;">검색어저장 끄기</a>,
#  <a class="_acOff" href="javascript:;">자동완성 끄기</a>,
#  <a class="btn_close _close" href="javascript:;"><i class="spat ico_close">닫기</i></a>,
#  <a href="http://naver_diary.blog.me/220982360603" onclick="clickcr(this,'sug.vote','','',event);" target="_blank">자세히보기</a>,
#  <a class="an_a mn_mail" data-clk="svc.mail" href="http://mail.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">메일</span>
#  </a>,
#  <a class="an_a mn_cafe" data-clk="svc.cafe" href="http://section.cafe.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">카페</span>
#  </a>,
#  <a class="an_a mn_blog" data-clk="svc.blog" href="http://section.blog.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">블로그</span>
#  </a>,
#  <a class="an_a mn_kin" data-clk="svc.kin" href="http://kin.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">지식인</span>
#  </a>,
#  <a class="an_a mn_shopping" data-clk="svc.shopping" href="http://shopping2.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">쇼핑</span>
#  </a>,
#  <a class="an_a mn_checkout" data-clk="svc.pay" href="http://pay.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">네이버페이</span>
#  </a>,
#  <a class="an_a mn_tvcast" data-clk="svc.tvcast" href="http://tv.naver.com/">
#  <span class="an_icon"></span><span class="an_txt">네이버TV</span>
#  </a>,
#  <a class="an_a mn_dic" data-clk="svc.dic" href="http://dic.naver.com/"><span class="an_icon"></span><span class="an_txt">사전</span></a>,
#  <a class="an_a mn_news" data-clk="svc.news" href="http://news.naver.com/"><span class="an_icon"></span><span class="an_txt">뉴스</span></a>,
#  <a class="an_a mn_stock" data-clk="svc.stock" href="http://stock.naver.com/"><span class="an_icon"></span><span class="an_txt">증권(금융)</span></a>,
#  <a class="an_a mn_land" data-clk="svc.land" href="http://land.naver.com/"><span class="an_icon"></span><span class="an_txt">부동산</span></a>,
#  <a class="an_a mn_map" data-clk="svc.map" href="http://map.naver.com/"><span class="an_icon"></span><span class="an_txt">지도</span></a>,
#  <a class="an_a mn_movie" data-clk="svc.movie" href="http://movie.naver.com/"><span class="an_icon"></span><span class="an_txt">영화</span></a>,
#  <a class="an_a mn_music" data-clk="svc.music" href="http://music.naver.com"><span class="an_icon"></span><span class="an_txt">뮤직</span></a>,
#  <a class="an_a mn_book" data-clk="svc.book" href="http://book.naver.com/"><span class="an_icon"></span><span class="an_txt">책</span></a>,
#  <a class="an_a mn_comic" data-clk="svc.webtoon" href="http://comic.naver.com/"><span class="an_icon"></span><span class="an_txt">만화 / 웹툰</span></a>,
#  <a class="PM_CL_btnServiceMore an_btn_more" data-clk="svc.more" href="#" id="PM_ID_btnServiceMore" role="button"><span class="an_mtxt"><span class="blind">더보기</span></span><span class="ico_an_more"></span></a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">1</span>
#  <span class="ah_k">아르곤</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">2</span>
#  <span class="ah_k">철원</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">3</span>
#  <span class="ah_k">신과함께</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">4</span>
#  <span class="ah_k">김재욱</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">5</span>
#  <span class="ah_k">송선미</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">6</span>
#  <span class="ah_k">생동성 연애</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">7</span>
#  <span class="ah_k">수요웹툰</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">8</span>
#  <span class="ah_k">코빗</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">9</span>
#  <span class="ah_k">사랑의 온도</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">10</span>
#  <span class="ah_k">박보검</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">11</span>
#  <span class="ah_k">내일날씨</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">12</span>
#  <span class="ah_k">란제리 소녀시대</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">13</span>
#  <span class="ah_k">농협 채용</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">14</span>
#  <span class="ah_k">국시원</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">15</span>
#  <span class="ah_k">gs칼텍스 채용</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">16</span>
#  <span class="ah_k">양세종</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">17</span>
#  <span class="ah_k">부산날씨</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">18</span>
#  <span class="ah_k">메가박스</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">19</span>
#  <span class="ah_k">유웨이</span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" href="#">
#  <span class="ah_r">20</span>
#  <span class="ah_k">롯데시네마</span>
#  </a>,
#  <a class="ah_ha" data-clk="lve.rankhistory" href="http://datalab.naver.com/keyword/realtimeList.naver?where=main"><span class="ah_ico_datalab">DataLab.</span>급상승 트래킹<span class="ah_ico_hlink"></span></a>,
#  <a class="ah_tab_btn ah_tab_on" data-clk="lve.tab1" data-tab="1to10" href="#" role="tab">1~10위</a>,
#  <a class="ah_tab_btn" data-clk="lve.tab2" data-tab="11to20" href="#" role="tab">11~20위</a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%95%84%EB%A5%B4%EA%B3%A4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%95%84%EB%A5%B4%EA%B3%A4&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">1</span>
#  <span class="ah_k">아르곤</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%95%84%EB%A5%B4%EA%B3%A4&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%B2%A0%EC%9B%90&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%B2%A0%EC%9B%90&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">2</span>
#  <span class="ah_k">철원</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%B2%A0%EC%9B%90&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%8B%A0%EA%B3%BC%ED%95%A8%EA%BB%98&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%8B%A0%EA%B3%BC%ED%95%A8%EA%BB%98&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">3</span>
#  <span class="ah_k">신과함께</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%8B%A0%EA%B3%BC%ED%95%A8%EA%BB%98&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EC%9E%AC%EC%9A%B1&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B9%80%EC%9E%AC%EC%9A%B1&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">4</span>
#  <span class="ah_k">김재욱</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EA%B9%80%EC%9E%AC%EC%9A%B1&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%86%A1%EC%84%A0%EB%AF%B8&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%86%A1%EC%84%A0%EB%AF%B8&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">5</span>
#  <span class="ah_k">송선미</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%86%A1%EC%84%A0%EB%AF%B8&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%83%9D%EB%8F%99%EC%84%B1+%EC%97%B0%EC%95%A0&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%83%9D%EB%8F%99%EC%84%B1+%EC%97%B0%EC%95%A0&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">6</span>
#  <span class="ah_k">생동성 연애</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%83%9D%EB%8F%99%EC%84%B1+%EC%97%B0%EC%95%A0&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%88%98%EC%9A%94%EC%9B%B9%ED%88%B0&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%88%98%EC%9A%94%EC%9B%B9%ED%88%B0&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">7</span>
#  <span class="ah_k">수요웹툰</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%88%98%EC%9A%94%EC%9B%B9%ED%88%B0&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%BD%94%EB%B9%97&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%BD%94%EB%B9%97&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">8</span>
#  <span class="ah_k">코빗</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%BD%94%EB%B9%97&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%82%AC%EB%9E%91%EC%9D%98+%EC%98%A8%EB%8F%84&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%82%AC%EB%9E%91%EC%9D%98+%EC%98%A8%EB%8F%84&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">9</span>
#  <span class="ah_k">사랑의 온도</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%82%AC%EB%9E%91%EC%9D%98+%EC%98%A8%EB%8F%84&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EA%B2%80&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EA%B2%80&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">10</span>
#  <span class="ah_k">박보검</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EB%B0%95%EB%B3%B4%EA%B2%80&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%82%B4%EC%9D%BC%EB%82%A0%EC%94%A8&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%82%B4%EC%9D%BC%EB%82%A0%EC%94%A8&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">11</span>
#  <span class="ah_k">내일날씨</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EB%82%B4%EC%9D%BC%EB%82%A0%EC%94%A8&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%9E%80%EC%A0%9C%EB%A6%AC+%EC%86%8C%EB%85%80%EC%8B%9C%EB%8C%80&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%9E%80%EC%A0%9C%EB%A6%AC+%EC%86%8C%EB%85%80%EC%8B%9C%EB%8C%80&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">12</span>
#  <span class="ah_k">란제리 소녀시대</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EB%9E%80%EC%A0%9C%EB%A6%AC+%EC%86%8C%EB%85%80%EC%8B%9C%EB%8C%80&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%86%8D%ED%98%91+%EC%B1%84%EC%9A%A9&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%86%8D%ED%98%91+%EC%B1%84%EC%9A%A9&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">13</span>
#  <span class="ah_k">농협 채용</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EB%86%8D%ED%98%91+%EC%B1%84%EC%9A%A9&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B5%AD%EC%8B%9C%EC%9B%90&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B5%AD%EC%8B%9C%EC%9B%90&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">14</span>
#  <span class="ah_k">국시원</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EA%B5%AD%EC%8B%9C%EC%9B%90&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=gs%EC%B9%BC%ED%85%8D%EC%8A%A4+%EC%B1%84%EC%9A%A9&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=gs%EC%B9%BC%ED%85%8D%EC%8A%A4+%EC%B1%84%EC%9A%A9&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">15</span>
#  <span class="ah_k">gs칼텍스 채용</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=gs%EC%B9%BC%ED%85%8D%EC%8A%A4+%EC%B1%84%EC%9A%A9&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%96%91%EC%84%B8%EC%A2%85&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%96%91%EC%84%B8%EC%A2%85&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">16</span>
#  <span class="ah_k">양세종</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%96%91%EC%84%B8%EC%A2%85&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B6%80%EC%82%B0%EB%82%A0%EC%94%A8&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B6%80%EC%82%B0%EB%82%A0%EC%94%A8&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">17</span>
#  <span class="ah_k">부산날씨</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EB%B6%80%EC%82%B0%EB%82%A0%EC%94%A8&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%A9%94%EA%B0%80%EB%B0%95%EC%8A%A4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%A9%94%EA%B0%80%EB%B0%95%EC%8A%A4&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">18</span>
#  <span class="ah_k">메가박스</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EB%A9%94%EA%B0%80%EB%B0%95%EC%8A%A4&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%9C%A0%EC%9B%A8%EC%9D%B4&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%9C%A0%EC%9B%A8%EC%9D%B4&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">19</span>
#  <span class="ah_k">유웨이</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EC%9C%A0%EC%9B%A8%EC%9D%B4&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_a" data-clk="lve.keyword" data-ssl="https://search.naver.com/search.naver?where=nexearch&amp;query=%EB%A1%AF%EB%8D%B0%EC%8B%9C%EB%84%A4%EB%A7%88&amp;sm=top_lve&amp;ie=utf8" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%A1%AF%EB%8D%B0%EC%8B%9C%EB%84%A4%EB%A7%88&amp;sm=top_lve&amp;ie=utf8">
#  <span class="ah_r">20</span>
#  <span class="ah_k">롯데시네마</span>
#  </a>,
#  <a class="ah_da" data-clk="lve.kwdhistory" href="http://datalab.naver.com/keyword/realtimeDetail.naver?datetime=2017-09-26T23:33:00&amp;query=%EB%A1%AF%EB%8D%B0%EC%8B%9C%EB%84%A4%EB%A7%88&amp;where=main">
#  <span class="blind">데이터랩 그래프 보기</span>
#  <span class="ah_ico_datagraph"></span>
#  </a>,
#  <a class="ah_btn_help" data-clk="lve.help" data-ssl="https://help.naver.com/support/alias/search/word/word_5.naver" href="http://help.naver.com/support/alias/search/word/word_5.naver">도움말</a>,
#  <a class="cf_ta" data-clk="ncy.newsflash" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y">연합뉴스<span class="cf_ico_link"></span></a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574601">文대통령 10·4계승 평화론 강조…'통 큰 제안'보다 '상황관리'</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574746">매티스 美국방 "북핵 문제 외교적 해결 원해"</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574751">영천 야생조류 분변서 AI 검출…고병원성 검사중</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574718">육군 일병 갑자기 날아든 총탄에 머리 맞아 사망</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574658">27일 전국에 비…남부 '장대비'·수도권 '가랑비'</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574792">트럼프, NFL에 '무릎끓기 금지규정' 제정 요구</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574622">법사위, 공수처 논의 시작…여야 이견 팽팽</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574674">추궈훙 "사드로 국민감정 영향…소통강화 희망"</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574460">'뇌물수수 혐의' 도태호 수원부시장 숨진 채 발견</a>,
#  <a class="ca_a" data-clk="ncy.quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0009574400">박근혜 구속 기간 연장할까 말까…법원 고민 시작</a>,
#  <a class="cl_a cl_news" data-clk="ncy.newshome" href="http://news.naver.com/">
#  네이버뉴스</a>,
#  <a class="cl_a cl_ent" data-clk="ncy.entertainment" href="http://entertain.naver.com/home">
#  연예</a>,
#  <a class="cl_a cl_sports" data-clk="ncy.sports" href="http://sports.news.naver.com/">
#  스포츠</a>,
#  <a class="cl_a cl_finance" data-clk="ncy.economy" href="http://news.naver.com/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101">
#  경제</a>,
#  <a class="cl_a cl_ranking" data-clk="ncy.special2" href="http://news.naver.com/main/ranking/popularDay.nhn?mid=etc&amp;sid1=111">
#  랭킹</a>,
#  <a class="an_ta" data-clk="nsd.title" href="http://newsstand.naver.com/" target="_blank">뉴스스탠드<span class="an_ico_link"></span></a>,
#  <a aria-selected="true" class="as_btn_press _PM_newsstand_total_type is_selected" data-clk="nsd.all" href="#" role="tab">전체 언론사</a>,
#  <a aria-selected="false" class="as_btn_my _PM_newsstand_my_type" data-clk="nsd.my" href="#" role="tab">MY 뉴스</a>,
#  <a aria-selected="true" class="as2_btn _PM_newsstand_thumb_type is_selected" data-clk="nsd.pressview" href="#" role="tab"><i class="as2_btn_ico ico_image"></i><span class="blind">이미지형</span></a>,
#  <a aria-selected="false" class="as2_btn _PM_newsstand_list_type" data-clk="nsd.articleview" href="#" role="tab"><i class="as2_btn_ico ico_list"></i><span class="blind">리스트형</span></a>,
#  <a class="as2_btn" data-clk="nsd.set" href="http://newsstand.naver.com/config.html" target="_blank"><i class="as2_btn_ico ico_setting"></i><span class="blind">설정</span></a>,
#  <a class="ap_btn _PM_newsstand_prev" data-clk="nsd.prev" href="#"><i class="ap_btn_ico ico_left"></i><span class="blind">이전 페이지</span></a>,
#  <a class="ap_btn _PM_newsstand_next" data-clk="nsd.next" href="#"><i class="ap_btn_ico ico_right"></i><span class="blind">다음 페이지</span></a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=326" target="_blank">
#  <img alt="KBS World" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd173138949.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="326" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="326" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=326" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=005" target="_blank">
#  <img alt="국민일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd1438916.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="005" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="005" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=005" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=277" target="_blank">
#  <img alt="아시아경제" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd153432228.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="277" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="277" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=277" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=038" target="_blank">
#  <img alt="한국일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd172837200.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="038" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="038" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=038" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=021" target="_blank">
#  <img alt="문화일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd19245981.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="021" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="021" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=021" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=030" target="_blank">
#  <img alt="전자신문" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd162528724.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="030" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="030" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=030" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=022" target="_blank">
#  <img alt="세계일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd145813557.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="022" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="022" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=022" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=079" target="_blank">
#  <img alt="노컷뉴스" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd143958887.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="079" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="079" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=079" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=055" target="_blank">
#  <img alt="SBS" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd173335676.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="055" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="055" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=055" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=214" target="_blank">
#  <img alt="MBC" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd17324940.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="214" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="214" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=214" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=215" target="_blank">
#  <img alt="한국경제TV" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd172755139.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="215" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="215" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=215" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct1&amp;pcode=109" target="_blank">
#  <img alt="OSEN" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd17338859.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="109" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="109" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct1&amp;pcode=109" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct6&amp;pcode=947" target="_blank">
#  <img alt="조이뉴스24" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd162759461.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="947" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="947" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct6&amp;pcode=947" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct7&amp;pcode=310" target="_blank">
#  <img alt="여성신문" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd154151666.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="310" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="310" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct7&amp;pcode=310" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct7&amp;pcode=042" target="_blank">
#  <img alt="데일리한국" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd144629578.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="042" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="042" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct7&amp;pcode=042" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct7&amp;pcode=140" target="_blank">
#  <img alt="씨네21" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd153251814.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="140" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="140" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct7&amp;pcode=140" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct8&amp;pcode=387" target="_blank">
#  <img alt="인천일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd154558680.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="387" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="387" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct8&amp;pcode=387" role="button" target="_blank">기사보기</a>,
#  <a aria-haspopup="true" class="api_link" href="http://newsstand.naver.com/?list=ct8&amp;pcode=926" target="_blank">
#  <img alt="중부일보" class="api_logo" height="24" src="https://s.pstatic.net/static/newsstand/up/2017/0424/nsd162931439.png"/>
#  </a>,
#  <a class="api_pbs_btn _PM_newsstand_subscribe" data-clk="nsd_all*p.sub" data-pid="926" href="#" role="button">구독</a>,
#  <a class="api_pbs_btn _PM_newsstand_unsubscribe" data-clk="nsd_all*p.sub" data-pid="926" href="#" role="button" style="display:none">해지</a>,
#  <a class="api_pbs_btn api_pbs_lb" data-all-clk="nsd_all*p.logo" data-my-clk="nsd_myn*p.logo" href="http://newsstand.naver.com/?list=ct8&amp;pcode=926" role="button" target="_blank">기사보기</a>,
#  <a class="aplc_link is_selected" data-category="ct2" data-clk="nsd_all.daei" href="#"><span class="aplc_name">종합/경제</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct3" data-clk="nsd_all.dtvcom" href="#"><span class="aplc_name">방송/통신</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct4" data-clk="nsd_all.dit" href="#"><span class="aplc_name">IT</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct5" data-clk="nsd_all.deng" href="#"><span class="aplc_name">영자지</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct6" data-clk="nsd_all.dsporent" href="#"><span class="aplc_name">스포츠/연예</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct7" data-clk="nsd_all.dmagtec" href="#"><span class="aplc_name">매거진/전문지</span><span class="aplc_paging"></span></a>,
#  <a class="aplc_link" data-category="ct8" data-clk="nsd_all.dloc" href="#"><span class="aplc_name">지역</span><span class="aplc_paging"></span></a>,
#  <a class="anv_btn" data-clk="nsd_myn*a.thum" href="http://newsstand.naver.com/config.html" role="button" target="_blank">언론사 추가</a>,
#  <a class="lg_global_btn" data-clk="log_off.pad" href="https://nid.naver.com/nidlogin.login?url=https%3A%2F%2Fwww.naver.com" role="button">
#  <i class="ico_global_login lang_en_v1"><span class="blind">NAVER Sign in</span></i>
#  </a>,
#  <a class="lg_link_join" data-clk="log_off.registration" href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com">Sign up</a>,
#  <a class="lg_find_text_en" data-clk="log_off.searchid" href="https://nid.naver.com/user/help.nhn?todo=idinquiry">Username</a>,
#  <a class="lg_find_text_en" data-clk="log_off.searchpass" href="https://nid.naver.com/nidreminder.form">Password?</a>,
#  <a class="hi_date" data-clk="squ.date" href="https://calendar.naver.com"><span class="hi_dnum">09.26.</span><span class="hi_day">(화)</span></a>,
#  <a class="hi_tit _PM_timesquare_lang_type" data-clk="squ_lan.set" href="#">영어회화<i aria-hidden="true" class="ico_btn_arrow"></i></a>,
#  <a class="header_btn_prev" data-clk="squ.pre" href="#"><i aria-hidden="true" class="ico_btn_prev"></i><span class="blind">앞의 목록으로 이동</span></a>,
#  <a class="header_btn_next" data-clk="squ.next" href="#"><i aria-hidden="true" class="ico_btn_next"></i><span class="blind">뒤의 목록으로 이동</span></a>,
#  <a class="tc_link" data-clk="squ_lan.con" href="http://phrasebook.naver.com/detail.nhn?bigCategoryNo=4&amp;middleCategoryNo=40&amp;smallCategoryNo=217&amp;targetLanguage=en">
#  <div class="tc_content">
#  <p class="tc_tt"><em class="tc_accent">체크인</em>하고 싶습니다.</p>
#  <p class="tc_st">I'd like to <em class="tc_accent">check in</em>.</p>
#  <p class="tc_pronounce">아잇 라익 투 <em class="tc_accent">체크인</em></p>
#  </div>
#  </a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_livinghome" data-clk="tct.lif" data-id="LIVINGHOME" data-nclick="lif" href="#LIVINGHOME" role="tab">리빙</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_living" data-clk="tct.fod" data-id="LIVING" data-nclick="fod" href="#LIVING" role="tab">푸드</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_sports" data-clk="tct.spo" data-id="SPORTS" data-nclick="spo" href="#SPORTS" role="tab">스포츠</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_cargame" data-clk="tct.aut" data-id="CARGAME" data-nclick="aut" href="#CARGAME" role="tab">자동차</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_beauty" data-clk="tct.bty" data-id="BEAUTY" data-nclick="bty" href="#BEAUTY" role="tab">패션뷰티</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_momkids" data-clk="tct.mom" data-id="MOMKIDS" data-nclick="mom" href="#MOMKIDS" role="tab">맘·키즈</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_health" data-clk="tct.hea" data-id="HEALTH" data-nclick="hea" href="#HEALTH" role="tab">건강</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_bboom" data-clk="tct.web" data-id="BBOOM" data-nclick="web" href="#BBOOM" role="tab">웹툰</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_gameapp" data-clk="tct.gam" data-id="GAMEAPP" data-nclick="gam" href="#GAMEAPP" role="tab">게임</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_video" data-clk="tct.tvc" data-id="VIDEO" data-nclick="tvc" href="#VIDEO" role="tab">TV연예</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_music" data-clk="tct.muc" data-id="MUSIC" data-nclick="muc" href="#MUSIC" role="tab">뮤직</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_movie" data-clk="tct.mov" data-id="MOVIE" data-nclick="mov" href="#MOVIE" role="tab">영화</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_culture" data-clk="tct.bok" data-id="CULTURE" data-nclick="bok" href="#CULTURE" role="tab">책문화</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_with" data-clk="tct.pub" data-id="WITH" data-nclick="pub" href="#WITH" role="tab">함께N</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_travel" data-clk="tct.tra" data-id="TRAVEL" data-nclick="tra" href="#TRAVEL" role="tab">여행+</a>,
#  <a aria-selected="true" class="PM_CL_themeItem ac_a tcc_design" data-clk="tct.des" data-id="DESIGN" data-nclick="des" href="#DESIGN" role="tab">디자인</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_finance" data-clk="tct.fin" data-id="FINANCE" data-nclick="fin" href="#FINANCE" role="tab">경제M</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_job" data-clk="tct.job" data-id="JOB" data-nclick="job" href="#JOB" role="tab">JOB&amp;</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_science" data-clk="tct.sci" data-id="SCIENCE" data-nclick="sci" href="#SCIENCE" role="tab">과학</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_china" data-clk="tct.chn" data-id="CHINA" data-nclick="chn" href="#CHINA" role="tab">중국</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_business" data-clk="tct.bsn" data-id="BUSINESS" data-nclick="bsn" href="#BUSINESS" role="tab">비즈니스</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_farm" data-clk="tct.far" data-id="FARM" data-nclick="far" href="#FARM" role="tab">FARM</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_school" data-clk="tct.scl" data-id="SCHOOL" data-nclick="scl" href="#SCHOOL" role="tab">스쿨잼</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_show" data-clk="tct.sow" data-id="SHOW" data-nclick="sow" href="#SHOW" role="tab">공연전시</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_law" data-clk="tct.law" data-id="LAW" data-nclick="law" href="#LAW" role="tab">법률</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_animal" data-clk="tct.ani" data-id="ANIMAL" data-nclick="ani" href="#ANIMAL" role="tab">동물공감</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_wedding" data-clk="tct.wed" data-id="WEDDING" data-nclick="wed" href="#WEDDING" role="tab">연애·결혼</a>,
#  <a aria-selected="false" class="PM_CL_themeItem ac_a tcc_ittech" data-clk="tct.tec" data-id="ITTECH" data-nclick="tec" href="#ITTECH" role="tab">테크</a>,
#  <a class="ac_btn_prev PM_CL_btnThemePrev" data-clk="tct.prev" href="#" role="button"><span class="blind">이전 주제</span><span class="ac_bicon"></span></a>,
#  <a class="ac_btn_next PM_CL_btnThemeNext" data-clk="tct.next" href="#" role="button"><span class="blind">다음 주제</span><span class="ac_bicon"></span></a>,
#  <a class="ac_btn_cate PM_CL_btnThemeEdit" data-clk="tct.menu" href="#" role="button"><span class="blind">전체 주제 열기</span><span class="ac_bicon"></span></a>,
#  <a class="at_btn_close PM_CL_btnThemeEdit" data-clk="tca.close" href="#" role="button"><span class="blind">전체 주제 목록 닫기</span><span class="at_bicon"></span></a>,
#  <a class="at_btn_setting PM_CL_btnThemeEditShow" data-clk="tca.like" href="#" role="button"><span class="at_bicon"></span>관심주제 설정</a>,
#  <a class="at_btn_import PM_CL_btnThemeImport" data-clk="tca.mobile" data-login-url="https://nid.naver.com/nidlogin.login?url=http%3A%2F%2Fwww.naver.com" href="#" role="button"><span class="at_bicon"></span>모바일 관심 주제 가져오기</a>,
#  <a class="at_btn_cancel PM_CL_btnThemeEditCancel" data-clk="tca*l.cancel" href="#" role="button">취소</a>,
#  <a class="at_btn_confirm PM_CL_btnThemeEditOk" data-clk="tca*l.ok" href="#" role="button">확인</a>,
#  <a class="at_btn_reset PM_CL_btnThemeEditInit" data-clk="tca*l.reset" href="#" role="button"><span class="at_bicon"></span>초기화</a>,
#  <a class="at_btn_all PM_CL_btnThemeSelectAll" data-clk="" href="#" role="button">전체선택</a>,
#  <a class="at_btn_import PM_CL_btnThemeImport" data-clk="tca.mobile" data-login-url="https://nid.naver.com/nidlogin.login?url=http%3A%2F%2Fwww.naver.com" href="#" role="button"><span class="at_bicon"></span>모바일 관심 주제 가져오기</a>,
#  <a class="tt_d" data-clk="tcc_des.link" data-gdid="UAT_1293311" href="http://blog.naver.com/designpress2016">세상을 바꾸는 디자인<br/>트렌드의 중심 디자인</a>,
#  <a class="tt_o" href="http://blog.naver.com/designpress2016">디자인프레스(주)</a>,
#  <a class="tb_a" data-clk="tcc_des.two" data-gdid="UAT_1854801" href="http://blog.naver.com/designpress2016/221104812267">
#  <div class="tb_mw">
#  <img alt="" class="tb_m" height="185" src="https://s.pstatic.net/static/www/mobile/edit/2017/0925/cropImg_346x185_106768278082927627.png" width="346"/>
#  <span class="tb_bd"></span>
#  </div>
#  <div class="tb_ow">
#  <span class="tb_bg"></span>
#  <span class="tb_tw">
#  <span class="tb_d"><b>Oh! 크리에이터</b> 한복디자이너 김영진 vol.2.</span>
#  <span class="tb_t">화보, 드라마, 영화, 오페라 속 그 한복! 어쩐지 예쁘더라!</span>
#  </span>
#  <span class="tb_align"></span>
#  </div>
#  </a>,
#  <a class="td_a" data-clk="tcc_des.contents" data-gdid="UAT_1854829" href="http://blog.naver.com/ssmadang_gallery/221090046835">
#  <span class="td_mw">
#  <img alt="" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0921/cropImg_166x108_106434535663673594.jpeg" width="166"/>
#  <span class="td_bd"></span>
#  </span>
#  <span class="td_tw">
#  <span class="td_t">프랑스 로맨티스트가 찍은 사진 '자끄 앙리 라띠그'展</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_des.contents" data-gdid="UAT_1854828" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=117&amp;oid=298&amp;aid=0000227452&amp;rc=N">
#  <span class="td_mw">
#  <img alt="" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0921/cropImg_166x108_106470917218051399.jpeg" width="166"/>
#  <span class="td_bd"></span>
#  </span>
#  <span class="td_tw">
#  <span class="td_t">엔진소리, 엘리베이터 버튼음까지?! 사운드 디자인</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_des.contents" data-gdid="UAT_1854827" href="http://blog.naver.com/designpress2016/221099580353">
#  <span class="td_mw">
#  <img alt="" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0921/cropImg_166x108_106470887341284097.jpeg" width="166"/>
#  <span class="td_bd"></span>
#  </span>
#  <span class="td_tw">
#  <span class="td_t">TRA's 패션디자인 만담 #프롤로그. 어쩌다 패션이야기</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_des.contents" data-gdid="UAT_1854826" href="http://terms.naver.com/entry.nhn?docId=3654295&amp;cid=59154&amp;categoryId=59154">
#  <span class="td_mw">
#  <img alt="" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0922/cropImg_166x108_106509616684939567.jpeg" width="166"/>
#  <span class="td_bd"></span>
#  </span>
#  <span class="td_tw">
#  <span class="td_t">'불국사, 1988년 3월' 버려진 기억을 수집하는, 장보윤</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_des.contents" data-gdid="UAT_1854825" href="http://blog.naver.com/printbakery/221096925533">
#  <span class="td_mw">
#  <img alt="" class="td_m" height="108" src="https://s.pstatic.net/static/www/mobile/edit/2017/0925/cropImg_166x108_106768020824432384.jpeg" width="166"/>
#  <span class="td_bd"></span>
#  </span>
#  <span class="td_tw">
#  <span class="td_t">50-60년대 오래되고 낡은 것으로 꾸민 카페, '앤더슨 C'</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_des.contents" data-gdid="UAT_1854824" href="http://swindow.naver.com/art/store/1000015221/home?first=2033316934">
#  <span class="td_mw">
#  <img alt="" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0921/cropImg_166x108_106440622435012250.jpeg" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166"/>
#  <span class="td_bd"></span>
#  </span>
#  <span class="td_tw">
#  <span class="td_t">도자기로 구워 낸 십자가 목걸이</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_des.contents" data-gdid="UAT_1854823" href="http://blog.naver.com/designpress2016/221081037826">
#  <span class="td_mw">
#  <img alt="" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0922/cropImg_166x108_106510152547938061.jpeg" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166"/>
#  <span class="td_bd"></span>
#  </span>
#  <span class="td_tw">
#  <span class="td_t">독특한 아이디어로 20대에 성공한 여성 CEO 3</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_des.contents" data-gdid="UAT_1854822" href="http://blog.naver.com/PostView.nhn?blogId=jaeinpapa&amp;logNo=220942370334&amp;referrerCode=0&amp;searchKeyword=%EC%BB%A8%EC%85%89">
#  <span class="td_mw">
#  <img alt="" class="td_m" data-src="https://blogthumb.pstatic.net/MjAxNzAyMjNfMTQw/MDAxNDg3Nzg0NTQ3MTc0.WCPlDIUV3QVhnTzwMc8d5OcWoz-j3_pyL5IeHX1TfEYg.LzNEsMN8WAfGkEGeihM2ArET2lYJxaA1b_LXk2XTOkwg.JPEG.jaeinpapa/%C6%C4%B7%E7.jpg?type=w2" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166"/>
#  <span class="td_bd"></span>
#  </span>
#  <span class="td_tw">
#  <span class="td_t">상용화를 기다린다!<br/> ㄱ자 스테플러 디자인</span>
#  </span>
#  </a>,
#  <a class="td_a" data-clk="tcc_des.contents" data-gdid="UAT_1854821" href="http://blog.naver.com/PostView.nhn?blogId=dazedandconfused&amp;logNo=221094431055&amp;categoryNo=0&amp;parentCategoryNo=0&amp;viewDate=¤tPage=3&amp;postListTopCurrentPage=&amp;from=menu&amp;userTopListOpen=true&amp;userTopListCount=5&amp;userTopListManageOpen=false&amp;userTopListCurrentPage=3">
#  <span class="td_mw">
#  <img alt="" class="td_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0922/cropImg_166x108_106509964395257266.jpeg" height="108" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="166"/>
#  <span class="td_bd"></span>
#  </span>
#  <span class="td_tw">
#  <span class="td_t">패피들의 성지, '소소한패션가' 최초 인터뷰!</span>
#  </span>
#  </a>,
#  <a class="tb_mw" data-clk="tcc_des.groupbtm" data-gdid="UAT_1854803" href="http://post.naver.com/viewer/postView.nhn?volumeNo=9685381&amp;memberNo=9781&amp;vType=VERTICAL&amp;mainMenu=DESIGN">
#  <img alt="여자들이 좋아하는 뱃살미남?&lt;br&gt;똥배 가방 열풍, 실화냐?" class="tb_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0925/cropImg_115x70_106765877774069490.jpeg" height="70" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="115"/>
#  <span class="tb_bd"></span>
#  </a>,
#  <a class="tb_t" data-clk="tcc_des.groupbtm" data-gdid="UAT_1854803" href="http://post.naver.com/viewer/postView.nhn?volumeNo=9685381&amp;memberNo=9781&amp;vType=VERTICAL&amp;mainMenu=DESIGN">여자들이 좋아하는 뱃살미남?<br/>똥배 가방 열풍, 실화냐?</a>,
#  <a class="tb_mw" data-clk="tcc_des.groupbtm" data-gdid="UAT_1854804" href="http://blog.naver.com/designpress2016/221102620913">
#  <img alt="캐릭터에 가려진 디자인 열정!&lt;br&gt;최초를 쓴 디자이너 황재근" class="tb_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0925/cropImg_115x70_106765939889231015.jpeg" height="70" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="115"/>
#  <span class="tb_bd"></span>
#  </a>,
#  <a class="tb_t" data-clk="tcc_des.groupbtm" data-gdid="UAT_1854804" href="http://blog.naver.com/designpress2016/221102620913">캐릭터에 가려진 디자인 열정!<br/>최초를 쓴 디자이너 황재근</a>,
#  <a class="tb_mw" data-clk="tcc_des.groupbtm" data-gdid="UAT_1854805" href="http://blog.naver.com/designpress2016/220939693085">
#  <img alt="우리가 만든 의자가 왜 저기에?&lt;br&gt;디자이너의 '짝퉁' 경험담" class="tb_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0925/cropImg_115x70_106780035668720254.jpeg" height="70" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="115"/>
#  <span class="tb_bd"></span>
#  </a>,
#  <a class="tb_t" data-clk="tcc_des.groupbtm" data-gdid="UAT_1854805" href="http://blog.naver.com/designpress2016/220939693085">우리가 만든 의자가 왜 저기에?<br/>디자이너의 '짝퉁' 경험담</a>,
#  <a class="tb_mw" data-clk="tcc_des.groupbtm" data-gdid="UAT_1854806" href="http://blog.naver.com/takeyourbeat/221095570227">
#  <img alt="5평 땅에 지은 협소주택&lt;br&gt;차곡차곡 쌓은 온 가족의 공간" class="tb_m" data-src="https://s.pstatic.net/static/www/mobile/edit/2017/0925/cropImg_115x70_106765642863933776.jpeg" height="70" src="https://s.pstatic.net/static/www/m/guide/dummy_1X1.jpg" width="115"/>
#  <span class="tb_bd"></span>
#  </a>,
#  <a class="tb_t" data-clk="tcc_des.groupbtm" data-gdid="UAT_1854806" href="http://blog.naver.com/takeyourbeat/221095570227">5평 땅에 지은 협소주택<br/>차곡차곡 쌓은 온 가족의 공간</a>,
#  <a href="https://castbox.shopping.naver.com/shopbox/main.nhn?svgless=true">https://castbox.shopping.naver.com/shopbox/main.nhn?svgless=true</a>,
#  <a class="bl_a" data-clk="mcb.left" href="http://www.d2startup.com/blog/6724" target="_blank">
#  <div class="bl_mw">
#  <img alt="D2SF x 로플랫 신개념 포토 리워드앱 매일 가는 곳에서 사진 찍고 리워드 받자!" class="bl_m" height="88" src="https://s.pstatic.net/static/www/mobile/edit/2017/0922/mobile_183004443819.jpg" title="D2SF x 로플랫 신개념 포토 리워드앱 매일 가는 곳에서 사진 찍고 리워드 받자!" width="166"/>
#  <span class="bl_bd"></span>
#  </div>
#  <div class="bl_tw">
#  <span class="bl_s">D2SF x 로플랫</span>
#  <strong class="bl_t">신개념 포토 리워드앱</strong>
#  <span class="bl_d">매일 가는 곳에서<br>사진 찍고 리워드 받자!</br></span>
#  </div>
#  </a>,
#  <a class="bl_a" data-clk="mcb.right" href="http://naver.me/IDMTAvae" target="_blank">
#  <div class="bl_mw">
#  <img alt="그라폴리오 그림책공모 당선작 전시 눈물 핑~ 웃음 팍~ 감동의 그림책을 만나보세요" class="bl_m" height="88" src="https://s.pstatic.net/static/www/mobile/edit/2017/0908/mobile_185631734490.jpg" title="그라폴리오 그림책공모 당선작 전시 눈물 핑~ 웃음 팍~ 감동의 그림책을 만나보세요" width="166"/>
#  <span class="bl_bd"></span>
#  </div>
#  <div class="bl_tw">
#  <span class="bl_s">그라폴리오</span>
#  <strong class="bl_t">그림책공모 당선작 전시</strong>
#  <span class="bl_d">눈물 핑~ 웃음 팍~<br>감동의 그림책을 만나보세요</br></span>
#  </div>
#  </a>,
#  <a class="an_ta" data-clk="ntc.notice" href="http://www.naver.com/NOTICE">공지사항</a>,
#  <a class="an_a" data-clk="ntc.notice" href="http://www.naver.com/NOTICE/read/1100001014/10000000000030657694">(주)이스트소프트 계정 침해 대상자에 대한 안내</a>,
#  <a class="as_a" data-clk="ntc.svcmap" href="more.html">서비스 전체보기<span class="as_ico_all"></span></a>,
#  <a data-clk="nad.ios" href="https://itunes.apple.com/us/app/neibeo-naver/id393499958?mt=8">아이폰</a>,
#  <a data-clk="nad.android" href="https://play.google.com/store/apps/details?id=com.nhn.android.search">안드로이드</a>,
#  <a class="aw_a" data-clk="wbd.bt" href="http://whale.naver.com/">다운받기</a>,
#  <a class="aw_qr" data-clk="wbd.bt" href="http://whale.naver.com/"><span class="blind">네이버웨일</span></a>,
#  <a class="at_a" data-clk="plc.intronhn" href="http://www.navercorp.com/">회사소개</a>,
#  <a class="at_a" data-clk="plc.adinfo" href="http://business.naver.com/">비즈니스ㆍ광고</a>,
#  <a class="at_a" data-clk="plc.search" href="https://smartplace.naver.com/">플레이스업체 등록</a>,
#  <a class="at_a" data-clk="plc.contact" href="https://www.navercorp.com/ko/company/proposalGuide.nhn">제휴제안</a>,
#  <a class="at_a" data-clk="plc.service" href="/policy/service.html">이용약관</a>,
#  <a class="at_a" data-clk="plc.privacy" href="/policy/privacy.html"><strong class="at_st">개인정보처리방침</strong></a>,
#  <a class="at_a" data-clk="plc.youth" href="/policy/youthpolicy.html">청소년보호정책</a>,
#  <a class="at_a" data-clk="plc.policy" href="/policy/spamcheck.html">네이버 정책</a>,
#  <a class="at_a" data-clk="plc.helpcenter" href="https://help.naver.com/">고객센터</a>,
#  <a class="at_ca" data-clk="plc.nhn" href="http://www.navercorp.com/" target="_blank">NAVER Corp.</a>]

# %%
bsObj.findAll("a",{"href":"#news_cast"})
# Out:
# [<a href="#news_cast" onclick="document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"><span>뉴스스탠드 바로가기</span></a>]

# %%
bsObj.findAll("a",{"href":"#news_cast"})[0].get_text()
# Out:
# '뉴스스탠드 바로가기'

# %%
bsObj.findAll("a",{"href":"#news_cast"})[0]["onclick"]
# Out:
# "document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;"

# %% [markdown]
# ## QUIZ 02
#
# [다음 메인 페이지](http://www.daum.net/)의 DIV 요소를 분석하고 레인아웃이 어떤 형태로 이루어져있는지 확인하라.
#
# - DIV 에 대한 학습은 다음 링크를 참고하자. [의미없는 요소 div와 span 그리고 class 속성](http://webberstudy.com/html-css/html-1/div-span-and-class-attr/)

# %%
# 다음 메인 페이지에서 DIV 요소 찾기


from bs4 import BeautifulSoup
from urllib.request import urlopen

html = urlopen("http://www.daum.net/")
bsObj = BeautifulSoup(html.read(), "html.parser")

## TODO : write your code!!
divlist = None 
print(divlist)

"""
Output :
[<div class="d_index" id="daumIndex">
 <a class="shortcut_g" href="#mainServiceTitle" rel="bookmark" tabindex="12">
 <span class="ico_vert inner_shortcut">주요 서비스 바로가기</span>
 </a>
 <a class="shortcut_g" href="#todayInfoTitle" rel="bookmark" tabindex="12">
 <span class="ico_vert inner_shortcut">오늘의 정보 바로가기</span>
 </a>
 <a class="shortcut_g" href="#mediaTitle" rel="bookmark" tabindex="12">
 <span class="ico_vert inner_shortcut">미디어 바로가기</span>
 </a>
 <a class="shortcut_g" href="#liveIssueTitle" rel="bookmark" tabindex="12">
 <span class="ico_vert inner_shortcut">실시간 이슈 바로가기</span>
 ....
 """

# %%
# div의 개수 확인

# Output : 
#196

# %% [markdown]
# - div의 id가 "news"인 것을 검색

# %%
import re

# id=re.compile("news")

"""
Output:
[<div class="wrap_tabcont wrap_news" id="news">
 <div class="news_prime news_tab1 #newsbox #news1">
 <div class="group_news">
 <div class="box_issue">
 <a class="link_issue #img @1-1 ?c_id=20170612183126024" href="http://media.daum.net/photo-viewer?cid=318190#20170612183126024">
 <img alt="" class="img_thumb" height="290" src="//img2.daumcdn.net/thumb/C640x580/?fname=http://t1.daumcdn.net/alvolo/_thumbnails_cutter/media_mobile/20170612GMT/20170612_094552GMT_n97vARW5LLKK6h3rLKLv" width="320">
 <span class="frame_g"></span>
 <span class="cover_g"></span>
 <div class="cont_item">"""
